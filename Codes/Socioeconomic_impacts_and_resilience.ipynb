# %%
pip install PyMuPDF

# %%
pip install BERTopic

# %%
import os
import fitz
import nltk
import re
import string
import gensim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pprint


# For tokenization
from nltk.tokenize import word_tokenize
nltk.download("punkt")
nltk.download('wordnet')

# For removing stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')

# For lemmatization
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')

# For TF-IDC
from gensim import corpora
from gensim.models import TfidfModel

# For N-grams
from collections import defaultdict
from nltk.util import ngrams as nltk_ngrams
from nltk.tokenize import word_tokenize

# For BERT topic
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# For coherence score
from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# ### Get text from PDFs

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as pdf:
        for page_num in range(len(pdf)):
            page = pdf.load_page(page_num)
            text += page.get_text()
    return text

# %% [markdown]
# ### Preprocess and vectorize text

# %% [markdown]
# *Preprocess pipeline*

# %%
# Loading WordNet POS tags for lemmatization
def wordnet_pos_tags(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def txt_preprocess_pipeline(text):

    # Removing multiple white spaces and line breaks
    clean_txt = re.sub(r'\n', ' ', text)
    clean_txt = re.sub(r'\s+', ' ', clean_txt)
    clean_txt = clean_txt.strip()

    # Tokenizing text
    tokens = nltk.word_tokenize(clean_txt)

    # Loading NLTK stopword list and adding original stopwords
    stop_words = set(stopwords.words('english')+['ehst event','ehst','th','lll','reasonable','good','good good','na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health','heat','temperature','change','risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])
    # Adding custom stopwords directly to the set
    custom_stopwords = set(['ehst event','ehst','th','lll','reasonable','good','good good','na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health', 'heat', 'temperature', 'change', 'risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])
    stop_words.update(custom_stopwords)

    # Standardize the text and removing non-alphabetic or stop words
    words = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

    # Defining lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Conducting POS tagging
    pos_tags = nltk.pos_tag(words)

    # Lemmatizing word-tokens via assigned POS tags
    lemma_tokens = [lemmatizer.lemmatize(token, wordnet_pos_tags(pos_tag)) for token, pos_tag in pos_tags]

    return lemma_tokens

# %% [markdown]
# *Iteration function*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def iterate_pdf_files(pdf_folder):
    # Creating a dictionary to display all documents and tokens together
    docs = {}

    # Counting to track the number of processed texts
    text_count = 0

    # Iterating over each file in the folder
    for filename in os.listdir(pdf_folder):

        # Checking whether the files are PDFs
        if filename.endswith('.pdf'):

            # Creating a path to the PDF files
            pdf_path = os.path.join(pdf_folder, filename)

            # Extracting the content of files
            text = extract_text_from_pdf(pdf_path)

            # Applying the preprocessing pipeline to the extracted tex
            preprocessed_text = txt_preprocess_pipeline(text)

            # Generating a unique name for the document based on the length of the docs dictionary for ease in readibility
            doc_name = f'doc{len(docs) + 1}'

            # Assigning the preprocessed text content of the current document in the docs dictionary with the document name as the key
            docs[doc_name] = [preprocessed_text]

            # Increasing the text count when finished assigning
            text_count += 1

    return docs

pdf_folder = '/content/drive/MyDrive/Documents/socio'

# Calling the iterate_pdf_files function to get the dictionary of documents
docs = iterate_pdf_files(pdf_folder)

# Printing each document's tokens as a list
for doc_name, tokens in docs.items():
    print(f"{doc_name}: {tokens}")

# %% [markdown]
# *Token dictionary*

# %%
# Iterating over the values in the docs dictionary created in the previous step. Each value in the sublist represents the tokens in a certain document
all_preprocessed_text = [token for sublist in docs.values() for token in sublist]

# Creating a gensim dictionary to assign an integer ID to each token
dictionary = corpora.Dictionary(all_preprocessed_text)
print(dictionary)

# %% [markdown]
# *BoW representation*

# %%
# Creating a Bag-of-Words (BoW) representation of the preprocessed text data using the dictionary created in the previous step
bow_corpus = [dictionary.doc2bow(text) for text in all_preprocessed_text]
pprint.pprint(bow_corpus)

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(bow_corpus))

# %% [markdown]
# ### TF-IDF

# %%
# Creating a TF-IDF model from the Bag-of-Words corpus
tfidf_model = TfidfModel(bow_corpus)

# Applying the TF-IDF model to the Bag-of-Words corpus to get the TF-IDF representation
tfidf_corpus = tfidf_model[bow_corpus]

# Printing the TF-IDF representation for the first few documents
for doc in tfidf_corpus[:5]:
    print(doc)

# %%
# Looking up the word corresponding to word_id = 0
word_id = 5
word = dictionary[word_id]
print("Word corresponding to word_id =", word_id, ":", word)

# %%
# Defining the TF-IDF threshold
threshold = 0.05

# Iterating through the TF-IDF representation of the documents
for doc in tfidf_corpus[:5]:  # Iterating over the first few documents

    # Filtering words with TF-IDF scores above the threshold
    words_above_threshold = [(dictionary[word_id], tfidf_score) for word_id, tfidf_score in doc if tfidf_score > threshold]

    # Printing the words with TF-IDF scores above the threshold
    print("Words with TF-IDF score > 0.05:", words_above_threshold)
# Out:
# Words with TF-IDF score > 0.05: [('bangko', 0.2731654882420059), ('enso', 0.06123114574364336), ('headline', 0.07355058525705206), ('impulse', 0.2890794382468332), ('inflation', 0.14824382653724183), ('inflationary', 0.14657660344693), ('luzon', 0.05330058307161091), ('macroeconomic', 0.15213533650405922), ('ng', 0.16778098016487464), ('output', 0.07358179674052537), ('parentheses', 0.05608650809697571), ('philippine', 0.17213086377326955), ('pilipinas', 0.2731654882420059), ('ppt', 0.35977893573337366), ('price', 0.05810813571762852), ('sentral', 0.2731654882420059), ('shock', 0.19126917416635486), ('transitory', 0.05608650809697571), ('xx', 0.14731988502281676), ('ℎ', 0.05330058307161091), ('𝐏𝐡𝐢𝐥𝐢𝐩𝐩𝐢𝐧𝐞𝐬', 0.073288301723465), ('𝐵𝐴𝑅𝑀𝑀', 0.073288301723465), ('𝐵𝑖𝑐𝑜𝑙', 0.073288301723465), ('𝐶𝐴𝐿𝐴𝐵𝐴𝑅𝑍𝑂𝑁', 0.073288301723465), ('𝐶𝐴𝑅', 0.073288301723465), ('𝐶𝐴𝑅𝐴𝐺𝐴', 0.073288301723465), ('𝐶𝑎𝑔𝑎𝑦𝑎𝑛', 0.073288301723465), ('𝐶𝑒𝑛𝑡𝑟𝑎𝑙', 0.14657660344693), ('𝐷𝑎𝑣𝑎𝑜', 0.073288301723465), ('𝐸𝑎𝑠𝑡', 0.073288301723465), ('𝐼𝑙𝑜𝑐𝑜𝑠', 0.073288301723465), ('𝐿𝑢𝑧𝑜𝑛', 0.14657660344693), ('𝑀𝐼𝑀𝐴𝑅𝑂𝑃𝐴', 0.073288301723465), ('𝑀𝑖𝑛𝑑𝑎𝑛𝑎𝑜', 0.14657660344693), ('𝑁𝐶𝑅', 0.073288301723465), ('𝑁𝑜', 0.08661344749136772), ('𝑁𝑜𝑟𝑡ℎ𝑒𝑟𝑛', 0.073288301723465), ('𝑆𝑂𝐶𝐶𝑆𝐾𝑆𝐴𝑅𝐺𝐸𝑁', 0.073288301723465), ('𝑉𝑎𝑙𝑙𝑒𝑦', 0.073288301723465), ('𝑉𝑖𝑠𝑎𝑦𝑎𝑠', 0.29315320689386), ('𝑊𝑒𝑠𝑡', 0.073288301723465), ('𝑍𝑎𝑚𝑏𝑜𝑎𝑛𝑔𝑎', 0.073288301723465), ('𝑖', 0.05101401851414703), ('𝑜𝑏𝑠', 0.07995087460741637), ('𝑜𝑓', 0.07368691563154571)]
# Words with TF-IDF score > 0.05: [('action', 0.052116472292553444), ('adaptive', 0.06414622237434144), ('agricultural', 0.12686246544897878), ('crop', 0.08998289527511785), ('farm', 0.14416883110651618), ('farmer', 0.06681472403977144), ('flood', 0.09964021178683063), ('household', 0.3183840009066243), ('income', 0.10151705426658907), ('livelihood', 0.06470569585095608), ('livestock', 0.16022573109431032), ('poor', 0.10873937802787154), ('precipitation', 0.06227253158010824), ('producer', 0.056362138798230405), ('production', 0.061833373591178964), ('rural', 0.18352797105981675), ('adoption', 0.06514307950894115), ('agrifood', 0.10148241992802387), ('azzarri', 0.07163464936095804), ('child', 0.059171026479830066), ('cucchi', 0.05586497794035381), ('elaboration', 0.13873704613985507), ('employment', 0.059820259649595725), ('extension', 0.0852146713482527), ('fao', 0.16571107446704872), ('female', 0.10512853111350402), ('gender', 0.10611388906230054), ('geodata', 0.060943612298567804), ('head', 0.08446588578449685), ('holding', 0.07956657745728113), ('incomes', 0.05724304630882334), ('jammu', 0.10157268716427965), ('kashmir', 0.08375429206029592), ('labour', 0.11009288300800804), ('liquidate', 0.05372598702071852), ('maladaptive', 0.08066431901157518), ('measuring', 0.08066431901157518), ('men', 0.10361123730246483), ('ndcs', 0.050132276812978646), ('plot', 0.12829244474868287), ('rulis', 0.10148241992802387), ('sensitivity', 0.05675938232540007), ('stressor', 0.20485983931605675), ('sudan', 0.05551280399744825), ('unjust', 0.2386958148360572), ('usd', 0.08505771114380727), ('wealth', 0.06414622237434144), ('woman', 0.18958681148616016), ('young', 0.11229947791056644), ('youth', 0.19487588250193025)]
# Words with TF-IDF score > 0.05: [('active', 0.07642909349337458), ('cool', 0.06284460655186505), ('evidence', 0.0667815447835343), ('horizon', 0.05011975321833553), ('intervention', 0.09117870201692466), ('pham', 0.060597782292308784), ('vulnerable', 0.06498939318980562), ('worker', 0.11993139468705608), ('deprive', 0.12795729600840808), ('disease', 0.0997973954679797), ('elderly', 0.09758879878890356), ('illness', 0.05006502103659244), ('imbalance', 0.08004348494439116), ('julian', 0.051867711033242586), ('morbidity', 0.10847182909406783), ('n', 0.10887392839773198), ('nancy', 0.05568126112419604), ('outdoor', 0.08761378681403677), ('socially', 0.06205783352457614), ('acclimatisation', 0.12006522741658675), ('alzheimer', 0.06752722968524305), ('ammes', 0.07937319824629005), ('areal', 0.05568126112419604), ('asl', 0.06752722968524305), ('asthma', 0.0922347201997902), ('athlete', 0.1753411702525961), ('athletes', 0.1587463964925801), ('aug', 0.05568126112419604), ('belmont', 0.060597782292308784), ('birth', 0.14087886955574283), ('bourhoods', 0.07937319824629005), ('campaign', 0.08057342176422005), ('cardiorespiratory', 0.060597782292308784), ('cardiovascular', 0.05732182012003093), ('chersich', 0.060597782292308784), ('chronic', 0.11430863745071093), ('chronically', 0.051867711033242586), ('clinical', 0.08992919333184156), ('clothe', 0.07107581136628205), ('congenital', 0.05568126112419604), ('cting', 0.07937319824629005), ('cvds', 0.1587463964925801), ('dance', 0.060597782292308784), ('ded', 0.060597782292308784), ('dehydration', 0.060430066323165034), ('disorder', 0.05635154782229714), ('disseminate', 0.0581047649448615), ('donato', 0.05568126112419604), ('dures', 0.07937319824629005), ('electrolyte', 0.0922347201997902), ('elena', 0.05568126112419604), ('enbelmanagement', 0.06752722968524305), ('exertional', 0.060597782292308784), ('firefighter', 0.14625544119378533), ('flyer', 0.06752722968524305), ('funders', 0.05568126112419604), ('gastroenteritis', 0.060597782292308784), ('glycaemic', 0.07937319824629005), ('havioural', 0.07937319824629005), ('healthcare', 0.10071677720527507), ('hing', 0.07937319824629005), ('homeless', 0.11270309564459428), ('hotlines', 0.06752722968524305), ('hydration', 0.09927688523778397), ('infarction', 0.05568126112419604), ('injury', 0.06882565564553494), ('insufficiency', 0.05568126112419604), ('isolate', 0.07964073447532098), ('jf', 0.060597782292308784), ('lazio', 0.06752722968524305), ('libraries', 0.06752722968524305), ('lightweight', 0.06752722968524305), ('madureira', 0.07937319824629005), ('manuela', 0.07937319824629005), ('mazzalai', 0.07937319824629005), ('mf', 0.05568126112419604), ('movie', 0.060597782292308784), ('myocardial', 0.060597782292308784), ('nakstad', 0.06752722968524305), ('natukunda', 0.06752722968524305), ('neurologic', 0.06752722968524305), ('ney', 0.060597782292308784), ('odic', 0.07937319824629005), ('outreach', 0.05011975321833553), ('pacheco', 0.07937319824629005), ('paigns', 0.06752722968524305), ('parkinson', 0.05568126112419604), ('passive', 0.06854278307769618), ('patient', 0.10936777658365536), ('pharmacological', 0.06752722968524305), ('physiopathological', 0.07937319824629005), ('piil', 0.051867711033242586), ('plemented', 0.07937319824629005), ('poster', 0.05568126112419604), ('pregnant', 0.0751796298275033), ('preterm', 0.10373542206648517), ('preventive', 0.12893612765445184), ('psychiatric', 0.08767058512629805), ('ral', 0.051867711033242586), ('renal', 0.16008696988878232), ('renovate', 0.07937319824629005), ('reschedule', 0.10373542206648517), ('retrofit', 0.0619064838687813), ('riodic', 0.07937319824629005), ('rom', 0.051867711033242586), ('roos', 0.05568126112419604), ('sario', 0.05568126112419604), ('sep', 0.060597782292308784), ('sousa', 0.051867711033242586), ('subsidy', 0.06397864800420404), ('summarise', 0.059952795554561046), ('suppression', 0.051867711033242586), ('ted', 0.051867711033242586), ('theatres', 0.07937319824629005), ('therapy', 0. ...
# Words with TF-IDF score > 0.05: [('farmer', 0.051714250314898694), ('february', 0.07078359153938804), ('occupational', 0.14905039591011474), ('worker', 0.16452697423514664), ('article', 0.12155258318529089), ('british', 0.05552870887425761), ('cod', 0.06840243745824806), ('medium', 0.07331594758266466), ('n', 0.17390580060265934), ('healthcare', 0.07660774881365272), ('indoor', 0.07331236830843485), ('occupation', 0.10100311054699355), ('staff', 0.06374988548559551), ('accessed', 0.13124967552097255), ('bc', 0.05562280889293901), ('canada', 0.15756485245330992), ('canadian', 0.10950976315462631), ('cancellation', 0.059177855298257996), ('cascade', 0.06691271261997733), ('cherry', 0.07704439905675402), ('classiﬁcations', 0.05294073371132455), ('columbia', 0.05095895371709528), ('crew', 0.10836228400925396), ('crossref', 0.5070144016380929), ('dome', 0.4263530195593053), ('environ', 0.06714694529410659), ('identiﬁed', 0.09132467339018689), ('kenny', 0.06362231644305144), ('modiﬁcations', 0.06913832749610356), ('news', 0.06396505694708587), ('occup', 0.06081983371424047), ('ohs', 0.05294073371132455), ('ottawa', 0.08335560308404152), ('paramedic', 0.08876678294738699), ('picker', 0.06913832749610356), ('pubmed', 0.11646961416491403), ('rooﬁng', 0.06913832749610356), ('systematize', 0.05136293270450268), ('tetzlaff', 0.05136293270450268), ('translational', 0.13827665499220712), ('unairconditioned', 0.07704439905675402), ('workplace', 0.10173435526842571), ('ﬁndings', 0.05663439770166451)]
# Words with TF-IDF score > 0.05: [('occupational', 0.14836043419714431), ('worker', 0.14592953822042465), ('illness', 0.08528502138994982), ('improvement', 0.10790555774450793), ('labour', 0.0554136908351507), ('mesoamerica', 0.05890391805601058), ('n', 0.05563953706573987), ('nicaragua', 0.10478093385983762), ('sanitation', 0.06210212887284381), ('chronic', 0.05563516282392912), ('injury', 0.10747319405196093), ('nb', 0.05237349299148217), ('preterm', 0.05890391805601058), ('environ', 0.05569676561416812), ('ioannou', 0.05237349299148217), ('kidney', 0.2543022503799187), ('workplace', 0.2169930468564317), ('ﬁelds', 0.055365328137724226), ('antonio', 0.10474698598296434), ('chichigalpa', 0.09014071128657367), ('ckdnt', 0.4957739120761551), ('glaser', 0.11503163503917677), ('hansson', 0.07668775669278449), ('hr', 0.2768266406886212), ('ingenio', 0.09014071128657367), ('lmics', 0.0688182827315134), ('mill', 0.07124378126467973), ('nicaraguan', 0.0688182827315134), ('pm', 0.1363528903866642), ('prep', 0.4056332007895815), ('prince', 0.07668775669278449), ('sugar', 0.10089715945341883), ('sugarcane', 0.1493455425156184), ('wesseling', 0.06323480209899532), ('widow', 0.08835587708401588)]

# %% [markdown]
# ### N-grams

# %%
# Taking a list of tokens as input and generating n-grams
def generate_ngrams(tokens, n=3):
    return list(nltk_ngrams(tokens, n))

# Creating n-gram model from a corpus
def create_ngram_model(corpus, n=3):
    ngram_model = defaultdict(int)
    for text in corpus:
        tokens = word_tokenize(text)
        ngrams = generate_ngrams(tokens, n)
        for ngram in ngrams:
            ngram_model[ngram] += 1
    return ngram_model

max_texts_to_process = None
docs = iterate_pdf_files(pdf_folder)

# Concatenating preprocessed tokens for each document into a single list of tokens
corpus_tokens = [tokens for sublist in docs.values() for tokens in sublist]

# Concatenating tokens into a single string for each document
corpus_strings = [' '.join(tokens) for tokens in corpus_tokens]

# Creating an n-gram model
ngram_model = create_ngram_model(corpus_strings, n=3)

# Printing all n-grams
print("All N-grams:")
for ngram, frequency in ngram_model.items():
    print(ngram, ":", frequency)

# %%
# Filtering n-grams with frequency greater than 1
filtered_ngram_model = {ngram: frequency for ngram, frequency in ngram_model.items() if frequency > 1}

# Printing filtered n-grams
print("Filtered N-grams:")
for ngram, frequency in filtered_ngram_model.items():
    print(ngram, ":", frequency)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('together', 'beat', 'drought') : 3
# ('beat', 'drought', 'trap') : 3
# ('drought', 'trap', 'munich') : 3
# ('trap', 'munich', 'foundation') : 3
# ('munich', 'foundation', 'munich') : 3
# ('globalagrisk', 'skees', 'jerry') : 3
# ('skees', 'jerry', 'challenge') : 3
# ('jerry', 'challenge', 'rural') : 3
# ('challenge', 'rural', 'financial') : 3
# ('rural', 'financial', 'market') : 9
# ('financial', 'market', 'blend') : 3
# ('market', 'blend', 'innovation') : 3
# ('blend', 'innovation', 'rural') : 3
# ('innovation', 'rural', 'finance') : 3
# ('rural', 'finance', 'washington') : 3
# ('country', 'time', 'period') : 18
# ('development', 'bank', 'aria') : 6
# ('bank', 'aria', 'diego') : 6
# ('aria', 'diego', 'covarrubias') : 6
# ('diego', 'covarrubias', 'katia') : 6
# ('covarrubias', 'katia', 'agricultural') : 6
# ('katia', 'agricultural', 'insurance') : 6
# ('agricultural', 'insurance', 'mesoamerica') : 6
# ('insurance', 'mesoamerica', 'opportunity') : 6
# ('mesoamerica', 'opportunity', 'deepen') : 6
# ('opportunity', 'deepen', 'rural') : 6
# ('deepen', 'rural', 'financial') : 6
# ('financial', 'market', 'washington') : 6
# ('latin', 'america', 'development') : 2
# ('america', 'development', 'bank') : 2
# ('insurance', 'product', 'still') : 2
# ('must', 'observable', 'easily') : 2
# ('observable', 'easily', 'measurable') : 2
# ('role', 'insurance', 'scheme') : 2
# ('less', 'adverse', 'selection') : 2
# ('usaid', 'globalagrisk', 'index') : 3
# ('globalagrisk', 'index', 'insurance') : 3
# ('index', 'insurance', 'weather') : 3
# ('insurance', 'weather', 'country') : 3
# ('weather', 'country', 'washington') : 3
# ('country', 'washington', 'bank') : 2
# ('manage', 'agricultural', 'production') : 4
# ('agricultural', 'production', 'washington') : 4
# ('washington', 'hazell', 'peter') : 2
# ('weather', 'recent', 'think') : 5
# ('recent', 'think', 'bank') : 3
# ('think', 'bank', 'agriculture') : 2
# ('bank', 'agriculture', 'rural') : 3
# ('development', 'department', 'manage') : 3
# ('department', 'manage', 'agricultural') : 3
# ('reduce', 'administration', 'cost') : 2
# ('administration', 'cost', 'insurance') : 3
# ('market', 'insurance', 'company') : 2
# ('seed', 'company', 'buy') : 2
# ('weather', 'event', 'trigger') : 2
# ('insurance', 'company', 'face') : 2
# ('agricultural', 'loss', 'threaten') : 4
# ('loss', 'threaten', 'livelihood') : 4
# ('trade', 'development', 'issue') : 2
# ('development', 'issue', 'agricultural') : 2
# ('issue', 'agricultural', 'insurance') : 2
# ('stoppa', 'andrea', 'index') : 3
# ('andrea', 'index', 'insurance') : 3
# ('index', 'insurance', 'develop') : 3
# ('develop', 'country', 'eschborn') : 4
# ('insurance', 'company', 'therefore') : 2
# ('basis', 'design', 'insurance') : 2
# ('design', 'insurance', 'scheme') : 2
# ('insurance', 'product', 'depend') : 2
# ('accord', 'interview', 'insurance') : 3
# ('interview', 'insurance', 'expert') : 3
# ('livestock', 'insurance', 'mongolia') : 5
# ('poor', 'farmer', 'develop') : 2
# ('carrier', 'private', 'insurance') : 2
# ('private', 'insurance', 'company') : 10
# ('layer', 'catastrophic', 'loss') : 2
# ('farmer', 'perspective', 'farmer') : 3
# ('reach', 'poor', 'farmer') : 2
# ('protection', 'small', 'farmer') : 2
# ('swiss', 'sigma', 'insurance') : 6
# ('sigma', 'insurance', 'emerge') : 6
# ('insurance', 'emerge', 'market') : 6
# ('emerge', 'market', 'sound') : 2
# ('market', 'sound', 'development') : 2
# ('sound', 'development', 'greenfield') : 2
# ('development', 'greenfield', 'agricultural') : 2
# ('greenfield', 'agricultural', 'insurance') : 2
# ('agricultural', 'insurance', 'zurich') : 2
# ('risk', 'normally', 'exclude') : 4
# ('exist', 'pilot', 'scheme') : 2
# ('insurance', 'key', 'fact') : 2
# ('key', 'fact', 'insurance') : 3
# ('fact', 'insurance', 'type') : 3
# ('cattle', 'yaks', 'sheep') : 2
# ('yaks', 'sheep', 'goat') : 2
# ('harsh', 'winter', 'lead') : 2
# ('start', 'scheme', 'developer') : 3
# ('carrier', 'distribute', 'insured') : 2
# ('distribute', 'insured', 'private') : 2
# ('insured', 'private', 'insurance') : 2
# ('insurance', 'company', 'government') : 2
# ('eligibility', 'farmer', 'regardless') : 2
# ('size', 'voluntary', 'cover') : 2
# ('voluntary', 'cover', 'period') : 2
# ('cover', 'period', 'june') : 2
# ('traditional', 'livestock', 'insurance') : 2
# ('livestock', 'insurance', 'product') : 2
# ('livestock', 'insurance', 'project') : 3
# ('globalagrisk', 'go', 'anne') : 2
# ('go', 'anne', 'livestock') : 2
# ('anne', 'livestock', 'insurance') : 2
# ('insurance', 'mongolia', 'potential') : 2
# ('mongolia', 'potential', 'financial') : 2
# ('potential', 'financial', 'sector') : 2
# ('financial', 'sector', 'development') : 2
# ('information', 'document', 'pid') : 2
# ('document', 'pid', 'mongolia') : 2
# ('pid', 'mongolia', 'livestock') : 2
# ('insurance', 'project', 'washington') : 2
# ('project', 'washington', 'bank') : 2
# ('washington', 'bank', 'skees') : 2
# ('bank', 'skees', 'jerry') : 2
# ('skees', 'jerry', 'ayurzana') : 2
# ('jerry', 'ayurzana', 'examine') : 2
# ('ayurzana', 'examine', 'feasibility') : 2
# ('examine', 'feasibility', 'livestock') : 2
# ('feasibility', 'livestock', 'insurance') : 2
# ('insurance', 'mongolia', 'washington') : 2
# ('livestock', 'insurance', 'scheme') : 3
# ('moral', 'hazard', 'reduce') : 3
# ('private', 'insurance', 'sector') : 2
# ('estimate', 'value', 'herd') : 4
# ('insurance', 'product', 'bip') : 2
# ('loss', 'exceed', 'estimate') : 2
# ('exceed', 'estimate', 'value') : 2
# ('insurance', 'company', 'cover') : 2
# ('insurance', 'disaster', 'response') : 2
# ('disaster', 'response', 'product') : 2
# ('response', 'product', 'drp') : 2
# ('cgap', 'work', 'group') : 3
# ('work', 'group', 'microinsurance') : 3
# ('group', 'microinsurance', 'newsletter') : 3
# ('microinsurance', 'newsletter', 'improve') : 3
# ('newsletter', 'improve', 'poor') : 3
# ('improve', 'poor', 'july') : 3
# ('poor', 'july', 'insurance') : 2
# ('small', 'administration', 'fee') : 2
# ('unlimited', 'stop', 'loss') : 2
# ('stop', 'loss', 'reinsurance') : 2
# ('loss', 'reinsurance', 'treaty') : 3
# ('insurance', 'scheme', 'mongolia') : 2
# ('payment', 'rate', 'bip') : 2
# ('rate', 'bip', 'payment') : 2
# ('bip', 'payment', 'x') : 2
# ('bank', 'quarterly', 'progress') : 2
# ('quarterly', 'progress', 'period') : 2
# ('progress', 'period', 'july') : 2
# ('period', 'july', 'september') : 2
# ('july', 'september', 'mongolia') : 2
# ('research', 'issue', 'although') : 3
# ('issue', 'although', 'many') : 3
# ('although', 'many', 'publication') : 3
# ('many', 'publication', 'provide') : 3
# ('publication', 'provide', 'insight') : 3
# ('research', 'need', 'do') : 3
# ('need', 'do', 'order') : 3
# ('do', 'order', 'success') : 3
# ('order', 'success', 'challenge') : 3
# ('success', 'challenge', 'reach') : 2
# ('challenge', 'reach', 'small') : 2
# ('reach', 'small', 'poor') : 2
# ('poor', 'farmer', 'protect') : 2
# ('farmer', 'protect', 'agricultural') : 2
# ('protect', 'agricultural', 'loss') : 2
# ('threaten', 'livelihood', 'furthermore') : 2
# ('livelihood', 'furthermore', 'sustainability') : 2
# ('furthermore', 'sustainability', 'financial') : 2
# ('financial', 'viability', 'relatively') : 2
# ('viability', 'relatively', 'new') : 2
# ('relatively', 'new', 'insurance') : 2
# ('insurance', 'scheme', 'observe') : 2
# ('insurance', 'type', 'rainfall') : 2
# ('type', 'rainfall', 'insurance') : 2
# ('rainfall', 'insurance', 'crop') : 2
# ('insufficient', 'excess', 'rainfall') : 2
# ('rainfall', 'monsoon', 'season') : 2
# ('icici', 'lombard', 'basix') : 4
# ('ismea', 'hartell', 'jason') : 7
# ('hartell', 'jason', 'ibarra') : 7
# ('jason', 'ibarra', 'hector') : 7
# ('ibarra', 'hector', 'skees') : 7
# ('hector', 'skees', 'jerry') : 7
# ('skees', 'jerry', 'syroka') : 7
# ('jerry', 'syroka', 'joanna') : 7
# ('syroka', 'joanna', 'agriculture') : 7
# ('joanna', 'agriculture', 'natural') : 7
# ('agriculture', 'natural', 'hazard') : 7
# ('rainfall', 'insurance', 'product') : 2
# ('rainfall', 'insurance', 'scheme') : 4
# ('weather', 'insurance', 'contract') : 2
# ('upper', 'low', 'threshold') : 3
# ('threshold', 'several', 'consecutive') : 2
# ('gine', 'xavier', 'townsend') : 2
# ('xavier', 'townsend', 'robert') : 2
# ('townsend', 'robert', 'vickery') : 2
# ('robert', 'vickery', 'james') : 2
# ('vickery', 'james', 'pattern') : 2
# ('james', 'pattern', 'rainfall') : 2
# ('pattern', 'rainfall', 'insurance') : 2
# ('rainfall', 'insurance', 'participation') : 2
# ('insurance', 'participation', 'rural') : 2
# ('insurance', 'scheme', 'example') : 2
# ('upper', 'threshold', 'lower') : 2
# ('threshold', 'lower', 'threshold') : 2
# ('lower', 'threshold', 'indemnification') : 2
# ('threshold', 'indemnification', 'threshold') : 3
# ('threshold', 'low', 'threshold') : 2
# ('low', 'threshold', 'indemnification') : 2
# ('phase', 'phase', 'phase') : 2
# ('mm', 'acre', 'mm') : 2
# ('acre', 'mm', 'acre') : 2
# ('deficit', 'rainfall', 'rj') : 2
# ('deficit', 'excess', 'rainfall') : 2
# ('icici', 'lombard', 'emerge') : 3
# ('lombard', 'emerge', 'trend') : 3
# ('emerge', 'trend', 'farm') : 3
# ('trend', 'farm', 'insurance') : 3
# ('farm', 'insurance', 'weather') : 3
# ('insurance', 'weather', 'insurance') : 3
# ('weather', 'insurance', 'presentation') : 3
# ('insurance', 'presentation', 'agriculture') : 3
# ('presentation', 'agriculture', 'summit') : 3
# ('agriculture', 'summit', 'delhi') : 3
# ('offer', 'weather', 'insurance') : 2
# ('social', 'affair', 'sustainable') : 4
# ('affair', 'sustainable', 'development') : 4
# ('sustainable', 'development', 'innovation') : 4
# ('development', 'innovation', 'brief') : 4
# ('innovation', 'brief', 'develop') : 4
# ('brief', 'develop', 'insurance') : 3
# ('develop', 'insurance', 'agriculture') : 3
# ('insurance', 'agriculture', 'develop') : 4
# ('agriculture', 'develop', 'country') : 4
# ('develop', 'country', 'march') : 4
# ('weather', 'insurance', 'policy') : 2
# ('crop', 'maize', 'bean') : 2
# ('maize', 'bean', 'sorghum') : 2
# ('bean', 'sorghum', 'barley') : 2
# ('mexican', 'agricultural', 'insurance') : 3
# ('agricultural', 'insurance', 'market') : 3
# ('catastrophic', 'farming', 'insurance') : 2
# ('farming', 'insurance', 'climatic') : 2
# ('agroasemex', 'mexican', 'experience') : 3
# ('mexican', 'experience', 'development') : 3
# ('experience', 'development', 'operation') : 3
# ('development', 'operation', 'parametric') : 3
# ('operation', 'parametric', 'insurance') : 3
# ('parametric', 'insurance', 'apply') : 3
# ('insurance', 'apply', 'agriculture') : 3
# ('apply', 'agriculture', 'august') : 3
# ('development', 'bank', 'mark') : 2
# ('bank', 'mark', 'wenner') : 2
# ('mark', 'wenner', 'agricultural') : 2
# ('wenner', 'agricultural', 'insurance') : 2
# ('case', 'natural', 'catastrophe') : 2
# ('private', 'reinsurance', 'company') : 2
# ('insurance', 'small', 'farmer') : 2
# ('catastrophic', 'weather', 'event') : 2
# ('sergio', 'advance', 'institute') : 3
# ('global', 'environmental', 'stakeholder') : 3
# ('environmental', 'stakeholder', 'view') : 3
# ('emerge', 'market', 'zurich') : 4
# ('max', 'hectare', 'farmer') : 2
# ('max', 'hectares', 'farmer') : 2
# ('hectares', 'farmer', 'state') : 2
# ('insured', 'state', 'government') : 2
# ('state', 'government', 'case') : 2
# ('guarantee', 'measurement', 'manipulate') : 2
# ('agroasemex', 'drought', 'monitoring') : 2
# ('drought', 'monitoring', 'approach') : 2
# ('monitoring', 'approach', 'parametric') : 2
# ('insurance', 'cover', 'fapracc') : 2
# ('time', 'reduce', 'individual') : 2
# ('impact', 'wave', 'drought') : 3
# ('cyclical', 'reoccurrence', 'el') : 3
# ('reoccurrence', 'el', 'niño') : 3
# ('exacerbate', 'climatic', 'challenge') : 3
# ('climatic', 'challenge', 'face') : 3
# ('challenge', 'face', 'country') : 3
# ('region', 'intensify', 'wave') : 3
# ('intensify', 'wave', 'drought') : 3
# ('wave', 'drought', 'episode') : 3
# ('security', 'economic', 'productivity') : 2
# ('gender', 'norm', 'power') : 2
# ('norm', 'power', 'relation') : 2
# ('power', 'relation', 'structural') : 2
# ('relation', 'structural', 'inequality') : 2
# ('people', 'marginalise', 'group') : 2
# ('gendered', 'effect', 'recur') : 2
# ('effect', 'recur', 'cycle') : 2
# ('economic', 'productivity', 'care') : 2
# ('productivity', 'care', 'work') : 2
# ('recommendation', 'humanitarian', 'disaster') : 2
# ('humanitarian', 'disaster', 'reduction') : 2
# ('disaster', 'reduction', 'practitioner') : 2
# ('reduction', 'practitioner', 'improve') : 2
# ('practitioner', 'improve', 'preparedness') : 2
# ('improve', 'preparedness', 'effort') : 2
# ('el', 'niño', 'exacerbate') : 2
# ('niño', 'exacerbate', 'climatic') : 2
# ('face', 'country', 'region') : 2
# ('country', 'region', 'intensify') : 2
# ('indonesia', 'malaysia', 'philippine') : 4
# ('challenge', 'include', 'limited') : 2
# ('include', 'limited', 'increased') : 2
# ('limited', 'increased', 'vulnerability') : 2
# ('increased', 'vulnerability', 'food') : 2
# ('food', 'security', 'alert') : 2
# ('acute', 'food', 'insecurity') : 2
# ('woman', 'asia', 'pacific') : 2
# ('woman', 'time', 'poverty') : 2
# ('effect', 'wave', 'drought') : 2
# ('work', 'asia', 'pacific') : 2
# ('travel', 'longer', 'distance') : 2
# ('un', 'woman', 'unfpa') : 2
# ('gender', 'food', 'security') : 2
# ('ocha', 'asia', 'pacific') : 2
# ('gender', 'time', 'poverty') : 2
# ('time', 'poverty', 'africa') : 2
# ('drought', 'heatwaves', 'state') : 2
# ('learn', 'outcome', 'evidence') : 2
# ('outcome', 'evidence', 'ethiopia') : 2
# ('evidence', 'ethiopia', 'bhavya') : 2
# ('ethiopia', 'bhavya', 'srivastava') : 2
# ('conclusion', 'express', 'entirely') : 2
# ('express', 'entirely', 'author') : 2
# ('entirely', 'author', 'necessarily') : 2
# ('represent', 'view', 'bank') : 2
# ('stake', 'university', 'entrance') : 2
# ('university', 'entrance', 'exam') : 4
# ('temperature', 'school', 'year') : 2
# ('school', 'year', 'lead') : 2
# ('year', 'lead', 'exam') : 3
# ('reduce', 'test', 'score') : 3
# ('score', 'female', 'student') : 2
# ('female', 'student', 'less') : 3
# ('student', 'less', 'impacted') : 2
# ('less', 'impacted', 'high') : 2
# ('impacted', 'high', 'temperature') : 2
# ('compare', 'male', 'counterpart') : 5
# ('score', 'student', 'school') : 2
# ('student', 'school', 'locate') : 5
# ('school', 'locate', 'hot') : 2
# ('learn', 'outcome', 'ethiopia') : 3
# ('group', 'bank', 'email') : 2
# ('reduce', 'amount', 'student') : 2
# ('amount', 'student', 'learn') : 2
# ('examine', 'relationship', 'temperature') : 2
# ('relationship', 'temperature', 'learn') : 2
# ('temperature', 'learn', 'outcome') : 2
# ('garg', 'jagnani', 'taraz') : 3
# ('mitigate', 'adverse', 'effect') : 3
# ('hot', 'day', 'grow') : 2
# ('day', 'grow', 'season') : 2
# ('low', 'test', 'score') : 2
# ('effect', 'temperatures', 'test') : 2
# ('temperatures', 'test', 'score') : 2
# ('zhang', 'chen', 'zhang') : 2
# ('impact', 'cognitive', 'mance') : 2
# ('find', 'negative', 'impact') : 3
# ('exam', 'ethiopian', 'high') : 2
# ('ethiopian', 'high', 'education') : 3
# ('high', 'education', 'entrance') : 3
# ('education', 'entrance', 'certificate') : 3
# ('entrance', 'certificate', 'examination') : 3
# ('certificate', 'examination', 'eheece') : 3
# ('examination', 'eheece', 'eheece') : 2
# ('student', 'fail', 'exam') : 2
# ('driven', 'hot', 'day') : 2
# ('day', 'school', 'year') : 3
# ('school', 'year', 'compare') : 3
# ('year', 'compare', 'hot') : 2
# ('hot', 'day', 'fall') : 3
# ('agricultural', 'grow', 'season') : 4
# ('effect', 'test', 'performance') : 2
# ('find', 'student', 'school') : 2
# ('school', 'locate', 'hotter') : 2
# ('locate', 'hotter', 'region') : 2
# ('hotter', 'region', 'well') : 2
# ('region', 'well', 'able') : 2
# ('well', 'able', 'cope') : 2
# ('able', 'cope', 'high') : 2
# ('locate', 'relatively', 'cool') : 2
# ('sexton', 'wang', 'mullins') : 2
# ('negligible', 'adoption', 'cool') : 2
# ('suggestive', 'evidence', 'acclimatization') : 2
# ('negative', 'impact', 'high') : 2
# ('impact', 'social', 'science') : 2
# ('ethiopian', 'education', 'system') : 3
# ('primary', 'secondary', 'tiary') : 2
# ('year', 'grade', 'grade') : 2
# ('upper', 'secondary', 'education') : 4
# ('natural', 'science', 'social') : 4
# ('science', 'social', 'science') : 6
# ('social', 'science', 'stream') : 7
# ('science', 'stream', 'completion') : 2
# ('stream', 'completion', 'upper') : 2
# ('completion', 'upper', 'secondary') : 2
# ('secondary', 'education', 'student') : 2
# ('high', 'education', 'institution') : 2
# ('condition', 'ac', 'system') : 2
# ('zone', 'cover', 'area') : 2
# ('cover', 'area', 'meter') : 2
# ('area', 'meter', 'sea') : 2
# ('level', 'temperature', 'range') : 2
# ('distribution', 'daily', 'maximum') : 5
# ('bin', 'school', 'year') : 3
# ('stream', 'specific', 'subject') : 3
# ('take', 'english', 'mathematics') : 2
# ('english', 'mathematics', 'civics') : 2
# ('mathematics', 'civics', 'aptitude') : 2
# ('take', 'stream', 'specific') : 2
# ('within', 'school', 'sample') : 2
# ('natural', 'science', 'student') : 2
# ('physic', 'chemistry', 'biology') : 4
# ('chemistry', 'biology', 'social') : 2
# ('biology', 'social', 'science') : 2
# ('student', 'natural', 'science') : 2
# ('natural', 'science', 'stream') : 2
# ('civics', 'aptitude', 'exam') : 2
# ('male', 'female', 'student') : 2
# ('refer', 'appendix', 'provide') : 2
# ('appendix', 'provide', 'map') : 2
# ('score', 'geographic', 'location') : 2
# ('potential', 'spatial', 'correlation') : 2
# ('variable', 'daily', 'maximum') : 3
# ('buffer', 'around', 'school') : 2
# ('standard', 'measurement', 'integrate') : 2
# ('measurement', 'integrate', 'survey') : 2
# ('integrate', 'survey', 'agriculture') : 2
# ('ethiopia', 'socioeconomic', 'survey') : 3
# ('household', 'survey', 'conduct') : 2
# ('total', 'test', 'score') : 2
# ('test', 'score', 'student') : 17
# ('µs', 'γj', 'αt') : 2
# ('stream', 'school', 'year') : 3
# ('jt', 'denote', 'number') : 2
# ('denote', 'number', 'day') : 2
# ('number', 'day', 'school') : 4
# ('school', 'year', 'daily') : 2
# ('daily', 'total', 'precipitation') : 2
# ('grow', 'season', 'season') : 4
# ('fix', 'effect', 'respectively') : 2
# ('deschenes', 'greenstone', 'guryan') : 2
# ('number', 'day', 'bin') : 7
# ('first', 'half', 'june') : 2
# ('paper', 'examine', 'student') : 2
# ('average', 'effect', 'find') : 2
# ('hot', 'day', 'test') : 2
# ('day', 'test', 'score') : 2
# ('standard', 'deviation', 'however') : 2
# ('standard', 'deviation', 'respectively') : 3
# ('duflo', 'dupas', 'kremer') : 2
# ('find', 'standard', 'deviation') : 2
# ('english', 'math', 'civics') : 2
# ('math', 'civics', 'aptitude') : 2
# ('significant', 'significance', 'level') : 3
# ('distribution', 'raw', 'score') : 3
# ('chemistry', 'biology', 'general') : 2
# ('biology', 'general', 'science') : 2
# ('table', 'find', 'negative') : 2
# ('deviation', 'respectively', 'size') : 2
# ('agricultural', 'season', 'drive') : 2
# ('hot', 'day', 'agricultural') : 3
# ('day', 'agricultural', 'season') : 2
# ('number', 'negative', 'food') : 4
# ('food', 'shock', 'experience') : 2
# ('shock', 'experience', 'household') : 2
# ('main', 'grow', 'season') : 2
# ('face', 'food', 'insecurity') : 2
# ('number', 'food', 'shock') : 2
# ('heterogeneity', 'effect', 'gender') : 2
# ('compare', 'male', 'peer') : 3
# ('gendered', 'difference', 'effort') : 2
# ('extend', 'absence', 'school') : 3
# ('travel', 'time', 'school') : 5
# ('absence', 'school', 'compare') : 2
# ('school', 'compare', 'male') : 3
# ('student', 'additional', 'minute') : 2
# ('additional', 'minute', 'travel') : 2
# ('evidence', 'female', 'student') : 3
# ('female', 'dent', 'put') : 2
# ('wagner', 'schober', 'spiel') : 2
# ('eriard', 'racinais', 'sawka') : 2
# ('adapt', 'high', 'temperature') : 2
# ('divide', 'school', 'quartile') : 3
# ('mean', 'number', 'day') : 8
# ('first', 'three', 'quartile') : 3
# ('experience', 'relatively', 'low') : 2
# ('exposure', 'test', 'performance') : 3
# ('score', 'relative', 'score') : 2
# ('subject', 'civics', 'aptitude') : 2
# ('journal', 'economics', 'retrieve') : 3
# ('socioeconomic', 'survey', 'retrieve') : 2
# ('survey', 'retrieve', 'csa') : 2
# ('retrieve', 'csa', 'ethiopia') : 2
# ('csa', 'ethiopia', 'socioeconomic') : 2
# ('school', 'journal', 'economics') : 2
# ('jagnani', 'taraz', 'human') : 2
# ('taraz', 'human', 'capital') : 2
# ('resource', 'economist', 'retrieve') : 4
# ('retrieve', 'graff', 'zivin') : 2
# ('africa', 'book', 'section') : 2
# ('book', 'section', 'ortner') : 2
# ('section', 'ortner', 'eds') : 2
# ('racinais', 'sawka', 'adaptation') : 2
# ('sawka', 'adaptation', 'mechanisms') : 2
# ('adaptation', 'mechanisms', 'human') : 2
# ('mechanisms', 'human', 'acclimation') : 2
# ('human', 'acclimation', 'application') : 2
# ('acclimation', 'application', 'competitive') : 2
# ('application', 'competitive', 'athlete') : 2
# ('competitive', 'athlete', 'sport') : 2
# ('retrieve', 'randell', 'gray') : 2
# ('table', 'table', 'exposure') : 2
# ('table', 'exposure', 'standardize') : 10
# ('exposure', 'standardize', 'score') : 10
# ('standardize', 'score', 'standardize') : 10
# ('score', 'standardize', 'score') : 10
# ('standardize', 'score', 'female') : 2
# ('score', 'female', 'control') : 2
# ('female', 'control', 'x') : 13
# ('control', 'x', 'x') : 15
# ('x', 'x', 'x') : 82
# ('x', 'x', 'avg') : 2
# ('x', 'x', 'age') : 3
# ('x', 'age', 'control') : 2
# ('age', 'control', 'x') : 2
# ('control', 'x', 'fix') : 3
# ('x', 'fix', 'effect') : 14
# ('effect', 'year', 'x') : 18
# ('year', 'x', 'x') : 17
# ('x', 'x', 'school') : 14
# ('school', 'x', 'x') : 14
# ('x', 'x', 'stream') : 14
# ('x', 'stream', 'x') : 11
# ('stream', 'x', 'x') : 11
# ('x', 'x', 'observation') : 13
# ('x', 'observation', 'note') : 14
# ('observation', 'note', 'estimate') : 18
# ('note', 'estimate', 'linear') : 18
# ('estimate', 'linear', 'regression') : 18
# ('linear', 'regression', 'use') : 18
# ('regression', 'use', 'panel') : 18
# ('use', 'panel', 'fix') : 18
# ('panel', 'fix', 'effect') : 18
# ('fix', 'effect', 'dependent') : 15
# ('effect', 'dependent', 'variable') : 14
# ('dependent', 'variable', 'standardized') : 6
# ('variable', 'standardized', 'test') : 6
# ('standardized', 'test', 'score') : 9
# ('score', 'student', 'take') : 12
# ('student', 'take', 'grade') : 12
# ('take', 'grade', 'exam') : 12
# ('grade', 'exam', 'construct') : 5
# ('exam', 'construct', 'mean') : 5
# ('construct', 'mean', 'close') : 8
# ('mean', 'close', 'zero') : 10
# ('close', 'zero', 'regressors') : 9
# ('zero', 'regressors', 'include') : 8
# ('regressors', 'include', 'number') : 13
# ('number', 'day', 'cycle') : 5
# ('day', 'cycle', 'regression') : 5
# ('cycle', 'regression', 'control') : 8
# ('regression', 'control', 'number') : 16
# ('control', 'number', 'day') : 16
# ('day', 'precipitation', 'bin') : 13
# ('precipitation', 'bin', 'error') : 8
# ('bin', 'error', 'cluster') : 9
# ('error', 'cluster', 'school') : 11
# ('cluster', 'school', 'level') : 13
# ('school', 'level', 'p') : 13
# ('level', 'p', 'p') : 18
# ('p', 'table', 'exposure') : 14
# ('table', 'exposure', 'performance') : 3
# ('x', 'x', 'fix') : 11
# ('dependent', 'variable', 'standardize') : 4
# ('variable', 'standardize', 'test') : 4
# ('grow', 'grow', 'grow') : 4
# ('school', 'year', 'school') : 5
# ('dardized', 'test', 'score') : 2
# ('year', 'regression', 'control') : 2
# ('outcome', 'mean', 'female') : 4
# ('mean', 'female', 'control') : 3
# ('precipitation', 'bin', 'rors') : 2
# ('bin', 'rors', 'cluster') : 2
# ('rors', 'cluster', 'school') : 2
# ('negative', 'food', 'consumption') : 3
# ('food', 'consumption', 'shock') : 3
# ('lag', 'lag', 'lag') : 9
# ('lag', 'grow', 'season') : 3
# ('grow', 'season', 'lag') : 3
# ('season', 'lag', 'grow') : 2
# ('season', 'lag', 'major') : 3
# ('lag', 'major', 'season') : 3
# ('major', 'season', 'lag') : 3
# ('season', 'lag', 'season') : 6
# ('lag', 'season', 'lag') : 5
# ('outcome', 'mean', 'fix') : 2
# ('mean', 'fix', 'effect') : 2
# ('x', 'x', 'enumeration') : 2
# ('x', 'enumeration', 'area') : 2
# ('enumeration', 'area', 'x') : 2
# ('area', 'x', 'x') : 2
# ('bin', 'previous', 'calendar') : 2
# ('previous', 'calendar', 'year') : 2
# ('control', 'precipitation', 'bin') : 3
# ('year', 'error', 'cluster') : 2
# ('error', 'cluster', 'enumeration') : 2
# ('cluster', 'enumeration', 'area') : 2
# ('enumeration', 'area', 'level') : 2
# ('area', 'level', 'p') : 2
# ('female', 'female', 'female') : 5
# ('female', 'travel', 'time') : 2
# ('standardize', 'score', 'quartile') : 2
# ('quartile', 'outcome', 'mean') : 2
# ('outcome', 'mean', 'school') : 2
# ('mean', 'school', 'mean') : 2
# ('school', 'mean', 'day') : 2
# ('mean', 'day', 'female') : 2
# ('day', 'female', 'control') : 2
# ('grade', 'exam', 'divide') : 2
# ('exam', 'divide', 'school') : 2
# ('school', 'quartile', 'base') : 2
# ('quartile', 'base', 'mean') : 2
# ('base', 'mean', 'number') : 2
# ('day', 'school', 'experience') : 2
# ('quartile', 'quartile', 'regressors') : 2
# ('quartile', 'regressors', 'include') : 2
# ('number', 'day', 'regression') : 4
# ('day', 'regression', 'control') : 4
# ('lag', 'lag', 'outcome') : 2
# ('lag', 'outcome', 'mean') : 2
# ('x', 'region', 'x') : 2
# ('fix', 'effect', 'run') : 3
# ('effect', 'run', 'school') : 3
# ('run', 'school', 'level') : 3
# ('school', 'level', 'dependent') : 3
# ('level', 'dependent', 'variable') : 2
# ('fraction', 'student', 'school') : 2
# ('time', 'student', 'grade') : 2
# ('student', 'grade', 'regression') : 2
# ('grade', 'regression', 'control') : 2
# ('precipitation', 'bin', 'time') : 2
# ('bin', 'time', 'current') : 2
# ('time', 'current', 'cohort') : 2
# ('current', 'cohort', 'student') : 2
# ('cohort', 'student', 'grade') : 2
# ('student', 'grade', 'error') : 2
# ('grade', 'error', 'cluster') : 2
# ('cluster', 'region', 'level') : 3
# ('region', 'level', 'p') : 3
# ('distribution', 'daily', 'max') : 2
# ('daily', 'max', 'year') : 2
# ('degrees', 'celsius', 'sum') : 2
# ('celsius', 'sum', 'day') : 13
# ('note', 'illustrate', 'cumulative') : 2
# ('illustrate', 'cumulative', 'sum') : 2
# ('cumulative', 'sum', 'day') : 2
# ('sum', 'day', 'within') : 2
# ('day', 'within', 'bin') : 2
# ('within', 'bin', 'span') : 2
# ('bin', 'span', 'year') : 2
# ('calculation', 'involve', 'initially') : 2
# ('involve', 'initially', 'derive') : 2
# ('initially', 'derive', 'weighted') : 2
# ('derive', 'weighted', 'average') : 3
# ('weighted', 'average', 'day') : 3
# ('average', 'day', 'every') : 2
# ('day', 'every', 'unique') : 2
# ('every', 'unique', 'school') : 3
# ('unique', 'school', 'location') : 3
# ('school', 'location', 'dataset') : 3
# ('location', 'dataset', 'year') : 3
# ('dataset', 'year', 'weight') : 2
# ('year', 'weight', 'determine') : 2
# ('weight', 'determine', 'number') : 3
# ('determine', 'number', 'student') : 3
# ('number', 'student', 'take') : 3
# ('take', 'exam', 'respective') : 3
# ('exam', 'respective', 'location') : 3
# ('respective', 'location', 'subsequently') : 2
# ('location', 'subsequently', 'aggregate') : 2
# ('subsequently', 'aggregate', 'weighted') : 2
# ('aggregate', 'weighted', 'mean') : 2
# ('weighted', 'mean', 'number') : 2
# ('number', 'day', 'fall') : 2
# ('fall', 'within', 'course') : 2
# ('within', 'course', 'multiple') : 2
# ('course', 'multiple', 'year') : 2
# ('multiple', 'year', 'encompass') : 2
# ('year', 'encompass', 'period') : 2
# ('celsius', 'estimate', 'standardized') : 2
# ('estimate', 'standardized', 'score') : 2
# ('note', 'plot', 'result') : 2
# ('plot', 'result', 'column') : 2
# ('result', 'column', 'table') : 2
# ('column', 'table', 'run') : 2
# ('table', 'run', 'fix') : 2
# ('run', 'fix', 'effect') : 2
# ('fix', 'effect', 'regression') : 2
# ('effect', 'regression', 'standardize') : 2
# ('regression', 'standardize', 'score') : 2
# ('standardize', 'score', 'grade') : 2
# ('score', 'grade', 'student') : 2
# ('grade', 'student', 'number') : 2
# ('student', 'number', 'hot') : 2
# ('exclude', 'reference', 'control') : 2
# ('reference', 'control', 'precipitation') : 2
# ('precipitation', 'bin', 'well') : 2
# ('bin', 'well', 'gender') : 2
# ('well', 'gender', 'student') : 2
# ('gender', 'student', 'represent') : 2
# ('student', 'represent', 'bin') : 2
# ('represent', 'bin', 'illustrates') : 2
# ('bin', 'illustrates', 'respective') : 2
# ('illustrates', 'respective', 'coefficient') : 2
# ('respective', 'coefficient', 'coefficient') : 2
# ('score', 'result', 'additional') : 2
# ('result', 'additional', 'hot') : 2
# ('interest', 'compare', 'reference') : 2
# ('lags', 'year', 'lags') : 2
# ('year', 'lags', 'year') : 2
# ('x', 'stream', 'observation') : 3
# ('stream', 'observation', 'note') : 3
# ('stream', 'construct', 'mean') : 2
# ('day', 'bin', 'cycle') : 2
# ('bin', 'cycle', 'regression') : 2
# ('science', 'standardize', 'score') : 2
# ('science', 'female', 'control') : 2
# ('percentage', 'average', 'number') : 2
# ('year', 'mean', 'number') : 2
# ('day', 'year', 'number') : 2
# ('utilized', 'analysis', 'source') : 2
# ('analysis', 'source', 'dataset') : 2
# ('degree', 'celsius', 'sum') : 11
# ('geographic', 'location', 'year') : 2
# ('location', 'year', 'subsequently') : 2
# ('year', 'subsequently', 'calculate') : 2
# ('subsequently', 'calculate', 'overall') : 2
# ('calculate', 'overall', 'average') : 2
# ('overall', 'average', 'multiple') : 2
# ('average', 'multiple', 'year') : 2
# ('number', 'day', 'high') : 2
# ('human', 'exposure', 'hws') : 2
# ('human', 'exposure', 'future') : 4
# ('exposure', 'future', 'hws') : 7
# ('future', 'hws', 'expect') : 2
# ('simultaneous', 'increase', 'population') : 2
# ('wave', 'hws', 'south') : 2
# ('hws', 'south', 'asia') : 3
# ('south', 'asia', 'sa') : 3
# ('exacerbate', 'population', 'exposure') : 2
# ('future', 'population', 'exposure') : 11
# ('population', 'exposure', 'daytime') : 17
# ('exposure', 'daytime', 'nighttime') : 12
# ('daytime', 'nighttime', 'hws') : 33
# ('nighttime', 'hws', 'sa') : 4
# ('use', 'couple', 'intercomparison') : 2
# ('intercomparison', 'project', 'model') : 3
# ('project', 'model', 'four') : 2
# ('model', 'four', 'share') : 2
# ('four', 'share', 'socioeconomic') : 2
# ('pathway', 'ssps', 'relative') : 2
# ('result', 'show', 'projected') : 2
# ('nighttime', 'hws', 'high') : 7
# ('hws', 'high', 'scenario') : 3
# ('high', 'scenario', 'follow') : 2
# ('relative', 'historical', 'period') : 13
# ('effect', 'future', 'population') : 2
# ('population', 'exposure', 'hws') : 7
# ('hws', 'select', 'ssps') : 3
# ('hws', 'range', 'million') : 2
# ('respectively', 'maximum', 'exposure') : 2
# ('maximum', 'exposure', 'occur') : 2
# ('exposure', 'occur', 'plain') : 2
# ('occur', 'plain', 'wide') : 2
# ('plain', 'wide', 'range') : 2
# ('decision', 'emphasize', 'importance') : 2
# ('gas', 'emission', 'adopt') : 2
# ('emission', 'adopt', 'sustainable') : 3
# ('adopt', 'sustainable', 'plan') : 2
# ('sustainable', 'plan', 'solution') : 2
# ('plan', 'solution', 'minimize') : 2
# ('solution', 'minimize', 'potential') : 2
# ('minimize', 'potential', 'socioeconomic') : 2
# ('potential', 'socioeconomic', 'impact') : 2
# ('socioeconomic', 'impact', 'hws') : 2
# ('plain', 'language', 'summary') : 3
# ('different', 'ssps', 'highlight') : 2
# ('access', 'article', 'term') : 3
# ('article', 'term', 'common') : 3
# ('term', 'common', 'permit') : 2
# ('common', 'permit', 'distribution') : 2
# ('permit', 'distribution', 'reproduction') : 2
# ('reproduction', 'medium', 'provide') : 4
# ('medium', 'provide', 'original') : 5
# ('provide', 'original', 'work') : 4
# ('original', 'work', 'properly') : 4
# ('work', 'properly', 'cite') : 4
# ('daytime', 'nighttime', 'wave') : 4
# ('nighttime', 'wave', 'south') : 2
# ('atmospheric', 'oceanic', 'science') : 8
# ('fudan', 'university', 'shanghai') : 5
# ('university', 'shanghai', 'china') : 5
# ('ca', 'usa', 'key') : 2
# ('chinese', 'academy', 'science') : 2
# ('nanjing', 'university', 'information') : 2
# ('university', 'information', 'science') : 2
# ('information', 'science', 'technology') : 2
# ('science', 'technology', 'nanjing') : 2
# ('technology', 'nanjing', 'china') : 2
# ('shared', 'socioeconomic', 'pathway') : 2
# ('compound', 'effect', 'population') : 4
# ('earth', 'future', 'receive') : 2
# ('future', 'receive', 'oct') : 2
# ('receive', 'oct', 'accept') : 2
# ('safi', 'ullah', 'qinglong') : 4
# ('safi', 'ullah', 'sachindra') : 4
# ('ullah', 'sachindra', 'waheed') : 3
# ('sachindra', 'waheed', 'ullah') : 3
# ('qinglong', 'deliang', 'chen') : 3
# ('research', 'article', 'earth') : 2
# ('article', 'earth', 'future') : 2
# ('earth', 'future', 'ullah') : 15
# ('sustainable', 'plan', 'mitigation') : 2
# ('region', 'highly', 'vulnerable') : 2
# ('hws', 'sa', 'however') : 2
# ('estimation', 'population', 'exposure') : 4
# ('climatic', 'population', 'factor') : 2
# ('gidden', 'neill', 'riahi') : 2
# ('change', 'daytime', 'nighttime') : 2
# ('estimate', 'future', 'population') : 2
# ('relative', 'contribution', 'population') : 3
# ('population', 'compound', 'effect') : 2
# ('population', 'exposure', 'region') : 2
# ('mukherjee', 'mishra', 'panda') : 2
# ('daily', 'maximum', 'tmax') : 3
# ('detail', 'select', 'model') : 2
# ('mention', 'part', 'sa') : 2
# ('part', 'sa', 'experience') : 2
# ('historical', 'period', 'future') : 5
# ('period', 'future', 'period') : 5
# ('download', 'koc', 'university') : 44
# ('koc', 'university', 'wiley') : 37
# ('university', 'wiley', 'library') : 37
# ('wiley', 'library', 'see') : 37
# ('library', 'see', 'term') : 37
# ('see', 'term', 'condition') : 37
# ('term', 'condition', 'wiley') : 37
# ('condition', 'wiley', 'library') : 37
# ('wiley', 'library', 'rule') : 37
# ('library', 'rule', 'oa') : 37
# ('rule', 'oa', 'article') : 37
# ('oa', 'article', 'govern') : 37
# ('article', 'govern', 'applicable') : 37
# ('govern', 'applicable', 'common') : 37
# ('applicable', 'common', 'earth') : 23
# ('common', 'earth', 'future') : 23
# ('scenario', 'consist', 'model') : 2
# ('use', 'bilinear', 'interpolation') : 2
# ('bilinear', 'interpolation', 'technique') : 2
# ('population', 'exposure', 'different') : 4
# ('different', 'type', 'hws') : 2
# ('type', 'hws', 'sa') : 2
# ('change', 'population', 'exposure') : 6
# ('mc', 'additive', 'scale') : 2
# ('observe', 'simulated', 'temperature') : 2
# ('spatial', 'distribution', 'historical') : 3
# ('nighttime', 'wave', 'hws') : 3
# ('model', 'download', 'koc') : 3
# ('daytime', 'nighttime', 'hw') : 3
# ('define', 'hw', 'event') : 3
# ('hw', 'event', 'area') : 2
# ('threshold', 'define', 'percentile') : 2
# ('define', 'percentile', 'tmax') : 2
# ('historical', 'period', 'daytime') : 2
# ('select', 'model', 'download') : 2
# ('daily', 'climatological', 'tmax') : 2
# ('climatological', 'tmax', 'tmin') : 2
# ('nighttime', 'hw', 'event') : 3
# ('hw', 'event', 'occur') : 3
# ('occurrence', 'daytime', 'nighttime') : 2
# ('mountainous', 'region', 'sa') : 2
# ('hws', 'population', 'exposure') : 2
# ('number', 'hw', 'event') : 8
# ('role', 'exposure', 'factor') : 2
# ('determine', 'relative', 'contribution') : 2
# ('constant', 'use', 'number') : 2
# ('use', 'number', 'hw') : 2
# ('hw', 'event', 'historical') : 2
# ('event', 'historical', 'period') : 2
# ('population', 'historical', 'period') : 3
# ('number', 'hws', 'historical') : 2
# ('hws', 'historical', 'period') : 2
# ('spatial', 'pattern', 'observe') : 2
# ('high', 'number', 'hw') : 2
# ('region', 'expect', 'experience') : 3
# ('occur', 'central', 'northwestern') : 2
# ('central', 'northwestern', 'southern') : 2
# ('northwestern', 'southern', 'northeastern') : 2
# ('southern', 'northeastern', 'part') : 2
# ('part', 'ssp', 'scenario') : 2
# ('ssp', 'scenario', 'relative') : 4
# ('scenario', 'relative', 'historical') : 5
# ('number', 'daytime', 'hws') : 3
# ('daytime', 'hws', 'occur') : 2
# ('northwestern', 'part', 'pakistan') : 2
# ('number', 'nighttime', 'hws') : 4
# ('nighttime', 'hws', 'occur') : 2
# ('number', 'daytime', 'nighttime') : 4
# ('nighttime', 'hws', 'relative') : 2
# ('hws', 'relative', 'historical') : 2
# ('decrease', 'southwestern', 'part') : 2
# ('southwestern', 'part', 'pakistan') : 3
# ('scenario', 'follow', 'relative') : 2
# ('follow', 'relative', 'historical') : 2
# ('nighttime', 'hws', 'likely') : 2
# ('part', 'pakistan', 'southern') : 2
# ('pakistan', 'southern', 'eastern') : 2
# ('southern', 'eastern', 'coastal') : 2
# ('eastern', 'coastal', 'region') : 2
# ('hws', 'high', 'daytime') : 2
# ('high', 'daytime', 'hws') : 2
# ('hws', 'future', 'note') : 2
# ('daytime', 'hws', 'select') : 2
# ('hws', 'select', 'scenario') : 3
# ('asymmetric', 'increase', 'tmax') : 2
# ('increase', 'tmax', 'tmin') : 2
# ('occur', 'large', 'area') : 2
# ('overall', 'result', 'suggest') : 2
# ('nighttime', 'hws', 'select') : 5
# ('hws', 'select', 'ssp') : 2
# ('select', 'ssp', 'scenario') : 4
# ('high', 'maximum', 'value') : 3
# ('ssps', 'relative', 'historical') : 2
# ('spatial', 'pattern', 'hws') : 2
# ('attribute', 'decrease', 'trend') : 2
# ('nighttime', 'hws', 'daytime') : 5
# ('hws', 'daytime', 'hws') : 4
# ('northeastern', 'part', 'sa') : 2
# ('exposure', 'future', 'daytime') : 2
# ('future', 'daytime', 'nighttime') : 4
# ('multiple', 'ssp', 'scenario') : 2
# ('high', 'degree', 'population') : 2
# ('degree', 'population', 'exposure') : 4
# ('asia', 'mean', 'different') : 2
# ('mean', 'different', 'share') : 2
# ('different', 'share', 'socioeconomic') : 2
# ('period', 'project', 'regional') : 2
# ('nighttime', 'hws', 'ssp') : 2
# ('hws', 'ssp', 'scenario') : 2
# ('million', 'population', 'exposure') : 3
# ('project', 'population', 'exposure') : 4
# ('regional', 'sum', 'population') : 2
# ('sum', 'population', 'exposure') : 2
# ('extent', 'population', 'exposure') : 3
# ('nighttime', 'hws', 'future') : 2
# ('population', 'growth', 'radiative') : 2
# ('growth', 'radiative', 'force') : 2
# ('could', 'possible', 'outcome') : 2
# ('rapid', 'urbanization', 'couple') : 2
# ('couple', 'radiative', 'forcing') : 3
# ('exposure', 'daytime', 'hws') : 6
# ('million', 'scenario', 'respectively') : 2
# ('population', 'exposure', 'nighttime') : 3
# ('exposure', 'nighttime', 'hws') : 2
# ('hws', 'million', 'scenario') : 2
# ('study', 'focus', 'exposure') : 2
# ('exceed', 'danger', 'threshold') : 2
# ('climatic', 'factor', 'likely') : 2
# ('effect', 'population', 'exposure') : 2
# ('anthropogenic', 'climatic', 'factor') : 2
# ('effect', 'urbanization', 'rate') : 2
# ('urbanization', 'rate', 'rapid') : 2
# ('rate', 'rapid', 'population') : 2
# ('daytime', 'hws', 'great') : 2
# ('error', 'bar', 'indicate') : 3
# ('bar', 'indicate', 'standard') : 3
# ('indicate', 'standard', 'deviation') : 4
# ('urbanization', 'population', 'couple') : 2
# ('population', 'couple', 'radiative') : 2
# ('climatic', 'factor', 'population') : 2
# ('factor', 'population', 'exposure') : 2
# ('measure', 'order', 'minimize') : 2
# ('order', 'minimize', 'human') : 2
# ('minimize', 'human', 'exposure') : 2
# ('ssp', 'scenario', 'estimate') : 2
# ('daytime', 'hws', 'scenario') : 2
# ('hws', 'scenario', 'follow') : 2
# ('conflict', 'interest', 'author') : 4
# ('conflict', 'interest', 'relevant') : 3
# ('interest', 'relevant', 'availability') : 3
# ('relevant', 'availability', 'statement') : 3
# ('world', 'environmental', 'research') : 3
# ('batibeniz', 'ashfaq', 'diffenbaugh') : 2
# ('ashfaq', 'diffenbaugh', 'key') : 2
# ('diffenbaugh', 'key', 'evans') : 2
# ('key', 'evans', 'turuncoglu') : 2
# ('double', 'population', 'exposure') : 2
# ('exposure', 'extremes', 'earth') : 2
# ('extremes', 'earth', 'future') : 2
# ('natural', 'science', 'foundation') : 5
# ('science', 'foundation', 'china') : 5
# ('evaluation', 'journal', 'advance') : 2
# ('population', 'exposure', 'precipitation') : 2
# ('exposure', 'precipitation', 'extremes') : 2
# ('earth', 'system', 'version') : 6
# ('eyring', 'bony', 'meehl') : 2
# ('bony', 'meehl', 'senior') : 2
# ('meehl', 'senior', 'stevens') : 2
# ('senior', 'stevens', 'stouffer') : 2
# ('stevens', 'stouffer', 'taylor') : 2
# ('stouffer', 'taylor', 'overview') : 2
# ('taylor', 'overview', 'couple') : 2
# ('gao', 'neill', 'map') : 2
# ('neill', 'map', 'global') : 2
# ('map', 'global', 'land') : 2
# ('global', 'land', 'century') : 2
# ('land', 'century', 'simulation') : 2
# ('century', 'simulation', 'share') : 2
# ('simulation', 'share', 'socioeconomic') : 2
# ('share', 'socioeconomic', 'way') : 3
# ('gasparrini', 'guo', 'serum') : 2
# ('institute', 'earth', 'system') : 2
# ('population', 'urbanization', 'economic') : 2
# ('urbanization', 'economic', 'scenario') : 2
# ('economic', 'scenario', 'belt') : 2
# ('scenario', 'belt', 'road') : 2
# ('belt', 'road', 'region') : 2
# ('road', 'region', 'share') : 2
# ('region', 'share', 'socioeconomic') : 2
# ('research', 'letter', 'jones') : 2
# ('jones', 'neill', 'mcdaniel') : 2
# ('neill', 'mcdaniel', 'mcginnis') : 2
# ('mcdaniel', 'mcginnis', 'mearns') : 2
# ('mcginnis', 'mearns', 'tebaldi') : 2
# ('mearns', 'tebaldi', 'future') : 2
# ('tebaldi', 'future', 'population') : 2
# ('population', 'exposure', 'u') : 2
# ('exposure', 'u', 'extremes') : 2
# ('u', 'extremes', 'nature') : 2
# ('community', 'earth', 'system') : 3
# ('zhou', 'zou', 'zhang') : 2
# ('system', 'version', 'description') : 2
# ('luo', 'wang', 'wang') : 2
# ('summertime', 'compound', 'hot') : 2
# ('compound', 'hot', 'extreme') : 3
# ('mazdiyasni', 'aghakouchak', 'davis') : 2
# ('aghakouchak', 'davis', 'madadgar') : 2
# ('davis', 'madadgar', 'mehran') : 2
# ('madadgar', 'mehran', 'ragno') : 2
# ('mehran', 'ragno', 'increase') : 2
# ('ragno', 'increase', 'mortality') : 2
# ('increase', 'mortality', 'indian') : 2
# ('mortality', 'indian', 'wave') : 2
# ('indian', 'wave', 'science') : 2
# ('wave', 'science', 'advance') : 2
# ('mishra', 'ambika', 'asoka') : 2
# ('ambika', 'asoka', 'aadhar') : 2
# ('asoka', 'aadhar', 'buzan') : 2
# ('aadhar', 'buzan', 'kumar') : 2
# ('buzan', 'kumar', 'huber') : 2
# ('kumar', 'huber', 'moist') : 2
# ('huber', 'moist', 'stress') : 3
# ('moist', 'stress', 'extreme') : 2
# ('stress', 'extreme', 'enhance') : 2
# ('mishra', 'mukherjee', 'kumar') : 2
# ('mukherjee', 'kumar', 'stone') : 2
# ('kumar', 'stone', 'wave') : 2
# ('stone', 'wave', 'exposure') : 2
# ('wave', 'exposure', 'current') : 2
# ('exposure', 'current', 'world') : 2
# ('current', 'world', 'environmental') : 2
# ('nature', 'mukherjee', 'mishra') : 2
# ('neill', 'tebaldi', 'van') : 2
# ('tebaldi', 'van', 'vuuren') : 2
# ('van', 'vuuren', 'eyring') : 2
# ('scenariomip', 'geoscientific', 'development') : 2
# ('raei', 'nikoo', 'aghakouchak') : 4
# ('nikoo', 'aghakouchak', 'mazdiyasni') : 4
# ('aghakouchak', 'mazdiyasni', 'sadegh') : 4
# ('mazdiyasni', 'sadegh', 'ghwr') : 3
# ('sadegh', 'ghwr', 'global') : 3
# ('ghwr', 'global', 'heatwave') : 3
# ('global', 'heatwave', 'record') : 3
# ('heatwave', 'record', 'toolbox') : 3
# ('record', 'toolbox', 'scientific') : 3
# ('geoscientific', 'development', 'discussion') : 2
# ('warm', 'tibetan', 'plateau') : 2
# ('china', 'global', 'warming') : 2
# ('description', 'basic', 'evaluation') : 2
# ('sensitivity', 'geoscientific', 'development') : 2
# ('volodin', 'mortikov', 'kostrykin') : 2
# ('mortikov', 'kostrykin', 'galin') : 2
# ('kostrykin', 'galin', 'lykossov') : 2
# ('galin', 'lykossov', 'gritsun') : 2
# ('lykossov', 'gritsun', 'simulation') : 2
# ('tett', 'yan', 'zhai') : 2
# ('yan', 'zhai', 'feng') : 2
# ('indus', 'river', 'basin') : 2
# ('occur', 'without', 'author') : 2
# ('clair', 'barnes', 'grantham') : 2
# ('barnes', 'grantham', 'institute') : 2
# ('college', 'london', 'uk') : 9
# ('friederike', 'l', 'otto') : 2
# ('l', 'otto', 'grantham') : 2
# ('otto', 'grantham', 'institute') : 2
# ('ben', 'clarke', 'grantham') : 2
# ('clarke', 'grantham', 'institute') : 2
# ('izidine', 'pinto', 'royal') : 2
# ('pinto', 'royal', 'netherlands') : 2
# ('institute', 'knmi', 'bilt') : 5
# ('knmi', 'bilt', 'netherlands') : 5
# ('crescent', 'centre', 'hague') : 16
# ('centre', 'hague', 'netherlands') : 16
# ('hague', 'netherlands', 'base') : 8
# ('ouagadougou', 'burkina', 'faso') : 5
# ('agence', 'nationale', 'meteorologie') : 3
# ('nationale', 'meteorologie', 'anam') : 2
# ('meteorologie', 'anam', 'ouagadougou') : 2
# ('anam', 'ouagadougou', 'burkina') : 2
# ('burkina', 'faso', 'cross') : 2
# ('maja', 'vahlberg', 'cross') : 2
# ('vahlberg', 'cross', 'crescent') : 2
# ('roop', 'singh', 'cross') : 2
# ('singh', 'cross', 'crescent') : 2
# ('netherlands', 'base', 'new') : 2
# ('julie', 'arrighi', 'cross') : 2
# ('arrighi', 'cross', 'crescent') : 2
# ('mariam', 'zachariah', 'grantham') : 2
# ('zachariah', 'grantham', 'institute') : 2
# ('sayanti', 'sengupta', 'cross') : 2
# ('sengupta', 'cross', 'crescent') : 2
# ('burkina', 'faso', 'mali') : 8
# ('faso', 'mali', 'country') : 2
# ('mali', 'country', 'population') : 2
# ('country', 'population', 'acclimate') : 2
# ('population', 'acclimate', 'temperature') : 2
# ('acclimate', 'temperature', 'length') : 2
# ('temperature', 'length', 'severity') : 2
# ('length', 'severity', 'heatwave') : 2
# ('severity', 'heatwave', 'make') : 2
# ('amongst', 'deadly', 'natural') : 2
# ('deadly', 'natural', 'hazard') : 2
# ('natural', 'hazard', 'thousand') : 2
# ('hazard', 'thousand', 'people') : 2
# ('people', 'die', 'cause') : 2
# ('die', 'cause', 'year') : 2
# ('ramadan', 'fast', 'power') : 2
# ('fast', 'power', 'cut') : 2
# ('power', 'cut', 'compound') : 2
# ('cut', 'compound', 'vulnerable') : 2
# ('compound', 'vulnerable', 'group') : 2
# ('vulnerable', 'group', 'even') : 2
# ('group', 'even', 'traditionally') : 2
# ('even', 'traditionally', 'consider') : 2
# ('traditionally', 'consider', 'vulnerable') : 2
# ('consider', 'vulnerable', 'even') : 2
# ('vulnerable', 'even', 'minimum') : 2
# ('even', 'minimum', 'temperature') : 2
# ('minimum', 'temperature', 'overnight') : 2
# ('temperature', 'overnight', 'remain') : 2
# ('overnight', 'remain', 'relatively') : 2
# ('remain', 'relatively', 'make') : 2
# ('relatively', 'make', 'people') : 2
# ('make', 'people', 'get') : 2
# ('people', 'get', 'break') : 2
# ('get', 'break', 'power') : 2
# ('break', 'power', 'cut') : 2
# ('power', 'cut', 'make') : 2
# ('cut', 'make', 'difficult') : 2
# ('make', 'difficult', 'access') : 2
# ('reduce', 'cop', 'capacity') : 2
# ('return', 'time', 'year') : 3
# ('year', 'maximum', 'temperature') : 2
# ('minimum', 'temperature', 'less') : 2
# ('time', 'maximum', 'temperature') : 2
# ('impossible', 'occur', 'without') : 2
# ('large', 'sahel', 'region') : 2
# ('human', 'warm', 'planet') : 2
# ('warm', 'planet', 'burn') : 2
# ('planet', 'burn', 'fossil') : 2
# ('minimum', 'temperature', 'faso') : 2
# ('warmer', 'global', 'warming') : 2
# ('warming', 'since', 'time') : 3
# ('event', 'magnitude', 'observe') : 2
# ('rapid', 'urbanization', 'loss') : 2
# ('urbanization', 'loss', 'green') : 2
# ('green', 'space', 'city') : 2
# ('space', 'city', 'bamako') : 2
# ('city', 'bamako', 'ouagadougou') : 2
# ('bamako', 'ouagadougou', 'increase') : 2
# ('ouagadougou', 'increase', 'island') : 2
# ('increase', 'island', 'couple') : 2
# ('island', 'couple', 'vulnerability') : 2
# ('couple', 'vulnerability', 'highlight') : 2
# ('highlight', 'need', 'sustainable') : 2
# ('need', 'sustainable', 'planning') : 2
# ('sustainable', 'planning', 'integrates') : 2
# ('planning', 'integrates', 'green') : 2
# ('integrates', 'green', 'space') : 2
# ('green', 'space', 'building') : 2
# ('building', 'design', 'account') : 2
# ('design', 'account', 'temperature') : 2
# ('account', 'temperature', 'critical') : 2
# ('temperature', 'critical', 'infrastructure') : 2
# ('infrastructure', 'electricity', 'water') : 2
# ('electricity', 'water', 'healthcare') : 2
# ('water', 'healthcare', 'system') : 2
# ('adapt', 'increase', 'frequency') : 2
# ('frequency', 'intensity', 'require') : 2
# ('increase', 'investment', 'ensure') : 2
# ('investment', 'ensure', 'reliable') : 2
# ('ensure', 'reliable', 'access') : 2
# ('reliable', 'access', 'service') : 2
# ('access', 'service', 'delivery') : 2
# ('north', 'africa', 'sahel') : 2
# ('sea', 'level', 'pressure') : 2
# ('period', 'march', 'april') : 3
# ('mali', 'burkina', 'faso') : 28
# ('burkina', 'faso', 'show') : 5
# ('show', 'maximum', 'temperature') : 3
# ('high', 'temperature', 'record') : 2
# ('record', 'north', 'africa') : 2
# ('analysis', 'southern', 'mali') : 3
# ('southern', 'mali', 'burkina') : 20
# ('minimum', 'temperature', 'average') : 3
# ('average', 'anomaly', 'daily') : 3
# ('anomaly', 'daily', 'maximum') : 2
# ('daily', 'maximum', 'period') : 2
# ('day', 'two', 'vertical') : 2
# ('two', 'vertical', 'line') : 2
# ('vertical', 'line', 'april') : 2
# ('line', 'april', 'day') : 2
# ('line', 'represent', 'previous') : 2
# ('minimum', 'temperature', 'region') : 2
# ('previous', 'study', 'assess') : 2
# ('temperature', 'drive', 'increase') : 2
# ('method', 'observational', 'daily') : 2
# ('observational', 'daily', 'maximum') : 2
# ('provisional', 'time', 'write') : 2
# ('reanalysis', 'product', 'hersbach') : 2
# ('cover', 'globe', 'resolution') : 2
# ('variable', 'directly', 'assimilate') : 2
# ('directly', 'assimilate', 'generate') : 2
# ('assimilate', 'generate', 'atmospheric') : 2
# ('generate', 'atmospheric', 'component') : 2
# ('atmospheric', 'component', 'integrate') : 2
# ('component', 'integrate', 'forecast') : 2
# ('integrate', 'forecast', 'system') : 2
# ('forecast', 'system', 'ifs') : 2
# ('system', 'ifs', 'modelling') : 2
# ('ifs', 'modelling', 'system') : 2
# ('modelling', 'system', 'reanalysis') : 2
# ('anthropogenic', 'filter', 'global') : 2
# ('filter', 'global', 'mean') : 2
# ('surface', 'gmst', 'take') : 2
# ('gmst', 'take', 'aeronautics') : 2
# ('take', 'aeronautics', 'space') : 2
# ('administration', 'nasa', 'goddard') : 2
# ('nasa', 'goddard', 'institute') : 2
# ('institute', 'space', 'science') : 2
# ('space', 'science', 'giss') : 2
# ('science', 'giss', 'surface') : 2
# ('giss', 'surface', 'analysis') : 2
# ('surface', 'analysis', 'gistemp') : 2
# ('analysis', 'gistemp', 'hansen') : 2
# ('gistemp', 'hansen', 'lenssen') : 2
# ('eyring', 'simulation', 'period') : 2
# ('simulation', 'period', 'base') : 2
# ('period', 'base', 'historical') : 2
# ('base', 'historical', 'simulation') : 2
# ('historical', 'simulation', 'scenario') : 2
# ('simulation', 'scenario', 'use') : 2
# ('scenario', 'use', 'remainder') : 2
# ('use', 'remainder', 'century') : 2
# ('remainder', 'century', 'statistical') : 2
# ('century', 'statistical', 'method') : 2
# ('method', 'observational', 'analysis') : 2
# ...
# ('great', 'mitchell', 'chakraborty') : 2
# ('sociodemographic', 'american', 'community') : 2
# ('hotter', 'census', 'tract') : 2
# ('census', 'tract', 'characterize') : 2
# ('socioeconomic', 'status', 'great') : 2
# ('neighborhood', 'diversity', 'modify') : 2
# ('diversity', 'modify', 'association') : 2
# ('association', 'proportion', 'black') : 2
# ('proportion', 'black', 'latinx') : 2
# ('black', 'latinx', 'asian') : 3
# ('metropolitan', 'area', 'serve') : 2
# ('census', 'tract', 'northeastern') : 2
# ('tract', 'northeastern', 'region') : 2
# ('state', 'census', 'tract') : 2
# ('census', 'tract', 'boundary') : 2
# ('census', 'tract', 'variable') : 2
# ('dependent', 'variable', 'mean') : 2
# ('distribution', 'mean', 'lst') : 2
# ('variable', 'mean', 'lst') : 2
# ('renteria', 'environmental', 'research') : 9
# ('reference', 'location', 'unit') : 2
# ('location', 'unit', 'analysis') : 2
# ('unit', 'analysis', 'social') : 2
# ('analysis', 'social', 'indicator') : 2
# ('social', 'indicator', 'indicator') : 2
# ('indicator', 'indicator', 'analytic') : 2
# ('indicator', 'analytic', 'method') : 2
# ('analytic', 'method', 'result') : 2
# ('median', 'hh', 'income') : 4
# ('hh', 'income', 'percentage') : 3
# ('income', 'percentage', 'follow') : 3
# ('day', 'average', 'summer') : 2
# ('ols', 'regression', 'spatial') : 3
# ('regression', 'spatial', 'error') : 3
# ('spatial', 'error', 'regression') : 4
# ('ciudad', 'arez', 'mexico') : 3
# ('pearson', 'correlation', 'spatial') : 2
# ('population', 'density', 'low') : 2
# ('density', 'low', 'proportion') : 2
# ('low', 'proportion', 'lack') : 2
# ('proportion', 'lack', 'access') : 2
# ('lack', 'access', 'care') : 2
# ('access', 'care', 'associate') : 2
# ('care', 'associate', 'high') : 2
# ('associate', 'high', 'lst') : 2
# ('high', 'mean', 'lst') : 3
# ('percentage', 'follow', 'ethnic') : 2
# ('follow', 'ethnic', 'minority') : 2
# ('minority', 'age', 'age') : 2
# ('age', 'age', 'live') : 3
# ('bg', 'percentage', 'follow') : 2
# ('ethnic', 'minority', 'poverty') : 2
# ('without', 'school', 'degree') : 2
# ('age', 'live', 'alone') : 2
# ('mean', 'lst', 'ndvi') : 2
# ('nlcd', 'tree', 'canopy') : 2
# ('holc', 'security', 'rating') : 2
# ('ct', 'population', 'density') : 2
# ('population', 'density', 'percentages') : 4
# ('density', 'percentages', 'follow') : 3
# ('percentages', 'follow', 'minority') : 3
# ('correlation', 'ols', 'regression') : 2
# ('table', 'provide', 'descriptive') : 2
# ('provide', 'descriptive', 'statistic') : 2
# ('maximum', 'mean', 'standard') : 2
# ('follow', 'ej', 'study') : 3
# ('harlan', 'mitchell', 'chakraborty') : 4
# ('proportion', 'child', 'age') : 3
# ('ej', 'study', 'examine') : 2
# ('socially', 'isolate', 'elderly') : 2
# ('increase', 'percentage', 'black') : 2
# ('population', 'density', 'ruca') : 2
# ('density', 'ruca', 'code') : 2
# ('omit', 'ruca', 'code') : 2
# ('reference', 'ruca', 'code') : 2
# ('connecticut', 'maine', 'massachusetts') : 4
# ('new', 'york', 'pennsylvania') : 4
# ('york', 'pennsylvania', 'rhode') : 4
# ('pennsylvania', 'rhode', 'island') : 4
# ('northeastern', 'u', 'renteria') : 2
# ('u', 'renteria', 'environmental') : 2
# ('third', 'research', 'question') : 2
# ('composition', 'standard', 'deviation') : 2
# ('calculate', 'simple', 'slope') : 2
# ('tract', 'ruca', 'code') : 2
# ('predict', 'mean', 'lst') : 3
# ('mean', 'lst', 'census') : 2
# ('lst', 'census', 'tracts') : 3
# ('second', 'research', 'question') : 2
# ('standard', 'deviation', 'proportion') : 4
# ('associate', 'mean', 'lst') : 5
# ('mean', 'lst', 'p') : 6
# ('deviation', 'associate', 'mean') : 2
# ('lst', 'p', 'standard') : 2
# ('p', 'standard', 'deviation') : 2
# ('diversity', 'associate', 'great') : 2
# ('whereby', 'standard', 'deviation') : 2
# ('significant', 'association', 'proportion') : 2
# ('deviation', 'mean', 'association') : 2
# ('p', 'positive', 'association') : 2
# ('positive', 'association', 'become') : 2
# ('association', 'become', 'strong') : 2
# ('become', 'strong', 'proportion') : 2
# ('low', 'standard', 'deviation') : 2
# ('deviation', 'mean', 'slope') : 2
# ('mean', 'slope', 'p') : 2
# ('suburban', 'rural', 'tract') : 4
# ('prop', 'black', 'nl') : 4
# ('black', 'nl', 'prop') : 3
# ('nl', 'prop', 'asian') : 3
# ('prop', 'asian', 'nl') : 2
# ('prop', 'auto', 'prop') : 3
# ('auto', 'prop', 'prop') : 3
# ('prop', 'prop', 'alone') : 3
# ('prop', 'alone', 'prop') : 3
# ('ruca', 'ruca', 'ruca') : 8
# ('new', 'york', 'metro') : 4
# ('boston', 'metro', 'philadelphia') : 3
# ('metro', 'philadelphia', 'metro') : 3
# ('philadelphia', 'metro', 'connecticut') : 3
# ('metro', 'connecticut', 'maine') : 3
# ('island', 'vermont', 'note') : 3
# ('disparity', 'within', 'northeast') : 2
# ('tract', 'rural', 'tract') : 2
# ('rural', 'tract', 'well') : 2
# ('los', 'angeles', 'mitchell') : 2
# ('angeles', 'mitchell', 'chakraborty') : 2
# ('result', 'gee', 'predict') : 2
# ('gee', 'predict', 'mean') : 2
# ('exp', 'b', 'std') : 2
# ('b', 'std', 'error') : 2
# ('std', 'error', 'p') : 2
# ('intercept', 'prop', 'latinx') : 2
# ('prop', 'latinx', 'nl') : 2
# ('latinx', 'nl', 'prop') : 2
# ('nl', 'prop', 'black') : 2
# ('prop', 'asian', 'prop') : 2
# ('asian', 'prop', 'race') : 2
# ('prop', 'race', 'diversity') : 2
# ('race', 'diversity', 'index') : 2
# ('diversity', 'index', 'x') : 2
# ('index', 'x', 'prop') : 2
# ('median', 'income', 'median') : 2
# ('median', 'income', 'sq') : 2
# ('income', 'sq', 'prop') : 2
# ('sq', 'prop', 'auto') : 2
# ('alone', 'prop', 'disabled') : 2
# ('prop', 'disabled', 'population') : 2
# ('disabled', 'population', 'density') : 2
# ('ruca', 'code', 'ruca') : 8
# ('code', 'ruca', 'code') : 8
# ('research', 'question', 'find') : 2
# ('coeff', 'coeff', 'coeff') : 2
# ('ref', 'ref', 'ref') : 2
# ('metropolitan', 'area', 'environ') : 2
# ('beatriz', 'fátima', 'alves') : 2
# ('fátima', 'alves', 'oliveira') : 2
# ('ﬁnd', 'stress', 'exposure') : 2
# ('stress', 'exposure', 'deforestation') : 2
# ('combine', 'effect', 'amazon') : 2
# ('effect', 'amazon', 'savannization') : 4
# ('institute', 'space', 'research') : 2
# ('space', 'research', 'inpe') : 2
# ('deforestation', 'brazilian', 'amazon') : 2
# ('numerical', 'modeling', 'experiment') : 2
# ('use', 'brazilian', 'earth') : 2
# ('brazilian', 'earth', 'system') : 3
# ('amazon', 'savannization', 'global') : 4
# ('solar', 'radiation', 'exposure') : 2
# ('month', 'average', 'daily') : 2
# ('amazon', 'basin', 'region') : 4
# ('daily', 'high', 'wbgt') : 2
# ('maximum', 'wbgt', 'warm') : 2
# ('wbgt', 'warm', 'month') : 2
# ('global', 'scenario', 'historical') : 2
# ('global', 'warm', 'scenarios') : 2
# ('historical', 'h', 'scenario') : 2
# ('h', 'scenario', 'forest') : 2
# ('scenario', 'forest', 'f') : 2
# ('forest', 'f', 'savannah') : 2
# ('combine', 'effect', 'deforestation') : 5
# ('maximum', 'daily', 'wbgt') : 2
# ('daily', 'wbgt', 'value') : 2
# ('increase', 'stress', 'exposure') : 2
# ('stress', 'exposure', 'might') : 2
# ('daily', 'maximum', 'outdoor') : 3
# ('maximum', 'outdoor', 'wbgt') : 3
# ('outdoor', 'wbgt', 'value') : 3
# ('end', 'century', 'amazon') : 2
# ('amazon', 'rainforest', 'deforestation') : 3
# ('wbgt', 'value', 'distribution') : 2
# ('daily', 'maximum', 'value') : 2
# ('amazon', 'rainforest', 'savannization') : 2
# ('savannization', 'global', 'scenario') : 2
# ('human', 'capital', 'infrastructure') : 2
# ('capital', 'infrastructure', 'income') : 2
# ('social', 'vulnerability', 'svi') : 7
# ('vulnerability', 'svi', 'social') : 4
# ('reside', 'northern', 'region') : 2
# ('vulnerability', 'impact', 'population') : 2
# ('result', 'suggest', 'deforestation') : 2
# ('k', 'moi', 'k') : 2
# ('k', 'observation', 'respectively') : 2
# ('k', 'soi', 'k') : 2
# ('use', 'calculate', 'outdoor') : 2
# ('calculate', 'outdoor', 'wbgt') : 2
# ('municipality', 'impact', 'amazon') : 2
# ('impact', 'amazon', 'savannization') : 2
# ('savannization', 'global', 'warming') : 2
# ('brazilian', 'global', 'atmospheric') : 2
# ('global', 'atmospheric', 'bam') : 2
# ('period', 'year', 'force') : 2
# ('cad', 'saúde', 'pública') : 2
# ('south', 'african', 'geographical') : 10
# ('african', 'geographical', 'journal') : 10
# ('influence', 'weather', 'condition') : 2
# ('weather', 'condition', 'magnitude') : 5
# ('condition', 'magnitude', 'spatial') : 5
# ('magnitude', 'spatial', 'distribution') : 7
# ('spatial', 'distribution', 'crime') : 9
# ('distribution', 'crime', 'tshwane') : 4
# ('crime', 'tshwane', 'francois') : 2
# ('tshwane', 'francois', 'h') : 2
# ('francois', 'h', 'schutte') : 3
# ('h', 'schutte', 'gregory') : 3
# ('schutte', 'gregory', 'breetzke') : 3
# ('crime', 'tshwane', 'south') : 2
# ('inﬂuence', 'weather', 'condition') : 2
# ('gregory', 'breetzke', 'department') : 2
# ('breetzke', 'department', 'geography') : 2
# ('department', 'geography', 'geoinformatics') : 2
# ('geography', 'geoinformatics', 'meteorology') : 2
# ('geoinformatics', 'meteorology', 'university') : 2
# ('meteorology', 'university', 'pretoria') : 2
# ('university', 'pretoria', 'pretoria') : 2
# ('pretoria', 'pretoria', 'south') : 2
# ('pretoria', 'south', 'africa') : 2
# ('spatial', 'distribution', 'violent') : 8
# ('distribution', 'violent', 'sexual') : 2
# ('violent', 'sexual', 'property') : 19
# ('sexual', 'property', 'crime') : 17
# ('property', 'crime', 'tshwane') : 2
# ('tshwane', 'south', 'africa') : 2
# ('analysis', 'variance', 'anova') : 2
# ('mean', 'amount', 'crime') : 2
# ('amount', 'crime', 'violent') : 2
# ('crime', 'violent', 'sexual') : 3
# ('day', 'stratiﬁed', 'rainfall') : 2
# ('spatial', 'point', 'pattern') : 17
# ('point', 'pattern', 'test') : 15
# ('pattern', 'test', 'use') : 2
# ('spatial', 'similarity', 'violent') : 2
# ('similarity', 'violent', 'sexual') : 2
# ('property', 'crime', 'rainfall') : 3
# ('crime', 'rainfall', 'day') : 3
# ('day', 'classiﬁed', 'low') : 2
# ('classiﬁed', 'low', 'random') : 2
# ('association', 'criminal', 'activity') : 2
# ('crime', 'find', 'diﬀer') : 4
# ('find', 'diﬀer', 'signiﬁcantly') : 2
# ('depend', 'type', 'weather') : 2
# ('law', 'enforcement', 'agency') : 2
# ('area', 'south', 'africa') : 2
# ('rainfall', 'spatial', 'point') : 2
# ('see', 'breetzke', 'cohn') : 3
# ('crime', 'change', 'depend') : 2
# ('depend', 'weather', 'condition') : 3
# ('day', 'experience', 'high') : 2
# ('experience', 'high', 'low') : 2
# ('high', 'low', 'rate') : 2
# ('low', 'rate', 'violent') : 2
# ('rate', 'violent', 'property') : 2
# ('violent', 'property', 'sexual') : 6
# ('property', 'sexual', 'crime') : 5
# ('distribution', 'violent', 'property') : 3
# ('individual', 'frustration', 'discomfort') : 2
# ('frustration', 'discomfort', 'level') : 2
# ('relationship', 'aggression', 'linear') : 2
# ('crime', 'occur', 'example') : 2
# ('seasonal', 'variation', 'crime') : 2
# ('brunsdon', 'corcoran', 'higgs') : 2
# ('motivate', 'oﬀender', 'suitable') : 2
# ('oﬀender', 'suitable', 'target') : 2
# ('might', 'encourage', 'individual') : 3
# ('encourage', 'individual', 'leave') : 3
# ('individual', 'leave', 'home') : 4
# ('leave', 'home', 'engage') : 2
# ('criminal', 'oﬀences', 'occur') : 2
# ('violent', 'property', 'crime') : 5
# ('examine', 'eﬀect', 'weather') : 2
# ('type', 'property', 'crime') : 2
# ('property', 'crime', 'vancouver') : 2
# ('examine', 'seasonal', 'variation') : 2
# ('seasonal', 'variation', 'violence') : 2
# ('variation', 'violence', 'norway') : 2
# ('homicide', 'sao', 'paulo') : 2
# ('crime', 'seasonality', 'research') : 2
# ('seasonal', 'crime', 'rate') : 2
# ('crime', 'rate', 'pronounce') : 2
# ('assault', 'rate', 'equably') : 2
# ('rate', 'equably', 'split') : 2
# ('neighbourhood', 'range', 'low') : 2
# ('range', 'low', 'deprivation') : 2
# ('south', 'african', 'weather') : 2
# ('african', 'weather', 'service') : 2
# ('mean', 'daily', 'day') : 3
# ('day', 'year', 'extract') : 2
# ('extract', 'dataset', 'day') : 2
# ('year', 'combine', 'yield') : 2
# ('mean', 'day', 'period') : 2
# ('yield', 'set', 'contain') : 2
# ('use', 'random', 'number') : 2
# ('random', 'number', 'generator') : 2
# ('number', 'generator', 'yield') : 2
# ('rainfall', 'day', 'day') : 3
# ('day', 'schutte', 'breetzke') : 2
# ('crime', 'information', 'analysis') : 2
# ('information', 'analysis', 'centre') : 2
# ('analysis', 'centre', 'ciac') : 2
# ('centre', 'ciac', 'south') : 2
# ('ciac', 'south', 'african') : 2
# ('south', 'african', 'police') : 2
# ('african', 'police', 'service') : 2
# ('police', 'service', 'sap') : 2
# ('crime', 'type', 'day') : 3
# ('robbery', 'common', 'robbery') : 2
# ('amount', 'violent', 'sexual') : 4
# ('property', 'crime', 'occur') : 3
# ('rainfall', 'day', 'calculate') : 2
# ('descriptive', 'statistic', 'amount') : 2
# ('statistic', 'amount', 'violent') : 2
# ('diﬀerent', 'type', 'rainfall') : 2
# ('type', 'rainfall', 'day') : 6
# ('property', 'crime', 'commit') : 2
# ('less', 'indicate', 'signiﬁcant') : 2
# ('indicate', 'signiﬁcant', 'spatial') : 2
# ('signiﬁcant', 'spatial', 'dissimilarity') : 2
# ('compare', 'spatial', 'similarity') : 2
# ('diﬀerent', 'day', 'rainfall') : 4
# ('day', 'rainfall', 'spatial') : 2
# ('police', 'foot', 'patrol') : 2
# ('open', 'source', 'crime') : 2
# ('descriptive', 'statistic', 'violent') : 3
# ('crime', 'day', 'stratiﬁed') : 3
# ('mean', 'amount', 'violent') : 2
# ('property', 'crime', 'high') : 3
# ('crime', 'high', 'day') : 3
# ('day', 'mean', 'amount') : 2
# ('high', 'day', 'rate') : 3
# ('day', 'rate', 'population') : 6
# ('rate', 'population', 'compare') : 5
# ('population', 'compare', 'low') : 5
# ('compare', 'low', 'rate') : 5
# ('low', 'rate', 'population') : 6
# ('rate', 'population', 'random') : 5
# ('population', 'random', 'rate') : 5
# ('random', 'rate', 'population') : 5
# ('rate', 'population', 'day') : 5
# ('property', 'crime', 'diﬀerent') : 3
# ('diﬀerent', 'rainfall', 'day') : 3
# ('statistic', 'violent', 'sexual') : 2
# ('property', 'crime', 'day') : 4
# ('n', 'violent', 'crime') : 2
# ('violent', 'crime', 'sexual') : 2
# ('crime', 'sexual', 'crime') : 2
# ('sexual', 'crime', 'property') : 2
# ('crime', 'property', 'crime') : 3
# ('property', 'crime', 'n') : 2
# ('crime', 'n', 'min') : 2
# ('n', 'min', 'mean') : 6
# ('mean', 'max', 'sd') : 6
# ('max', 'sd', 'n') : 4
# ('sd', 'n', 'min') : 4
# ('max', 'sd', 'day') : 2
# ('sd', 'day', 'day') : 2
# ('violent', 'crime', 'day') : 3
# ('population', 'day', 'however') : 2
# ('day', 'however', 'diﬀerences') : 2
# ('however', 'diﬀerences', 'relatively') : 2
# ('show', 'result', 'anova') : 2
# ('result', 'anova', 'used') : 2
# ('anova', 'used', 'ass') : 2
# ('used', 'ass', 'whether') : 2
# ('ass', 'whether', 'diﬀerences') : 2
# ('day', 'observe', 'table') : 2
# ('observe', 'table', 'signiﬁcant') : 2
# ('find', 'signiﬁcant', 'diﬀerences') : 2
# ('diﬀerences', 'magnitude', 'crime') : 2
# ('crime', 'type', 'rainfall') : 3
# ('table', 'anova', 'violent') : 2
# ('anova', 'violent', 'sexual') : 2
# ('day', 'mean', 'df') : 2
# ('mean', 'df', 'f') : 2
# ('df', 'f', 'violent') : 2
# ('f', 'violent', 'crime') : 2
# ('violent', 'crime', 'temp') : 2
# ('crime', 'temp', 'low') : 6
# ('temp', 'low', 'temp') : 6
# ('low', 'temp', 'random') : 6
# ('temp', 'random', 'temp') : 6
# ('sexual', 'crime', 'temp') : 2
# ('property', 'crime', 'temp') : 2
# ('crime', 'rain', 'rain') : 3
# ('rain', 'rain', 'random') : 6
# ('rain', 'random', 'rain') : 6
# ('random', 'rain', 'south') : 2
# ('rain', 'south', 'african') : 2
# ('global', 'value', 'indicate') : 2
# ('crime', 'diﬀerent', 'day') : 3
# ('table', 'illustrates', 'global') : 2
# ('violent', 'crime', 'rainfall') : 2
# ('distribution', 'violent', 'crime') : 3
# ('crime', 'spatially', 'distribute') : 3
# ('compare', 'warm', 'day') : 2
# ('violent', 'crime', 'distribution') : 2
# ('rainfall', 'violent', 'crime') : 2
# ('day', 'versus', 'rainfall') : 2
# ('versus', 'rainfall', 'day') : 2
# ('rainfall', 'sexual', 'crime') : 2
# ('sexual', 'crime', 'find') : 2
# ('crime', 'type', 'category') : 2
# ('value', 'property', 'crime') : 2
# ('property', 'crime', 'find') : 4
# ('distribution', 'property', 'crime') : 2
# ('table', 'spatial', 'point') : 3
# ('random', 'temp', 'rain') : 3
# ('random', 'rain', 'temp') : 3
# ('rain', 'temp', 'rain') : 3
# ('temp', 'rain', 'low') : 3
# ('rain', 'low', 'temp') : 3
# ('low', 'temp', 'rain') : 3
# ('temp', 'rain', 'random') : 2
# ('rain', 'random', 'temp') : 2
# ('random', 'temp', 'random') : 2
# ('temp', 'random', 'rain') : 2
# ('crime', 'occur', 'day') : 3
# ('warmer', 'weather', 'might') : 2
# ('weather', 'might', 'encourage') : 2
# ('contact', 'victim', 'perpetrator') : 2
# ('victim', 'perpetrator', 'result') : 2
# ('violent', 'sexual', 'crime') : 2
# ('heavy', 'rainfall', 'day') : 2
# ('distribution', 'crime', 'day') : 2
# ('day', 'compare', 'cold') : 2
# ('police', 'call', 'service') : 2
# ('journal', 'research', 'crime') : 2
# ('research', 'crime', 'delinquency') : 2

# %% [markdown]
# ### BERT topic

# %%
def preprocess_texts(docs):
    preprocessed_docs = [' '.join(tokens) for tokens in (doc[0] for doc in docs.values())]
    return preprocessed_docs
preprocessed_texts = preprocess_texts(docs)

# %%
# Initializing the SentenceTransformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Encoding the preprocessed texts into embeddings
embeddings = model.encode(preprocessed_texts, show_progress_bar=True)

# %%
# Initializing BERTopic with custom parameters
topic_model = BERTopic(min_topic_size=2,
                       top_n_words=6,
                       n_gram_range=(1, 2),
                       calculate_probabilities=True)

# Fitting BERTopic on the preprocessed texts and embeddings
topics, probs = topic_model.fit_transform(preprocessed_texts,embeddings)

# %%
# Checking the topics identified
topic_info = topic_model.get_topic_info()
print(topic_info)
# Out:
#     Topic  Count                                      Name  \
# 0      -1     13  -1_exposure_population_vulnerability_air
# 1       0     31       0_disaster_country_development_loss
# 2       1     15         1_worker_work_stress_occupational
# 3       2      6             2_ination_shock_region_future
# 4       3      5        3_emission_energy_trade_technology
# 5       4      5               4_unit_insurance_tdcj_texas
# 6       5      5         5_drought_vegetation_ozone_global
# 7       6      5  6_migration_tourism_australia_australian
# 8       7      4            7_stratum_day_mean_electricity
# 9       8      4         8_event_return_firm_excess return
# 10      9      3    9_location_threshold_fan_neighbourhood
# 11     10      3               10_damage_loss_drought_cost
# 12     11      3             11_cool_roof_cool roof_access
# 13     12      2               12_mortality_city_tract_uhi
#
#                                        Representation  \
# 0   [exposure, population, vulnerability, air, cit...
# 1   [disaster, country, development, loss, people,...
# 2   [worker, work, stress, occupational, labour, p...
# 3   [ination, shock, region, future, hws, population]
# 4   [emission, energy, trade, technology, cool, se...
# 5         [unit, insurance, tdcj, texas, hate, tweet]
# 6      [drought, vegetation, ozone, global, use, lst]
# 7   [migration, tourism, australia, australian, mi...
# 8   [stratum, day, mean, electricity, household, s...
# 9   [event, return, firm, excess return, excess, day]
# 10  [location, threshold, fan, neighbourhood, conu...
# 11       [damage, loss, drought, cost, germany, wood]
# 12      [cool, roof, cool roof, access, energy, wave]
# 13            [mortality, city, tract, uhi, lst, age]
#
#                                   Representative_Docs
# 0   [asian development bank beat invest solution r...
# 1   [reduce poverty protect livelihood build asset...
# 2   [labour impact workplace workplace environment...
# 3   [article global warming extreme enhance inﬂati...
# 4   [measure impact rural poor woman youth food ag...
# 5   [available author publish elsevier open access...
# 6   [open access global regional impact representa...
# 7   [migration update information iom work migrati...
# 8   [wave economic activity evidence latin america...
# 9   [poverty render madagascar highly vulnerable u...
# 10  [policy beat protect child heatwaves europe ce...
# 11  [v l p n c l n f n n c finance context novembe...
# 12  [introduction cooler mihir bhatt disaster miti...
# 13  [article economic valuation mortality attribut...

# %%
topic_model.get_topic(12)
# Out:
# [('mortality', 0.03391142049449049),
#  ('city', 0.026461964488021333),
#  ('tract', 0.02524872411513278),
#  ('uhi', 0.02442543094815526),
#  ('lst', 0.018210789397039358),
#  ('age', 0.017465661306799912)]

# %%
# Getting the topic words
topic_words = topic_model.get_topics()

# Preprocessing the texts
preprocessed_texts = preprocess_texts(docs)

# Converting preprocessed texts to list of words for coherence model
texts = [doc.split() for doc in preprocessed_texts]

# Creating a dictionary and corpus for the coherence model
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

coherence_scores = []
for topic_id, topic in topic_words.items():
    # Preparing the data for coherence model
    topics = [[word for word, _ in topic]]

    # Computing Coherence Score using Gensim's CoherenceModel for each topic
    coherence_model = CoherenceModel(topics=topics, texts=texts, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()

    coherence_scores.append((topic_id, coherence_score))

# Printing coherence scores for each topic
for topic_id, coherence_score in coherence_scores:
    print(f'Topic {topic_id}: Coherence Score: {coherence_score}')
# Out:
# Topic -1: Coherence Score: 0.5865906945517748
# Topic 0: Coherence Score: 0.49169192606711837
# Topic 1: Coherence Score: 0.8309315789563628
# Topic 2: Coherence Score: 0.35907251148303115
# Topic 3: Coherence Score: 0.6224394017065169
# Topic 4: Coherence Score: 0.268453167273575
# Topic 5: Coherence Score: 0.40617713979120246
# Topic 6: Coherence Score: 0.5758808812855526
# Topic 7: Coherence Score: 0.6061261761116337
# Topic 8: Coherence Score: 0.6528843252746699
# Topic 9: Coherence Score: 0.5942455799010785
# Topic 10: Coherence Score: 0.6150541191028925
# Topic 11: Coherence Score: 0.6687805530825827
# Topic 12: Coherence Score: 0.697434974884389
