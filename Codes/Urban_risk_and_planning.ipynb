# %%
pip install PyMuPDF

# %%
pip install BERTopic

# %%
import os
import fitz
import nltk
import re
import string
import gensim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pprint


# For tokenization
from nltk.tokenize import word_tokenize
nltk.download("punkt")
nltk.download('wordnet')

# For removing stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')

# For lemmatization
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')

# For TF-IDC
from gensim import corpora
from gensim.models import TfidfModel

# For N-grams
from collections import defaultdict
from nltk.util import ngrams as nltk_ngrams
from nltk.tokenize import word_tokenize

# For BERT topic
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# For coherence score
from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# ### Get text from PDFs

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as pdf:
        for page_num in range(len(pdf)):
            page = pdf.load_page(page_num)
            text += page.get_text()
    return text

# %% [markdown]
# ### Preprocess and vectorize text

# %% [markdown]
# *Preprocess pipeline*

# %%
# Loading WordNet POS tags for lemmatization
def wordnet_pos_tags(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def txt_preprocess_pipeline(text):

    # Removing multiple white spaces and line breaks
    clean_txt = re.sub(r'\n', ' ', text)
    clean_txt = re.sub(r'\s+', ' ', clean_txt)
    clean_txt = clean_txt.strip()

    # Tokenizing text
    tokens = nltk.word_tokenize(clean_txt)

    # Loading NLTK stopword list and adding original stopwords
    stop_words = set(stopwords.words('english')+['na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health','heat','temperature','change','risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])

    # Adding custom stopwords directly to the set
    custom_stopwords = set(['na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health', 'heat', 'temperature', 'change', 'risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])
    stop_words.update(custom_stopwords)

    # Standardize the text and removing non-alphabetic or stop words
    words = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

    # Defining lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Conducting POS tagging
    pos_tags = nltk.pos_tag(words)

    # Lemmatizing word-tokens via assigned POS tags
    lemma_tokens = [lemmatizer.lemmatize(token, wordnet_pos_tags(pos_tag)) for token, pos_tag in pos_tags]

    return lemma_tokens

# %% [markdown]
# *Iteration function*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def iterate_pdf_files(pdf_folder):
    # Creating a dictionary to display all documents and tokens together
    docs = {}

    # Counting to track the number of processed texts
    text_count = 0

    # Iterating over each file in the folder
    for filename in os.listdir(pdf_folder):

        # Checking whether the files are PDFs
        if filename.endswith('.pdf'):

            # Creating a path to the PDF files
            pdf_path = os.path.join(pdf_folder, filename)

            # Extracting the content of files
            text = extract_text_from_pdf(pdf_path)

            # Applying the preprocessing pipeline to the extracted tex
            preprocessed_text = txt_preprocess_pipeline(text)

            # Generating a unique name for the document based on the length of the docs dictionary for ease in readibility
            doc_name = f'doc{len(docs) + 1}'

            # Assigning the preprocessed text content of the current document in the docs dictionary with the document name as the key
            docs[doc_name] = [preprocessed_text]

            # Increasing the text count when finished assigning
            text_count += 1

    return docs

pdf_folder = '/content/drive/MyDrive/Documents/urban'

# Calling the iterate_pdf_files function to get the dictionary of documents
docs = iterate_pdf_files(pdf_folder)

# Printing each document's tokens as a list
for doc_name, tokens in docs.items():
    print(f"{doc_name}: {tokens}")

# %% [markdown]
# *Token dictionary*

# %%
# Iterating over the values in the docs dictionary created in the previous step. Each value in the sublist represents the tokens in a certain document
all_preprocessed_text = [token for sublist in docs.values() for token in sublist]

# Creating a gensim dictionary to assign an integer ID to each token
dictionary = corpora.Dictionary(all_preprocessed_text)
print(dictionary)

# %% [markdown]
# *BoW representation*

# %%
# Creating a Bag-of-Words (BoW) representation of the preprocessed text data using the dictionary created in the previous step
bow_corpus = [dictionary.doc2bow(text) for text in all_preprocessed_text]
pprint.pprint(bow_corpus)

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(bow_corpus))

# %% [markdown]
# ### TF-IDF

# %%
# Creating a TF-IDF model from the Bag-of-Words corpus
tfidf_model = TfidfModel(bow_corpus)

# Applying the TF-IDF model to the Bag-of-Words corpus to get the TF-IDF representation
tfidf_corpus = tfidf_model[bow_corpus]

# Printing the TF-IDF representation for the first few documents
for doc in tfidf_corpus[:5]:
    print(doc)

# %%
# Looking up the word corresponding to word_id = 0
word_id = 5
word = dictionary[word_id]
print("Word corresponding to word_id =", word_id, ":", word)

# %%
# Defining the TF-IDF threshold
threshold = 0.05

# Iterating through the TF-IDF representation of the documents
for doc in tfidf_corpus[:5]:  # Iterating over the first few documents

    # Filtering words with TF-IDF scores above the threshold
    words_above_threshold = [(dictionary[word_id], tfidf_score) for word_id, tfidf_score in doc if tfidf_score > threshold]

    # Printing the words with TF-IDF scores above the threshold
    print("Words with TF-IDF score > 0.05:", words_above_threshold)
# Out:
# Words with TF-IDF score > 0.05: [('albedo', 0.08906430587592756), ('ambient', 0.07929650788008907), ('cdhs', 0.14400377824244195), ('citybes', 0.09423535706453677), ('climatic', 0.051926166576292725), ('composite', 0.050314451937933866), ('cool', 0.051353785807703764), ('daytime', 0.06287651214602896), ('decrease', 0.07529930573762746), ('eight', 0.07162548068739372), ('greenery', 0.1029902455995029), ('gwh', 0.06554380756805411), ('irrigate', 0.17327041771993873), ('irrigated', 0.09831571135208118), ('kwh', 0.09082338898713427), ('load', 0.09927743891183959), ('lst', 0.054754638809700246), ('masiaf', 0.09600251882829462), ('mesoscale', 0.09082338898713427), ('mitigation', 0.07253257535471588), ('miɵgaɵon', 0.12800335843772617), ('overheat', 0.05504649652282836), ('photonic', 0.06400167921886309), ('plementary', 0.05384877546544958), ('precinct', 0.05053420843640615), ('qcomb', 0.06400167921886309), ('qmit', 0.06400167921886309), ('radiative', 0.07042545734804272), ('ref', 0.06708593591724515), ('reflective', 0.10614890734484841), ('retrofit', 0.06290305620435462), ('riyadh', 0.7537537870326223), ('santamouris', 0.0813347552538599), ('scenario', 0.05544179996630066), ('sensible', 0.05069194228025413), ('simulation', 0.06462186995422818), ('simulaɵons', 0.12800335843772617), ('supplementary', 0.13903769780494074), ('vegetaɵon', 0.09600251882829462)]
# Words with TF-IDF score > 0.05: [('dataset', 0.05264241655831463), ('datasets', 0.05551426705635108), ('layer', 0.05412874154993304), ('overheat', 0.12336100801628415), ('property', 0.3842293633190632), ('school', 0.06480062567217357), ('socioeconomic', 0.12178966848734935), ('vulnerability', 0.05099943697521045), ('vulnerable', 0.08527372971975426), ('appendix', 0.050065895543199894), ('arup', 0.056206733190939634), ('beis', 0.05456571018941749), ('borough', 0.06485392291262265), ('care', 0.10378076407210599), ('crime', 0.07726147185663887), ('deprivation', 0.32426961456311326), ('epc', 0.35857466695902923), ('ethnicity', 0.0633105491232996), ('geospatial', 0.07409839691314653), ('gla', 0.22533139522267595), ('glaze', 0.11036639766008619), ('home', 0.05465030827967696), ('hospital', 0.10901287425711602), ('idaci', 0.062360811645048565), ('informative', 0.0505845989275395), ('laei', 0.062360811645048565), ('london', 0.27262942649290045), ('lsoa', 0.27282855094708747), ('metadata', 0.07878178928794245), ('neighbourhood', 0.06129035499902221), ('noise', 0.09685916800611287), ('occupant', 0.09484594804882755), ('openable', 0.05902673270826719), ('os', 0.09336280802656846), ('overcrowd', 0.06438039863505027), ('pp', 0.06099891989968742), ('pupil', 0.05456571018941749), ('score', 0.08128874818965694), ('suews', 0.09181936199063785), ('tabul', 0.062360811645048565), ('tabular', 0.062360811645048565), ('tightness', 0.05246820685179306), ('trust', 0.0686198977011108), ('ward', 0.05017489685813576), ('weighting', 0.06418693051826582), ('yes', 0.08112029708946825)]
# Words with TF-IDF score > 0.05: [('atmospheric', 0.052180989954597946), ('canopy', 0.08297571522058646), ('flux', 0.08142058555623453), ('height', 0.05339331814706341), ('influence', 0.06541903714213756), ('layer', 0.09895917326391734), ('measurement', 0.10253369246426511), ('mesoscale', 0.08145574799373602), ('meteorological', 0.0994190552784157), ('model', 0.05593247924872087), ('observation', 0.0748060107785853), ('rural', 0.0846389956085278), ('section', 0.10320449083334496), ('simulation', 0.053719853595701944), ('station', 0.052223064128446336), ('surface', 0.05306081047946525), ('surroundings', 0.09555279247037991), ('grimmond', 0.06402620247458787), ('guidance', 0.10510257261274285), ('metadata', 0.1687855479106433), ('monitoring', 0.08453957096351038), ('orm', 0.054956087545682354), ('site', 0.07954048425526782), ('ucl', 0.16503475795707345), ('agl', 0.09500766425492037), ('baklanov', 0.07125574819119027), ('chapter', 0.23895652340500445), ('characterization', 0.06179401571938594), ('crowdsourcing', 0.06001263925711762), ('facet', 0.06891862732489257), ('hydrometeorological', 0.07706642143678813), ('instrument', 0.09765426541482064), ('isl', 0.08906968523898784), ('ius', 0.10094564327085288), ('lcz', 0.11351303324099951), ('meteorology', 0.06314400462822611), ('microscale', 0.23054723523793438), ('nwp', 0.06494810346307914), ('orms', 0.11282160130271794), ('phenology', 0.057784872774873), ('representativeness', 0.056756516620499756), ('roughness', 0.10158755553031162), ('rsl', 0.08313170622305532), ('schlünzen', 0.10094564327085288), ('sensor', 0.15595305572809226), ('sit', 0.056667696461228566), ('sublayer', 0.05937979015932523), ('subsection', 0.39468462873717325), ('synoptic', 0.052696510911527855), ('traverse', 0.05955132565569992), ('ubl', 0.08493213529787273), ('ucp', 0.06081055352196403), ('wmo', 0.21078604364611142)]
# Words with TF-IDF score > 0.05: [('step', 0.05396806959101797), ('action', 0.05997721781408442), ('actor', 0.14096394883127122), ('assumption', 0.05068507378507842), ('cross', 0.21863947679787432), ('team', 0.10753088914015498), ('forecast', 0.06036214761766529), ('german', 0.1085114436885429), ('hydrometeorological', 0.07347492428878624), ('nam', 0.4283020991395971), ('trigger', 0.0628441737969881), ('activation', 0.12434577071794756), ('anticipation', 0.06802590362552412), ('anticipatory', 0.27210361450209647), ('eap', 0.1257479757231672), ('fbf', 0.1743666120093896), ('finance', 0.0655918430393623), ('financing', 0.17756418058125203), ('hanoi', 0.3304217822973169), ('ifrc', 0.10203885543828617), ('imhen', 0.1743666120093896), ('nchmf', 0.09963806400536548), ('preventionweb', 0.0747285480040241), ('ready', 0.06130477248567279), ('tent', 0.07347492428878624), ('viet', 0.4877654881531821)]
# Words with TF-IDF score > 0.05: [('asian', 0.09659524871937591), ('productivity', 0.064371846939717), ('roof', 0.0768514715681424), ('settlement', 0.12228382698373619), ('south', 0.23066889260869794), ('child', 0.10139177371169938), ('indoor', 0.06822806202343508), ('learn', 0.05440986403570738), ('policymaking', 0.06587985160273914), ('worker', 0.11648385923166779), ('asia', 0.4334009311692615), ('informal', 0.30144164284878827), ('ahmedabad', 0.14394533059719117), ('amirtham', 0.10429620992705593), ('authorize', 0.06245837261222724), ('bank', 0.07917901627130738), ('bengaluru', 0.05265071097013502), ('bussolo', 0.06257772595623355), ('cognitive', 0.05466113499656324), ('disclosure', 0.05696492797871531), ('dodman', 0.15795213291040505), ('ghosh', 0.06245837261222724), ('gupta', 0.06559336199587588), ('informality', 0.07020094796018003), ('kotharkar', 0.05265071097013502), ('labor', 0.07483111485820221), ('muhammad', 0.07807296576528404), ('neha', 0.05265071097013502), ('pakistan', 0.09332949888632189), ('rajan', 0.08775118495022503), ('rallapalli', 0.06257772595623355), ('sharma', 0.0809878336718972), ('sheher', 0.06257772595623355), ('stanberry', 0.06257772595623355), ('tasgaonkar', 0.10429620992705593), ('venugopal', 0.08775118495022503), ('workplace', 0.07623222003946468), ('yadav', 0.08343696794164475)]

# %% [markdown]
# ### N-grams

# %%
# Taking a list of tokens as input and generating n-grams
def generate_ngrams(tokens, n=3):
    return list(nltk_ngrams(tokens, n))

# Creating n-gram model from a corpus
def create_ngram_model(corpus, n=3):
    ngram_model = defaultdict(int)
    for text in corpus:
        tokens = word_tokenize(text)
        ngrams = generate_ngrams(tokens, n)
        for ngram in ngrams:
            ngram_model[ngram] += 1
    return ngram_model

max_texts_to_process = None
docs = iterate_pdf_files(pdf_folder)

# Concatenating preprocessed tokens for each document into a single list of tokens
corpus_tokens = [tokens for sublist in docs.values() for tokens in sublist]

# Concatenating tokens into a single string for each document
corpus_strings = [' '.join(tokens) for tokens in corpus_tokens]

# Creating an n-gram model
ngram_model = create_ngram_model(corpus_strings, n=3)

# Printing all n-grams
print("All N-grams:")
for ngram, frequency in ngram_model.items():
    print(ngram, ":", frequency)

# %%
# Filtering n-grams with frequency greater than 1
filtered_ngram_model = {ngram: frequency for ngram, frequency in ngram_model.items() if frequency > 1}

# Printing filtered n-grams
print("Filtered N-grams:")
for ngram, frequency in filtered_ngram_model.items():
    print(ngram, ":", frequency)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('resilience', 'london', 'partnership') : 4
# ('london', 'partnership', 'identify') : 2
# ('partnership', 'identify', 'prioritise') : 2
# ('identify', 'prioritise', 'critical') : 2
# ('prioritise', 'critical', 'infrastructure') : 2
# ('critical', 'infrastructure', 'vulnerable') : 2
# ('infrastructure', 'vulnerable', 'community') : 2
# ('vulnerable', 'community', 'flood') : 3
# ('community', 'flood', 'reduce') : 2
# ('flood', 'reduce', 'local') : 2
# ('reduce', 'local', 'surface') : 2
# ('local', 'surface', 'water') : 2
# ('water', 'flood', 'mayor') : 2
# ('transport', 'london', 'tfl') : 2
# ('thames', 'water', 'review') : 2
# ('water', 'review', 'drain') : 2
# ('review', 'drain', 'gully') : 2
# ('drain', 'gully', 'maintenance') : 3
# ('gully', 'maintenance', 'programme') : 3
# ('maintenance', 'programme', 'particularly') : 2
# ('programme', 'particularly', 'area') : 2
# ('particularly', 'area', 'order') : 2
# ('area', 'order', 'capacity') : 2
# ('order', 'capacity', 'cope') : 2
# ('recover', 'flood', 'seek') : 2
# ('flood', 'seek', 'raise') : 2
# ('seek', 'raise', 'individual') : 2
# ('raise', 'individual', 'awareness') : 3
# ('individual', 'awareness', 'flood') : 2
# ('awareness', 'flood', 'mayor') : 2
# ('environment', 'agency', 'number') : 3
# ('agency', 'number', 'londoner') : 2
# ('number', 'londoner', 'sign') : 2
# ('londoner', 'sign', 'floodline') : 2
# ('sign', 'floodline', 'warn') : 3
# ('floodline', 'warn', 'direct') : 5
# ('warn', 'direct', 'scheme') : 2
# ('direct', 'scheme', 'raise') : 2
# ('scheme', 'raise', 'awareness') : 2
# ('awareness', 'measure', 'individual') : 2
# ('measure', 'individual', 'community') : 2
# ('individual', 'community', 'undertake') : 2
# ('community', 'undertake', 'reduce') : 2
# ('undertake', 'reduce', 'risk') : 2
# ('reduce', 'risk', 'manage') : 2
# ('risk', 'manage', 'consequence') : 2
# ('manage', 'consequence', 'flood') : 2
# ('approach', 'manage', 'flood') : 2
# ('flood', 'drain', 'london') : 3
# ('drain', 'london', 'identify') : 2
# ('london', 'identify', 'two') : 2
# ('identify', 'two', 'community') : 2
# ('two', 'community', 'significant') : 2
# ('community', 'significant', 'flood') : 2
# ('significant', 'flood', 'work') : 2
# ('flood', 'work', 'develop') : 2
# ('work', 'develop', 'bespoke') : 2
# ('develop', 'bespoke', 'community') : 2
# ('bespoke', 'community', 'flood') : 3
# ('community', 'flood', 'plan') : 8
# ('flood', 'plan', 'build') : 2
# ('plan', 'build', 'capacity') : 3
# ('build', 'capacity', 'manage') : 2
# ('capacity', 'manage', 'flood') : 2
# ('year', 'sufficient', 'water') : 2
# ('sufficient', 'water', 'meet') : 3
# ('water', 'meet', 'demand') : 3
# ('water', 'environment', 'environment') : 2
# ('number', 'business', 'affect') : 2
# ('summary', 'assessment', 'mayor') : 2
# ('london', 'already', 'vulnerable') : 2
# ('increase', 'population', 'combine') : 2
# ('supply', 'demand', 'balance') : 3
# ('london', 'robust', 'drought') : 4
# ('drought', 'mayor', 'work') : 3
# ('partner', 'improve', 'sustainability') : 2
# ('improve', 'sustainability', 'london') : 2
# ('sustainability', 'london', 'water') : 2
# ('london', 'water', 'supply') : 3
# ('demand', 'balance', 'make') : 2
# ('balance', 'make', 'london') : 2
# ('make', 'london', 'robust') : 3
# ('robust', 'drought', 'take') : 2
# ('drought', 'take', 'strategic') : 2
# ('take', 'strategic', 'view') : 4
# ('strategic', 'view', 'london') : 4
# ('view', 'london', 'water') : 5
# ('resource', 'reduce', 'demand') : 2
# ('reduce', 'demand', 'water') : 4
# ('demand', 'water', 'london') : 4
# ('water', 'london', 'improve') : 2
# ('london', 'improve', 'response') : 2
# ('improve', 'response', 'drought') : 4
# ('response', 'drought', 'mayor') : 2
# ('water', 'resource', 'mayor') : 4
# ('resource', 'mayor', 'publish') : 2
# ('mayor', 'publish', 'regularly') : 2
# ('publish', 'regularly', 'review') : 2
# ('regularly', 'review', 'london') : 2
# ('review', 'london', 'water') : 2
# ('london', 'water', 'strategy') : 5
# ('water', 'strategy', 'present') : 2
# ('strategy', 'present', 'view') : 2
# ('present', 'view', 'manage') : 2
# ('view', 'manage', 'water') : 2
# ('manage', 'water', 'resource') : 2
# ('water', 'resource', 'goal') : 2
# ('resource', 'goal', 'improved') : 2
# ('goal', 'improved', 'water') : 2
# ('improved', 'water', 'water') : 2
# ('water', 'water', 'want') : 2
# ('water', 'want', 'drinking') : 2
# ('want', 'drinking', 'water') : 2
# ('drinking', 'water', 'water') : 2
# ('water', 'water', 'sewage') : 2
# ('water', 'sewage', 'floodwater') : 2
# ('sewage', 'floodwater', 'wrong') : 2
# ('floodwater', 'wrong', 'place') : 2
# ('wrong', 'place', 'london') : 2
# ('place', 'london', 'water') : 2
# ('london', 'water', 'group') : 4
# ('water', 'group', 'undertake') : 2
# ('group', 'undertake', 'define') : 2
# ('undertake', 'define', 'water') : 3
# ('define', 'water', 'neutrality') : 3
# ('water', 'neutrality', 'london') : 3
# ('neutrality', 'london', 'explore') : 2
# ('london', 'explore', 'strategic') : 2
# ('explore', 'strategic', 'scale') : 2
# ('measure', 'could', 'make') : 2
# ('could', 'make', 'london') : 2
# ('make', 'london', 'resilient') : 2
# ('london', 'resilient', 'drought') : 2
# ('resilient', 'drought', 'change') : 2
# ('drought', 'change', 'water') : 2
# ('change', 'water', 'resource') : 2
# ('resource', 'mayor', 'lobby') : 2
# ('mayor', 'lobby', 'water') : 2
# ('lobby', 'water', 'utility') : 3
# ('water', 'utility', 'regulator') : 3
# ('utility', 'regulator', 'ofwat') : 4
# ('regulator', 'ofwat', 'encourage') : 3
# ('ofwat', 'encourage', 'enable') : 4
# ('encourage', 'enable', 'water') : 3
# ('enable', 'water', 'company') : 3
# ('water', 'company', 'deliver') : 3
# ('company', 'deliver', 'great') : 3
# ('deliver', 'great', 'household') : 3
# ('great', 'household', 'water') : 3
# ('household', 'water', 'efficiency') : 3
# ('water', 'efficiency', 'saving') : 3
# ('efficiency', 'saving', 'great') : 3
# ('saving', 'great', 'investment') : 3
# ('great', 'investment', 'london') : 3
# ('investment', 'london', 'water') : 3
# ('london', 'water', 'infrastructure') : 3
# ('water', 'infrastructure', 'london') : 2
# ('infrastructure', 'london', 'must') : 2
# ('london', 'must', 'reduce') : 2
# ('must', 'reduce', 'amount') : 2
# ('reduce', 'amount', 'water') : 5
# ('amount', 'water', 'consumes') : 2
# ('water', 'consumes', 'reduce') : 2
# ('consumes', 'reduce', 'environment') : 2
# ('reduce', 'environment', 'demand') : 2
# ('environment', 'demand', 'water') : 3
# ('demand', 'water', 'improve') : 3
# ('water', 'improve', 'resilience') : 2
# ('improve', 'resilience', 'drought') : 2
# ('resilience', 'drought', 'mayor') : 2
# ('work', 'boroughs', 'home') : 2
# ('boroughs', 'home', 'energy') : 2
# ('efficiency', 'programme', 'improve') : 2
# ('programme', 'improve', 'energy') : 2
# ('improve', 'energy', 'water') : 5
# ('water', 'efficiency', 'million') : 3
# ('efficiency', 'million', 'home') : 3
# ('million', 'home', 'london') : 2
# ('home', 'london', 'business') : 2
# ('london', 'business', 'gla') : 2
# ('business', 'gla', 'estate') : 2
# ('gla', 'estate', 'manager') : 3
# ('estate', 'manager', 'improve') : 2
# ('manager', 'improve', 'energy') : 2
# ('water', 'efficiency', 'commercial') : 2
# ('efficiency', 'commercial', 'building') : 2
# ('commercial', 'building', 'london') : 2
# ('water', 'company', 'responses') : 2
# ('company', 'responses', 'drought') : 2
# ('responses', 'drought', 'emergency') : 2
# ('drought', 'emergency', 'drought') : 2
# ('drought', 'mayor', 'recommend') : 2
# ('mayor', 'recommend', 'london') : 5
# ('recommend', 'london', 'resilience') : 5
# ('resilience', 'partnership', 'review') : 2
# ('partnership', 'review', 'need') : 2
# ('review', 'need', 'drought') : 5
# ('increase', 'average', 'summer') : 2
# ('summer', 'temperature', 'mean') : 2
# ('large', 'proportion', 'london') : 2
# ('proportion', 'london', 'population') : 4
# ('live', 'poor', 'quality') : 2
# ('significant', 'proportion', 'london') : 3
# ('london', 'development', 'infrastructure') : 2
# ('vision', 'make', 'london') : 2
# ('make', 'london', 'comfortable') : 2
# ('london', 'comfortable', 'live') : 2
# ('work', 'play', 'ensure') : 2
# ('play', 'ensure', 'robust') : 2
# ('ensure', 'robust', 'emergency') : 2
# ('robust', 'emergency', 'exist') : 2
# ('emergency', 'exist', 'heatwaves') : 2
# ('mayor', 'seek', 'reduce') : 2
# ('seek', 'reduce', 'manage') : 2
# ('reduce', 'manage', 'hot') : 2
# ('manage', 'hot', 'weather') : 2
# ('hot', 'weather', 'londoner') : 2
# ('weather', 'londoner', 'work') : 2
# ('londoner', 'work', 'partner') : 2
# ('improve', 'understand', 'overheat') : 5
# ('understand', 'overheat', 'london') : 2
# ('overheat', 'london', 'identifying') : 2
# ('london', 'identifying', 'affect') : 2
# ('identifying', 'affect', 'manage') : 2
# ('affect', 'manage', 'rise') : 2
# ('manage', 'rise', 'temperature') : 4
# ('rise', 'temperature', 'london') : 5
# ('temperature', 'london', 'increase') : 2
# ('london', 'increase', 'amount') : 2
# ('increase', 'amount', 'green') : 2
# ('space', 'vegetation', 'reduce') : 2
# ('vegetation', 'reduce', 'overheat') : 2
# ('reduce', 'overheat', 'need') : 3
# ('overheat', 'need', 'mechanical') : 5
# ('mechanical', 'cool', 'new') : 4
# ('cool', 'new', 'exist') : 4
# ('new', 'exist', 'development') : 4
# ('exist', 'development', 'infrastructure') : 5
# ('development', 'infrastructure', 'ensure') : 2
# ('infrastructure', 'ensure', 'london') : 2
# ('ensure', 'london', 'robust') : 5
# ('london', 'robust', 'heatwave') : 5
# ('currently', 'poor', 'understand') : 2
# ('poor', 'understand', 'temperature') : 2
# ('understand', 'temperature', 'vary') : 2
# ('temperature', 'vary', 'london') : 3
# ('vary', 'london', 'microclimate') : 2
# ('london', 'microclimate', 'intensify') : 2
# ('microclimate', 'intensify', 'rise') : 2
# ('intensify', 'rise', 'temperature') : 2
# ('rise', 'temperature', 'future') : 2
# ('temperature', 'future', 'vulnerable') : 2
# ('future', 'vulnerable', 'temperature') : 2
# ('vulnerable', 'temperature', 'need') : 2
# ('temperature', 'need', 'improve') : 2
# ('need', 'improve', 'understand') : 2
# ('understand', 'overheat', 'target') : 3
# ('overheat', 'target', 'priority') : 3
# ('priority', 'area', 'mayor') : 2
# ('area', 'mayor', 'work') : 3
# ('work', 'partner', 'undertake') : 2
# ('partner', 'undertake', 'feasibility') : 2
# ('undertake', 'feasibility', 'create') : 2
# ('feasibility', 'create', 'maintain') : 2
# ('create', 'maintain', 'network') : 2
# ('maintain', 'network', 'weather') : 2
# ('weather', 'station', 'london') : 2
# ('station', 'london', 'improve') : 2
# ('improve', 'understand', 'london') : 2
# ('understand', 'london', 'microclimate') : 2
# ('london', 'microclimate', 'green') : 2
# ('microclimate', 'green', 'measure') : 2
# ('green', 'measure', 'manage') : 2
# ('measure', 'manage', 'temperature') : 2
# ('strategy', 'london', 'mayor') : 4
# ('sustainable', 'city', 'option') : 3
# ('city', 'option', 'respond') : 3
# ('option', 'respond', 'impact') : 3
# ('respond', 'impact', 'outcomes') : 3
# ('impact', 'outcomes', 'scorchio') : 2
# ('development', 'city', 'lucid') : 2
# ('lucid', 'project', 'improve') : 2
# ('project', 'improve', 'understand') : 3
# ('improve', 'understand', 'affect') : 3
# ('understand', 'affect', 'summer') : 2
# ('affect', 'summer', 'temperatures') : 2
# ('summer', 'temperatures', 'future') : 2
# ('temperatures', 'future', 'identify') : 2
# ('future', 'identify', 'prioritise') : 3
# ('identify', 'prioritise', 'area') : 3
# ('prioritise', 'area', 'overheat') : 3
# ('area', 'overheat', 'option') : 3
# ('overheat', 'option', 'believe') : 2
# ('option', 'believe', 'increase') : 2
# ('believe', 'increase', 'green') : 2
# ('vegetation', 'cover', 'manage') : 2
# ('cover', 'manage', 'offset') : 2
# ('manage', 'offset', 'rise') : 2
# ('offset', 'rise', 'temperature') : 2
# ('rise', 'temperature', 'manage') : 2
# ('temperature', 'manage', 'flood') : 2
# ('manage', 'flood', 'mayor') : 2
# ('work', 'partner', 'enhance') : 2
# ('green', 'space', 'offset') : 2
# ('space', 'offset', 'island') : 2
# ('offset', 'island', 'manage') : 2
# ('island', 'manage', 'flood') : 2
# ('manage', 'flood', 'provide') : 2
# ('flood', 'provide', 'biodiversity') : 2
# ('provide', 'biodiversity', 'corridor') : 2
# ('work', 'partner', 'green') : 2
# ('partner', 'green', 'cover') : 2
# ('green', 'cover', 'central') : 3
# ('cover', 'central', 'london') : 2
# ('manage', 'temperature', 'hottest') : 2
# ('temperature', 'hottest', 'london') : 2
# ('hottest', 'london', 'mayor') : 2
# ('work', 'partner', 'tree') : 2
# ('partner', 'tree', 'cover') : 2
# ('tree', 'cover', 'london') : 2
# ('work', 'partner', 'enable') : 2
# ('partner', 'enable', 'delivery') : 2
# ('enable', 'delivery', 'new') : 3
# ('delivery', 'new', 'green') : 3
# ('green', 'roof', 'baseline') : 2
# ('roof', 'baseline', 'need') : 2
# ('baseline', 'need', 'reduce') : 2
# ('need', 'reduce', 'overheat') : 2
# ('reduce', 'overheat', 'demand') : 2
# ('overheat', 'demand', 'mechanical') : 2
# ('demand', 'mechanical', 'cool') : 2
# ('development', 'infrastructure', 'mayor') : 2
# ('infrastructure', 'mayor', 'charter') : 2
# ('mayor', 'charter', 'institution') : 2
# ('service', 'engineer', 'publish') : 2
# ('engineer', 'publish', 'design') : 2
# ('publish', 'design', 'guidance') : 2
# ('design', 'guidance', 'architects') : 2
# ('guidance', 'architects', 'developer') : 2
# ('architects', 'developer', 'reduce') : 2
# ('developer', 'reduce', 'overheat') : 3
# ('reduce', 'overheat', 'encourage') : 2
# ('overheat', 'encourage', 'revise') : 2
# ('encourage', 'revise', 'london') : 2
# ('revise', 'london', 'mayor') : 2
# ('london', 'mayor', 'propose') : 2
# ('mayor', 'propose', 'new') : 2
# ('propose', 'new', 'cool') : 2
# ('new', 'cool', 'hierarchy') : 3
# ('cool', 'hierarchy', 'policy') : 4
# ('hierarchy', 'policy', 'draft') : 2
# ('policy', 'draft', 'london') : 2
# ('draft', 'london', 'require') : 2
# ('london', 'require', 'developer') : 3
# ('require', 'developer', 'reduce') : 2
# ('developer', 'reduce', 'potential') : 2
# ('reduce', 'potential', 'overheat') : 2
# ('potential', 'overheat', 'need') : 2
# ('mechanical', 'cool', 'london') : 2
# ('cool', 'london', 'development') : 3
# ('work', 'borough', 'map') : 2
# ('borough', 'map', 'opportunity') : 2
# ('map', 'opportunity', 'decentralise') : 3
# ('opportunity', 'decentralise', 'energy') : 2
# ('decentralise', 'energy', 'power') : 2
# ('energy', 'power', 'cool') : 2
# ('programme', 'london', 'partnership') : 2
# ('london', 'partnership', 'work') : 4
# ('partnership', 'work', 'social') : 2
# ('work', 'social', 'housing') : 2
# ('social', 'housing', 'landlord') : 2
# ('housing', 'landlord', 'undertake') : 2
# ('landlord', 'undertake', 'demonstration') : 2
# ('demonstration', 'project', 'retrofit') : 2
# ('project', 'retrofit', 'social') : 2
# ('retrofit', 'social', 'housing') : 3
# ('social', 'housing', 'development') : 3
# ('housing', 'development', 'reduce') : 3
# ('development', 'reduce', 'overheat') : 3
# ('reduce', 'overheat', 'use') : 2
# ('overheat', 'use', 'passive') : 2
# ('passive', 'measure', 'mayor') : 2
# ('measure', 'mayor', 'work') : 2
# ('work', 'partner', 'assess') : 2
# ('partner', 'assess', 'promote') : 2
# ('assess', 'promote', 'cool') : 3
# ('promote', 'cool', 'roof') : 3
# ('cool', 'roof', 'technology') : 3
# ('roof', 'technology', 'highly') : 2
# ('technology', 'highly', 'reflective') : 2
# ('reflective', 'roof', 'london') : 2
# ('roof', 'london', 'reduce') : 2
# ('london', 'reduce', 'demand') : 3
# ('reduce', 'demand', 'mechanical') : 2
# ('mechanical', 'cooling', 'want') : 2
# ('cooling', 'want', 'ensure') : 2
# ('want', 'ensure', 'london') : 2
# ('robust', 'heatwave', 'londoner') : 2
# ('heatwave', 'londoner', 'know') : 2
# ('londoner', 'know', 'heatwave') : 2
# ('know', 'heatwave', 'stay') : 2
# ('heatwave', 'stay', 'cool') : 2
# ('stay', 'cool', 'save') : 2
# ('save', 'energy', 'mayor') : 2
# ('energy', 'mayor', 'recommend') : 2
# ('resilience', 'partnership', 'assess') : 2
# ('partnership', 'assess', 'benefit') : 2
# ('assess', 'benefit', 'heatwave') : 2
# ('benefit', 'heatwave', 'refuge') : 3
# ('heatwave', 'refuge', 'publicly') : 2
# ('refuge', 'publicly', 'accessible') : 2
# ('accessible', 'cool', 'building') : 2
# ('cool', 'building', 'use') : 2
# ('building', 'use', 'provide') : 2
# ('use', 'provide', 'temporary') : 2
# ('provide', 'temporary', 'shelter') : 2
# ('temporary', 'shelter', 'heatwaves') : 2
# ('shelter', 'heatwaves', 'mayor') : 2
# ('heatwaves', 'mayor', 'review') : 2
# ('mayor', 'review', 'lesson') : 2
# ('review', 'lesson', 'learn') : 2
# ('lesson', 'learn', 'develop') : 2
# ('learn', 'develop', 'community') : 2
# ('develop', 'community', 'flood') : 3
# ('flood', 'plan', 'see') : 2
# ('plan', 'see', 'determine') : 2
# ('see', 'determine', 'best') : 2
# ('determine', 'best', 'encourage') : 3
# ('best', 'encourage', 'enable') : 3
# ('encourage', 'enable', 'response') : 3
# ('enable', 'response', 'heatwaves') : 3
# ('flood', 'drought', 'heatwaves') : 2
# ('issue', 'environment', 'economy') : 2
# ('environment', 'economy', 'infrastructure') : 2
# ('economy', 'infrastructure', 'purpose') : 2
# ('issue', 'analysis', 'early') : 2
# ('analysis', 'early', 'stage') : 2
# ('early', 'stage', 'therefore') : 2
# ('stage', 'therefore', 'work') : 2
# ('therefore', 'work', 'required') : 2
# ('work', 'required', 'understand') : 2
# ('required', 'understand', 'challenge') : 2
# ('understand', 'challenge', 'relevant') : 2
# ('challenge', 'relevant', 'action') : 2
# ('relevant', 'action', 'detail') : 2
# ('partnership', 'work', 'london') : 2
# ('work', 'london', 'regional') : 4
# ('london', 'regional', 'group') : 4
# ('regional', 'group', 'undertake') : 2
# ('group', 'undertake', 'assessment') : 2
# ('undertake', 'assessment', 'impact') : 3
# ('assessment', 'impact', 'opportunities') : 2
# ('impact', 'opportunities', 'london') : 2
# ('opportunities', 'london', 'service') : 2
# ('london', 'service', 'provide') : 2
# ('service', 'provide', 'recommendation') : 2
# ('provide', 'recommendation', 'sector') : 2
# ('recommendation', 'sector', 'priority') : 2
# ('sector', 'priority', 'risk') : 2
# ('priority', 'risk', 'opportunity') : 2
# ('risk', 'opportunity', 'mayor') : 2
# ('opportunity', 'mayor', 'work') : 2
# ('regional', 'group', 'london') : 4
# ('group', 'london', 'london') : 2
# ('london', 'london', 'primary') : 2
# ('london', 'primary', 'care') : 2
# ('primary', 'care', 'trust') : 5
# ('care', 'trust', 'ensure') : 2
# ('trust', 'ensure', 'risk') : 2
# ('ensure', 'risk', 'addressed') : 3
# ('risk', 'addressed', 'refurbishment') : 2
# ('addressed', 'refurbishment', 'programme') : 2
# ('refurbishment', 'programme', 'commissioning') : 2
# ('programme', 'commissioning', 'service') : 2
# ('commissioning', 'service', 'mayor') : 2
# ('service', 'mayor', 'work') : 2
# ('environment', 'agency', 'partner') : 2
# ('agency', 'partner', 'restore') : 2
# ('london', 'river', 'london') : 3
# ('river', 'london', 'river') : 2
# ('mayor', 'engage', 'business') : 2
# ('engage', 'business', 'organisation') : 3
# ('business', 'organisation', 'key') : 3
# ('organisation', 'key', 'stakeholder') : 3
# ('key', 'stakeholder', 'consider') : 2
# ('stakeholder', 'consider', 'raise') : 2
# ('consider', 'raise', 'awareness') : 2
# ('raise', 'awareness', 'need') : 2
# ('awareness', 'need', 'integrate') : 2
# ('need', 'integrate', 'risk') : 2
# ('integrate', 'risk', 'opportunity') : 2
# ('risk', 'opportunity', 'routine') : 2
# ('opportunity', 'routine', 'plan') : 2
# ('routine', 'plan', 'whether') : 2
# ('plan', 'whether', 'practical') : 2
# ('whether', 'practical', 'assistance') : 2
# ('practical', 'assistance', 'give') : 2
# ('assistance', 'give', 'london') : 2
# ('give', 'london', 'business') : 2
# ('london', 'business', 'include') : 2
# ('business', 'include', 'smes') : 2
# ('include', 'smes', 'mayor') : 2
# ('smes', 'mayor', 'work') : 2
# ('mayor', 'work', 'insurance') : 2
# ('work', 'insurance', 'sector') : 2
# ('insurance', 'sector', 'call') : 2
# ('sector', 'call', 'government') : 2
# ('call', 'government', 'amend') : 2
# ('government', 'amend', 'building') : 4
# ('amend', 'building', 'regulation') : 4
# ('require', 'building', 'rebuild') : 3
# ('building', 'rebuild', 'renovate') : 3
# ('rebuild', 'renovate', 'resilient') : 3
# ('tfl', 'undertake', 'assessment') : 2
# ('undertake', 'assessment', 'asset') : 2
# ('assessment', 'asset', 'operation') : 2
# ('asset', 'operation', 'develop') : 3
# ('operation', 'develop', 'prioritise') : 3
# ('develop', 'prioritise', 'plan') : 3
# ('prioritise', 'plan', 'key') : 3
# ('plan', 'key', 'risk') : 3
# ('key', 'risk', 'mayor') : 2
# ('risk', 'mayor', 'believe') : 2
# ('london', 'resilient', 'energy') : 3
# ('energy', 'supply', 'work') : 3
# ('supply', 'work', 'distribution') : 3
# ('work', 'distribution', 'network') : 4
# ('distribution', 'network', 'operator') : 5
# ('network', 'operator', 'energy') : 4
# ('operator', 'energy', 'retailer') : 4
# ('energy', 'retailer', 'ensure') : 4
# ('retailer', 'ensure', 'distribution') : 4
# ('ensure', 'distribution', 'infrastructure') : 4
# ('distribution', 'infrastructure', 'resilient') : 4
# ('infrastructure', 'resilient', 'impact') : 4
# ('resilient', 'impact', 'energy') : 4
# ('impact', 'energy', 'supplier') : 4
# ('energy', 'supplier', 'meet') : 4
# ('supplier', 'meet', 'seasonal') : 4
# ('meet', 'seasonal', 'variation') : 4
# ('seasonal', 'variation', 'demand') : 4
# ('weather', 'event', 'heatwaves') : 2
# ('quality', 'life', 'london') : 2
# ('consequence', 'london', 'prepare') : 2
# ('london', 'mayor', 'must') : 2
# ('mitigation', 'energy', 'strategy') : 6
# ('prioritise', 'key', 'action') : 2
# ('infrastructure', 'locate', 'design') : 2
# ('experience', 'design', 'life') : 2
# ('improve', 'resilience', 'london') : 6
# ('challenge', 'opportunity', 'present') : 2
# ('london', 'mitigation', 'energy') : 3
# ('london', 'become', 'exemplar') : 3
# ('project', 'change', 'london') : 2
# ('issue', 'chapter', 'summarise') : 2
# ('london', 'economy', 'business') : 2
# ('infrastructure', 'transport', 'energy') : 2
# ('transport', 'energy', 'waste') : 2
# ('provide', 'acceptable', 'level') : 2
# ('acceptable', 'level', 'protection') : 2
# ('steady', 'state', 'adapt') : 2
# ('term', 'use', 'describe') : 2
# ('average', 'weather', 'variability') : 2
# ('weather', 'variability', 'long') : 2
# ('variability', 'long', 'period') : 2
# ('ground', 'floor', 'building') : 2
# ('example', 'air', 'condition') : 2
# ('use', 'prevent', 'prepare') : 2
# ('prevent', 'prepare', 'respond') : 2
# ('raise', 'flood', 'defence') : 2
# ('development', 'flood', 'plain') : 2
# ('understand', 'risk', 'opportunity') : 2
# ('asset', 'raise', 'awareness') : 2
# ('take', 'improve', 'resilience') : 2
# ('every', 'five', 'year') : 2
# ('london', 'draft', 'strategy') : 2
# ('key', 'risk', 'london') : 2
# ('private', 'sector', 'london') : 2
# ('every', 'year', 'last') : 2
# ('summer', 'get', 'progressively') : 2
# ('get', 'progressively', 'warm') : 2
# ('late', 'generation', 'projection') : 2
# ('uk', 'impact', 'programme') : 4
# ('provide', 'probabilistic', 'projection') : 2
# ('emission', 'scenario', 'medium') : 2
# ('weaken', 'gulf', 'stream') : 2
# ('block', 'weather', 'system') : 2
# ('century', 'medium', 'emission') : 3
# ('emission', 'scenario', 'compare') : 3
# ('scenario', 'compare', 'baseline') : 3
# ('century', 'figure', 'show') : 2
# ('summer', 'winter', 'temperature') : 3
# ('increase', 'seasonality', 'rainfall') : 2
# ('winter', 'warmer', 'average') : 2
# ('warmer', 'average', 'winter') : 2
# ('tidal', 'surge', 'tidal') : 2
# ('surge', 'tidal', 'surge') : 2
# ('tidal', 'surge', 'see') : 2
# ('height', 'tidal', 'surge') : 2
# ('change', 'average', 'summer') : 2
# ('london', 'century', 'compare') : 4
# ('century', 'compare', 'baseline') : 4
# ('compare', 'baseline', 'central') : 4
# ('baseline', 'central', 'medium') : 4
# ('central', 'medium', 'emission') : 4
# ('emission', 'scenario', 'change') : 3
# ('scenario', 'change', 'average') : 2
# ('rainfall', 'percentage', 'baseline') : 2
# ('percentage', 'baseline', 'london') : 2
# ('baseline', 'london', 'century') : 2
# ('emission', 'scenario', 'average') : 2
# ('london', 'century', 'medium') : 2
# ('ipcc', 'third', 'assessment') : 2
# ('association', 'british', 'insurer') : 5
# ('gla', 'london', 'borough') : 2
# ('flood', 'flood', 'defence') : 2
# ('london', 'flood', 'defence') : 2
# ('standard', 'protection', 'provide') : 3
# ('regionally', 'important', 'asset') : 2
# ('important', 'asset', 'flood') : 2
# ('work', 'require', 'develop') : 2
# ('flood', 'environment', 'agency') : 5
# ('environment', 'agency', 'produce') : 2
# ('agency', 'produce', 'catchment') : 2
# ('area', 'flood', 'today') : 2
# ('local', 'authority', 'require') : 3
# ('strategic', 'flood', 'assessment') : 3
# ('plan', 'local', 'authority') : 2
# ('borough', 'face', 'share') : 2
# ('environment', 'agency', 'flood') : 2
# ('floodline', 'warning', 'direct') : 3
# ('london', 'tidal', 'fluvial') : 2
# ('tidal', 'fluvial', 'flooding') : 6
# ('produce', 'flood', 'plan') : 2
# ('face', 'share', 'flood') : 2
# ('london', 'recovery', 'protocol') : 2
# ('follow', 'regional', 'emergency') : 2
# ('regional', 'emergency', 'protocol') : 2
# ('local', 'authority', 'basis') : 2
# ('authority', 'basis', 'local') : 2
# ('basis', 'local', 'recovery') : 2
# ('insurance', 'claim', 'process') : 2
# ('flood', 'resilient', 'design') : 2
# ('therefore', 'possible', 'prevent') : 2
# ('business', 'plan', 'ofwat') : 2
# ('water', 'company', 'invest') : 2
# ('help', 'reduce', 'need') : 2
# ('current', 'gap', 'adapt') : 3
# ('water', 'company', 'need') : 2
# ('community', 'individual', 'respond') : 2
# ('drought', 'desalination', 'plant') : 2
# ('requirement', 'government', 'body') : 2
# ('government', 'body', 'agency') : 2
# ('body', 'agency', 'produce') : 2
# ('agency', 'produce', 'drought') : 2
# ('hot', 'weather', 'building') : 2
# ('london', 'resilience', 'review') : 3
# ('resilience', 'review', 'need') : 3
# ('heatwave', 'relies', 'gps') : 2
# ('borough', 'social', 'service') : 4
# ('service', 'identify', 'vulnerable') : 2
# ('vulnerable', 'people', 'ensure') : 2
# ('person', 'vulnerability', 'vary') : 2
# ('vulnerable', 'people', 'consider') : 2
# ('people', 'consider', 'vulnerable') : 2
# ('fit', 'air', 'condition') : 2
# ('guidance', 'reduce', 'overheat') : 2
# ('gps', 'social', 'service') : 2
# ('chapter', 'flood', 'london') : 2
# ('vision', 'policy', 'policy') : 3
# ('policy', 'policy', 'mayor') : 3
# ('policy', 'mayor', 'work') : 2
# ('flood', 'source', 'flood') : 2
# ('association', 'london', 'borough') : 2
# ('area', 'london', 'flood') : 2
# ('tidal', 'flood', 'defence') : 4
# ('high', 'standard', 'flood') : 2
# ('standard', 'flood', 'protection') : 2
# ('freshwater', 'flow', 'thames') : 3
# ('thames', 'tidal', 'defence') : 6
# ('london', 'thames', 'estuary') : 2
# ('east', 'coast', 'uk') : 2
# ('tide', 'water', 'level') : 2
# ('thames', 'barrier', 'closure') : 2
# ('riverside', 'development', 'west') : 2
# ('development', 'west', 'london') : 2
# ('closure', 'thames', 'barrier') : 2
# ('thames', 'barrier', 'close') : 2
# ('flood', 'follow', 'section') : 2
# ('provide', 'flood', 'insurance') : 2
# ('area', 'surface', 'water') : 2
# ('flood', 'tidal', 'fluvial') : 3
# ('drainage', 'system', 'design') : 3
# ('system', 'design', 'frequency') : 2
# ('design', 'frequency', 'low') : 2
# ('frequency', 'low', 'rainfall') : 2
# ('water', 'flood', 'london') : 3
# ('dark', 'blue', 'area') : 2
# ('contamination', 'disease', 'flood') : 2
# ('disease', 'flood', 'sewer') : 2
# ('flood', 'sewer', 'water') : 2
# ('advance', 'warn', 'flood') : 2
# ('alone', 'support', 'network') : 2
# ('network', 'low', 'income') : 2
# ('less', 'likely', 'able') : 2
# ('advance', 'warn', 'time') : 2
# ('strategy', 'london', 'table') : 2
# ('predict', 'flood', 'occur') : 2
# ('environment', 'agency', 'meet') : 2
# ('agency', 'meet', 'office') : 2
# ('flood', 'warn', 'service') : 2
# ('river', 'level', 'environment') : 2
# ('level', 'environment', 'agency') : 3
# ('londoner', 'live', 'work') : 2
# ('environment', 'agency', 'plan') : 2
# ('awareness', 'prior', 'construction') : 2
# ('prior', 'construction', 'thames') : 2
# ('construction', 'thames', 'barrier') : 2
# ('regular', 'flood', 'drill') : 2
# ('flood', 'drill', 'hold') : 2
# ('environment', 'agency', 'estimate') : 2
# ('flood', 'insurance', 'flood') : 2
# ('live', 'social', 'housing') : 2
# ('key', 'social', 'civil') : 2
# ('social', 'civil', 'infrastructure') : 2
# ('station', 'ambulance', 'station') : 2
# ('gla', 'regional', 'flood') : 2
# ('prepare', 'respond', 'flood') : 2
# ('include', 'emergency', 'service') : 2
# ('defence', 'provide', 'high') : 2
# ('provide', 'high', 'standard') : 2
# ('sea', 'level', 'increase') : 2
# ('thames', 'barrier', 'associate') : 2
# ('strategic', 'flood', 'option') : 2
# ('reduce', 'consequence', 'flood') : 2
# ('water', 'level', 'rise') : 3
# ('improve', 'defence', 'maximise') : 2
# ('defence', 'maximise', 'storage') : 2
# ('maximise', 'storage', 'new') : 2
# ('storage', 'new', 'barrier') : 2
# ('new', 'barrier', 'provide') : 2
# ('barrier', 'provide', 'protection') : 2
# ('upstream', 'thames', 'barrier') : 2
# ('set', 'flood', 'defence') : 2
# ('thames', 'barrier', 'raise') : 4
# ('barrier', 'raise', 'defence') : 4
# ('improve', 'thames', 'barrier') : 2
# ('restore', 'interim', 'defence') : 2
# ('defence', 'flood', 'storage') : 3
# ('raise', 'defence', 'flood') : 3
# ('number', 'time', 'thames') : 3
# ('time', 'thames', 'barrier') : 3
# ('high', 'river', 'level') : 2
# ('thames', 'barrier', 'need') : 2
# ('barrier', 'need', 'close') : 2
# ('end', 'century', 'possible') : 2
# ('peak', 'river', 'flow') : 2
# ('property', 'flood', 'resilient') : 2
# ('flood', 'resilience', 'measure') : 2
# ('thames', 'catchment', 'flood') : 2
# ('cover', 'thames', 'tributary') : 2
# ('peak', 'river', 'level') : 2
# ('area', 'mayor', 'believe') : 3
# ('manage', 'surface', 'water') : 2
# ('london', 'borough', 'camden') : 2
# ('mayor', 'work', 'thames') : 2
# ('work', 'thames', 'water') : 3
# ('london', 'london', 'borough') : 3
# ('london', 'flood', 'response') : 2
# ('protection', 'provide', 'flood') : 2
# ('manage', 'local', 'emergency') : 2
# ('local', 'emergency', 'service') : 2
# ('affect', 'borough', 'resilience') : 2
# ('borough', 'resilience', 'partner') : 2
# ('london', 'emergency', 'service') : 2
# ('emergency', 'service', 'liaison') : 2
# ('service', 'liaison', 'panel') : 2
# ('borough', 'require', 'produce') : 2
# ('require', 'produce', 'flood') : 2
# ('consider', 'follow', 'issue') : 2
# ('balance', 'supply', 'demand') : 5
# ('supply', 'demand', 'water') : 4
# ('water', 'supply', 'need') : 2
# ('drought', 'measure', 'water') : 2
# ('thames', 'river', 'lee') : 2
# ('thames', 'catchment', 'lose') : 2
# ('catchment', 'lose', 'evaporation') : 2
# ('lose', 'evaporation', 'use') : 2
# ('evaporation', 'use', 'plant') : 2
# ('mean', 'amount', 'water') : 2
# ('rainfall', 'thames', 'catchment') : 2
# ('water', 'company', 'supply') : 4
# ('london', 'population', 'serve') : 2
# ('amount', 'water', 'supply') : 2
# ('ofwat', 'june', 'return') : 2
# ('sutton', 'east', 'surrey') : 4
# ('water', 'consume', 'device') : 2
# ('million', 'litre', 'day') : 2
# ('source', 'thames', 'water') : 2
# ('people', 'people', 'people') : 3
# ('london', 'build', 'clay') : 2
# ('build', 'clay', 'deposit') : 2
# ('clay', 'deposit', 'former') : 2
# ('deposit', 'former', 'floodplain') : 2
# ('water', 'company', 'apply') : 2
# ('water', 'company', 'must') : 4
# ('period', 'low', 'rainfall') : 2
# ('demand', 'plus', 'headroom') : 2
# ('abstraction', 'water', 'company') : 3
# ('abstract', 'water', 'environment') : 2
# ('london', 'catchment', 'abstraction') : 2
# ('emergency', 'drought', 'order') : 3
# ('main', 'replacement', 'programme') : 2
# ('drought', 'water', 'company') : 2
# ('year', 'thames', 'water') : 2
# ('demand', 'restriction', 'measure') : 2
# ('company', 'supply', 'london') : 2
# ('low', 'river', 'flow') : 2
# ('many', 'london', 'river') : 2
# ('sewage', 'treatment', 'work') : 3
# ('cut', 'standpipe', 'delivery') : 2
# ('affect', 'water', 'availability') : 2
# ('reduce', 'river', 'flow') : 2
# ('groundwater', 'replenishment', 'recharge') : 2
# ('water', 'efficiency', 'measure') : 3
# ('efficiency', 'measure', 'difficult') : 2
# ('mean', 'great', 'proportion') : 2
# ('london', 'experience', 'high') : 2
# ('seasonal', 'rainfall', 'cause') : 3
# ('however', 'warmer', 'winter') : 2
# ('amount', 'water', 'lose') : 2
# ('demand', 'water', 'increase') : 2
# ('hotter', 'drier', 'summer') : 2
# ('mayor', 'draft', 'water') : 4
# ('water', 'bill', 'meter') : 2
# ('concept', 'water', 'neutrality') : 2
# ('rise', 'demand', 'water') : 2
# ('total', 'water', 'wider') : 2
# ('water', 'wider', 'area') : 2
# ('draft', 'water', 'strategy') : 3
# ('improve', 'water', 'efficiency') : 5
# ('water', 'efficiency', 'standard') : 3
# ('change', 'consumer', 'behaviour') : 2
# ('water', 'strategy', 'propose') : 2
# ('efficiency', 'standard', 'litres') : 2
# ('standard', 'litres', 'person') : 2
# ('litres', 'person', 'day') : 2
# ('consultation', 'draft', 'replacement') : 2
# ('draft', 'replacement', 'london') : 2
# ('new', 'home', 'build') : 2
# ('home', 'water', 'efficient') : 2
# ('specie', 'require', 'little') : 2
# ('water', 'energy', 'efficiency') : 2
# ('mayor', 'work', 'borough') : 2
# ('drought', 'could', 'significantly') : 2
# ('water', 'reclaim', 'water') : 2
# ('major', 'new', 'development') : 2
# ('flood', 'water', 'enter') : 2
# ('artificial', 'groundwater', 'recharge') : 2
# ('water', 'environment', 'agency') : 2
# ('option', 'environment', 'agency') : 2
# ('essex', 'suffolk', 'water') : 3
# ('london', 'thames', 'water') : 2
# ('north', 'london', 'aquifer') : 2
# ('london', 'aquifer', 'recharge') : 2
# ('aquifer', 'recharge', 'scheme') : 2
# ('inject', 'aquifer', 'abstract') : 2
# ('rainfall', 'cause', 'great') : 2
# ('enhance', 'green', 'space') : 2
# ('melt', 'road', 'surface') : 2
# ('excess', 'death', 'august') : 2
# ('death', 'august', 'heatwave') : 2
# ('response', 'rise', 'temperature') : 2
# ('typical', 'profile', 'island') : 2
# ('day', 'hot', 'night') : 3
# ('increase', 'demand', 'cool') : 2
# ('response', 'high', 'temperature') : 2
# ('average', 'maximum', 'summer') : 2
# ('number', 'hour', 'intense') : 2
# ('hour', 'intense', 'island') : 2
# ('strategy', 'london', 'london') : 2
# ('reflect', 'incoming', 'solar') : 2
# ('design', 'building', 'infrastructure') : 2
# ('building', 'infrastructure', 'minimise') : 2
# ('overheat', 'hot', 'weather') : 3
# ('temperature', 'london', 'island') : 2
# ('protect', 'exist', 'green') : 2
# ('central', 'activity', 'zone') : 2
# ('mechanical', 'ventilation', 'cool') : 2
# ('ventilation', 'cool', 'system') : 3
# ('deciduous', 'street', 'tree') : 5
# ('incorporate', 'green', 'roof') : 2
# ('tree', 'provide', 'dense') : 2
# ('charter', 'institute', 'building') : 3
# ('institute', 'building', 'service') : 3
# ('exist', 'housing', 'stock') : 2
# ('mixed', 'mode', 'ventilation') : 2
# ('good', 'thermal', 'insulation') : 2
# ('low', 'emissivity', 'material') : 2
# ('effective', 'passive', 'ventilation') : 2
# ('single', 'aspect', 'development') : 2
# ('london', 'energy', 'supply') : 2
# ('care', 'trust', 'borough') : 2
# ('trust', 'borough', 'social') : 2
# ('drain', 'london', 'project') : 2
# ('plan', 'provide', 'insight') : 2
# ('influence', 'many', 'factor') : 2
# ('direct', 'effect', 'delivery') : 2
# ('effect', 'delivery', 'service') : 2
# ('social', 'care', 'service') : 4
# ('water', 'availability', 'water') : 5
# ('winter', 'reduce', 'number') : 2
# ('reduce', 'number', 'excess') : 2
# ('number', 'excess', 'winter') : 2
# ('excess', 'winter', 'death') : 2
# ('excess', 'winter', 'mortality') : 2
# ('provide', 'winter', 'fuel') : 2
# ('winter', 'fuel', 'subsidy') : 2
# ('longer', 'grow', 'season') : 2
# ('less', 'cloud', 'cover') : 2
# ('mayor', 'draft', 'air') : 2
# ('draft', 'air', 'quality') : 2
# ('warmer', 'winter', 'extend') : 2
# ('locally', 'grown', 'produce') : 2
# ('pattern', 'increase', 'weather') : 2
# ('increase', 'weather', 'event') : 2
# ('black', 'asian', 'minority') : 2
# ('asian', 'minority', 'ethnic') : 2
# ('unable', 'get', 'work') : 2
# ('partner', 'restore', 'london') : 2
# ('restore', 'london', 'river') : 3
# ('offset', 'island', 'reduce') : 2
# ('island', 'reduce', 'energy') : 2
# ('london', 'biodiversity', 'adapt') : 2
# ('wall', 'street', 'tree') : 8
# ('london', 'green', 'east') : 2
# ('green', 'east', 'london') : 2
# ('enhance', 'ecosystem', 'service') : 2
# ('green', 'space', 'new') : 2
# ('green', 'space', 'enhance') : 2
# ('london', 'land', 'area') : 2
# ('freshwater', 'graze', 'marsh') : 2
# ('environment', 'agency', 'thames') : 3
# ('draft', 'london', 'water') : 3
# ('surface', 'water', 'drain') : 2
# ('london', 'tree', 'woodland') : 2
# ('tree', 'cover', 'five') : 2
# ('action', 'action', 'identify') : 2
# ('identify', 'strategy', 'help') : 2
# ('strategy', 'help', 'improve') : 2
# ('need', 'adapt', 'change') : 2
# ('safe', 'secure', 'place') : 2
# ('secure', 'place', 'business') : 2
# ('segment', 'financial', 'service') : 3
# ('financial', 'service', 'sector') : 7
# ('enable', 'london', 'become') : 2
# ('become', 'exemplar', 'tackle') : 2
# ('munich', 'megacities', 'megarisks') : 2
# ('megacities', 'megarisks', 'trend') : 2
# ('megarisks', 'trend', 'challenge') : 2
# ('trend', 'challenge', 'insurance') : 2
# ('challenge', 'insurance', 'manager') : 2
# ('usa', 'new', 'york') : 3
# ('london', 'financial', 'service') : 2
# ('sector', 'financial', 'service') : 2
# ('frequency', 'intensity', 'location') : 2
# ('practice', 'know', 'raise') : 2
# ('general', 'insurance', 'industry') : 3
# ('change', 'draft', 'strategy') : 3
# ('business', 'area', 'impact') : 2
# ('area', 'impact', 'assessment') : 2
# ('impact', 'assessment', 'tool') : 2
# ('identify', 'challenge', 'opportunity') : 2
# ('design', 'construction', 'maintenance') : 2
# ('staff', 'unable', 'work') : 2
# ('london', 'transport', 'network') : 4
# ('london', 'underground', 'london') : 3
# ('underground', 'london', 'overground') : 2
# ('docklands', 'light', 'railway') : 3
# ('train', 'operate', 'company') : 2
# ('transport', 'walk', 'cycle') : 2
# ('tidal', 'fluvial', 'surface') : 2
# ('london', 'underground', 'network') : 9
# ('fluvial', 'tidal', 'flow') : 2
# ('port', 'london', 'authority') : 2
# ('underground', 'london', 'underground') : 2
# ('agency', 'thames', 'water') : 2
# ('increase', 'seasonal', 'variation') : 2
# ('affect', 'frequency', 'intensity') : 2
# ('frequency', 'intensity', 'hot') : 2
# ('passenger', 'comfort', 'transport') : 2
# ('thermal', 'expansion', 'rail') : 2
# ('surface', 'section', 'line') : 2
# ('cool', 'london', 'underground') : 2
# ('london', 'underground', 'aim') : 2
# ('thermal', 'comfort', 'passenger') : 2
# ('automatic', 'ventilation', 'system') : 2
# ('cutting', 'tunnel', 'bridge') : 2
# ('winter', 'extend', 'grow') : 2
# ('island', 'energy', 'demand') : 2
# ('photovoltaic', 'solar', 'thermal') : 2
# ('solar', 'thermal', 'array') : 2
# ('nuclear', 'power', 'station') : 2
# ('rainfall', 'high', 'temperature') : 2
# ('combine', 'cool', 'heat') : 2
# ('cool', 'heat', 'power') : 2
# ('potential', 'change', 'profile') : 2
# ('change', 'profile', 'municipal') : 2
# ('profile', 'municipal', 'waste') : 2
# ('strategy', 'london', 'lead') : 2
# ('london', 'lead', 'partner') : 3
# ('lead', 'partner', 'deliver') : 4
# ('environment', 'agency', 'mayor') : 3
# ('agency', 'mayor', 'london') : 5
# ('mayor', 'london', 'boroughs') : 3
# ('london', 'boroughs', 'london') : 3
# ('boroughs', 'london', 'resilience') : 2
# ('drain', 'london', 'spring') : 3
# ('london', 'spring', 'create') : 2
# ('mayor', 'london', 'borough') : 3
# ('london', 'borough', 'spring') : 2
# ('london', 'mayor', 'london') : 3
# ('mayor', 'london', 'environment') : 2
# ('london', 'environment', 'agency') : 2
# ('thames', 'water', 'veolia') : 2
# ('east', 'surrey', 'water') : 2
# ('drought', 'london', 'resilience') : 2
# ('development', 'agency', 'mayor') : 2
# ('east', 'london', 'green') : 2
# ('boroughs', 'voluntary', 'sector') : 2
# ('group', 'london', 'summer') : 2
# ('river', 'restoration', 'centre') : 2
# ('mayor', 'london', 'summer') : 3
# ('gas', 'electricity', 'market') : 2
# ('requirement', 'reference', 'address') : 2
# ('gla', 'throughout', 'strategy') : 9
# ('throughout', 'strategy', 'particular') : 8
# ('strategy', 'particular', 'chapter') : 8
# ('particular', 'chapter', 'promote') : 2
# ('particular', 'chapter', 'regard') : 2
# ('london', 'gla', 'amend') : 2
# ('gla', 'amend', 'gla') : 4
# ('amend', 'gla', 'throughout') : 3
# ('throughout', 'strategy', 'consistent') : 3
# ('throughout', 'strategy', 'particularly') : 2
# ('strategy', 'particularly', 'chapter') : 2
# ('gol', 'guidance', 'para') : 10
# ('guidance', 'para', 'throughout') : 6
# ('para', 'throughout', 'strategy') : 6
# ('consistent', 'gol', 'guidance') : 3
# ('guidance', 'para', 'yes') : 3
# ('london', 'assembly', 'functional') : 2
# ('assembly', 'functional', 'body') : 2
# ('east', 'england', 'development') : 2
# ('england', 'development', 'agency') : 2
# ('gla', 'draft', 'london') : 2
# ('mean', 'summer', 'medium') : 2
# ('summer', 'medium', 'emission') : 2
# ('emission', 'scenario', 'interval') : 2
# ('period', 'time', 'example') : 2
# ('environment', 'agency', 'personal') : 2
# ('agency', 'personal', 'communication') : 2
# ('refers', 'take', 'measure') : 2
# ('demand', 'dry', 'year') : 2
# ('personal', 'communication', 'gla') : 3
# ('environment', 'agency', 'gla') : 2
# ('asian', 'city', 'resilience') : 9
# ('city', 'resilience', 'network') : 9
# ('resilience', 'network', 'acccrn') : 6
# ('network', 'acccrn', 'respond') : 2
# ('acccrn', 'respond', 'challenge') : 29
# ('institute', 'social', 'environmental') : 4
# ('social', 'environmental', 'transition') : 3
# ('kangkung', 'district', 'bandar') : 2
# ('district', 'bandar', 'lampung') : 3
# ('indrawan', 'mercy', 'corp') : 3
# ('mercy', 'corp', 'indonesia') : 4
# ('respond', 'challenge', 'core') : 2
# ('challenge', 'core', 'theme') : 2
# ('core', 'theme', 'acccrn') : 2
# ('theme', 'acccrn', 'acccrn') : 2
# ('acccrn', 'process', 'acccrn') : 3
# ('acccrn', 'case', 'study') : 2
# ('acccrn', 'case', 'vietnam') : 2
# ('tho', 'da', 'nang') : 2
# ('da', 'nang', 'quy') : 3
# ('nang', 'quy', 'nhon') : 3
# ('gorakhpur', 'surat', 'indore') : 3
# ('surat', 'indore', 'indonesia') : 2
# ('indore', 'indonesia', 'semarang') : 2
# ('indonesia', 'semarang', 'bandar') : 2
# ('semarang', 'bandar', 'lampung') : 3
# ('bandar', 'lampung', 'thailand') : 2
# ('lampung', 'thailand', 'chiang') : 2
# ('thailand', 'chiang', 'rai') : 3
# ('chiang', 'rai', 'hat') : 7
# ('rai', 'hat', 'yai') : 7
# ('hat', 'yai', 'acccrn') : 2
# ('thailand', 'vietnam', 'indonesia') : 5
# ('vietnam', 'indonesia', 'acccrn') : 2
# ('indonesia', 'acccrn', 'respond') : 3
# ('population', 'acccrn', 'respond') : 2
# ('phase', 'acccrn', 'program') : 2
# ('city', 'develop', 'resilience') : 2
# ('engage', 'acccrn', 'process') : 2
# ('resilience', 'strategy', 'action') : 5
# ('impact', 'poor', 'vulnerable') : 2
# ('poor', 'vulnerable', 'population') : 5
# ('group', 'well', 'local') : 2
# ('well', 'local', 'government') : 2
# ('build', 'resilience', 'acccrn') : 3
# ('resilience', 'acccrn', 'process') : 2
# ('share', 'lesson', 'city') : 2
# ('resilience', 'poor', 'vulnerable') : 2
# ('vulnerable', 'people', 'acccrn') : 2
# ('tho', 'quy', 'nhon') : 2
# ('quy', 'nhon', 'da') : 2
# ('nhon', 'da', 'nang') : 2
# ('indonesia', 'thatcher', 'cook') : 2
# ('thatcher', 'cook', 'mercy') : 2
# ('cook', 'mercy', 'corp') : 2
# ('mercy', 'corp', 'acccrn') : 2
# ('resilience', 'strategy', 'consider') : 2
# ('identify', 'resilience', 'strategy') : 2
# ('disaster', 'reduction', 'expert') : 2
# ('phase', 'acccrn', 'process') : 2
# ('acccrn', 'process', 'timeline') : 2
# ('tho', 'vietnam', 'challenge') : 3
# ('current', 'future', 'vulnerability') : 3
# ('share', 'learn', 'dialogue') : 5
# ('share', 'learn', 'within') : 2
# ('learn', 'within', 'city') : 2
# ('within', 'city', 'country') : 2
# ('city', 'country', 'sector') : 2
# ('community', 'government', 'agency') : 2
# ('slds', 'review', 'lesson') : 2
# ('review', 'lesson', 'revise') : 2
# ('lesson', 'revise', 'monitor') : 2
# ('revise', 'monitor', 'document') : 2
# ('monitor', 'document', 'use') : 3
# ('document', 'use', 'slds') : 3
# ('use', 'slds', 'reflect') : 3
# ('vulnerable', 'group', 'area') : 2
# ('slds', 'vulnerability', 'assessment') : 2
# ('vulnerability', 'assessment', 'begin') : 2
# ('resilience', 'strategy', 'plan') : 4
# ('respond', 'challenge', 'acccrn') : 4
# ('thi', 'nai', 'lagoon') : 3
# ('quy', 'nhon', 'vietnam') : 4
# ('binh', 'dinh', 'province') : 4
# ('vietnam', 'acccrn', 'case') : 3
# ('respond', 'challenge', 'tho') : 2
# ('cultural', 'heritage', 'environmental') : 2
# ('acccrn', 'process', 'vietnam') : 3
# ('da', 'nang', 'tho') : 2
# ('area', 'suburban', 'area') : 2
# ('policy', 'strategy', 'study') : 2
# ('strategy', 'study', 'nistpass') : 2
# ('acccrn', 'case', 'country') : 17
# ('case', 'country', 'vietnam') : 4
# ('country', 'vietnam', 'acccrn') : 2
# ('vietnam', 'acccrn', 'respond') : 2
# ('timeframe', 'process', 'participant') : 4
# ('expert', 'citizen', 'group') : 2
# ('ctc', 'partner', 'vulnerable') : 2
# ('community', 'local', 'technical') : 2
# ('local', 'technical', 'expert') : 2
# ('march', 'sector', 'study') : 2
# ('challenge', 'include', 'f') : 4
# ('sector', 'f', 'lack') : 2
# ('mekong', 'river', 'delta') : 2
# ('southwestern', 'bank', 'hau') : 2
# ('bank', 'hau', 'river') : 2
# ('hau', 'river', 'large') : 2
# ('river', 'large', 'branch') : 2
# ('large', 'branch', 'mekong') : 2
# ('branch', 'mekong', 'river') : 2
# ('connect', 'rest', 'country') : 2
# ('rice', 'farm', 'aquaculture') : 2
# ('characteristic', 'population', 'primary') : 4
# ('population', 'primary', 'economic') : 7
# ('primary', 'economic', 'activity') : 10
# ('port', 'gdp', 'growth') : 2
# ('gdp', 'growth', 'rate') : 3
# ('growth', 'rate', 'tropical') : 4
# ('rate', 'tropical', 'monsoon') : 2
# ('tropical', 'monsoon', 'two') : 3
# ('monsoon', 'two', 'season') : 2
# ('season', 'rainy', 'november') : 2
# ('rainy', 'november', 'dry') : 2
# ('november', 'dry', 'december') : 2
# ('dry', 'december', 'april') : 2
# ('vietnam', 'challenge', 'acccrn') : 2
# ('challenge', 'acccrn', 'respond') : 2
# ('rainfall', 'mm', 'year') : 2
# ('mm', 'year', 'fall') : 2
# ('year', 'fall', 'monsoon') : 2
# ('fall', 'monsoon', 'average') : 2
# ('vulnerability', 'context', 'project') : 3
# ('context', 'project', 'impact') : 3
# ('level', 'rise', 'increase') : 3
# ('rise', 'increase', 'temperature') : 2
# ('dry', 'season', 'drought') : 3
# ('couple', 'drought', 'could') : 2
# ('level', 'rise', 'could') : 2
# ('acccrn', 'coordinator', 'department') : 2
# ('department', 'natural', 'resource') : 2
# ('center', 'natural', 'resource') : 2
# ('lead', 'inundation', 'portion') : 2
# ('rural', 'area', 'increase') : 3
# ('tien', 'sa', 'port') : 2
# ('system', 'within', 'monsoon') : 2
# ('within', 'monsoon', 'period') : 2
# ('monsoon', 'period', 'tropical') : 2
# ('period', 'tropical', 'depression') : 2
# ('tropical', 'depression', 'typhoon') : 2
# ('average', 'da', 'nang') : 2
# ('song', 'han', 'river') : 2
# ('occur', 'rainy', 'season') : 2
# ('economic', 'activity', 'tourism') : 2
# ('two', 'season', 'typhoon') : 2
# ('season', 'typhoon', 'peak') : 2
# ('typhoon', 'peak', 'rainfall') : 2
# ('peak', 'rainfall', 'tember') : 2
# ('rainfall', 'tember', 'december') : 2
# ('tember', 'december', 'associate') : 2
# ('december', 'associate', 'typhoon') : 2
# ('associate', 'typhoon', 'tropical') : 2
# ('typhoon', 'tropical', 'depression') : 2
# ('tropical', 'depression', 'location') : 2
# ('depression', 'location', 'coastal') : 2
# ('respond', 'challenge', 'vulnerability') : 2
# ('challenge', 'vulnerability', 'context') : 2
# ('south', 'ha', 'thanh') : 2
# ('ha', 'thanh', 'river') : 2
# ('characteristic', 'population', 'estimate') : 2
# ('nhon', 'vietnam', 'acccrn') : 2
# ('ward', 'commune', 'affect') : 2
# ('governance', 'policy', 'landscape') : 3
# ('policy', 'landscape', 'government') : 2
# ('prime', 'minister', 'council') : 2
# ('indore', 'surat', 'gorakhpur') : 2
# ('surat', 'gorakhpur', 'environmental') : 2
# ('gorakhpur', 'environmental', 'group') : 5
# ('environmental', 'group', 'geag') : 5
# ('group', 'geag', 'gorakhpur') : 2
# ('gorakhpur', 'acccrn', 'process') : 2
# ('engage', 'key', 'stakeholder') : 2
# ('small', 'group', 'meeting') : 3
# ('election', 'conclude', 'vulnerability') : 2
# ('level', 'acccrn', 'case') : 2
# ('council', 'ministry', 'environment') : 2
# ('agriculture', 'water', 'resource') : 5
# ('committee', 'general', 'board') : 2
# ('requirement', 'fund', 'policy') : 2
# ('fund', 'policy', 'program') : 2
# ('policy', 'program', 'fund') : 2
# ('water', 'supply', 'sanitation') : 8
# ('vulnerability', 'population', 'local') : 2
# ('population', 'local', 'ngos') : 2
# ('key', 'opportunity', 'challenge') : 6
# ('f', 'lack', 'appropriate') : 2
# ('lack', 'appropriate', 'f') : 2
# ('appropriate', 'f', 'lack') : 2
# ('f', 'lack', 'capacity') : 2
# ('lack', 'capacity', 'vulnerability') : 2
# ('capacity', 'vulnerability', 'survey') : 2
# ('waterlogging', 'poor', 'drainage') : 2
# ('increase', 'incidence', 'severity') : 2
# ('million', 'growth', 'rate') : 3
# ('growth', 'rate', 'poor') : 3
# ('rate', 'poor', 'population') : 3
# ('sea', 'level', 'acccrn') : 2
# ('challenge', 'acccrn', 'process') : 3
# ('acccrn', 'process', 'gorakhpur') : 2
# ('gorakhpur', 'municipal', 'corporation') : 2
# ('municipal', 'corporation', 'gmc') : 2
# ('share', 'learn', 'logue') : 2
# ('development', 'plan', 'implementation') : 2
# ('lead', 'vulnerability', 'analysis') : 2
# ('vulnerability', 'analysis', 'work') : 2
# ('case', 'country', 'vulnerability') : 2
# ('country', 'vulnerability', 'context') : 2
# ('include', 'increase', 'precipitation') : 2
# ('shallow', 'hand', 'pump') : 2
# ('year', 'last', 'two') : 2
# ('southern', 'gujarat', 'chamber') : 2
# ('gujarat', 'chamber', 'commerce') : 2
# ('chamber', 'commerce', 'industry') : 2
# ('characteristic', 'population', 'million') : 2
# ('population', 'million', 'growth') : 2
# ('river', 'divide', 'surat') : 2
# ('divide', 'surat', 'northern') : 2
# ...
# ('downtown', 'area', 'flux') : 2
# ('area', 'flux', 'could') : 2
# ('flux', 'could', 'reach') : 2
# ('could', 'reach', 'hour') : 3
# ('reach', 'hour', 'generally') : 3
# ('hour', 'generally', 'range') : 3
# ('generally', 'range', 'flux') : 2
# ('range', 'flux', 'hour') : 2
# ('flux', 'hour', 'large') : 2
# ('hour', 'large', 'distribution') : 3
# ('large', 'distribution', 'uneven') : 3
# ('distribution', 'uneven', 'plot') : 2
# ('uneven', 'plot', 'b') : 2
# ('plot', 'b', 'heatmap') : 5
# ('b', 'heatmap', 'spatial') : 3
# ('heatmap', 'spatial', 'distribution') : 3
# ('spatial', 'distribution', 'flux') : 2
# ('distribution', 'flux', 'building') : 2
# ('flux', 'building', 'plot') : 2
# ('building', 'plot', 'b') : 3
# ('spatial', 'variation', 'result') : 3
# ('variation', 'result', 'microclimate') : 3
# ('result', 'microclimate', 'variability') : 3
# ('microclimate', 'variability', 'coastal') : 3
# ('variability', 'coastal', 'versus') : 3
# ('coastal', 'versus', 'inland') : 3
# ('versus', 'inland', 'area') : 3
# ('inland', 'area', 'morphology') : 3
# ('area', 'morphology', 'variability') : 3
# ('morphology', 'variability', 'downtown') : 3
# ('variability', 'downtown', 'versus') : 3
# ('downtown', 'versus', 'residential') : 3
# ('versus', 'residential', 'area') : 3
# ('residential', 'area', 'determine') : 3
# ('area', 'determine', 'waste') : 3
# ('area', 'building', 'footprint') : 3
# ('building', 'footprint', 'condition') : 3
# ('footprint', 'condition', 'understand') : 3
# ('condition', 'understand', 'factor') : 3
# ('understand', 'factor', 'contributes') : 3
# ('factor', 'contributes', 'major') : 3
# ('contributes', 'major', 'discrepancy') : 3
# ('major', 'discrepancy', 'spatial') : 3
# ('discrepancy', 'spatial', 'distribution') : 3
# ('spatial', 'distribution', 'ah') : 3
# ('distribution', 'ah', 'analyze') : 3
# ('ah', 'analyze', 'emission') : 3
# ('analyze', 'emission', 'intensity') : 3
# ('emission', 'intensity', 'building') : 3
# ('area', 'lsf', 'example') : 3
# ('lsf', 'example', 'prototype') : 3
# ('example', 'prototype', 'plot') : 3
# ('prototype', 'plot', 'percentiles') : 3
# ('plot', 'percentiles', 'hourly') : 3
# ('intensity', 'lsf', 'range') : 3
# ('lsf', 'range', 'microclimate') : 3
# ('range', 'microclimate', 'condition') : 3
# ('microclimate', 'condition', 'without') : 3
# ('condition', 'without', 'take') : 3
# ('without', 'take', 'level') : 3
# ('take', 'level', 'footprint') : 3
# ('level', 'footprint', 'account') : 3
# ('footprint', 'account', 'spatial') : 3
# ('account', 'spatial', 'variation') : 3
# ('spatial', 'variation', 'outdoor') : 3
# ('variation', 'outdoor', 'air') : 3
# ('outdoor', 'air', 'condition') : 3
# ('air', 'condition', 'emission') : 3
# ('condition', 'emission', 'intensity') : 3
# ('emission', 'intensity', 'vary') : 3
# ('intensity', 'vary', 'accordingly') : 3
# ('vary', 'accordingly', 'show') : 3
# ('accordingly', 'show', 'wide') : 3
# ('wide', 'range', 'hotter') : 3
# ('range', 'hotter', 'day') : 3
# ('hotter', 'day', 'september') : 3
# ('day', 'september', 'hot') : 3
# ('september', 'hot', 'weather') : 3
# ('hot', 'weather', 'percentile') : 3
# ('weather', 'percentile', 'ah') : 3
# ('percentile', 'ah', 'intensity') : 3
# ('ah', 'intensity', 'grid') : 3
# ('intensity', 'grid', 'percentile') : 3
# ('peer', 'review', 'spatial') : 2
# ('review', 'spatial', 'variation') : 2
# ('determine', 'waste', 'floor') : 2
# ('waste', 'floor', 'area') : 2
# ('floor', 'area', 'building') : 2
# ('intensity', 'building', 'floor') : 2
# ('floor', 'area', 'lsf') : 2
# ('percentiles', 'hourly', 'flux') : 2
# ('hourly', 'flux', 'intensity') : 2
# ('flux', 'intensity', 'lsf') : 2
# ('grid', 'percentile', 'percentile') : 2
# ('percentile', 'percentile', 'emission') : 2
# ('percentile', 'emission', 'intensity') : 3
# ('emission', 'intensity', 'large') : 6
# ('intensity', 'large', 'house') : 6
# ('large', 'house', 'plot') : 3
# ('house', 'plot', 'spatial') : 3
# ('plot', 'spatial', 'variation') : 3
# ('spatial', 'variation', 'emission') : 3
# ('variation', 'emission', 'intensity') : 3
# ('emission', 'intensity', 'lsf') : 3
# ('intensity', 'lsf', 'wide') : 2
# ('lsf', 'wide', 'microclimate') : 2
# ('wide', 'microclimate', 'simulate') : 2
# ('microclimate', 'simulate', 'wrf') : 3
# ('simulate', 'wrf', 'hot') : 3
# ('wrf', 'hot', 'hour') : 3
# ('hot', 'hour', 'hot') : 3
# ('hour', 'hot', 'day') : 3
# ('hot', 'day', 'september') : 3
# ('day', 'september', 'pm') : 3
# ('september', 'pm', 'wave') : 3
# ('pm', 'wave', 'event') : 3
# ('wave', 'event', 'ah') : 3
# ('event', 'ah', 'intensity') : 3
# ('ah', 'intensity', 'value') : 3
# ('intensity', 'value', 'inland') : 3
# ('value', 'inland', 'area') : 3
# ('inland', 'area', 'reach') : 3
# ('area', 'reach', 'compare') : 3
# ('reach', 'compare', 'value') : 3
# ('compare', 'value', 'coastal') : 3
# ('value', 'coastal', 'area') : 3
# ('coastal', 'area', 'around') : 3
# ('area', 'around', 'overall') : 3
# ('around', 'overall', 'although') : 3
# ('overall', 'although', 'morphology') : 3
# ('although', 'morphology', 'play') : 3
# ('morphology', 'play', 'major') : 3
# ('major', 'role', 'ah') : 3
# ('role', 'ah', 'spatial') : 3
# ('ah', 'spatial', 'variation') : 3
# ('spatial', 'variation', 'variance') : 3
# ('variation', 'variance', 'cause') : 3
# ('variance', 'cause', 'microclimate') : 3
# ('cause', 'microclimate', 'ignore') : 3
# ('microclimate', 'ignore', 'emission') : 2
# ('ignore', 'emission', 'intensity') : 2
# ('large', 'house', 'microclimate') : 3
# ('house', 'microclimate', 'discussion') : 3
# ('microclimate', 'discussion', 'quantifying') : 3
# ('discussion', 'quantifying', 'building') : 3
# ('quantifying', 'building', 'waste') : 3
# ('waste', 'discharge', 'use') : 3
# ('discharge', 'use', 'build') : 3
# ('use', 'build', 'model') : 3
# ('build', 'model', 'spatially') : 3
# ('model', 'spatially', 'resolve') : 3
# ('spatially', 'resolve', 'microclimate') : 3
# ('resolve', 'microclimate', 'information') : 3
# ('microclimate', 'information', 'could') : 3
# ('information', 'could', 'help') : 3
# ('could', 'help', 'advance') : 3
# ('help', 'advance', 'understanding') : 3
# ('advance', 'understanding', 'response') : 3
# ('understanding', 'response', 'microclimate') : 3
# ('response', 'microclimate', 'anthropogenic') : 3
# ('microclimate', 'anthropogenic', 'heating') : 3
# ('anthropogenic', 'heating', 'weather') : 3
# ('heating', 'weather', 'event') : 3
# ('weather', 'event', 'calculation') : 3
# ('event', 'calculation', 'emission') : 3
# ('calculation', 'emission', 'different') : 2
# ('emission', 'different', 'building') : 2
# ('different', 'building', 'system') : 2
# ('building', 'system', 'component') : 3
# ('system', 'component', 'aggregation') : 3
# ('component', 'aggregation', 'hourly') : 3
# ('aggregation', 'hourly', 'discharge') : 3
# ('hourly', 'discharge', 'temporal') : 3
# ('discharge', 'temporal', 'spatial') : 3
# ('spatial', 'variation', 'take') : 2
# ('variation', 'take', 'consideration') : 2
# ('take', 'consideration', 'include') : 3
# ('consideration', 'include', 'difference') : 2
# ('include', 'difference', 'peak') : 2
# ('difference', 'peak', 'time') : 2
# ('peak', 'time', 'amount') : 3
# ('time', 'amount', 'commercial') : 3
# ('amount', 'commercial', 'residential') : 3
# ('building', 'type', 'result') : 3
# ('type', 'result', 'simulation') : 3
# ('available', 'accessed', 'august') : 4
# ('build', 'environ', 'crossref') : 2
# ('appl', 'meteorol', 'clim') : 3
# ('meteorol', 'clim', 'crossref') : 3
# ('atmospheric', 'environ', 'crossref') : 2
# ('atmos', 'environ', 'crossref') : 2
# ('meteorol', 'soc', 'crossref') : 2
# ('re', 'lett', 'crossref') : 2
# ('int', 'clim', 'crossref') : 2
# ('weather', 'rev', 'crossref') : 2
# ('broadway', 'new', 'york') : 2
# ('vegetated', 'green', 'roof') : 2
# ('green', 'roof', 'effective') : 2
# ('satellite', 'imagery', 'software') : 2
# ('background', 'warm', 'trend') : 3
# ('warm', 'trend', 'associate') : 3
# ('trend', 'associate', 'urbanization') : 2
# ('three', 'green', 'roof') : 3
# ('green', 'roof', 'site') : 7
# ('bartesaghi', 'koc', 'osmond') : 2
# ('koc', 'osmond', 'peter') : 2
# ('shafique', 'kim', 'rafiq') : 2
# ('kim', 'rafiq', 'green') : 2
# ('rafiq', 'green', 'roof') : 2
# ('city', 'society', 'mcconnell') : 11
# ('mahdiyar', 'tabatabaee', 'abdullah') : 2
# ('tabatabaee', 'abdullah', 'marto') : 2
# ('roof', 'cool', 'performance') : 2
# ('chapman', 'watson', 'salazar') : 2
# ('watson', 'salazar', 'thatcher') : 2
# ('salazar', 'thatcher', 'mcalpine') : 2
# ('allen', 'lindberg', 'grimmond') : 2
# ('erdem', 'okumus', 'terzi') : 2
# ('halder', 'bandyopadhyay', 'banik') : 2
# ('liu', 'zhang', 'zhang') : 2
# ('zhang', 'zhang', 'zhang') : 2
# ('zhang', 'zhang', 'teng') : 2
# ('effect', 'build', 'densification') : 2
# ('rizvi', 'alam', 'iqbal') : 2
# ('green', 'infrastructure', 'mitigation') : 2
# ('hayhoe', 'sheridan', 'kalkstein') : 2
# ('sheridan', 'kalkstein', 'greene') : 2
# ('chicago', 'zone', 'ordinance') : 2
# ('sharma', 'smith', 'roebber') : 2
# ('hurwitz', 'braneon', 'kirschbaum') : 2
# ('braneon', 'kirschbaum', 'mandarino') : 2
# ('kirschbaum', 'mandarino', 'mansour') : 2
# ('mackey', 'lee', 'smith') : 2
# ('evaluate', 'green', 'roof') : 2
# ('parison', 'hendel', 'royon') : 2
# ('causal', 'effect', 'green') : 3
# ('mallen', 'bakin', 'stone') : 2
# ('bakin', 'stone', 'sivakumar') : 2
# ('stone', 'sivakumar', 'lanza') : 2
# ('chen', 'zhao', 'li') : 2
# ('zhao', 'li', 'yin') : 2
# ('gohain', 'mohammad', 'goswami') : 2
# ('number', 'sample', 'point') : 2
# ('roof', 'installation', 'see') : 2
# ('green', 'roof', 'alone') : 3
# ('causal', 'green', 'roof') : 2
# ('lst', 'ndvi', 'green') : 2
# ('ndvi', 'green', 'roof') : 2
# ('relative', 'control', 'site') : 5
# ('treatment', 'control', 'site') : 2
# ('site', 'draw', 'landsat') : 2
# ('draw', 'landsat', 'tm') : 2
# ('three', 'vegetate', 'rooftop') : 2
# ('walmart', 'supercenter', 'rooftop') : 2
# ('supercenter', 'rooftop', 'millennium') : 2
# ('rooftop', 'millennium', 'park') : 2
# ('millennium', 'park', 'hall') : 5
# ('plant', 'specie', 'include') : 2
# ('plant', 'lurie', 'garden') : 2
# ('farbstein', 'axelrod', 'shibley') : 2
# ('axelrod', 'shibley', 'wener') : 2
# ('millennium', 'park', 'large') : 2
# ('hall', 'rooftop', 'garden') : 2
# ('green', 'roof', 'compose') : 2
# ('green', 'roof', 'geodatabase') : 2
# ('vegetate', 'rooftop', 'location') : 2
# ('control', 'sit', 'show') : 2
# ('allow', 'u', 'evaluate') : 3
# ('μ', 'band', 'μ') : 2
# ('son', 'chen', 'chen') : 2
# ('chen', 'chen', 'thanh') : 2
# ('chen', 'thanh', 'vuong') : 2
# ('identify', 'causal', 'effect') : 2
# ('roof', 'installation', 'lst') : 2
# ('installation', 'lst', 'ndvi') : 2
# ('lst', 'ndvi', 'model') : 2
# ('lst', 'ndvi', 'value') : 2
# ('change', 'lst', 'ndvi') : 2
# ('treatment', 'control', 'sit') : 2
# ('u', 'evaluate', 'absolute') : 2
# ('control', 'site', 'three') : 2
# ('doick', 'peace', 'hutchings') : 2
# ('society', 'mcconnell', 'parallel') : 2
# ('mcconnell', 'parallel', 'trend') : 2
# ('estimate', 'vertical', 'line') : 2
# ('line', 'indicate', 'green') : 2
# ('roof', 'construction', 'period') : 2
# ('construction', 'period', 'interpretation') : 2
# ('period', 'interpretation', 'reference') : 2
# ('parallel', 'trend', 'plot') : 3
# ('prior', 'green', 'roof') : 2
# ('mean', 'lst', 'well') : 2
# ('compare', 'control', 'site') : 2
# ('mean', 'lst', 'period') : 2
# ('green', 'roof', 'control') : 4
# ('roof', 'control', 'site') : 3
# ('absolute', 'mean', 'lst') : 2
# ('experience', 'significantly', 'low') : 2
# ('low', 'lst', 'k') : 2
# ('ndvi', 'period', 'relative') : 2
# ('period', 'relative', 'control') : 2
# ('millennium', 'park', 'site') : 2
# ('mitigate', 'large', 'warm') : 2
# ('large', 'warm', 'trend') : 4
# ('control', 'site', 'experience') : 2
# ('park', 'hall', 'walmart') : 2
# ('walmart', 'green', 'roof') : 3
# ('green', 'roof', 'able') : 2
# ('green', 'roof', 'fully') : 2
# ('reduction', 'lst', 'relative') : 2
# ('need', 'thoroughly', 'evaluate') : 2
# ('type', 'rooftop', 'location') : 2
# ('eksi', 'rowe', 'wichman') : 2
# ('rowe', 'wichman', 'andresen') : 2
# ('lee', 'ryu', 'jiang') : 2
# ('lst', 'ndvi', 'lst') : 2
# ('ndvi', 'lst', 'ndvi') : 2
# ('temperate', 'region', 'chicago') : 2
# ('region', 'chicago', 'intensive') : 2
# ('chicago', 'intensive', 'green') : 2
# ('absolute', 'reduction', 'land') : 2
# ('reduction', 'land', 'surface') : 2
# ('remote', 'sense', 'analysis') : 2
# ('result', 'three', 'site') : 2
# ('yin', 'kong', 'dronova') : 2
# ('kong', 'dronova', 'middel') : 2
# ('dronova', 'middel', 'james') : 2
# ('lamb', 'creutzig', 'callaghan') : 2
# ('creutzig', 'callaghan', 'minx') : 2
# ('planning', 'development', 'provide') : 2
# ('surface', 'model', 'procedure') : 2
# ('use', 'follow', 'equation') : 2
# ('rescaling', 'factor', 'metadata') : 2
# ('thermal', 'conversion', 'constant') : 2
# ('conversion', 'constant', 'take') : 2
# ('constant', 'take', 'metadata') : 2
# ('quattrochi', 'bounoua', 'lachir') : 2
# ('bounoua', 'lachir', 'zhang') : 2
# ('associate', 'band', 'landsat') : 2
# ('energy', 'building', 'url') : 4
# ('building', 'environment', 'url') : 2
# ('landscape', 'plan', 'url') : 3
# ('sense', 'environment', 'url') : 3
# ('letter', 'article', 'url') : 4
# ('society', 'article', 'url') : 7
# ('journal', 'great', 'lake') : 2
# ('great', 'lake', 'research') : 2
# ('city', 'society', 'url') : 2
# ('outdoor', 'thermal', 'performance') : 2
# ('adverse', 'effect', 'crop') : 2
# ('effect', 'crop', 'yield') : 2
# ('adverse', 'impact', 'human') : 2
# ('land', 'assimilation', 'system') : 5
# ('assimilation', 'system', 'hrldas') : 2
# ('three', 'different', 'wrf') : 2
# ('different', 'wrf', 'configuration') : 2
# ('performance', 'evaluate', 'base') : 2
# ('provide', 'best', 'performance') : 2
# ('excessive', 'factor', 'ehf') : 2
# ('kaiyu', 'chen', 'andrew') : 2
# ('chen', 'andrew', 'newman') : 2
# ('andrew', 'newman', 'mengjiao') : 2
# ('newman', 'mengjiao', 'huang') : 2
# ('hw', 'uhi', 'impact') : 2
# ('kaiyu', 'chen', 'write') : 2
# ('koc', 'university', 'wiley') : 18
# ('university', 'wiley', 'library') : 18
# ('applicable', 'common', 'geohealth') : 17
# ('common', 'geohealth', 'chen') : 17
# ('use', 'horizontal', 'resolution') : 2
# ('domain', 'cover', 'chicago') : 2
# ('ncep', 'north', 'american') : 4
# ('american', 'mesoscale', 'nam') : 4
# ('mesoscale', 'nam', 'analysis') : 4
# ('nam', 'analysis', 'ncep') : 2
# ('analysis', 'ncep', 'north') : 2
# ('turbulent', 'kinetic', 'energy') : 2
# ('ncep', 'adp', 'global') : 3
# ('adp', 'global', 'upper') : 3
# ('global', 'upper', 'air') : 3
# ('upper', 'air', 'observational') : 3
# ('air', 'observational', 'weather') : 4
# ('observational', 'weather', 'ncep') : 2
# ('weather', 'ncep', 'adp') : 2
# ('less', 'computational', 'resource') : 2
# ('show', 'support', 'information') : 2
# ('chicago', 'surround', 'area') : 4
# ('use', 'excess', 'factor') : 4
# ('temperature', 'three', 'consecutive') : 2
# ('daily', 'surface', 'weather') : 2
# ('surface', 'weather', 'north') : 2
# ('weather', 'north', 'america') : 2
# ('find', 'figure', 'support') : 2
# ('figure', 'support', 'information') : 4
# ('low', 'mb', 'ge') : 2
# ('surround', 'area', 'compare') : 2
# ('statistical', 'metric', 'reveal') : 2
# ('show', 'figure', 'support') : 2
# ('different', 'period', 'hw') : 2
# ('area', 'slightly', 'high') : 2
# ('high', 'rural', 'area') : 2
# ('rural', 'area', 'hw') : 3
# ('area', 'hw', 'event') : 2
# ('hw', 'event', 'july') : 3
# ('temperatures', 'rural', 'area') : 2
# ('rural', 'area', 'significantly') : 2
# ('period', 'rural', 'area') : 2
# ('rural', 'area', 'chicago') : 2
# ('nighttime', 'temperature', 'compare') : 2
# ('rural', 'area', 'high') : 3
# ('nighttime', 'rural', 'temperature') : 2
# ('rural', 'area', 'slightly') : 2
# ('wind', 'speed', 'less') : 3
# ('breeze', 'lake', 'michigan') : 3
# ('wind', 'speed', 'hw') : 2
# ('temperature', 'suburban', 'area') : 2
# ('rural', 'area', 'maximum') : 2
# ('maximum', 'hw', 'impact') : 2
# ('impact', 'lake', 'breeze') : 2
# ('area', 'hw', 'episode') : 2
# ('rural', 'area', 'less') : 2
# ('area', 'high', 'temperature') : 2
# ('early', 'hw', 'period') : 2
# ('significantly', 'low', 'nighttime') : 2
# ('lake', 'michigan', 'cause') : 2
# ('coastal', 'area', 'mitigate') : 2
# ('increase', 'rural', 'area') : 2
# ('rural', 'uhi', 'effect') : 2
# ('uhi', 'effect', 'observe') : 3
# ('low', 'fraction', 'area') : 2
# ('late', 'hw', 'event') : 3
# ('effect', 'observe', 'nighttime') : 2
# ('impact', 'rural', 'area') : 2
# ('rural', 'area', 'nighttime') : 2
# ('tmax', 'tmin', 'tmean') : 2
# ('varghese', 'hansen', 'nitschke') : 2
# ('use', 'mlucm', 'wrf') : 2
# ('observation', 'nudge', 'wrf') : 2
# ('provide', 'university', 'utah') : 2
# ('south', 'australia', 'journal') : 2
# ('university', 'library', 'ip') : 9

# %% [markdown]
# ### BERT topic

# %%
def preprocess_texts(docs):
    preprocessed_docs = [' '.join(tokens) for tokens in (doc[0] for doc in docs.values())]
    return preprocessed_docs
preprocessed_texts = preprocess_texts(docs)

# %%
# Initializing the SentenceTransformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Encoding the preprocessed texts into embeddings
embeddings = model.encode(preprocessed_texts, show_progress_bar=True)

# %%
# Initializing BERTopic with custom parameters
topic_model = BERTopic(min_topic_size=5,
                       top_n_words=6,
                       n_gram_range=(1, 2),
                       calculate_probabilities=True)

# Fitting BERTopic on the preprocessed texts and embeddings
topics, probs = topic_model.fit_transform(preprocessed_texts,embeddings)

# %%
# Checking the topics identified
topic_info = topic_model.get_topic_info()
print(topic_info)
# Out:
#    Topic  Count                               Name  \
# 0     -1     18         -1_london_area_water_flood
# 1      0     16       0_cool_green_energy_building
# 2      1     15    1_exposure_population_city_area
# 3      2     13      2_roof_energy_cool_resilience
# 4      3     11          3_city_cool_energy_policy
# 5      4      6  4_heatwave_people_cross_community
#
#                                     Representation  \
# 0                [london, area, water, flood, use]
# 1            [cool, green, energy, building, roof]
# 2       [exposure, population, city, area, future]
# 3          [roof, energy, cool, resilience, green]
# 4               [city, cool, energy, policy, area]
# 5  [heatwave, people, cross, community, heatwaves]
#
#                                  Representative_Docs
# 0  [future want could greatest city uccrn technic...
# 1  [rethink city arid environment chief function ...
# 2  [projection human exposure dangerous african c...
# 3  [cool neighborhood nyc new york mayor bill bla...
# 4  [island mean east asia city disclosure authori...
# 5  [hea twave cross crescent branch hea tw cross ...

# %%
topic_model.get_topic(2)
# Out:
# [('roof', 0.024588811059978836),
#  ('energy', 0.01789413364865717),
#  ('cool', 0.016465337393834312),
#  ('resilience', 0.01598379126088959),
#  ('green', 0.015255074441601416)]

# %%
# Getting the topic words
topic_words = topic_model.get_topics()

# Preprocessing the texts
preprocessed_texts = preprocess_texts(docs)

# Converting preprocessed texts to list of words for coherence model
texts = [doc.split() for doc in preprocessed_texts]

# Creating a dictionary and corpus for the coherence model
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

coherence_scores = []
for topic_id, topic in topic_words.items():
    # Preparing the data for coherence model
    topics = [[word for word, _ in topic]]

    # Computing Coherence Score using Gensim's CoherenceModel for each topic
    coherence_model = CoherenceModel(topics=topics, texts=texts, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()

    coherence_scores.append((topic_id, coherence_score))

# Printing coherence scores for each topic
for topic_id, coherence_score in coherence_scores:
    print(f'Topic {topic_id}: Coherence Score: {coherence_score}')
# Out:
# Topic -1: Coherence Score: 0.515613337022925
# Topic 0: Coherence Score: 0.7305625224062327
# Topic 1: Coherence Score: 0.5406070659828366
# Topic 2: Coherence Score: 0.6558229975005739
# Topic 3: Coherence Score: 0.5012490435701056
# Topic 4: Coherence Score: 0.6862564404750863
