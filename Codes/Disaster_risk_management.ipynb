# %%
pip install PyMuPDF

# %%
pip install BERTopic

# %%
import os
import fitz
import nltk
import re
import string
import gensim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pprint


# For tokenization
from nltk.tokenize import word_tokenize
nltk.download("punkt")
nltk.download('wordnet')

# For removing stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')

# For lemmatization
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')

# For TF-IDC
from gensim import corpora
from gensim.models import TfidfModel

# For N-grams
from collections import defaultdict
from nltk.util import ngrams as nltk_ngrams
from nltk.tokenize import word_tokenize

# For BERT topic
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# For coherence score
from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# ### Get text from PDFs

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as pdf:
        for page_num in range(len(pdf)):
            page = pdf.load_page(page_num)
            text += page.get_text()
    return text

# %% [markdown]
# ### Preprocess and vectorize text

# %% [markdown]
# *Preprocess pipeline*

# %%
# Loading WordNet POS tags for lemmatization
def wordnet_pos_tags(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def txt_preprocess_pipeline(text):

    # Removing multiple white spaces and line breaks
    clean_txt = re.sub(r'\n', ' ', text)
    clean_txt = re.sub(r'\s+', ' ', clean_txt)
    clean_txt = clean_txt.strip()

    # Tokenizing text
    tokens = nltk.word_tokenize(clean_txt)

    # Loading NLTK stopword list and adding original stopwords
    stop_words = set(stopwords.words('english')+['chwesl event','global','nsw','australian','pp','mean,','fhd','trend','good','good good','department','alert','wave','heatwave','million','na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health','heat','temperature','change','risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])
    # Adding custom stopwords directly to the set
    custom_stopwords = set(['chwesl event','global','nsw','australian','pp','mean','fhd','trend','good','good good','department','alert','wave','heatwave','million','na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health', 'heat', 'temperature', 'change', 'risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])
    stop_words.update(custom_stopwords)

    # Standardize the text and removing non-alphabetic or stop words
    words = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

    # Defining lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Conducting POS tagging
    pos_tags = nltk.pos_tag(words)

    # Lemmatizing word-tokens via assigned POS tags
    lemma_tokens = [lemmatizer.lemmatize(token, wordnet_pos_tags(pos_tag)) for token, pos_tag in pos_tags]

    return lemma_tokens

# %% [markdown]
# *Iteration function*

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def iterate_pdf_files(pdf_folder):
    # Creating a dictionary to display all documents and tokens together
    docs = {}

    # Counting to track the number of processed texts
    text_count = 0

    # Iterating over each file in the folder
    for filename in os.listdir(pdf_folder):

        # Checking whether the files are PDFs
        if filename.endswith('.pdf'):

            # Creating a path to the PDF files
            pdf_path = os.path.join(pdf_folder, filename)

            # Extracting the content of files
            text = extract_text_from_pdf(pdf_path)

            # Applying the preprocessing pipeline to the extracted tex
            preprocessed_text = txt_preprocess_pipeline(text)

            # Generating a unique name for the document based on the length of the docs dictionary for ease in readibility
            doc_name = f'doc{len(docs) + 1}'

            # Assigning the preprocessed text content of the current document in the docs dictionary with the document name as the key
            docs[doc_name] = [preprocessed_text]

            # Increasing the text count when finished assigning
            text_count += 1

    return docs

pdf_folder = '/content/drive/MyDrive/Documents/drm'

# Calling the iterate_pdf_files function to get the dictionary of documents
docs = iterate_pdf_files(pdf_folder)

# Printing each document's tokens as a list
for doc_name, tokens in docs.items():
    print(f"{doc_name}: {tokens}")

# %% [markdown]
# *Token dictionary*

# %%
# Iterating over the values in the docs dictionary created in the previous step. Each value in the sublist represents the tokens in a certain document
all_preprocessed_text = [token for sublist in docs.values() for token in sublist]

# Creating a gensim dictionary to assign an integer ID to each token
dictionary = corpora.Dictionary(all_preprocessed_text)
print(dictionary)

# %% [markdown]
# *BoW representation*

# %%
# Creating a Bag-of-Words (BoW) representation of the preprocessed text data using the dictionary created in the previous step
bow_corpus = [dictionary.doc2bow(text) for text in all_preprocessed_text]
pprint.pprint(bow_corpus)

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(bow_corpus))

# %% [markdown]
# ### TF-IDF

# %%
# Creating a TF-IDF model from the Bag-of-Words corpus
tfidf_model = TfidfModel(bow_corpus)

# Applying the TF-IDF model to the Bag-of-Words corpus to get the TF-IDF representation
tfidf_corpus = tfidf_model[bow_corpus]

# Printing the TF-IDF representation for the first few documents
for doc in tfidf_corpus[:5]:
    print(doc)

# %%
# Looking up the word corresponding to word_id = 0
word_id = 5
word = dictionary[word_id]
print("Word corresponding to word_id =", word_id, ":", word)

# %%
# Defining the TF-IDF threshold
threshold = 0.05

# Iterating through the TF-IDF representation of the documents
for doc in tfidf_corpus[:5]:  # Iterating over the first few documents

    # Filtering words with TF-IDF scores above the threshold
    words_above_threshold = [(dictionary[word_id], tfidf_score) for word_id, tfidf_score in doc if tfidf_score > threshold]

    # Printing the words with TF-IDF scores above the threshold
    print("Words with TF-IDF score > 0.05:", words_above_threshold)
# Out:
# Words with TF-IDF score > 0.05: [('bulb', 0.06466934480722977), ('calculate', 0.06224828377643545), ('countermeasure', 0.17600840977243404), ('countermeasures', 0.06400305809906692), ('dangerous', 0.05982551304958181), ('eq', 0.14107080943897718), ('exhibition', 0.06400305809906692), ('expo', 0.42791602469163187), ('ground', 0.09038670123519861), ('humidity', 0.06787976069048968), ('infrared', 0.06474103857589078), ('japanese', 0.11415455367215344), ('kobe', 0.06400305809906692), ('marathon', 0.10653329515291082), ('meteorological', 0.051930314141160956), ('mist', 0.17264276953570873), ('observatory', 0.1313411487569437), ('olympics', 0.06400305809906692), ('osaka', 0.26633323788227703), ('prefectural', 0.062266120184810966), ('radiant', 0.06500470160990773), ('radiation', 0.2966694785811324), ('shade', 0.10824340003087206), ('site', 0.11868491631345558), ('solar', 0.18275281809696894), ('spray', 0.18500703230910703), ('stroke', 0.061853856100280616), ('sunny', 0.11100421938546425), ('surface', 0.05686361561519431), ('takebayashi', 0.1420443935372144), ('td', 0.09652998109136889), ('tg', 0.191824424861766), ('thermal', 0.06001793182052843), ('tokyo', 0.11585645721011702), ('tw', 0.12428884434506261), ('uncomfortable', 0.16412998104766577), ('velocity', 0.1358992549723059), ('wbgt', 0.3409211228108615), ('wind', 0.05931627268559909)]
# Words with TF-IDF score > 0.05: [('ahmedabad', 0.161757274015941), ('aidmi', 0.29173104657637783), ('ainsley', 0.05676278898939127), ('akash', 0.05676278898939127), ('asia', 0.11032357235135251), ('bangladesh', 0.07871237319024005), ('bhatt', 0.1303705117593561), ('cbga', 0.05676278898939127), ('chakrabarti', 0.05676278898939127), ('click', 0.059259323526980046), ('coal', 0.07413123874727293), ('coat', 0.06430120075717062), ('corrugate', 0.14567617835736785), ('dhaka', 0.06430120075717062), ('dorothea', 0.05676278898939127), ('electricity', 0.0509297605883672), ('evn', 0.05676278898939127), ('ews', 0.0756837186525217), ('gujarat', 0.07304174866918703), ('heatwaves', 0.2864761670126682), ('hilhorst', 0.05676278898939127), ('hoisa', 0.17028836696817382), ('humanitarian', 0.11423718108739546), ('icva', 0.05676278898939127), ('informal', 0.11519108392040385), ('iron', 0.21522487066055446), ('iss', 0.06474496815883016), ('keya', 0.05676278898939127), ('khayal', 0.05676278898939127), ('labourer', 0.05028472655825631), ('livelihood', 0.09662822381799059), ('mihir', 0.13492429083869015), ('niladri', 0.05676278898939127), ('oxide', 0.06885545811298835), ('paint', 0.0638574333555111), ('pathak', 0.06474496815883016), ('poultry', 0.0820173999560589), ('prabodh', 0.0756837186525217), ('rcdc', 0.2459720856206955), ('recyclers', 0.0756837186525217), ('sewa', 0.21333356469712816), ('south', 0.07675054404170013), ('soutrik', 0.05676278898939127), ('student', 0.0591002536201893), ('trahan', 0.05676278898939127), ('trivedi', 0.05676278898939127), ('vendor', 0.052808297788245084), ('vietnam', 0.15316205903642327), ('vishal', 0.06474496815883016), ('woman', 0.12994830099660803), ('worker', 0.08510958492275471)]
# Words with TF-IDF score > 0.05: [('building', 0.05670196378477415), ('tree', 0.06876960174742022), ('fire', 0.055894519734329205), ('heatwaves', 0.12106427261258167), ('interviewee', 0.06528418500445532), ('manchester', 0.07529671835630986), ('organisation', 0.05015715233257998), ('participant', 0.3045255677335213), ('policy', 0.05892038599336493), ('preparedness', 0.05521240916334778), ('prioritise', 0.05656125141936466), ('resilience', 0.05051701904833324), ('responder', 0.07891993036528626), ('uk', 0.22205856521562312), ('wildlife', 0.06343149601335457), ('workplace', 0.05364524094392345), ('beis', 0.05211152435876629), ('brigade', 0.07409583124167825), ('commitment', 0.09042011455803231), ('england', 0.2986850519549334), ('grantham', 0.11739611788801342), ('howarth', 0.06924643237854874), ('london', 0.15070019093005385), ('mcloughlin', 0.05356519582825499), ('miranda', 0.05356519582825499), ('nap', 0.15741926001000292), ('overheat', 0.4376773224921465), ('overheating', 0.05211152435876629), ('rail', 0.059761686952150894), ('retrofit', 0.07421618191705319), ('wildfire', 0.06414828310604605), ('yorkshire', 0.11541072063091457), ('zero', 0.05879745381717109)]
# Words with TF-IDF score > 0.05: [('technology', 0.05517666726856947), ('ew', 0.3138544627549618), ('ews', 0.25622698170604497), ('resilience', 0.052417833905140994), ('theme', 0.061318919530953586), ('warning', 0.0640342369173302), ('africa', 0.10502468633041442), ('ai', 0.13631319713459347), ('betweenness', 0.06317925576313438), ('bibliographic', 0.056159338456119444), ('bibliometric', 0.19655768459641806), ('blockchain', 0.14741826344731354), ('centrality', 0.1614580980613434), ('closeness', 0.056159338456119444), ('cluster', 0.07348891270544719), ('crossref', 0.42753263419400406), ('device', 0.05770587161011781), ('drone', 0.05952986045739297), ('historiography', 0.056159338456119444), ('iot', 0.174154039835219), ('pagerank', 0.056159338456119444), ('pubmed', 0.07576527694577287), ('sadc', 0.5195333276281568), ('scientiﬁc', 0.11905972091478594), ('scopus', 0.08423900768417916), ('sensor', 0.07316855042618955), ('ﬂood', 0.06996114128564732)]
# Words with TF-IDF score > 0.05: [('cloud', 0.1199239664481839), ('instrument', 0.08861125822111846), ('actor', 0.12617473861486878), ('definition', 0.05981456420487788), ('diverse', 0.05252881837144369), ('ews', 0.07987661197073212), ('gap', 0.06551973074463258), ('governance', 0.24380982709007062), ('leadership', 0.08615845243062661), ('literacy', 0.11546724643202314), ('partner', 0.0671882232437235), ('ramirez', 0.0683318524876416), ('sectoral', 0.05787165312999818), ('solution', 0.12284949514618607), ('systemic', 0.05996198322409195), ('theme', 0.1268584625360203), ('un', 0.05626562590774801), ('wmo', 0.07716220417333092), ('audience', 0.14196773251137776), ('brief', 0.055306354362391), ('cascade', 0.07137716942567895), ('concurrently', 0.05307051057822698), ('consultant', 0.06167062105284646), ('identified', 0.053888645321834426), ('unaddressed', 0.06157860111018871), ('workshop', 0.08811802134136446), ('itu', 0.05678709300455111), ('package', 0.33309345731983514), ('undrr', 0.07987661197073212), ('word', 0.07049441707309156), ('abiyant', 0.07987661197073212), ('affirm', 0.06157860111018871), ('aims', 0.05678709300455111), ('amelia', 0.12315720222037742), ('arrighi', 0.05003384162709821), ('ashley', 0.06157860111018871), ('bishop', 0.07987661197073212), ('carlos', 0.05678709300455111), ('coe', 0.34072255802730667), ('considerate', 0.07987661197073212), ('cuellar', 0.07987661197073212), ('daniela', 0.05678709300455111), ('dearman', 0.06157860111018871), ('deliverable', 0.15010152488129463), ('deliverables', 0.07987661197073212), ('digest', 0.05003384162709821), ('duke', 0.05678709300455111), ('durham', 0.05678709300455111), ('excellence', 0.08656118049929062), ('ghhin', 0.21228204231290793), ('girardet', 0.0683318524876416), ('glenn', 0.06157860111018871), ('goverance', 0.07987661197073212), ('hieber', 0.0683318524876416), ('hondula', 0.07987661197073212), ('iom', 0.05003384162709821), ('iwmi', 0.06157860111018871), ('joy', 0.05307051057822698), ('julie', 0.05678709300455111), ('keith', 0.05307051057822698), ('kendrovski', 0.05678709300455111), ('kotani', 0.0683318524876416), ('ladd', 0.0683318524876416), ('legislator', 0.07987661197073212), ('loretta', 0.0683318524876416), ('marisol', 0.0683318524876416), ('martyn', 0.06157860111018871), ('menu', 0.06157860111018871), ('mhews', 0.1366637049752832), ('nairn', 0.05003384162709821), ('nicholas', 0.05678709300455111), ('offs', 0.05307051057822698), ('phoenix', 0.05307051057822698), ('puley', 0.06157860111018871), ('rcrc', 0.07987661197073212), ('resrouces', 0.07987661197073212), ('rui', 0.07987661197073212), ('sandholz', 0.07987661197073212), ('scoping', 0.12457725328540943), ('scrambling', 0.07987661197073212), ('scratch', 0.06157860111018871), ('shin', 0.06157860111018871), ('simone', 0.06157860111018871), ('steward', 0.06157860111018871), ('undermined', 0.06157860111018871), ('unu', 0.05678709300455111), ('vargas', 0.0683318524876416), ('vladimir', 0.05307051057822698), ('wellcome', 0.06157860111018871), ('wrap', 0.05678709300455111), ('yglesia', 0.07987661197073212)]

# %% [markdown]
# ### N-grams

# %%
# Taking a list of tokens as input and generating n-grams
def generate_ngrams(tokens, n=3):
    return list(nltk_ngrams(tokens, n))

# Creating n-gram model from a corpus
def create_ngram_model(corpus, n=3):
    ngram_model = defaultdict(int)
    for text in corpus:
        tokens = word_tokenize(text)
        ngrams = generate_ngrams(tokens, n)
        for ngram in ngrams:
            ngram_model[ngram] += 1
    return ngram_model

max_texts_to_process = None
docs = iterate_pdf_files(pdf_folder)

# Concatenating preprocessed tokens for each document into a single list of tokens
corpus_tokens = [tokens for sublist in docs.values() for tokens in sublist]

# Concatenating tokens into a single string for each document
corpus_strings = [' '.join(tokens) for tokens in corpus_tokens]

# Creating an n-gram model
ngram_model = create_ngram_model(corpus_strings, n=3)

# Printing all n-grams
print("All N-grams:")
for ngram, frequency in ngram_model.items():
    print(ngram, ":", frequency)

# %%
# Filtering n-grams with frequency greater than 1
filtered_ngram_model = {ngram: frequency for ngram, frequency in ngram_model.items() if frequency > 1}

# Printing filtered n-grams
print("Filtered N-grams:")
for ngram, frequency in filtered_ngram_model.items():
    print(ngram, ":", frequency)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('rag', 'forest', 'fire') : 2
# ('british', 'columbia', 'wildfire') : 2
# ('affect', 'physical', 'biological') : 2
# ('incidence', 'severity', 'expect') : 2
# ('number', 'fire', 'area') : 2
# ('fire', 'area', 'burn') : 2
# ('area', 'burn', 'canada') : 2
# ('ha', 'fire', 'ha') : 3
# ('fire', 'ha', 'fire') : 3
# ('source', 'brian', 'stock') : 2
# ('brian', 'stock', 'natural') : 2
# ('stock', 'natural', 'resource') : 2
# ('canadian', 'forest', 'fire') : 3
# ('major', 'fire', 'year') : 2
# ('account', 'total', 'area') : 2
# ('total', 'area', 'burn') : 3
# ('fire', 'grow', 'large') : 2
# ('canadian', 'fire', 'agency') : 2
# ('large', 'area', 'burn') : 2
# ('condition', 'multiple', 'ignition') : 2
# ('ontario', 'manitoba', 'saskatchewan') : 2
# ('area', 'forest', 'fire') : 2
# ('fire', 'danger', 'condition') : 2
# ('home', 'defensible', 'space') : 4
# ('trim', 'tree', 'branch') : 2
# ('prevent', 'accumulation', 'leave') : 2
# ('accumulation', 'leave', 'needle') : 2
# ('lake', 'ha', 'ha') : 2
# ('time', 'year', 'least') : 2
# ('flood', 'disaster', 'occur') : 5
# ('avoid', 'development', 'flood') : 2
# ('development', 'flood', 'prone') : 2
# ('normal', 'water', 'level') : 3
# ('water', 'level', 'inundate') : 2
# ('flood', 'canada', 'flood') : 2
# ('canada', 'flood', 'cause') : 2
# ('flood', 'ice', 'jam') : 2
# ('common', 'type', 'canada') : 2
# ('river', 'flood', 'result') : 2
# ('event', 'ever', 'record') : 2
# ('july', 'montreal', 'quebec') : 2
# ('ice', 'jam', 'flood') : 3
# ('jam', 'flood', 'occur') : 2
# ('saint', 'john', 'river') : 2
# ('carry', 'away', 'flood') : 2
# ('canadian', 'pacific', 'railway') : 3
# ('see', 'section', 'storm') : 2
# ('section', 'storm', 'surge') : 2
# ('see', 'section', 'tsunami') : 3
# ('system', 'coastal', 'area') : 2
# ('seasonal', 'distribution', 'flood') : 2
# ('table', 'list', 'canada') : 2
# ('list', 'canada', 'bad') : 2
# ('financial', 'assistance', 'arrangement') : 5
# ('new', 'brunswick', 'nova') : 2
# ('brunswick', 'nova', 'scotia') : 2
# ('new', 'brunswick', 'source') : 2
# ('increase', 'population', 'urbanization') : 2
# ('land', 'practice', 'protect') : 2
# ('business', 'vulnerable', 'area') : 2
# ('emergency', 'survival', 'kit') : 3
# ('synthesis', 'geological', 'hazard') : 7
# ('geological', 'hazard', 'canada') : 8
# ('hazard', 'canada', 'geological') : 2
# ('canada', 'geological', 'survey') : 5
# ('geological', 'survey', 'canada') : 20
# ('survey', 'canada', 'bulletin') : 3
# ('flood', 'hazard', 'canada') : 2
# ('assessment', 'flood', 'hazard') : 2
# ('make', 'difficult', 'see') : 2
# ('figure', 'show', 'distribution') : 2
# ('coast', 'nova', 'scotia') : 2
# ('west', 'coast', 'vancouver') : 2
# ('source', 'read', 'environment') : 4
# ('read', 'environment', 'canada') : 4
# ('source', 'etkin', 'brun') : 2
# ('british', 'columbia', 'alberta') : 2
# ('canada', 'bad', 'hailstorm') : 2
# ('disaster', 'see', 'table') : 4
# ('see', 'section', 'tornado') : 2
# ('occur', 'late', 'early') : 2
# ('late', 'early', 'evening') : 3
# ('hour', 'day', 'night') : 2
# ('calgary', 'alberta', 'july') : 7
# ('alberta', 'july', 'calgary') : 4
# ('july', 'calgary', 'alberta') : 5
# ('alberta', 'july', 'southern') : 2
# ('july', 'edmonton', 'alberta') : 3
# ('edmonton', 'alberta', 'july') : 3
# ('alberta', 'calgary', 'alberta') : 2
# ('montreal', 'quebec', 'june') : 2
# ('extensive', 'property', 'damage') : 2
# ('weather', 'watch', 'warning') : 4
# ('seek', 'shelter', 'immediately') : 2
# ('source', 'read', 'etkin') : 2
# ('canada', 'environment', 'canada') : 4
# ('environment', 'canada', 'prairie') : 4
# ('canada', 'prairie', 'northern') : 3
# ('prairie', 'northern', 'region') : 3
# ('ontario', 'ministry', 'labour') : 2
# ('three', 'successive', 'day') : 2
# ('cause', 'serious', 'illness') : 2
# ('european', 'country', 'experience') : 2
# ('exposure', 'physical', 'activity') : 3
# ('physical', 'activity', 'caution') : 2
# ('possible', 'prolonged', 'exposure') : 2
# ('prolonged', 'exposure', 'physical') : 2
# ('give', 'sip', 'cool') : 2
# ('sip', 'cool', 'water') : 2
# ('people', 'live', 'without') : 2
# ('vehicle', 'factory', 'air') : 2
# ('factory', 'air', 'conditioner') : 2
# ('time', 'air', 'condition') : 2
# ('natural', 'hazard', 'nos') : 2
# ('september', 'hurricane', 'juan') : 3
# ('eastern', 'eyewall', 'storm') : 2
# ('canadian', 'hurricane', 'centre') : 7
# ('experience', 'significant', 'loss') : 3
# ('issue', 'environment', 'canada') : 3
# ('environment', 'canada', 'hurricane') : 3
# ('canada', 'hurricane', 'juan') : 3
# ('hurricane', 'kilometre', 'diameter') : 2
# ('category', 'hurricane', 'make') : 2
# ('experience', 'tropical', 'storm') : 2
# ('one', 'tropical', 'cyclone') : 2
# ('tropical', 'cyclone', 'every') : 2
# ('cyclone', 'every', 'year') : 2
# ('one', 'tropical', 'storm') : 2
# ('tropical', 'storm', 'every') : 2
# ('storm', 'every', 'year') : 2
# ('environment', 'canada', 'canadian') : 2
# ('canada', 'canadian', 'hurricane') : 2
# ('ocean', 'temperature', 'change') : 2
# ('change', 'climatic', 'factor') : 2
# ('storm', 'surge', 'strong') : 2
# ('hurricane', 'create', 'storm') : 2
# ('create', 'storm', 'surge') : 3
# ('area', 'usually', 'within') : 2
# ('usually', 'within', 'hour') : 2
# ('know', 'deep', 'water') : 2
# ('fire', 'source', 'read') : 2
# ('positive', 'storm', 'surge') : 2
# ('negative', 'storm', 'surge') : 2
# ('wind', 'wind', 'parallel') : 2
# ('wind', 'parallel', 'shore') : 2
# ('parallel', 'shore', 'shore') : 2
# ('storm', 'surge', 'forecast') : 2
# ('wind', 'push', 'water') : 2
# ('along', 'atlantic', 'coast') : 2
# ('area', 'storm', 'surge') : 2
# ('coastal', 'area', 'especially') : 2
# ('track', 'weather', 'system') : 2
# ('environment', 'canada', 'warning') : 2
# ('environment', 'canada', 'statement') : 2
# ('university', 'corporation', 'atmospheric') : 2
# ('corporation', 'atmospheric', 'research') : 2
# ('kill', 'people', 'injure') : 2
# ('people', 'injure', 'hundred') : 2
# ('hail', 'storm', 'hit') : 2
# ('georgian', 'bay', 'kingston') : 2
# ('hail', 'lightning', 'heavy') : 2
# ('lightning', 'heavy', 'rain') : 2
# ('severe', 'weather', 'element') : 2
# ('air', 'aloft', 'dry') : 2
# ('fall', 'updraft', 'destroy') : 2
# ('factor', 'influence', 'development') : 2
# ('occur', 'part', 'canada') : 2
# ('canada', 'issue', 'severe') : 3
# ('issue', 'severe', 'weather') : 4
# ('severe', 'weather', 'watch') : 2
# ('watch', 'severe', 'thunderstorm') : 2
# ('severe', 'thunderstorm', 'watch') : 2
# ('watch', 'issue', 'severe') : 2
# ('thunderstorm', 'expect', 'develop') : 2
# ('weather', 'warning', 'severe') : 2
# ('severe', 'weather', 'occur') : 3
# ('try', 'provide', 'lead') : 2
# ('warning', 'severe', 'thunderstorm') : 3
# ('heavy', 'rain', 'warn') : 3
# ('community', 'mitigate', 'engaging') : 2
# ('offer', 'little', 'protection') : 2
# ('property', 'damage', 'four') : 2
# ('one', 'canada', 'worst') : 2
# ('canada', 'worst', 'natural') : 2
# ('dead', 'hundred', 'injure') : 3
# ('hundred', 'injure', 'damage') : 2
# ('dead', 'injured', 'damage') : 2
# ('tornado', 'account', 'tornado') : 2
# ('roof', 'blow', 'home') : 2
# ('exterior', 'wall', 'roof') : 2
# ('great', 'distance', 'tornado') : 2
# ('table', 'frequency', 'tornado') : 2
# ('que', 'man', 'alta') : 2
# ('emergency', 'plan', 'place') : 2
# ('quebec', 'eastern', 'ontario') : 2
# ('type', 'winter', 'storm') : 3
# ('winter', 'storm', 'common') : 2
# ('source', 'modify', 'stewart') : 2
# ('snow', 'condition', 'typically') : 3
# ('along', 'west', 'coast') : 2
# ('issue', 'special', 'weather') : 2
# ('weather', 'statement', 'winter') : 2
# ('statement', 'winter', 'storm') : 2
# ('winter', 'storm', 'watch') : 3
# ('winter', 'weather', 'warning') : 4
# ('condition', 'favorable', 'development') : 2
# ('favorable', 'development', 'severe') : 2
# ('rain', 'warn', 'heavy') : 2
# ('warn', 'heavy', 'rain') : 2
# ('windchill', 'warn', 'cold') : 2
# ('winter', 'storm', 'warn') : 2
# ('weather', 'warning', 'environment') : 2
# ('baker', 'kovacs', 'natural') : 2
# ('kovacs', 'natural', 'hazard') : 2
# ('hazard', 'canadian', 'insurance') : 2
# ('canadian', 'insurance', 'industry') : 4
# ('loss', 'reduction', 'institute') : 2
# ('reduction', 'institute', 'business') : 2
# ('los', 'angeles', 'area') : 2
# ('antelope', 'valley', 'freeway') : 2
# ('valley', 'freeway', 'collapse') : 2
# ('freeway', 'collapse', 'onto') : 2
# ('collapse', 'onto', 'golden') : 2
# ('onto', 'golden', 'state') : 2
# ('golden', 'state', 'freeway') : 2
# ('santa', 'monica', 'freeway') : 2
# ('source', 'transportation', 'federal') : 2
# ('transportation', 'federal', 'highway') : 2
# ('federal', 'highway', 'administration') : 2
# ('highway', 'administration', 'roads') : 2
# ('administration', 'roads', 'summer') : 2
# ('return', 'original', 'shape') : 2
# ('source', 'institute', 'crustal') : 2
# ('institute', 'crustal', 'study') : 2
# ('crustal', 'study', 'university') : 2
# ('study', 'university', 'california') : 2
# ('california', 'santa', 'barbara') : 2
# ('santa', 'barbara', 'understand') : 2
# ('barbara', 'understand', 'earthquake') : 2
# ('vertical', 'ground', 'motion') : 2
# ('occur', 'annually', 'canada') : 2
# ('coast', 'british', 'columbia') : 2
# ('ten', 'million', 'dollar') : 2
# ('tsunami', 'kill', 'people') : 2
# ('three', 'type', 'margin') : 2
# ('source', 'geological', 'survey') : 2
# ('family', 'member', 'understand') : 2
# ('sécurité', 'publique', 'québec') : 2
# ('provincial', 'emergency', 'program') : 11
# ('canadian', 'centre', 'emergency') : 4
# ('hazard', 'synthesis', 'geological') : 2
# ('hazard', 'canada', 'brook') : 4
# ('canada', 'brook', 'ed') : 4
# ('brook', 'ed', 'gsc') : 5
# ('ed', 'gsc', 'bulletin') : 5
# ('southwestern', 'british', 'columbia') : 2
# ('geomagnetic', 'storm', 'march') : 2
# ('eruption', 'know', 'solar') : 2
# ('know', 'solar', 'flare') : 2
# ('interact', 'magnetic', 'field') : 2
# ('electrical', 'transmission', 'system') : 2
# ('hundred', 'thousand', 'kilometre') : 2
# ('canadian', 'geomagnetism', 'program') : 2
# ('vulnerable', 'geomagnetic', 'storm') : 2
# ('geomagnetic', 'storm', 'electrical') : 2
# ('thousand', 'kilometres', 'electrical') : 2
# ('kilometres', 'electrical', 'power') : 2
# ('regain', 'control', 'anik') : 2
# ('way', 'reduce', 'vulnerability') : 3
# ('reduce', 'vulnerability', 'example') : 2
# ('operate', 'geological', 'survey') : 2
# ('space', 'weather', 'canada') : 2
# ('boteler', 'geomagnetic', 'hazard') : 2
# ('landslide', 'disaster', 'canadian') : 2
# ('disaster', 'canadian', 'history') : 2
# ('sidebar', 'frank', 'rock') : 2
# ('cordillera', 'western', 'canada') : 2
# ('sensitive', 'marine', 'sediment') : 2
# ('failure', 'landslides', 'occur') : 2
# ('prevent', 'loss', 'life') : 2
# ('build', 'defensive', 'dyke') : 2
# ('defensive', 'dyke', 'protect') : 2
# ('change', 'surface', 'water') : 2
# ('surface', 'water', 'drainage') : 2
# ('source', 'british', 'columbia') : 2
# ('british', 'columbia', 'provincial') : 6
# ('columbia', 'provincial', 'emergency') : 6
# ('science', 'v', 'advocacy') : 2
# ('low', 'part', 'slope') : 2
# ('survey', 'canada', 'sidebar') : 2
# ('resource', 'geological', 'survey') : 3
# ('snow', 'avalanche', 'occur') : 2
# ('sidebar', 'avalanche', 'death') : 2
# ('british', 'columbia', 'yukon') : 2
# ('columbia', 'yukon', 'territory') : 2
# ('snow', 'move', 'downslope') : 2
# ('source', 'canadian', 'avalanche') : 2
# ('canadian', 'avalanche', 'association') : 3
# ('snow', 'avalanche', 'size') : 2
# ('avalanche', 'size', 'classification') : 2
# ('forest', 'area', 'hectares') : 2
# ('control', 'ski', 'area') : 2
# ('condition', 'typically', 'result') : 2
# ('typically', 'result', 'series') : 2
# ('council', 'canada', 'dbr') : 2
# ('avalanche', 'accident', 'canada') : 2
# ('snow', 'avalanche', 'hazard') : 2
# ('prince', 'william', 'sound') : 4
# ('along', 'pacific', 'coast') : 2
# ('sidebar', 'bad', 'friday') : 2
# ('british', 'columbia', 'community') : 2
# ('british', 'columbia', 'source') : 2
# ('british', 'columbia', 'civil') : 2
# ('columbia', 'civil', 'defense') : 2
# ('civil', 'defense', 'circular') : 2
# ('defense', 'circular', 'summer') : 2
# ('circular', 'summer', 'edition') : 2
# ('summer', 'edition', 'special') : 2
# ('edition', 'special', 'alberni') : 2
# ('special', 'alberni', 'tidal') : 2
# ('alberni', 'tidal', 'disaster') : 2
# ('ford', 'charles', 'tidal') : 2
# ('charles', 'tidal', 'british') : 2
# ('tidal', 'british', 'columbia') : 2
# ('strong', 'ground', 'shake') : 2
# ('hazard', 'mitigation', 'program') : 2
# ('pyroclastic', 'surge', 'hot') : 2
# ('source', 'state', 'geological') : 2
# ('accurately', 'assess', 'much') : 2
# ('subduction', 'zone', 'juan') : 2
# ('zone', 'juan', 'fuca') : 2
# ('pacific', 'ring', 'fire') : 2
# ('stikine', 'volcanic', 'belt') : 2
# ('volcanic', 'belt', 'british') : 2
# ('belt', 'british', 'columbia') : 2
# ('volcano', 'western', 'canada') : 2
# ('british', 'airway', 'boeing') : 2
# ('airway', 'boeing', 'aircraft') : 2
# ('survey', 'canada', 'volcano') : 2
# ('canada', 'volcano', 'canada') : 2
# ('property', 'expose', 'hazard') : 2
# ('chance', 'hazard', 'occur') : 2
# ('see', 'section', 'prediction') : 2
# ('without', 'outside', 'assistance') : 2
# ('impact', 'hazardous', 'event') : 2
# ('example', 'emergency', 'ontario') : 2
# ('many', 'insurance', 'company') : 2
# ('community', 'richmond', 'south') : 2
# ('richmond', 'south', 'vancouver') : 2
# ('south', 'vancouver', 'fear') : 2
# ('vancouver', 'fear', 'flood') : 2
# ('fear', 'flood', 'event') : 2
# ('flood', 'event', 'fraser') : 2
# ('event', 'fraser', 'river') : 2
# ('flood', 'dartmouth', 'flood') : 2
# ('dartmouth', 'flood', 'observatory') : 3
# ('resource', 'canada', 'earthquake') : 2
# ('canada', 'earthquake', 'canada') : 2
# ('canada', 'maps', 'history') : 2
# ('maps', 'history', 'research') : 2
# ('canada', 'meteorological', 'service') : 2
# ('bulletin', 'etkin', 'haque') : 2
# ('mileti', 'disaster', 'design') : 2
# ('disaster', 'design', 'reassessment') : 3
# ('design', 'reassessment', 'natural') : 3
# ('reassessment', 'natural', 'hazard') : 3
# ('natural', 'hazard', 'state') : 3
# ('hazard', 'state', 'joseph') : 3
# ('state', 'joseph', 'henry') : 3
# ('joseph', 'henry', 'press') : 3
# ('henry', 'press', 'washington') : 3
# ('timely', 'warning', 'forecast') : 2
# ('well', 'advice', 'respond') : 2
# ('see', 'section', 'mitigation') : 2
# ('section', 'emergency', 'preparedness') : 2
# ('help', 'define', 'risk') : 2
# ('community', 'face', 'year') : 2
# ('face', 'year', 'decade') : 2
# ('year', 'decade', 'ahead') : 2
# ('maker', 'community', 'member') : 2
# ('predict', 'natural', 'event') : 2
# ('make', 'accurate', 'prediction') : 3
# ('prediction', 'lead', 'time') : 2
# ('forecast', 'weather', 'watch') : 2
# ('present', 'future', 'hazardous') : 2
# ('canada', 'see', 'section') : 2
# ('survey', 'canada', 'gsc') : 2
# ('see', 'section', 'landslide') : 2
# ('resource', 'canada', 'geological') : 3
# ('adapt', 'natural', 'hazard') : 2
# ('risk', 'associated', 'natural') : 2
# ('builder', 'build', 'house') : 2
# ('build', 'house', 'one') : 2
# ('construct', 'properly', 'house') : 2
# ('event', 'become', 'disaster') : 2
# ('make', 'vulnerable', 'hazard') : 2
# ('disaster', 'cost', 'rise') : 2
# ('see', 'section', 'disaster') : 3
# ('natural', 'disaster', 'natural') : 4
# ('response', 'recovery', 'mitigation') : 2
# ('locate', 'help', 'victim') : 2
# ('help', 'victim', 'rebuild') : 2
# ('saguenay', 'flood', 'quebec') : 2
# ('human', 'control', 'nature') : 2
# ('become', 'well', 'adapt') : 3
# ('research', 'mitigation', 'investment') : 2
# ('impact', 'risk', 'associated') : 2
# ('undertake', 'mitigation', 'effort') : 2
# ('emergency', 'measure', 'organization') : 8
# ('measure', 'organization', 'emo') : 2
# ('provincial', 'territorial', 'emos') : 3
# ('implement', 'community', 'emergency') : 2
# ('community', 'emergency', 'plan') : 2
# ('emergency', 'plan', 'program') : 2
# ('government', 'federal', 'government') : 2
# ('disaster', 'financial', 'assistance') : 11
# ('assistance', 'arrangement', 'dfaa') : 4
# ('community', 'emergency', 'program') : 3
# ('need', 'vulnerable', 'group') : 2
# ('manitoba', 'emergency', 'measure') : 2
# ('map', 'extent', 'damage') : 5
# ('canada', 'centre', 'remote') : 2
# ('centre', 'remote', 'sense') : 3
# ('remote', 'sense', 'ccrs') : 2
# ('remote', 'sense', 'application') : 2
# ('canada', 'remote', 'sense') : 2
# ('locate', 'stricken', 'area') : 2
# ('topographic', 'land', 'map') : 2
# ('land', 'cover', 'map') : 2
# ('regional', 'rainfall', 'evaporation') : 2
# ('rainfall', 'evaporation', 'transpiration') : 2
# ('evaporation', 'transpiration', 'rate') : 2
# ('weather', 'forecast', 'map') : 2
# ('forecast', 'map', 'extent') : 2
# ('canadian', 'space', 'agency') : 5
# ('sea', 'ice', 'iceberg') : 2
# ('fire', 'danger', 'monitor') : 2
# ('remote', 'sense', 'information') : 2
# ('disaster', 'assistance', 'program') : 4
# ('section', 'disaster', 'financial') : 2
# ('long', 'certain', 'condition') : 2
# ('certain', 'condition', 'meet') : 2
# ('provide', 'safety', 'victim') : 2
# ('resource', 'rebuild', 'damage') : 2
# ('rebuild', 'damage', 'property') : 2
# ('canada', 'government', 'private') : 2
# ('private', 'sector', 'provide') : 2
# ('sector', 'provide', 'insurance') : 2
# ('crop', 'insurance', 'program') : 3
# ('federal', 'provincial', 'government') : 3
# ('table', 'crop', 'insurance') : 2
# ('crop', 'insurance', 'cost') : 2
# ('sustainable', 'water', 'supply') : 2
# ('federal', 'provincial', 'territorial') : 2
# ('insurance', 'company', 'make') : 2
# ('loss', 'sewer', 'backup') : 2
# ('rise', 'property', 'value') : 2
# ('reduce', 'vulnerability', 'well') : 2
# ('federal', 'disaster', 'financial') : 2
# ('provincial', 'territorial', 'government') : 6
# ('maintain', 'prudent', 'level') : 2
# ('prudent', 'level', 'insurance') : 2
# ('readily', 'obtainable', 'private') : 2
# ('obtainable', 'private', 'source') : 2
# ('local', 'government', 'authority') : 2
# ('province', 'territory', 'government') : 2
# ('territory', 'government', 'canada') : 2
# ('assistance', 'provincial', 'territorial') : 2
# ('financial', 'assistance', 'dfa') : 2
# ('building', 'essential', 'operation') : 2
# ('federal', 'assistance', 'dfaa') : 2
# ('eligible', 'federal', 'assistance') : 2
# ('federal', 'assistance', 'give') : 2
# ('expense', 'eligible', 'federal') : 2
# ('eligible', 'federal', 'cost') : 2
# ('federal', 'cost', 'share') : 2
# ('normal', 'operating', 'expense') : 2
# ('restoration', 'replacement', 'repair') : 2
# ('dfaa', 'payouts', 'province') : 2
# ('grow', 'population', 'increase') : 2
# ('assist', 'develop', 'country') : 2
# ('determines', 'development', 'take') : 2
# ('development', 'take', 'place') : 2
# ('take', 'place', 'structure') : 2
# ('place', 'structure', 'build') : 2
# ('show', 'peak', 'ground') : 2
# ('loss', 'reduction', 'iclr') : 2
# ('canada', 'provide', 'information') : 2
# ('natural', 'hazard', 'canada') : 2
# ('space', 'agency', 'csa') : 2
# ('disaster', 'mitigation', 'strategy') : 2
# ('canadian', 'vulnerable', 'natural') : 2
# ('vulnerable', 'natural', 'disaster') : 2
# ('natural', 'disaster', 'could') : 2
# ('disaster', 'could', 'knowledge') : 2
# ('could', 'knowledge', 'skill') : 2
# ('skill', 'make', 'community') : 2
# ('community', 'safer', 'thing') : 2
# ('safer', 'thing', 'reduce') : 2
# ('thing', 'reduce', 'potential') : 2
# ('reduce', 'potential', 'disaster') : 2
# ('potential', 'disaster', 'enhance') : 2
# ('disaster', 'enhance', 'preparedness') : 2
# ('enhance', 'preparedness', 'disaster') : 2
# ('improve', 'ability', 'respond') : 2
# ('ability', 'respond', 'recover') : 2
# ('respond', 'recover', 'modify') : 2
# ('vulnerability', 'disaster', 'disaster') : 2
# ('disaster', 'disaster', 'loss') : 2
# ('human', 'toll', 'though') : 2
# ('toll', 'though', 'less') : 2
# ('even', 'damage', 'event') : 2
# ('damage', 'event', 'predict') : 2
# ('event', 'predict', 'future') : 2
# ('protect', 'disaster', 'demand') : 2
# ('disaster', 'demand', 'increase') : 2
# ('demand', 'increase', 'awareness') : 2
# ('increase', 'awareness', 'operation') : 2
# ('awareness', 'operation', 'commitment') : 2
# ('operation', 'commitment', 'corporation') : 2
# ('commitment', 'corporation', 'community') : 2
# ('corporation', 'community', 'group') : 2
# ('build', 'home', 'business') : 2
# ('population', 'growth', 'increase') : 2
# ('natural', 'ecosystem', 'increase') : 2
# ('produce', 'great', 'benefit') : 3
# ('reduce', 'vulnerability', 'flood') : 2
# ('vulnerability', 'arid', 'region') : 3
# ('arid', 'region', 'impact') : 3
# ('region', 'impact', 'adaptive') : 3
# ('impact', 'adaptive', 'strategy') : 3
# ('mechanism', 'make', 'possible') : 2
# ('strategic', 'environmental', 'assessment') : 4
# ('arab', 'water', 'council') : 4
# ('process', 'perspective', 'document') : 2
# ('managed', 'water', 'resource') : 2
# ('change', 'crop', 'type') : 2
# ('many', 'oping', 'country') : 2
# ('storm', 'surge', 'threaten') : 2
# ('require', 'immediate', 'attention') : 2
# ('one', 'country', 'another') : 2
# ('basin', 'home', 'people') : 2
# ('nile', 'basin', 'decision') : 2
# ('basin', 'decision', 'support') : 2
# ('land', 'assimilation', 'system') : 4
# ('land', 'surface', 'model') : 2
# ('water', 'flow', 'downstream') : 2
# ('regional', 'water', 'supply') : 2
# ('change', 'weather', 'condition') : 2
# ('state', 'water', 'resource') : 2
# ('kenya', 'arid', 'land') : 4
# ('land', 'resource', 'project') : 2
# ('yes', 'yes', 'yes') : 7
# ('renew', 'able', 'w') : 2
# ('able', 'w', 'ater') : 2
# ('w', 'ater', 'res') : 2
# ('allow', 'country', 'make') : 2
# ('ipcc', 'freshwater', 'resource') : 2
# ('research', 'work', 'bank') : 2
# ('bank', 'bank', 'project') : 2
# ('rapid', 'glacier', 'retreat') : 6
# ('glacier', 'retreat', 'tropical') : 5
# ('retreat', 'tropical', 'andes') : 5
# ('investment', 'moderate', 'investment') : 3
# ('moderate', 'investment', 'low') : 3
# ('investment', 'low', 'investment') : 3
# ('state', 'nature', 'severe') : 2
# ('moderate', 'low', 'probability') : 2
# ('payoff', 'cost', 'billion') : 2
# ('billion', 'dollar', 'expect') : 3
# ('dollar', 'expect', 'value') : 3
# ('michael', 'glantz', 'qian') : 3
# ('glantz', 'qian', 'ye') : 3
# ('usable', 'thought', 'water') : 4
# ('thought', 'water', 'weather') : 4
# ('water', 'weather', 'century') : 4
# ('introduction', 'rate', 'process') : 2
# ('rate', 'process', 'change') : 2
# ('process', 'change', 'year') : 2
# ('change', 'year', 'new') : 2
# ('gas', 'ghgs', 'atmosphere') : 4
# ('press', 'nation', 'university') : 2
# ('nation', 'university', 'jingumae') : 2
# ('university', 'jingumae', 'tokyo') : 2
# ('jingumae', 'tokyo', 'japan') : 3
# ('tokyo', 'japan', 'sale') : 2
# ('nation', 'plaza', 'room') : 2
# ('normal', 'university', 'china') : 2
# ('v', 'r', 'n') : 2
# ('r', 'n', 'n') : 2
# ('n', 'v', 'l') : 2
# ('truth', 'approach', 'deliver') : 2
# ('deliver', 'un', 'conso') : 2
# ('un', 'conso', 'ip') : 2
# ('conso', 'ip', 'fri') : 2
# ('ip', 'fri', 'fe') : 2
# ('fri', 'fe', 'c') : 2
# ('fe', 'c', 'bank') : 2
# ('c', 'bank', 'recons') : 2
# ('deliver', 'bank', 'un') : 122
# ('bank', 'un', 'consortium') : 130
# ('un', 'consortium', 'ip') : 130
# ('consortium', 'ip', 'fri') : 130
# ('ip', 'fri', 'feb') : 130
# ('fri', 'feb', 'c') : 130
# ('feb', 'c', 'bank') : 130
# ('c', 'bank', 'reconstruction') : 130
# ('development', 'bank', 'convenient') : 18
# ('inconvenient', 'truth', 'deliver') : 13
# ('truth', 'deliver', 'bank') : 13
# ('environmental', 'assessment', 'policy') : 2
# ('assessment', 'policy', 'instrument') : 2
# ('environmental', 'flow', 'water') : 2
# ('flow', 'water', 'resource') : 2
# ('water', 'resource', 'policy') : 2
# ('resource', 'policy', 'plan') : 2
# ('policy', 'plan', 'project') : 2
# ('approach', 'deliver', 'bank') : 6
# ('development', 'bank', 'bank') : 5
# ('natural', 'resource', 'ecosystem') : 3
# ('c', 'h', 'p') : 10
# ('h', 'p', 'r') : 10
# ('p', 'r', 'bank') : 2
# ('r', 'bank', 'biodiversity') : 2
# ('bank', 'biodiversity', 'conservation') : 10
# ('biodiversity', 'conservation', 'contribution') : 2
# ('impact', 'ecosystems', 'biodiversity') : 2
# ('impact', 'human', 'community') : 4
# ('human', 'community', 'livelihood') : 6
# ('protect', 'ecosystems', 'biodiversity') : 2
# ('ecosystems', 'biodiversity', 'matter') : 2
# ('biodiversity', 'matter', 'change') : 2
# ('p', 'r', 'natural') : 2
# ('r', 'natural', 'ecosystems') : 2
# ('natural', 'ecosystems', 'mitigation') : 12
# ('secure', 'carbon', 'store') : 2
# ('carbon', 'store', 'protection') : 2
# ('store', 'protection', 'restoration') : 2
# ('protection', 'restoration', 'natural') : 2
# ('restoration', 'natural', 'ecosystem') : 2
# ('protect', 'area', 'convenient') : 2
# ('area', 'convenient', 'solution') : 2
# ('convenient', 'solution', 'protect') : 2
# ('solution', 'protect', 'carbon') : 2
# ('protect', 'carbon', 'sink') : 5
# ('carbon', 'sink', 'ecosystem') : 4
# ('sink', 'ecosystem', 'service') : 4
# ('coastal', 'marine', 'system') : 2
# ('marine', 'system', 'carbon') : 2
# ('invest', 'alternative', 'energy') : 2
# ('p', 'r', 'reduce') : 2
# ('r', 'reduce', 'vulnerability') : 2
# ('restore', 'natural', 'ecosystem') : 4
# ('natural', 'ecosystem', 'reduce') : 2
# ('ecosystem', 'reduce', 'vulnerability') : 3
# ('adopt', 'indigenous', 'knowledge') : 2
# ('indigenous', 'knowledge', 'adapt') : 2
# ('area', 'marine', 'protect') : 2
# ('marine', 'protect', 'area') : 19
# ('invest', 'ecosystem', 'versus') : 2
# ('ecosystem', 'versus', 'infrastructure') : 2
# ('p', 'r', 'biodiversity') : 2
# ('r', 'biodiversity', 'conservation') : 2
# ('biodiversity', 'conservation', 'food') : 10
# ('conservation', 'food', 'water') : 10
# ('food', 'water', 'livelihood') : 10
# ('water', 'livelihood', 'security') : 10
# ('livelihood', 'security', 'emerge') : 2
# ('security', 'emerge', 'issue') : 2
# ('manage', 'invasive', 'alien') : 2
# ('invasive', 'alien', 'specie') : 34
# ('specie', 'deliver', 'bank') : 2
# ('development', 'bank', 'protect') : 2
# ('bank', 'protect', 'natural') : 2
# ('protect', 'natural', 'ecosystem') : 5
# ('natural', 'ecosystem', 'water') : 2
# ('ecosystem', 'water', 'service') : 2
# ('natural', 'water', 'tower') : 3
# ('p', 'r', 'implement') : 2
# ('r', 'implement', 'approach') : 2
# ('look', 'forward', 'strategic') : 2
# ('forward', 'strategic', 'framework') : 2
# ('grow', 'forest', 'partnership') : 6
# ('develop', 'financing', 'mechanism') : 2
# ('emission', 'deforestation', 'degradation') : 2
# ('secure', 'carbon', 'finance') : 3
# ('carbon', 'finance', 'bank') : 3
# ('finance', 'bank', 'minimum') : 3
# ('bank', 'minimum', 'project') : 3
# ('minimum', 'project', 'requirement') : 5
# ('monitor', 'biodiversity', 'hot') : 2
# ('biodiversity', 'hot', 'spot') : 6
# ('biodiversity', 'loss', 'hövsgöl') : 2
# ('loss', 'hövsgöl', 'park') : 2
# ('hövsgöl', 'park', 'mongolia') : 4
# ('likely', 'regional', 'impact') : 4
# ('regional', 'impact', 'human') : 2
# ('reforestation', 'biocarbon', 'fund') : 2
# ('resilience', 'promote', 'native') : 2
# ('promote', 'native', 'vegetation') : 2
# ('native', 'vegetation', 'mali') : 2
# ('economic', 'argument', 'sustainable') : 2
# ('argument', 'sustainable', 'forest') : 2
# ('sustainable', 'forest', 'carbon') : 3
# ('carbon', 'conservation', 'forest') : 2
# ('conservation', 'forest', 'indonesia') : 2
# ('nariva', 'wetland', 'restoration') : 2
# ('wetland', 'restoration', 'carbon') : 2
# ('restoration', 'carbon', 'offset') : 2
# ('carbon', 'offset', 'trinidad') : 2
# ('offset', 'trinidad', 'tobago') : 2
# ('grassland', 'capture', 'carbon') : 2
# ('capture', 'carbon', 'lesson') : 2
# ('carbon', 'lesson', 'china') : 2
# ('amazon', 'region', 'protect') : 6
# ('region', 'protect', 'area') : 6
# ('protect', 'area', 'program') : 4
# ('area', 'program', 'storehouse') : 2
# ('program', 'storehouse', 'carbon') : 2
# ('storehouse', 'carbon', 'biodiversity') : 2
# ('crucial', 'role', 'ocean') : 2
# ('economics', 'protect', 'coral') : 2
# ('protect', 'coral', 'reef') : 3
# ('reef', 'manado', 'ocean') : 2
# ('manado', 'ocean', 'declaration') : 8
# ('nakai', 'nam', 'theun') : 7
# ('nam', 'theun', 'forest') : 2
# ('theun', 'forest', 'conservation') : 2
# ('forest', 'conservation', 'protect') : 2
# ('conservation', 'protect', 'hydropower') : 2
# ('protect', 'hydropower', 'investment') : 2
# ('hydropower', 'investment', 'lao') : 2
# ('investment', 'lao', 'pdr') : 2
# ('biofuels', 'much', 'thing') : 2
# ('biological', 'corridor', 'change') : 2
# ('restore', 'low', 'danube') : 2
# ('rebuild', 'resilience', 'wetland') : 2
# ('resilience', 'wetland', 'ecosystems') : 2
# ('ecomarkets', 'costa', 'rica') : 2
# ('development', 'bank', 'measure') : 2
# ('measure', 'salinas', 'aguada') : 2
# ('salinas', 'aguada', 'blanca') : 7
# ('aguada', 'blanca', 'reserve') : 7
# ('blanca', 'reserve', 'peru') : 4
# ('address', 'impact', 'ocean') : 2
# ('impact', 'ocean', 'ecosystems') : 2
# ('ocean', 'ecosystems', 'coastal') : 2
# ('ecosystems', 'coastal', 'community') : 2
# ('coremap', 'coral', 'reef') : 5
# ('coral', 'reef', 'rehabilitation') : 7
# ('reef', 'rehabilitation', 'project') : 6
# ('rehabilitation', 'project', 'indonesia') : 2
# ('coral', 'triangle', 'initiative') : 8
# ('triangle', 'initiative', 'coral') : 2
# ('initiative', 'coral', 'reef') : 2
# ('coral', 'reef', 'fishery') : 2
# ('reef', 'fishery', 'food') : 2
# ('protect', 'natural', 'forest') : 2
# ('natural', 'forest', 'flood') : 2
# ('forest', 'flood', 'control') : 2
# ('insect', 'orange', 'juice') : 2
# ('orange', 'juice', 'pay') : 2
# ('juice', 'pay', 'ecosystem') : 2
# ('pay', 'ecosystem', 'service') : 2
# ('ecosystem', 'service', 'costa') : 2
# ('service', 'costa', 'rica') : 3
# ('water', 'tank', 'irrigation') : 3
# ('tank', 'irrigation', 'andhra') : 2
# ('irrigation', 'andhra', 'pradesh') : 2
# ('exploit', 'agrobiodiversity', 'highlands') : 2
# ('agrobiodiversity', 'highlands', 'republic') : 2
# ('highlands', 'republic', 'yemen') : 2
# ('conservation', 'farm', 'practice') : 2
# ('farm', 'practice', 'south') : 2
# ('practice', 'south', 'africa') : 2
# ('environmental', 'service', 'protect') : 2
# ('service', 'protect', 'biodiversity') : 2
# ('protect', 'biodiversity', 'carbon') : 2
# ('biodiversity', 'carbon', 'agricultural') : 2
# ('carbon', 'agricultural', 'landscape') : 2
# ('solution', 'increase', 'water') : 2
# ('increase', 'water', 'supply') : 3
# ('water', 'supply', 'remove') : 2
# ('supply', 'remove', 'invasive') : 2
# ('remove', 'invasive', 'specie') : 2
# ('invasive', 'specie', 'south') : 2
# ('specie', 'south', 'africa') : 2
# ('downstream', 'benefit', 'forest') : 2
# ('benefit', 'forest', 'conservation') : 4
# ('forest', 'conservation', 'madagascar') : 2
# ('lakes', 'central', 'yangtze') : 2
# ('central', 'yangtze', 'river') : 2
# ('yangtze', 'river', 'basin') : 2
# ('river', 'basin', 'china') : 2
# ('wetland', 'protect', 'area') : 2
# ('protect', 'area', 'water') : 3
# ('area', 'water', 'tower') : 2
# ('water', 'tower', 'mongolia') : 2
# ('tower', 'mongolia', 'least') : 2
# ('mongolia', 'least', 'costly') : 2
# ('least', 'costly', 'solution') : 2
# ('principle', 'leverage', 'benefit') : 2
# ('leverage', 'benefit', 'redd') : 2
# ('benefit', 'redd', 'poor') : 2
# ('carbon', 'market', 'save') : 2
# ('market', 'save', 'sumatran') : 2
# ('save', 'sumatran', 'tiger') : 2
# ('sumatran', 'tiger', 'elephant') : 5
# ('likely', 'change', 'earth') : 2
# ('earth', 'system', 'depend') : 2
# ('system', 'depend', 'mitigation') : 2
# ('depend', 'mitigation', 'activity') : 2
# ('mitigation', 'activity', 'undertake') : 2
# ('forest', 'area', 'forest') : 3
# ('area', 'forest', 'carbon') : 3
# ('forest', 'carbon', 'stock') : 3
# ('carbon', 'stock', 'land') : 2
# ('stock', 'land', 'suitable') : 2
# ('land', 'suitable', 'major') : 2
# ('suitable', 'major', 'driver') : 2
# ('major', 'driver', 'tropical') : 2
# ('driver', 'tropical', 'deforestation') : 2
# ('amount', 'carbon', 'store') : 2
# ('carbon', 'store', 'protected') : 2
# ('store', 'protected', 'area') : 2
# ('protected', 'area', 'region') : 2
# ('table', 'five', 'threat') : 2
# ('five', 'threat', 'country') : 2
# ('total', 'biodiversity', 'investment') : 2
# ('biodiversity', 'investment', 'year') : 2
# ('investment', 'year', 'source') : 2
# ('year', 'source', 'funding') : 2
# ('carbon', 'stock', 'natural') : 2
# ('stock', 'natural', 'ecosystems') : 2
# ('natural', 'ecosystems', 'croplands') : 2
# ('know', 'invasive', 'specie') : 3
# ('invasive', 'specie', 'propose') : 3
# ('specie', 'propose', 'suitable') : 3
# ('propose', 'suitable', 'biofuel') : 3
# ('suitable', 'biofuel', 'production') : 3
# ('approach', 'defend', 'natural') : 3
# ('defend', 'natural', 'disaster') : 3
# ('explore', 'impact', 'offset') : 2
# ('impact', 'offset', 'infrastructure') : 2
# ('offset', 'infrastructure', 'project') : 2
# ('infrastructure', 'project', 'protect') : 2
# ('project', 'protect', 'carbon') : 2
# ('potential', 'benefit', 'ecosystem') : 2
# ('benefit', 'ecosystem', 'protection') : 3
# ('development', 'bank', 'deliver') : 7
# ('bank', 'deliver', 'bank') : 8
# ('acg', 'area', 'conservación') : 2
# ('area', 'conservación', 'guanacaste') : 4
# ('afep', 'aceh', 'forest') : 2
# ('aceh', 'forest', 'environment') : 4
# ('forest', 'environment', 'project') : 4
# ('ahteg', 'ad', 'hoc') : 2
# ('arpa', 'amazon', 'region') : 2
# ('caricom', 'caribbean', 'community') : 2
# ('cbd', 'convention', 'biological') : 2
# ('biological', 'diversity', 'cdm') : 2
# ('diversity', 'cdm', 'clean') : 2
# ('cepf', 'critical', 'ecosystem') : 2
# ('critical', 'ecosystem', 'partnership') : 4
# ('ecosystem', 'partnership', 'fund') : 4
# ('kyoto', 'protocol', 'cdm') : 2
# ('cfr', 'cape', 'floristic') : 2
# ('cape', 'floristic', 'region') : 6
# ('floral', 'kingdom', 'locate') : 2
# ('cifs', 'investment', 'fund') : 2
# ('crtr', 'coral', 'reef') : 2
# ('coral', 'reef', 'target') : 4
# ('reef', 'target', 'research') : 4
# ('target', 'research', 'capacity') : 3
# ('research', 'capacity', 'build') : 2
# ('capacity', 'build', 'program') : 2
# ('endemic', 'bird', 'area') : 5
# ('fcpf', 'forest', 'carbon') : 2
# ('forest', 'carbon', 'partnership') : 6
# ('carbon', 'partnership', 'facility') : 6
# ('fip', 'forest', 'investment') : 2
# ('forest', 'investment', 'program') : 6
# ('fondo', 'nacional', 'financiamiento') : 3
# ('nacional', 'financiamiento', 'forestal') : 3
# ('brazilian', 'biodiversity', 'fund') : 2
# ('gfp', 'grow', 'forest') : 2
# ('forest', 'partnership', 'initiative') : 2
# ('gisp', 'invasive', 'specie') : 3
# ('invasive', 'specie', 'programme') : 5
# ('important', 'bird', 'area') : 5
# ('kfw', 'kreditanstalt', 'für') : 2
# ('kreditanstalt', 'für', 'wiederaufbau') : 4
# ('lulucf', 'land', 'land') : 2
# ('mabc', 'mesoamerican', 'biological') : 2
# ('mesoamerican', 'biological', 'corridor') : 5
# ('ppcr', 'pilot', 'program') : 3
# ('program', 'payment', 'environmental') : 2
# ('scf', 'strategic', 'fund') : 2
# ('sfccd', 'strategic', 'framework') : 2
# ('cultural', 'organization', 'unfccc') : 2
# ('organization', 'unfccc', 'nation') : 2
# ('nation', 'collaborative', 'program') : 4
# ('collaborative', 'program', 'reducing') : 3
# ('program', 'reducing', 'emission') : 3
# ('reducing', 'emission', 'deforestation') : 3
# ('forest', 'degradation', 'develop') : 4
# ('degradation', 'develop', 'country') : 4
# ('wwf', 'wide', 'fund') : 3
# ('bank', 'mission', 'alleviate') : 2
# ('mission', 'alleviate', 'poverty') : 2
# ('alleviate', 'poverty', 'support') : 2
# ('serious', 'environmental', 'challenge') : 2
# ('environmental', 'challenge', 'could') : 2
# ('challenge', 'could', 'undermine') : 2
# ('accumulation', 'greenhouse', 'gas') : 2
# ('occur', 'last', 'year') : 2
# ('last', 'year', 'rate') : 2
# ('year', 'rate', 'accelerate') : 2
# ('rate', 'accelerate', 'rise') : 2
# ('accelerate', 'rise', 'temperature') : 2
# ('rise', 'temperature', 'significant') : 2
# ('temperature', 'significant', 'impact') : 2
# ('impact', 'scale', 'local') : 2
# ('scale', 'local', 'regional') : 2
# ('ghg', 'emission', 'reverse') : 2
# ('goal', 'many', 'impact') : 2
# ('already', 'evidence', 'result') : 2
# ('evidence', 'result', 'government') : 2
# ('civil', 'society', 'increasingly') : 2
# ('society', 'increasingly', 'concerned') : 2
# ('increasingly', 'concerned', 'anticipate') : 2
# ('concerned', 'anticipate', 'future') : 2
# ('anticipate', 'future', 'effect') : 2
# ('future', 'effect', 'search') : 2
# ('mitigate', 'adapt', 'current') : 2
# ('current', 'future', 'effect') : 2
# ('warm', 'change', 'already') : 2
# ('already', 'observe', 'impact') : 2
# ('observe', 'impact', 'natural') : 2
# ('coral', 'reef', 'cloud') : 2
# ('reef', 'cloud', 'forest') : 2
# ('cloud', 'forest', 'arctic') : 2
# ('enhance', 'protection', 'biological') : 2
# ('protection', 'biological', 'resource') : 2
# ('mitigate', 'impact', 'contribute') : 2
# ('nation', 'community', 'strive') : 2
# ('community', 'strive', 'adapt') : 2
# ('biodiversity', 'foundation', 'mainstay') : 2
# ('forest', 'fishery', 'biological') : 2
# ('fishery', 'biological', 'resource') : 2
# ('biological', 'resource', 'provide') : 2
# ('resource', 'provide', 'raw') : 2
# ('provide', 'raw', 'material') : 2
# ('raw', 'material', 'livelihood') : 2
# ('medicine', 'trade', 'tourism') : 2
# ('overview', 'deliver', 'bank') : 4
# ('marine', 'natural', 'ecosystem') : 2
# ('ecosystem', 'provide', 'range') : 2
# ('provide', 'range', 'service') : 4
# ('range', 'service', 'often') : 2
# ('economic', 'account', 'vital') : 2
# ('account', 'vital', 'human') : 2
# ('vital', 'human', 'welfare') : 2
# ('human', 'welfare', 'regulation') : 2
# ('welfare', 'regulation', 'water') : 2
# ('water', 'flow', 'water') : 5
# ('flow', 'water', 'quality') : 5
# ('quality', 'flood', 'control') : 2
# ('flood', 'control', 'pollination') : 2
# ('control', 'pollination', 'decontamination') : 2
# ('pollination', 'decontamination', 'carbon') : 2
# ('decontamination', 'carbon', 'sequestration') : 2
# ('carbon', 'sequestration', 'soil') : 3
# ('nutrient', 'hydrological', 'cycling') : 2
# ('current', 'effort', 'focus') : 2
# ('effort', 'focus', 'mainly') : 2
# ('focus', 'mainly', 'reduce') : 2
# ('reduce', 'vulnerability', 'community') : 2
# ('improve', 'infrastructure', 'meet') : 2
# ('infrastructure', 'meet', 'new') : 2
# ('argument', 'include', 'approach') : 2
# ('strategy', 'offer', 'proven') : 2
# ('offer', 'proven', 'sustainable') : 2
# ('proven', 'sustainable', 'solution') : 2
# ('terrestrial', 'oceanic', 'ecosystem') : 2
# ('oceanic', 'ecosystem', 'play') : 2
# ('ecosystem', 'play', 'significant') : 2
# ('significant', 'role', 'carbon') : 2
# ('role', 'carbon', 'cycle') : 2
# ('gigatons', 'carbon', 'gtc') : 3
# ('atmosphere', 'every', 'year') : 2
# ('worldwide', 'soil', 'alone') : 2
# ('soil', 'alone', 'store') : 2
# ('major', 'carbon', 'store') : 2
# ('carbon', 'store', 'sink') : 6
# ('mitigate', 'reduce', 'ghg') : 3
# ('biological', 'mitigation', 'ghgs') : 2
# ('mitigation', 'ghgs', 'occur') : 2
# ('ghgs', 'occur', 'sequestration') : 2
# ('occur', 'sequestration', 'increase') : 2
# ('sequestration', 'increase', 'size') : 2
# ('increase', 'size', 'carbon') : 2
# ('size', 'carbon', 'pool') : 3
# ('carbon', 'pool', 'example') : 2
# ('pool', 'example', 'afforestation') : 2
# ('example', 'afforestation', 'reforestation') : 2
# ('afforestation', 'reforestation', 'restoration') : 2
# ('reforestation', 'restoration', 'natural') : 3
# ('b', 'maintenance', 'exist') : 2
# ('maintenance', 'exist', 'carbon') : 2
# ('exist', 'carbon', 'store') : 2
# ('carbon', 'store', 'example') : 2
# ('fuel', 'energy', 'cleaner') : 2
# ('energy', 'cleaner', 'technology') : 2
# ('potential', 'biological', 'mitigation') : 2
# ('mitigation', 'afforestation', 'reforestation') : 2
# ('afforestation', 'reforestation', 'avoid') : 2
# ('reforestation', 'avoid', 'deforestation') : 2
# ('gtc', 'equivalent', 'project') : 2
# ('equivalent', 'project', 'fossil') : 2
# ('project', 'fossil', 'fuel') : 2
# ('fuel', 'emission', 'period') : 2
# ('land', 'area', 'store') : 2
# ('area', 'store', 'earth') : 2
# ('store', 'earth', 'terrestrial') : 2
# ('earth', 'terrestrial', 'carbon') : 2
# ('terrestrial', 'carbon', 'gtc') : 2
# ('carbon', 'gtc', 'plant') : 2
# ('gtc', 'plant', 'biomass') : 2
# ('plant', 'biomass', 'litter') : 2
# ('biomass', 'litter', 'debris') : 2
# ('litter', 'debris', 'soil') : 2
# ('emission', 'cause', 'deforestation') : 2
# ('cause', 'deforestation', 'land') : 2
# ('deforestation', 'land', 'change') : 2
# ('land', 'clearance', 'much') : 2
# ('clearance', 'much', 'high') : 2
# ('much', 'high', 'total') : 2
# ('maintain', 'carbon', 'stock') : 2
# ('carbon', 'stock', 'stand') : 2
# ('stock', 'stand', 'forest') : 2
# ('stand', 'forest', 'short') : 2
# ('forest', 'short', 'term') : 2
# ('type', 'swamp', 'forest') : 2
# ('swamp', 'forest', 'mangrove') : 2
# ('forest', 'mangrove', 'peatlands') : 2
# ('mangrove', 'peatlands', 'mire') : 2
# ('peatlands', 'mire', 'important') : 2
# ('mire', 'important', 'carbon') : 2
# ('important', 'carbon', 'sink') : 3
# ('carbon', 'sink', 'store') : 2
# ('anaerobic', 'condition', 'inundate') : 2
# ('condition', 'inundate', 'wetland') : 2
# ('inundate', 'wetland', 'soil') : 2
# ('wetland', 'soil', 'slow') : 2
# ('soil', 'slow', 'decomposition') : 2
# ('slow', 'decomposition', 'rate') : 2
# ('decomposition', 'rate', 'contribute') : 2
# ('peatlands', 'extend', 'meter') : 2
# ('extend', 'meter', 'depth') : 2
# ('ton', 'carbon', 'tc') : 2
# ('carbon', 'tc', 'hectare') : 2
# ('tc', 'hectare', 'year') : 3
# ('occur', 'every', 'continent') : 2
# ('every', 'continent', 'except') : 2
# ('continent', 'except', 'antarctica') : 2
# ('except', 'antarctica', 'constitute') : 2
# ('antarctica', 'constitute', 'stock') : 2
# ('constitute', 'stock', 'terrestrial') : 2
# ('stock', 'terrestrial', 'carbon') : 2
# ('overgrazing', 'conversion', 'cropland') : 2
# ('conversion', 'cropland', 'desertification') : 2
# ('cropland', 'desertification', 'fire') : 2
# ('desertification', 'fire', 'fragmentation') : 2
# ('fire', 'fragmentation', 'introduction') : 2
# ('fragmentation', 'introduction', 'specie') : 2
# ('introduction', 'specie', 'affect') : 2
# ('capacity', 'store', 'carbon') : 2
# ('case', 'even', 'lead') : 2
# ('lose', 'soil', 'organic') : 2
# ('carbon', 'content', 'cultivation') : 2
# ('burn', 'biomass', 'especially') : 2
# ('biomass', 'especially', 'tropical') : 2
# ('especially', 'tropical', 'savanna') : 2
# ('tropical', 'savanna', 'contribute') : 2
# ('savanna', 'contribute', 'gross') : 2
# ('oceans', 'substantial', 'reservoir') : 2
# ('substantial', 'reservoir', 'carbon') : 2
# ('approximately', 'time', 'carbon') : 2
# ('efficient', 'take', 'atmospheric') : 2
# ('take', 'atmospheric', 'carbon') : 2
# ('atmospheric', 'carbon', 'plankton') : 2
# ('carbon', 'plankton', 'photosynthesis') : 2
# ('plankton', 'photosynthesis', 'mix') : 2
# ('photosynthesis', 'mix', 'atmospheric') : 2
# ('mix', 'atmospheric', 'seawater') : 2
# ('atmospheric', 'seawater', 'formation') : 2
# ('seawater', 'formation', 'carbonate') : 2
# ('formation', 'carbonate', 'bicarbonate') : 2
# ('carbonate', 'bicarbonate', 'conversion') : 2
# ('carbon', 'particulate', 'organic') : 2
# ('particulate', 'organic', 'matter') : 2
# ('organic', 'matter', 'burial') : 2
# ('particle', 'deep', 'sea') : 2
# ('protection', 'improve', 'natural') : 3
# ('improve', 'natural', 'ecosystem') : 2
# ('many', 'protect', 'area') : 2
# ('area', 'carbon', 'stock') : 3
# ('carbon', 'stock', 'globally') : 2
# ('stock', 'globally', 'ecosystems') : 2
# ('globally', 'ecosystems', 'within') : 2
# ('area', 'store', 'gtc') : 2
# ('store', 'gtc', 'terrestrial') : 2
# ('stock', 'protect', 'varies') : 2
# ('increasingly', 'important', 'development') : 2
# ('protect', 'forest', 'wetlands') : 2
# ('forest', 'wetlands', 'coastal') : 2
# ('wetlands', 'coastal', 'habitat') : 2
# ('coastal', 'habitat', 'natural') : 2
# ('habitat', 'natural', 'ecosystem') : 2
# ('ecosystem', 'provide', 'social') : 3
# ('provide', 'social', 'economic') : 3
# ('environmental', 'benefit', 'directly') : 3
# ('benefit', 'directly', 'sustainable') : 3
# ('directly', 'sustainable', 'biological') : 3
# ('sustainable', 'biological', 'resource') : 3
# ('biological', 'resource', 'indirectly') : 3
# ('resource', 'indirectly', 'ecosystem') : 2
# ('indirectly', 'ecosystem', 'service') : 2
# ('range', 'good', 'ecosystem') : 2
# ('good', 'ecosystem', 'service') : 2
# ('service', 'include', 'natural') : 2
# ('resource', 'water', 'timber') : 2
# ('water', 'timber', 'fishery') : 2
# ('timber', 'fishery', 'human') : 2
# ('fishery', 'human', 'livelihood') : 2
# ('human', 'livelihood', 'depend') : 2
# ('protect', 'area', 'natural') : 3
# ('area', 'natural', 'habitat') : 3
# ('natural', 'habitat', 'within') : 3
# ('habitat', 'within', 'protect') : 2
# ('within', 'protect', 'watershed') : 2
# ('protect', 'watershed', 'regulate') : 2
# ('watershed', 'regulate', 'flow') : 2
# ('regulate', 'flow', 'quality') : 2
# ('flow', 'quality', 'water') : 2
# ('quality', 'water', 'prevent') : 2
# ('water', 'prevent', 'soil') : 2
# ('soil', 'erosion', 'influence') : 2
# ('erosion', 'influence', 'rainfall') : 2
# ('influence', 'rainfall', 'regimes') : 3
# ('rainfall', 'regimes', 'local') : 3
# ('regimes', 'local', 'conserve') : 2
# ('local', 'conserve', 'renewable') : 2
# ('conserve', 'renewable', 'harvestable') : 2
# ('renewable', 'harvestable', 'resource') : 2
# ('harvestable', 'resource', 'genetic') : 2
# ('resource', 'genetic', 'reservoir') : 2
# ('genetic', 'reservoir', 'protect') : 2
# ('reservoir', 'protect', 'breed') : 2
# ('protect', 'breed', 'stock') : 2
# ('breed', 'stock', 'natural') : 2
# ('stock', 'natural', 'pollinator') : 2
# ('natural', 'pollinator', 'seed') : 2
# ('pollinator', 'seed', 'dispersers') : 2
# ('seed', 'dispersers', 'maintain') : 2
# ('dispersers', 'maintain', 'ecosystem') : 2
# ('last', 'decade', 'bank') : 3
# ('decade', 'bank', 'project') : 3
# ('bank', 'project', 'make') : 2
# ('project', 'make', 'explicit') : 2
# ('make', 'explicit', 'linkage') : 2
# ('conservation', 'sustainable', 'natural') : 3
# ('sustainable', 'natural', 'ecosystem') : 2
# ('watershed', 'value', 'associate') : 2
# ('value', 'associate', 'erosion') : 2
# ('associate', 'erosion', 'control') : 2
# ('erosion', 'control', 'clean') : 2
# ('control', 'clean', 'water') : 2
# ('clean', 'water', 'supply') : 2
# ('supply', 'flood', 'control') : 2
# ('natural', 'resource', 'benefit') : 2
# ('resource', 'benefit', 'poor') : 2
# ('benefit', 'poor', 'marginalize') : 2
# ('poor', 'marginalize', 'indigenous') : 2
# ('marginalize', 'indigenous', 'community') : 2
# ('protect', 'ecosystem', 'service') : 3
# ('ecosystem', 'service', 'maintain') : 2
# ('service', 'maintain', 'access') : 2
# ('maintain', 'access', 'resource') : 2
# ('difficult', 'time', 'include') : 2
# ('coastal', 'defense', 'flood') : 2
# ('defense', 'flood', 'control') : 2
# ('forest', 'wetlands', 'natural') : 2
# ('complement', 'substitute', 'expensive') : 2
# ('floodplain', 'forest', 'coastal') : 2
# ('forest', 'coastal', 'mangrove') : 2
# ('coastal', 'mangrove', 'provide') : 2
# ('mangrove', 'provide', 'storm') : 2
# ('serve', 'safety', 'barrier') : 2
# ('hazard', 'flood', 'hurricane') : 2
# ('flood', 'hurricane', 'tsunamis') : 2
# ('wetland', 'filter', 'pollutant') : 2
# ('traditional', 'engineered', 'solution') : 2
# ('lead', 'habitat', 'loss') : 2
# ('instead', 'argentina', 'ecuador') : 2
# ('argentina', 'ecuador', 'flood') : 2
# ('ecuador', 'flood', 'control') : 2
# ('flood', 'control', 'project') : 2
# ('natural', 'storage', 'recharge') : 2
# ('storage', 'recharge', 'property') : 2
# ('recharge', 'property', 'critical') : 2
# ('property', 'critical', 'forest') : 2
# ('critical', 'forest', 'wetlands') : 2
# ('forest', 'wetlands', 'integrate') : 2
# ('wetlands', 'integrate', 'live') : 2
# ('integrate', 'live', 'flood') : 2
# ('live', 'flood', 'strategy') : 2
# ('protect', 'area', 'riparian') : 2
# ('area', 'riparian', 'corridor') : 2
# ('three', 'great', 'challenge') : 2
# ('loss', 'water', 'shortage') : 2
# ('water', 'scarcity', 'increase') : 2
# ('scarcity', 'increase', 'crop') : 2
# ('crop', 'failure', 'pest') : 2
# ('failure', 'pest', 'infestation') : 2
# ('pest', 'infestation', 'overstock') : 2
# ('infestation', 'overstock', 'permanent') : 2
# ('overstock', 'permanent', 'degradation') : 2
# ('permanent', 'degradation', 'graze') : 2
# ('degradation', 'graze', 'land') : 2
# ('graze', 'land', 'livestock') : 2
# ('land', 'livestock', 'death') : 2
# ('productivity', 'food', 'security') : 3
# ('already', 'impose', 'severe') : 2
# ('impose', 'severe', 'economic') : 2
# ('severe', 'economic', 'social') : 2
# ('economic', 'social', 'cost') : 2
# ('particularly', 'affect', 'vulnerable') : 3
# ('rainfall', 'pattern', 'expect') : 2
# ('pattern', 'expect', 'significant') : 2
# ('expect', 'significant', 'impact') : 2
# ('impact', 'agricultural', 'productivity') : 3
# ('agricultural', 'productivity', 'especially') : 2
# ('productivity', 'especially', 'arid') : 2
# ('especially', 'arid', 'semiarid') : 2
# ('model', 'scenario', 'indicate') : 2
# ('scenario', 'indicate', 'drylands') : 2
# ('indicate', 'drylands', 'west') : 2
# ('drylands', 'west', 'central') : 2
# ('central', 'asia', 'north') : 2
# ('north', 'africa', 'instance') : 2
# ('africa', 'instance', 'severely') : 2
# ('affect', 'drought', 'temperature') : 2
# ('drought', 'temperature', 'year') : 2
# ('temperature', 'year', 'come') : 2
# ('almost', 'land', 'currently') : 2
# ('development', 'bank', 'agriculture') : 3
# ('agriculture', 'could', 'convert') : 2
# ('could', 'convert', 'intensive') : 2
# ('force', 'poor', 'farmer') : 2
# ('poor', 'farmer', 'open') : 2
# ('farmer', 'open', 'ever') : 2
# ('open', 'ever', 'marginal') : 2
# ('ever', 'marginal', 'land') : 2
# ('marginal', 'land', 'one') : 2
# ('could', 'lead', 'reduction') : 2
# ('lead', 'reduction', 'crop') : 2
# ('accord', 'model', 'tropical') : 2
# ('model', 'tropical', 'country') : 2
# ('tropical', 'country', 'even') : 2
# ('country', 'even', 'moderate') : 2
# ('even', 'moderate', 'warm') : 2
# ('south', 'asia', 'large') : 2
# ('asia', 'large', 'number') : 2
# ('rural', 'poor', 'rural') : 2
# ('rural', 'population', 'dependent') : 2
# ('population', 'dependent', 'agriculture') : 2
# ('agriculture', 'recent', 'study') : 2
# ('study', 'show', 'farm') : 2
# ('show', 'farm', 'animal') : 2
# ('animal', 'husbandry', 'informal') : 2
# ('husbandry', 'informal', 'forestry') : 2
# ...
# ('particular', 'control', 'variable') : 2
# ('ppml', 'versus', 'linear') : 2
# ('versus', 'linear', 'estimator') : 2
# ('could', 'lead', 'bias') : 2
# ('many', 'primary', 'study') : 2
# ('primary', 'study', 'employ') : 2
# ('result', 'discuss', 'implication') : 2
# ('export', 'fix', 'effect') : 2
# ('effect', 'hierarchical', 'intercept') : 4
# ('hierarchical', 'intercept', 'characteristic') : 4
# ('intercept', 'characteristic', 'degree') : 4
# ('primary', 'commodity', 'livestock') : 4
# ('commodity', 'livestock', 'process') : 4
# ('livestock', 'process', 'food') : 5
# ('process', 'food', 'estimation') : 4
# ('food', 'estimation', 'characteristic') : 4
# ('characteristic', 'ppml', 'ppml') : 4
# ('ppml', 'ppml', 'estimator') : 4
# ('ppml', 'estimator', 'cluster') : 3
# ('estimator', 'cluster', 'error') : 3
# ('cluster', 'error', 'absence') : 3
# ('error', 'absence', 'cluster') : 3
# ('absence', 'cluster', 'error') : 3
# ('cluster', 'error', 'exporter') : 3
# ('error', 'exporter', 'fix') : 3
# ('exporter', 'fix', 'absence') : 3
# ('fix', 'absence', 'exporter') : 3
# ('absence', 'exporter', 'fix') : 3
# ('presence', 'regressors', 'exporter') : 2
# ('regressors', 'exporter', 'size') : 2
# ('exporter', 'size', 'absence') : 2
# ('size', 'absence', 'exporter') : 2
# ('absence', 'exporter', 'size') : 2
# ('exporter', 'size', 'observation') : 2
# ('size', 'observation', 'akaike') : 3
# ('observation', 'akaike', 'information') : 4
# ('information', 'criterion', 'r') : 4
# ('criterion', 'r', 'q') : 4
# ('r', 'q', 'statistic') : 4
# ('q', 'statistic', 'likelihood') : 4
# ('statistic', 'likelihood', 'ratio') : 4
# ('likelihood', 'ratio', 'note') : 4
# ('ratio', 'note', 'standard') : 4
# ('note', 'standard', 'error') : 4
# ('standard', 'error', 'report') : 4
# ('error', 'report', 'parenthesis') : 4
# ('report', 'parenthesis', 'r') : 4
# ('parenthesis', 'r', 'give') : 4
# ('r', 'give', 'value') : 4
# ('give', 'value', 'pearson') : 4
# ('value', 'pearson', 'correlation') : 4
# ('pearson', 'correlation', 'test') : 4
# ('correlation', 'test', 'observe') : 4
# ('test', 'observe', 'fit') : 4
# ('observe', 'fit', 'value') : 4
# ('fit', 'value', 'report') : 4
# ('value', 'report', 'q') : 4
# ('report', 'q', 'statistic') : 4
# ('q', 'statistic', 'corresponds') : 4
# ('statistic', 'corresponds', 'test') : 4
# ('corresponds', 'test', 'null') : 4
# ('null', 'hypothesis', 'homogeneity') : 5
# ('hypothesis', 'homogeneity', 'size') : 4
# ('homogeneity', 'size', 'study') : 4
# ('size', 'study', 'p') : 4
# ('study', 'p', 'p') : 4
# ('destination', 'import', 'fix') : 2
# ('import', 'fix', 'effect') : 2
# ('table', 'precipitation', 'destination') : 2
# ('importer', 'fix', 'absence') : 2
# ('fix', 'absence', 'importer') : 2
# ('absence', 'importer', 'fix') : 2
# ('p', 'p', 'aes') : 2
# ('p', 'aes', 'vital') : 2
# ('likelihood', 'ratio', 'test') : 4
# ('indicate', 'random', 'effect') : 2
# ('heterogeneity', 'primary', 'estimate') : 3
# ('none', 'primary', 'study') : 2
# ('generate', 'credible', 'result') : 2
# ('effect', 'precipitation', 'importer') : 2
# ('precipitation', 'importer', 'table') : 2
# ('first', 'find', 'study') : 2
# ('find', 'study', 'conduct') : 2
# ('study', 'conduct', 'recently') : 2
# ('conduct', 'recently', 'tend') : 2
# ('recently', 'tend', 'generate') : 2
# ('tend', 'generate', 'small') : 2
# ('generate', 'small', 'estimate') : 2
# ('small', 'estimate', 'precipitation') : 2
# ('estimate', 'precipitation', 'import') : 2
# ('presence', 'fix', 'effect') : 2
# ('fix', 'effect', 'primary') : 2
# ('effect', 'primary', 'study') : 2
# ('primary', 'study', 'significantly') : 2
# ('study', 'significantly', 'reduce') : 2
# ('significantly', 'reduce', 'marginal') : 2
# ('reduce', 'marginal', 'precipitation') : 2
# ('marginal', 'precipitation', 'importer') : 2
# ('study', 'fail', 'account') : 2
# ('fail', 'account', 'factor') : 2
# ('account', 'factor', 'potentially') : 2
# ('factor', 'potentially', 'suffer') : 2
# ('potentially', 'suffer', 'miss') : 2
# ('suffer', 'miss', 'variable') : 2
# ('miss', 'variable', 'bias') : 2
# ('variable', 'bias', 'reflect') : 2
# ('bias', 'reflect', 'result') : 2
# ('reflect', 'result', 'study') : 2
# ('result', 'study', 'might') : 2
# ('study', 'might', 'conflate') : 2
# ('might', 'conflate', 'variation') : 2
# ('conflate', 'variation', 'weather') : 2
# ('weather', 'condition', 'factor') : 2
# ('condition', 'factor', 'produce') : 2
# ('factor', 'produce', 'large') : 2
# ('produce', 'large', 'positive') : 2
# ('large', 'positive', 'estimate') : 2
# ('positive', 'estimate', 'precipitation') : 2
# ('estimate', 'precipitation', 'finally') : 2
# ('precipitation', 'finally', 'primary') : 2
# ('control', 'economic', 'size') : 2
# ('observe', 'large', 'estimate') : 2
# ('large', 'estimate', 'precipitation') : 2
# ('estimate', 'effect', 'weather') : 2
# ('evidence', 'impact', 'precipitation') : 2
# ('impact', 'precipitation', 'export') : 2
# ('anderson', 'van', 'wincoop') : 2
# ('natural', 'disaster', 'hurricane') : 2
# ('climatic', 'natural', 'disaster') : 2
# ('trade', 'rather', 'agricultural') : 2
# ('rather', 'agricultural', 'trade') : 2
# ('agricultural', 'trade', 'se') : 2
# ('small', 'number', 'estimate') : 2
# ('computable', 'general', 'equilibrium') : 2
# ('general', 'equilibrium', 'model') : 2
# ('estimate', 'fix', 'effect') : 2
# ('assumption', 'underlie', 'fix') : 2
# ('underlie', 'fix', 'effect') : 2
# ('explain', 'set', 'moderator') : 2
# ('set', 'moderator', 'variable') : 2
# ('erba', 'fang', 'dominicis') : 2
# ('collect', 'primary', 'study') : 2
# ('table', 'present', 'result') : 2
# ('small', 'number', 'primary') : 2
# ('number', 'primary', 'estimate') : 2
# ('table', 'result', 'q') : 2
# ('result', 'q', 'likelihood') : 2
# ('q', 'likelihood', 'ratio') : 2
# ('random', 'effect', 'appropriate') : 2
# ('impact', 'agricultural', 'trade') : 2
# ('environ', 'dev', 'econ') : 2
# ('spatial', 'econ', 'anal') : 2
# ('smith', 'chhetri', 'analysis') : 2
# ('chhetri', 'analysis', 'crop') : 2
# ('analysis', 'crop', 'yield') : 2
# ('econ', 'dall', 'erba') : 2
# ('weather', 'variation', 'trade') : 2
# ('scot', 'polit', 'econ') : 2
# ('agricultural', 'trade', 'agric') : 2
# ('trade', 'agric', 'econ') : 2
# ('yu', 'zhou', 'b') : 2
# ('trade', 'creation', 'trade') : 2
# ('creation', 'trade', 'diversion') : 2
# ('agric', 'resour', 'econ') : 2
# ('resour', 'econ', 'rev') : 2
# ('econ', 'rev', 'reilly') : 2
# ('rev', 'reilly', 'hohmann') : 2
# ('science', 'harvard', 'university') : 2
# ('harvard', 'university', 'cambridge') : 2
# ('university', 'cambridge', 'state') : 2
# ('poor', 'country', 'indonesia') : 2
# ('project', 'ac', 'demand') : 2
# ('must', 'consider', 'future') : 2
# ('consider', 'future', 'power') : 2
# ('future', 'power', 'system') : 4
# ('power', 'system', 'plan') : 4
# ('ac', 'electricity', 'demand') : 5
# ('electricity', 'demand', 'require') : 3
# ('electricity', 'demand', 'associate') : 3
# ('unable', 'present', 'handle') : 2
# ('present', 'handle', 'project') : 2
# ('handle', 'project', 'peak') : 2
# ('low', 'bound', 'future') : 2
# ('relative', 'humidity', 'hurs') : 2
# ('water', 'vapor', 'pressure') : 2
# ('consortium', 'consortium', 'consortium') : 2
# ('sherman', 'lin', 'mcelroy') : 6
# ('lin', 'mcelroy', 'energy') : 6
# ('mcelroy', 'energy', 'building') : 6
# ('increase', 'ac', 'demand') : 2
# ('ac', 'power', 'demand') : 2
# ('number', 'people', 'household') : 2
# ('eac', 'country', 'ð') : 2
# ('country', 'ð', 'þ') : 4
# ('statistic', 'household', 'projection') : 2
# ('household', 'projection', 'korea') : 2
# ('projection', 'korea', 'statistic') : 2
# ('state', 'census', 'change') : 2
# ('census', 'change', 'household') : 2
# ('change', 'household', 'size') : 2
# ('central', 'ac', 'system') : 2
# ('use', 'identify', 'region') : 2
# ('energy', 'building', 'future') : 2
# ('electricity', 'grid', 'country') : 2
# ('associate', 'electricity', 'demand') : 2
# ('electricity', 'demand', 'country') : 3
# ('roughly', 'total', 'electricity') : 2
# ('density', 'function', 'pdfs') : 2
# ('function', 'pdfs', 'multimodel') : 2
# ('pdfs', 'multimodel', 'percentage') : 2
# ('interpretation', 'reference', 'color') : 2
# ('reference', 'color', 'ﬁgure') : 2
# ('color', 'ﬁgure', 'legend') : 2
# ('daily', 'ac', 'electricity') : 2
# ('assume', 'growth', 'rate') : 2
# ('project', 'minimum', 'ac') : 2
# ('ac', 'demand', 'require') : 2
# ('peak', 'demand', 'period') : 2
# ('change', 'ac', 'demand') : 2
# ('thermal', 'comfort', 'threshold') : 2
# ('projection', 'ac', 'demand') : 2
# ('low', 'swbgt', 'threshold') : 3
# ('regional', 'mate', 'model') : 2
# ('ncc', 'output', 'prepare') : 2
# ('output', 'prepare', 'cmip') : 15
# ('prepare', 'cmip', 'earth') : 15
# ('cmip', 'earth', 'system') : 15
# ('consortium', 'output', 'prepare') : 4
# ('system', 'federation', 'consortium') : 2
# ('federation', 'consortium', 'output') : 2
# ('output', 'prepare', 'earth') : 3
# ('prepare', 'earth', 'system') : 3
# ('system', 'federation', 'lovato') : 2
# ('federation', 'lovato', 'peano') : 2
# ('cmcc', 'output', 'prepare') : 2
# ('volodin', 'mortikov', 'gritsun') : 2
# ('mortikov', 'gritsun', 'inm') : 2
# ('gritsun', 'inm', 'output') : 2
# ('inm', 'output', 'prepare') : 2
# ('via', 'community', 'science') : 2
# ('community', 'science', 'project') : 7
# ('community', 'member', 'reveal') : 2
# ('variation', 'covariation', 'air') : 2
# ('covariation', 'air', 'ozone') : 2
# ('within', 'neighborhood', 'scale') : 2
# ('research', 'forecast', 'atmospheric') : 4
# ('forecast', 'atmospheric', 'chemistry') : 4
# ('variation', 'neighborhood', 'scale') : 2
# ('different', 'tree', 'type') : 2
# ('tree', 'type', 'size') : 2
# ('community', 'science', 'engagement') : 4
# ('otherwise', 'impossible', 'insight') : 2
# ('neighborhood', 'vulnerability', 'air') : 3
# ('via', 'community', 'engagement') : 3
# ('pilot', 'project', 'community') : 3
# ('project', 'community', 'science') : 5
# ('community', 'science', 'involve') : 2
# ('large', 'spatial', 'variation') : 3
# ('suggest', 'green', 'space') : 2
# ('resolve', 'predict', 'neighborhood') : 3
# ('predict', 'neighborhood', 'vulnerability') : 2
# ('air', 'pollution', 'insight') : 2
# ('pollution', 'insight', 'pilot') : 2
# ('insight', 'pilot', 'project') : 2
# ('university', 'iowa', 'iowa') : 2
# ('iowa', 'iowa', 'ia') : 2
# ('iowa', 'ia', 'usa') : 2
# ('wang', 'darrel', 'jenerette') : 6
# ('darrel', 'jenerette', 'mark') : 8
# ('jenerette', 'mark', 'chandler') : 7
# ('mark', 'chandler', 'jing') : 3
# ('chandler', 'jing', 'zeng') : 3
# ('wang', 'lorena', 'darrel') : 3
# ('lorena', 'darrel', 'jenerette') : 3
# ('resolution', 'image', 'spectroradiometer') : 4
# ('image', 'spectroradiometer', 'modis') : 3
# ('los', 'angeles', 'megapolitan') : 2
# ('angeles', 'megapolitan', 'region') : 2
# ('regional', 'weather', 'research') : 3
# ('air', 'neighborhood', 'scale') : 2
# ('citizen', 'science', 'project') : 3
# ('chandler', 'cui', 'ge') : 3
# ('cui', 'ge', 'dion') : 2
# ('ge', 'dion', 'kucera') : 2
# ('dion', 'kucera', 'sofia') : 2
# ('kucera', 'sofia', 'koutzoukis') : 2
# ('mark', 'chandler', 'cui') : 2
# ('wang', 'mark', 'chandler') : 2
# ('applicable', 'common', 'geohealth') : 13
# ('common', 'geohealth', 'wang') : 13
# ('integrate', 'community', 'engagement') : 2
# ('result', 'community', 'science') : 2
# ('quadrats', 'three', 'sensor') : 2
# ('three', 'sensor', 'node') : 2
# ('spectroradiometer', 'modis', 'land') : 2
# ('see', 'text', 'detail') : 2
# ('system', 'model', 'complex') : 2
# ('web', 'service', 'phone') : 2
# ('spatial', 'distribution', 'weather') : 3
# ('ask', 'answer', 'question') : 2
# ('air', 'pollution', 'time') : 2
# ('example', 'show', 'impact') : 2
# ('show', 'impact', 'different') : 2
# ('type', 'tree', 'diurnal') : 2
# ('tree', 'diurnal', 'variation') : 2
# ('canopy', 'radius', 'daytime') : 2
# ('distribution', 'weather', 'research') : 2
# ('atmospheric', 'chemistry', 'forecast') : 2
# ('average', 'utc', 'july') : 2
# ('linear', 'correlation', 'coefficient') : 2
# ('correlation', 'coefficient', 'r') : 2
# ('normalized', 'standard', 'deviation') : 2
# ('normalize', 'standard', 'deviation') : 2
# ('variability', 'spatial', 'variability') : 2
# ('water', 'body', 'salton') : 2
# ('body', 'salton', 'sea') : 2
# ('surround', 'salton', 'sea') : 2
# ('contrast', 'figure', 'suggest') : 2
# ('lst', 'spatial', 'variability') : 2
# ('spatial', 'variability', 'lst') : 2
# ('spatial', 'variability', 'neighborhood') : 3
# ('variability', 'neighborhood', 'scale') : 3
# ('model', 'show', 'slightly') : 2
# ('show', 'slightly', 'good') : 2
# ('slightly', 'good', 'performance') : 2
# ('los', 'angeles', 'basin') : 4
# ('angeles', 'basin', 'overall') : 2
# ('ozone', 'los', 'angeles') : 2
# ('nasa', 'earth', 'science') : 2
# ('use', 'fully', 'couple') : 2
# ('ge', 'wang', 'reid') : 2
# ('mesoscale', 'model', 'smoke') : 3
# ('model', 'smoke', 'transport') : 3
# ('smoke', 'transport', 'southeast') : 2
# ('transport', 'southeast', 'asian') : 2
# ('southeast', 'asian', 'maritime') : 3
# ('asian', 'maritime', 'continent') : 3
# ('institute', 'food', 'agriculture') : 3
# ('frontier', 'ecology', 'environment') : 2
# ('perennial', 'biomass', 'crop') : 8
# ('biomass', 'crop', 'marginal') : 4
# ('crop', 'marginal', 'land') : 4
# ('marginal', 'land', 'improve') : 2
# ('land', 'improve', 'regional') : 2
# ('improve', 'regional', 'agricultural') : 2
# ('regional', 'agricultural', 'productivity') : 2
# ('system', 'science', 'interdisciplinary') : 2
# ('science', 'interdisciplinary', 'center') : 2
# ('interdisciplinary', 'center', 'university') : 2
# ('center', 'university', 'maryland') : 2
# ('university', 'maryland', 'college') : 3
# ('maryland', 'college', 'park') : 3
# ('college', 'park', 'maryland') : 2
# ('park', 'maryland', 'usa') : 2
# ('biology', 'university', 'illinois') : 2
# ('university', 'illinois', 'champaign') : 4
# ('illinois', 'champaign', 'illinois') : 3
# ('champaign', 'illinois', 'usa') : 3
# ('illinois', 'usa', 'science') : 2
# ('institute', 'technology', 'palakkad') : 2
# ('technology', 'palakkad', 'kanjikode') : 2
# ('palakkad', 'kanjikode', 'kerala') : 2
# ('science', 'foundation', 'innovation') : 2
# ('corn', 'soybean', 'yield') : 2
# ('grow', 'perennial', 'marginal') : 2
# ('perennial', 'marginal', 'land') : 2
# ('marginal', 'land', 'could') : 4
# ('vapor', 'pressure', 'deficit') : 2
# ('pressure', 'deficit', 'vpd') : 2
# ('food', 'feed', 'crop') : 6
# ('lobell', 'ort', 'long') : 2
# ('large', 'leaf', 'canopy') : 2
# ('cool', 'wet', 'effect') : 2
# ('marginal', 'land', 'area') : 2
# ('productive', 'perennial', 'grass') : 3
# ('way', 'interaction', 'crop') : 2
# ('develop', 'fully', 'couple') : 2
# ('control', 'way', 'way') : 2
# ('way', 'simulation', 'use') : 2
# ('fully', 'couple', 'biocro') : 2
# ('way', 'way', 'simulation') : 6
# ('exist', 'vegetation', 'marginal') : 2
# ('vegetation', 'marginal', 'land') : 5
# ('marginal', 'land', 'way') : 3
# ('affect', 'crop', 'growth') : 2
# ('way', 'simulation', 'first') : 2
# ('calibrate', 'biomass', 'partition') : 2
# ('conjunctive', 'subsurface', 'process') : 3
# ('subsurface', 'process', 'cssp') : 3
# ('grow', 'miscanthus', 'marginal') : 6
# ('miscanthus', 'marginal', 'land') : 8
# ('grow', 'marginal', 'land') : 2
# ('regional', 'biomass', 'production') : 2
# ('land', 'surface', 'quantity') : 2
# ('soil', 'carbon', 'sequestration') : 2
# ('two', 'mlu', 'scenario') : 3
# ('current', 'vegetation', 'marginal') : 2
# ('point', 'marginal', 'land') : 2
# ('marginal', 'land', 'ml') : 2
# ('marginal', 'land', 'fraction') : 2
# ('miscanthus', 'mha', 'marginal') : 2
# ('mha', 'marginal', 'land') : 3
# ('way', 'feedback', 'predict') : 2
# ('perennial', 'grass', 'marginal') : 2
# ('grass', 'marginal', 'land') : 2
# ('miscanthus', 'similar', 'perennial') : 2
# ('corn', 'yield', 'soybean') : 2
# ('yield', 'soybean', 'yield') : 2
# ('food', 'energy', 'crop') : 2
# ('benefit', 'grow', 'miscanthus') : 2
# ('bioenergy', 'feedstock', 'production') : 2
# ('feedstock', 'production', 'gcb') : 2
# ('production', 'gcb', 'bioenergy') : 2
# ('giganteus', 'panicum', 'virgatum') : 2
# ('parton', 'long', 'delucia') : 2
# ('field', 'b', 'direct') : 3
# ('perennial', 'bioenergy', 'crop') : 2
# ('state', 'proceeding', 'academy') : 2
# ('jaiswal', 'souza', 'larsen') : 2
# ('souza', 'larsen', 'lebauer') : 2
# ('larsen', 'lebauer', 'miguez') : 2
# ('lebauer', 'miguez', 'sparovek') : 2
# ('miguez', 'sparovek', 'bollero') : 2
# ('sparovek', 'bollero', 'buckeridge') : 2
# ('bollero', 'buckeridge', 'long') : 2
# ('yield', 'yield', 'stability') : 2
# ('loarie', 'lobell', 'asner') : 2
# ('lobell', 'asner', 'mu') : 2
# ('asner', 'mu', 'field') : 2
# ('mu', 'field', 'b') : 2
# ('b', 'direct', 'impact') : 2
# ('direct', 'impact', 'local') : 2
# ('impact', 'local', 'cane') : 2
# ('bioenergy', 'crop', 'miscanthus') : 2

# %% [markdown]
# ### BERT topic

# %%
def preprocess_texts(docs):
    preprocessed_docs = [' '.join(tokens) for tokens in (doc[0] for doc in docs.values())]
    return preprocessed_docs
preprocessed_texts = preprocess_texts(docs)

# %%
# Initializing the SentenceTransformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Encoding the preprocessed texts into embeddings
embeddings = model.encode(preprocessed_texts, show_progress_bar=True)

# %%
# Initializing BERTopic with custom parameters
topic_model = BERTopic(min_topic_size=5,
                       top_n_words=6,
                       n_gram_range=(1, 2),
                       calculate_probabilities=True)

# Fitting BERTopic on the preprocessed texts and embeddings
topics, probs = topic_model.fit_transform(preprocessed_texts,embeddings)

# %%
# Checking the topics identified
topic_info = topic_model.get_topic_info()
print(topic_info)
# Out:
#    Topic  Count                                        Name  \
# 0     -1     30           -1_water_development_include_need
# 1      0     26               0_event_weather_europe_system
# 2      1     18       1_disaster_information_thailand_flood
# 3      2     16                 2_food_water_country_system
# 4      3     14               3_cool_energy_demand_thousand
# 5      4     12            4_ahmedabad_cool_disaster_people
# 6      5      5  5_event_attribution_event attribution_wave
#
#                                       Representation  \
# 0  [water, development, include, need, system, area]
# 1     [event, weather, europe, system, warm, change]
# 2  [disaster, information, thailand, flood, hazar...
# 3  [food, water, country, system, crop, agricultu...
# 4          [cool, energy, demand, thousand, ac, air]
# 5  [ahmedabad, cool, disaster, people, karachi, c...
# 6  [event, attribution, event attribution, wave, ...
#
#                                  Representative_Docs
# 0  [columbus complete december content read docum...
# 1  [heatwaves guidance development meteorological...
# 2  [adapt europe central asia june bank ii acrony...
# 3  [towards future want end hunger make transitio...
# 4  [energy building content list available scienc...
# 5  [karachi guide plan response commissioner kara...
# 6  [date february host university arizona washing...

# %%
topic_model.get_topic(3)
# Out:
# [('cool', 0.03179153357869848),
#  ('energy', 0.025628968852471165),
#  ('demand', 0.015830782575974266),
#  ('thousand', 0.01533011473086865),
#  ('ac', 0.014736306358852964),
#  ('air', 0.013264940125494182)]

# %%
# Getting the topic words
topic_words = topic_model.get_topics()

# Preprocessing the texts
preprocessed_texts = preprocess_texts(docs)

# Converting preprocessed texts to list of words for coherence model
texts = [doc.split() for doc in preprocessed_texts]

# Creating a dictionary and corpus for the coherence model
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

coherence_scores = []
for topic_id, topic in topic_words.items():
    # Preparing the data for coherence model
    topics = [[word for word, _ in topic]]

    # Computing Coherence Score using Gensim's CoherenceModel for each topic
    coherence_model = CoherenceModel(topics=topics, texts=texts, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()

    coherence_scores.append((topic_id, coherence_score))

# Printing coherence scores for each topic
for topic_id, coherence_score in coherence_scores:
    print(f'Topic {topic_id}: Coherence Score: {coherence_score}')
# Out:
# Topic -1: Coherence Score: 0.4524959746600248
# Topic 0: Coherence Score: 0.5370282401503276
# Topic 1: Coherence Score: 0.5371841989998796
# Topic 2: Coherence Score: 0.5978951212439262
# Topic 3: Coherence Score: 0.6777445188306749
# Topic 4: Coherence Score: 0.5022842441073684
# Topic 5: Coherence Score: 0.4812935539983826
