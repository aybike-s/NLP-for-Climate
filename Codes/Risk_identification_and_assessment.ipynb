# %%
pip install PyMuPDF

# %%
pip install BERTopic

# %%
import os
import fitz
import nltk
import re
import string
import gensim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pprint


# For tokenization
from nltk.tokenize import word_tokenize
nltk.download("punkt")
nltk.download('wordnet')

# For removing stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')

# For lemmatization
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')

# For TF-IDC
from gensim import corpora
from gensim.models import TfidfModel

# For N-grams
from collections import defaultdict
from nltk.util import ngrams as nltk_ngrams
from nltk.tokenize import word_tokenize

# For BERT topic
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# For coherence score
from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# ### Get text from PDFs

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as pdf:
        for page_num in range(len(pdf)):
            page = pdf.load_page(page_num)
            text += page.get_text()
    return text

# %% [markdown]
# ### Preprocess and vectorize text

# %% [markdown]
# *Preprocess pipeline*

# %%
# Loading WordNet POS tags for lemmatization
def wordnet_pos_tags(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def txt_preprocess_pipeline(text):

    # Removing multiple white spaces and line breaks
    clean_txt = re.sub(r'\n', ' ', text)
    clean_txt = re.sub(r'\s+', ' ', clean_txt)
    clean_txt = clean_txt.strip()

    # Tokenizing text
    tokens = nltk.word_tokenize(clean_txt)

    # Loading NLTK stopword list and adding original stopwords
    stop_words = set(stopwords.words('english')+['impact','event','area','project','region','change','country','na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health','heat','temperature','change','risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])

    # Adding custom stopwords directly to the set
    custom_stopwords = set(['impact','event','area','project','region','change','country','na','na na','city','oecd','urban','red','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health', 'heat', 'temperature', 'change', 'risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])
    stop_words.update(custom_stopwords)

    # Standardize the text and removing non-alphabetic or stop words
    words = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

    # Defining lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Conducting POS tagging
    pos_tags = nltk.pos_tag(words)

    # Lemmatizing word-tokens via assigned POS tags
    lemma_tokens = [lemmatizer.lemmatize(token, wordnet_pos_tags(pos_tag)) for token, pos_tag in pos_tags]

    return lemma_tokens

# %% [markdown]
# *Iteration function*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def iterate_pdf_files(pdf_folder):
    # Creating a dictionary to display all documents and tokens together
    docs = {}

    # Counting to track the number of processed texts
    text_count = 0

    # Iterating over each file in the folder
    for filename in os.listdir(pdf_folder):

        # Checking whether the files are PDFs
        if filename.endswith('.pdf'):

            # Creating a path to the PDF files
            pdf_path = os.path.join(pdf_folder, filename)

            # Extracting the content of files
            text = extract_text_from_pdf(pdf_path)

            # Applying the preprocessing pipeline to the extracted tex
            preprocessed_text = txt_preprocess_pipeline(text)

            # Generating a unique name for the document based on the length of the docs dictionary for ease in readibility
            doc_name = f'doc{len(docs) + 1}'

            # Assigning the preprocessed text content of the current document in the docs dictionary with the document name as the key
            docs[doc_name] = [preprocessed_text]

            # Increasing the text count when finished assigning
            text_count += 1

    return docs

pdf_folder = '/content/drive/MyDrive/Documents/risk'

# Calling the iterate_pdf_files function to get the dictionary of documents
docs = iterate_pdf_files(pdf_folder)

# Printing each document's tokens as a list
for doc_name, tokens in docs.items():
    print(f"{doc_name}: {tokens}")

# %% [markdown]
# *Token dictionary*

# %%
# Iterating over the values in the docs dictionary created in the previous step. Each value in the sublist represents the tokens in a certain document
all_preprocessed_text = [token for sublist in docs.values() for token in sublist]

# Creating a gensim dictionary to assign an integer ID to each token
dictionary = corpora.Dictionary(all_preprocessed_text)
print(dictionary)

# %% [markdown]
# *BoW representation*

# %%
# Creating a Bag-of-Words (BoW) representation of the preprocessed text data using the dictionary created in the previous step
bow_corpus = [dictionary.doc2bow(text) for text in all_preprocessed_text]
pprint.pprint(bow_corpus)

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(bow_corpus))

# %% [markdown]
# ### TF-IDF

# %%
# Creating a TF-IDF model from the Bag-of-Words corpus
tfidf_model = TfidfModel(bow_corpus)

# Applying the TF-IDF model to the Bag-of-Words corpus to get the TF-IDF representation
tfidf_corpus = tfidf_model[bow_corpus]

# Printing the TF-IDF representation for the first few documents
for doc in tfidf_corpus[:5]:
    print(doc)

# %%
# Looking up the word corresponding to word_id = 0
word_id = 5
word = dictionary[word_id]
print("Word corresponding to word_id =", word_id, ":", word)

# %%
# Defining the TF-IDF threshold
threshold = 0.05

# Iterating through the TF-IDF representation of the documents
for doc in tfidf_corpus[:5]:  # Iterating over the first few documents

    # Filtering words with TF-IDF scores above the threshold
    words_above_threshold = [(dictionary[word_id], tfidf_score) for word_id, tfidf_score in doc if tfidf_score > threshold]

    # Printing the words with TF-IDF scores above the threshold
    print("Words with TF-IDF score > 0.05:", words_above_threshold)
# Out:
# Words with TF-IDF score > 0.05: [('accelerator', 0.07399326460810697), ('authority', 0.10882206085155267), ('borough', 0.13479113588542466), ('defence', 0.07433646848692198), ('deliver', 0.05573735493173089), ('delivery', 0.0548006897905706), ('estuary', 0.07433646848692198), ('finance', 0.06543770837239964), ('flood', 0.0797671636481851), ('gla', 0.346605777991092), ('government', 0.07566566040354253), ('hall', 0.07184560415010921), ('investment', 0.051095890383497565), ('london', 0.5442802681618405), ('londoner', 0.1829308272730763), ('mayor', 0.4239032238452045), ('organisation', 0.06034460378965195), ('programme', 0.05416840245447675), ('recommendation', 0.1258272336824305), ('resilience', 0.1015657546021439), ('riverside', 0.051791214257431974), ('say', 0.10071327796695474), ('strategic', 0.08999909945983191), ('suds', 0.10687915998948783), ('tfl', 0.06739556794271233), ('thames', 0.20972981616068084), ('uk', 0.11111170907736309), ('vision', 0.05042787325463444)]
# Words with TF-IDF score > 0.05: [('france', 0.053796882139292596), ('game', 0.06116436668194649), ('scenario', 0.0514454285243285), ('abdulaziz', 0.10769623880364608), ('analog', 0.2513525998096188), ('analogs', 0.1901854929799112), ('bcc', 0.0812014478711172), ('bias', 0.057874296837978643), ('boxplots', 0.11288819717763221), ('cccma', 0.0812014478711172), ('ceccr', 0.10769623880364608), ('cmcc', 0.10230578272988801), ('correction', 0.0948661248350448), ('extremevalueanalysis', 0.057055647893973355), ('generator', 0.058736221600279574), ('gev', 0.06752582771159875), ('ipsl', 0.3903988656632171), ('miroc', 0.1461511181855543), ('mri', 0.0950927464899556), ('ncc', 0.0950927464899556), ('npj', 0.06752582771159875), ('olympic', 0.11692089454844344), ('olympics', 0.11411129578794671), ('reanalysis', 0.05079420983013482), ('safran', 0.07607419719196447), ('simulation', 0.10763974106035648), ('slp', 0.20193044775683638), ('ssp', 0.22465683546063425), ('stochastic', 0.10768307293384588), ('swg', 0.5705564789397336), ('tg', 0.06731392912630513), ('tokyo', 0.051058371695598695), ('yiou', 0.1272618134672724)]
# Words with TF-IDF score > 0.05: [('cool', 0.056257317191384826), ('council', 0.07370383195259718), ('district', 0.10961185240038396), ('foundation', 0.06049582180580443), ('green', 0.10859358271612518), ('park', 0.08920004325749688), ('plant', 0.15447104096934117), ('pond', 0.06194469764495081), ('resilience', 0.06599544196996847), ('space', 0.054318355067472845), ('street', 0.05861717128349795), ('tree', 0.14138999093833515), ('water', 0.0622336761932994), ('atlantic', 0.09559029129615362), ('adrienne', 0.3642377041581015), ('aqueduct', 0.3292025785838647), ('athens', 0.08126655311273204), ('attica', 0.11725246339937118), ('cc', 0.059336466080651885), ('element', 0.1560698260630803), ('fountain', 0.06290141902473206), ('grass', 0.05319150769198158), ('gravel', 0.06753686119126912), ('guideline', 0.1693475048028891), ('hadrian', 0.5225220313219242), ('irrigation', 0.0669938206405072), ('microclimate', 0.054631361410100894), ('municipality', 0.06468054508627794), ('palatte', 0.05331857462468615), ('pave', 0.07256841643826305), ('pavement', 0.12684023293328966), ('pergola', 0.05687314626633189), ('permeable', 0.06636931890530444), ('playground', 0.11374629253266379), ('playgrounds', 0.05331857462468615), ('plaza', 0.06070628402635026), ('rainwater', 0.05466904957231441), ('root', 0.05601752340125464), ('shrubs', 0.05535324874176421), ('specie', 0.06318680272118629), ('square', 0.05536477050496691), ('streetscape', 0.07588285503293782), ('typology', 0.12503763531325043), ('wastewater', 0.05916549948029473)]
# Words with TF-IDF score > 0.05: [('cabinet', 0.0561856347810753), ('chain', 0.06969661939109797), ('cni', 0.058094809792154145), ('cool', 0.20135123811015648), ('cooling', 0.10687234458119961), ('critical', 0.12597723391282295), ('deliver', 0.09189900196288986), ('energy', 0.06692065419254324), ('equipment', 0.11536875652298), ('food', 0.2004420026510035), ('infrastructure', 0.1757889136604962), ('interdependency', 0.05350521779497332), ('optimise', 0.06293974616016683), ('overheat', 0.05384319709194454), ('productivity', 0.06219837145669443), ('provision', 0.07327070626862175), ('recognise', 0.07246607455552125), ('resilient', 0.055817188681589254), ('security', 0.07697694357011071), ('sustainable', 0.1272126357997008), ('technology', 0.0569488805400276), ('vision', 0.07674904606912297), ('africa', 0.05732311781922987), ('thermal', 0.08807028632286978), ('worldwide', 0.06932260189050786), ('digital', 0.08025652627685566), ('holistic', 0.053181663567196086), ('thermally', 0.05228121932860555), ('waste', 0.07064262048816813), ('appliance', 0.06421215403551463), ('fork', 0.058094809792154145), ('gci', 0.05442656666630688), ('kigali', 0.05442656666630688), ('mrna', 0.09524649166603703), ('npsa', 0.05442656666630688), ('nutritional', 0.07643602542139045), ('perishable', 0.058094809792154145), ('radical', 0.0561856347810753), ('refrigerate', 0.09524649166603703), ('refrigeration', 0.23237923916861658), ('renewable', 0.06578489663067683), ('retail', 0.05228121932860555), ('rwanda', 0.20914131525175492), ('sdgs', 0.05394835385157157), ('supermarket', 0.058094809792154145), ('vaccine', 0.5123559494203345), ('vcc', 0.05442656666630688), ('workplace', 0.06876488000371626)]
# Words with TF-IDF score > 0.05: [('direction', 0.05383177076471368), ('district', 0.05460043821888256), ('parameter', 0.08506845826656241), ('robustness', 0.12585610984283663), ('simulation', 0.11659839499772533), ('jacob', 0.05853502718678545), ('county', 0.22773447510506697), ('label', 0.06651168130860233), ('standardised', 0.051866187919082), ('visualisation', 0.12234272310294483), ('arrow', 0.05605035496322357), ('bandwidth', 0.16736157340839303), ('bathiany', 0.07707866094402968), ('diana', 0.08368078670419651), ('diﬀerent', 0.3049806929023766), ('eﬀective', 0.07195765435578082), ('gcm', 0.052533073473626186), ('gerics', 0.5579157620195215), ('german', 0.2489523418740334), ('graphical', 0.08770247051887325), ('hannover', 0.13947894050488038), ('hereon', 0.09298596033658693), ('icon', 0.09298596033658693), ('outlook', 0.2858110698180177), ('pfeifer', 0.13947894050488038), ('rcm', 0.12847164896560928), ('rcps', 0.08264040994983157), ('rechid', 0.08368078670419651), ('sebastian', 0.06423582448280464), ('signiﬁcant', 0.15381005840675782), ('susanne', 0.09298596033658693)]

# %% [markdown]
# ### N-grams

# %%
# Taking a list of tokens as input and generating n-grams
def generate_ngrams(tokens, n=3):
    return list(nltk_ngrams(tokens, n))

# Creating n-gram model from a corpus
def create_ngram_model(corpus, n=3):
    ngram_model = defaultdict(int)
    for text in corpus:
        tokens = word_tokenize(text)
        ngrams = generate_ngrams(tokens, n)
        for ngram in ngrams:
            ngram_model[ngram] += 1
    return ngram_model

max_texts_to_process = None
docs = iterate_pdf_files(pdf_folder)

# Concatenating preprocessed tokens for each document into a single list of tokens
corpus_tokens = [tokens for sublist in docs.values() for tokens in sublist]

# Concatenating tokens into a single string for each document
corpus_strings = [' '.join(tokens) for tokens in corpus_tokens]

# Creating an n-gram model
ngram_model = create_ngram_model(corpus_strings, n=3)

# Printing all n-grams
print("All N-grams:")
for ngram, frequency in ngram_model.items():
    print(ngram, ":", frequency)

# %%
# Filtering n-grams with frequency greater than 1
filtered_ngram_model = {ngram: frequency for ngram, frequency in ngram_model.items() if frequency > 1}

# Printing filtered n-grams
print("Filtered N-grams:")
for ngram, frequency in filtered_ngram_model.items():
    print(ngram, ":", frequency)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('frontier', 'hydrology', 'geoscience') : 2
# ('hydrology', 'geoscience', 'communication') : 2
# ('geoscience', 'communication', 'earth') : 2
# ('communication', 'earth', 'environ') : 2
# ('earth', 'environ', 'seibert') : 2
# ('environ', 'seibert', 'investigate') : 2
# ('seibert', 'investigate', 'transition') : 2
# ('investigate', 'transition', 'zone') : 2
# ('transition', 'zone', 'oceans') : 2
# ('zone', 'oceans', 'ourresearch') : 2
# ('oceans', 'ourresearch', 'future') : 2
# ('ourresearch', 'future', 'tebaldi') : 2
# ('future', 'tebaldi', 'sea') : 2
# ('tebaldi', 'sea', 'level') : 2
# ('level', 'different', 'global') : 2
# ('warming', 'level', 'nat') : 2
# ('nat', 'clim', 'rasmussen') : 2
# ('clim', 'rasmussen', 'sea') : 2
# ('rasmussen', 'sea', 'level') : 2
# ('sea', 'level', 'implication') : 2
# ('level', 'implication', 'degree') : 2
# ('implication', 'degree', 'c') : 2
# ('degree', 'c', 'stabilization') : 2
# ('c', 'stabilization', 'target') : 2
# ('stabilization', 'target', 'centuries') : 2
# ('target', 'centuries', 'environ') : 2
# ('centuries', 'environ', 're') : 2
# ('re', 'lett', 'wahl') : 2
# ('lett', 'wahl', 'understand') : 2
# ('wahl', 'understand', 'sea') : 2
# ('nat', 'commun', 'philip') : 2
# ('commun', 'philip', 'rapid') : 2
# ('philip', 'rapid', 'attribution') : 6
# ('rapid', 'attribution', 'analysis') : 10
# ('attribution', 'analysis', 'extraordinary') : 8
# ('analysis', 'extraordinary', 'wave') : 2
# ('extraordinary', 'wave', 'paciﬁc') : 2
# ('wave', 'paciﬁc', 'coast') : 2
# ('paciﬁc', 'coast', 'u') : 5
# ('coast', 'u', 'canada') : 9
# ('u', 'canada', 'june') : 8
# ('canada', 'june', 'earth') : 6
# ('june', 'earth', 'syst') : 5
# ('syst', 'dyn', 'clemesha') : 2
# ('dyn', 'clemesha', 'guirguis') : 2
# ('clemesha', 'guirguis', 'gershunov') : 2
# ('guirguis', 'gershunov', 'small') : 2
# ('gershunov', 'small', 'tardy') : 2
# ('small', 'tardy', 'california') : 2
# ('tardy', 'california', 'wave') : 2
# ('california', 'wave', 'spatial') : 2
# ('wave', 'spatial', 'evolution') : 2
# ('spatial', 'evolution', 'variation') : 2
# ('evolution', 'variation', 'coastal') : 2
# ('variation', 'coastal', 'modulation') : 2
# ('coastal', 'modulation', 'low') : 2
# ('modulation', 'low', 'cloud') : 2
# ('low', 'cloud', 'clim') : 2
# ('cloud', 'clim', 'dyn') : 2
# ('clim', 'dyn', 'sharma') : 2
# ('dyn', 'sharma', 'mujumdar') : 2
# ('sharma', 'mujumdar', 'increase') : 2
# ('mujumdar', 'increase', 'frequency') : 2
# ('increase', 'frequency', 'spatial') : 2
# ('frequency', 'spatial', 'extent') : 2
# ('spatial', 'extent', 'concurrent') : 3
# ('extent', 'concurrent', 'meteorological') : 2
# ('concurrent', 'meteorological', 'drought') : 2
# ('meteorological', 'drought', 'heatwaves') : 2
# ('drought', 'heatwaves', 'sci') : 2
# ('heatwaves', 'sci', 'gershunov') : 2
# ('sci', 'gershunov', 'guirguis') : 2
# ('gershunov', 'guirguis', 'california') : 2
# ('future', 'geophys', 'burden') : 2
# ('geophys', 'burden', 'mortality') : 2
# ('nat', 'clim', 'perkins') : 2
# ('re', 'lett', 'domeisen') : 2
# ('lett', 'domeisen', 'prediction') : 2
# ('domeisen', 'prediction', 'projection') : 2
# ('prediction', 'projection', 'heatwaves') : 2
# ('projection', 'heatwaves', 'nat') : 2
# ('heatwaves', 'nat', 'rev') : 2
# ('earth', 'environ', 'guirguis') : 2
# ('environ', 'guirguis', 'gershunov') : 2
# ('guirguis', 'gershunov', 'tardy') : 2
# ('gershunov', 'tardy', 'recent') : 2
# ('tardy', 'recent', 'wave') : 2
# ('recent', 'wave', 'human') : 2
# ('wave', 'human', 'california') : 2
# ('human', 'california', 'appl') : 2
# ('california', 'appl', 'meteorol') : 2
# ('meteorol', 'climatol', 'arns') : 2
# ('climatol', 'arns', 'interaction') : 2
# ('arns', 'interaction', 'modulates') : 2
# ('interaction', 'modulates', 'global') : 2
# ('modulates', 'global', 'sea') : 2
# ('level', 'coastal', 'ﬂood') : 2
# ('coastal', 'ﬂood', 'exposure') : 2
# ('ﬂood', 'exposure', 'impact') : 2
# ('exposure', 'impact', 'nat') : 2
# ('nat', 'commun', 'ipcc') : 2
# ('commun', 'ipcc', 'contribution') : 2
# ('ipcc', 'contribution', 'work') : 2
# ('science', 'basis', 'vousdoukas') : 2
# ('basis', 'vousdoukas', 'global') : 2
# ('vousdoukas', 'global', 'probabilistic') : 2
# ('global', 'probabilistic', 'projection') : 2
# ('probabilistic', 'projection', 'sea') : 2
# ('sea', 'level', 'show') : 2
# ('level', 'show', 'intensiﬁcation') : 2
# ('show', 'intensiﬁcation', 'coastal') : 2
# ('intensiﬁcation', 'coastal', 'ﬂood') : 2
# ('coastal', 'ﬂood', 'hazard') : 2
# ('ﬂood', 'hazard', 'nat') : 2
# ('hazard', 'nat', 'commun') : 2
# ('nat', 'commun', 'hinkel') : 2
# ('commun', 'hinkel', 'coastal') : 2
# ('hinkel', 'coastal', 'ﬂood') : 2
# ('coastal', 'ﬂood', 'damage') : 2
# ('ﬂood', 'damage', 'cost') : 2
# ('cost', 'century', 'rise') : 2
# ('century', 'rise', 'proc') : 2
# ('rise', 'proc', 'natl') : 2
# ('acad', 'sci', 'macmanus') : 2
# ('sci', 'macmanus', 'balk') : 2
# ('macmanus', 'balk', 'engin') : 2
# ('balk', 'engin', 'mcgranahan') : 2
# ('engin', 'mcgranahan', 'inman') : 2
# ('mcgranahan', 'inman', 'estimate') : 2
# ('inman', 'estimate', 'population') : 2
# ('estimate', 'population', 'area') : 2
# ('population', 'area', 'coastal') : 2
# ('area', 'coastal', 'hazard') : 2
# ('coastal', 'hazard', 'choice') : 2
# ('hazard', 'choice', 'matter') : 2
# ('choice', 'matter', 'earth') : 2
# ('matter', 'earth', 'syst') : 2
# ('syst', 'sci', 'knox') : 2
# ('sci', 'knox', 'alicante') : 2
# ('knox', 'alicante', 'hit') : 2
# ('alicante', 'hit', 'caused') : 2
# ('hit', 'caused', 'saharan') : 2
# ('caused', 'saharan', 'surge') : 2
# ('saharan', 'surge', 'brit') : 2
# ('surge', 'brit', 'tourist') : 2
# ('brit', 'tourist', 'face') : 2
# ('tourist', 'face', 'sizzler') : 2
# ('face', 'sizzler', 'sun') : 2
# ('sizzler', 'sun', 'article') : 2
# ('sun', 'article', 'communication') : 2
# ('earth', 'environment', 'peacock') : 2
# ('environment', 'peacock', 'alicante') : 2
# ('peacock', 'alicante', 'hit') : 2
# ('alicante', 'hit', 'leave') : 2
# ('hit', 'leave', 'part') : 2
# ('leave', 'part', 'brit') : 2
# ('part', 'brit', 'tourist') : 2
# ('brit', 'tourist', 'hotspot') : 2
# ('tourist', 'hotspot', 'water') : 2
# ('hotspot', 'water', 'mirror') : 2
# ('water', 'mirror', 'seneviratne') : 2
# ('mirror', 'seneviratne', 'contribution') : 2
# ('seneviratne', 'contribution', 'work') : 2
# ('science', 'basis', 'muis') : 2
# ('basis', 'muis', 'global') : 2
# ('muis', 'global', 'dataset') : 2
# ('global', 'dataset', 'sea') : 2
# ('dataset', 'sea', 'level') : 2
# ('sea', 'level', 'tide') : 2
# ('level', 'tide', 'storm') : 2
# ('surge', 'include', 'future') : 2
# ('include', 'future', 'projection') : 2
# ('future', 'projection', 'marine') : 2
# ('projection', 'marine', 'sci') : 2
# ('marine', 'sci', 'neumann') : 2
# ('sci', 'neumann', 'vafeidis') : 2
# ('neumann', 'vafeidis', 'zimmermann') : 2
# ('vafeidis', 'zimmermann', 'nicholls') : 2
# ('zimmermann', 'nicholls', 'future') : 2
# ('nicholls', 'future', 'coastal') : 2
# ('future', 'coastal', 'population') : 2
# ('coastal', 'population', 'growth') : 2
# ('population', 'growth', 'exposure') : 2
# ('growth', 'exposure', 'rise') : 2
# ('exposure', 'rise', 'coastal') : 2
# ('rise', 'coastal', 'global') : 2
# ('coastal', 'global', 'assessment') : 2
# ('global', 'assessment', 'plo') : 2
# ('assessment', 'plo', 'one') : 2
# ('plo', 'one', 'jones') : 3
# ('one', 'jones', 'b') : 2
# ('b', 'neill', 'global') : 2
# ('neill', 'global', 'degree') : 2
# ('global', 'degree', 'population') : 2
# ('degree', 'population', 'base') : 2
# ('center', 'sedac', 'access') : 2
# ('sedac', 'access', 'barragán') : 2
# ('access', 'barragán', 'andrés') : 2
# ('barragán', 'andrés', 'analysis') : 2
# ('andrés', 'analysis', 'trend') : 2
# ('analysis', 'trend', 'coastal') : 2
# ('trend', 'coastal', 'city') : 2
# ('coastal', 'city', 'agglomeration') : 2
# ('city', 'agglomeration', 'ocean') : 2
# ('agglomeration', 'ocean', 'coastal') : 2
# ('ocean', 'coastal', 'manag') : 2
# ('coastal', 'manag', 'wang') : 2
# ('manag', 'wang', 'zhang') : 2
# ('wang', 'zhang', 'raymond') : 2
# ('zhang', 'raymond', 'matthew') : 2
# ('raymond', 'matthew', 'grow') : 2
# ('matthew', 'grow', 'threat') : 2
# ('grow', 'threat', 'swing') : 2
# ('threat', 'swing', 'hot') : 2
# ('swing', 'hot', 'wet') : 2
# ('hot', 'wet', 'extreme') : 2
# ('wet', 'extreme', 'warmer') : 2
# ('extreme', 'warmer', 'geophys') : 2
# ('warmer', 'geophys', 're') : 2
# ('re', 'lett', 'hendry') : 2
# ('lett', 'hendry', 'assess') : 2
# ('hendry', 'assess', 'characteristic') : 2
# ('assess', 'characteristic', 'driver') : 2
# ('characteristic', 'driver', 'compound') : 2
# ('driver', 'compound', 'ﬂooding') : 2
# ('compound', 'ﬂooding', 'event') : 2
# ('ﬂooding', 'event', 'around') : 2
# ('event', 'around', 'uk') : 2
# ('around', 'uk', 'coast') : 2
# ('uk', 'coast', 'hydrol') : 2
# ('coast', 'hydrol', 'earth') : 2
# ('syst', 'sci', 'zscheischler') : 2
# ('earth', 'environ', 'ha') : 2
# ('environ', 'ha', 'dynamic') : 2
# ('ha', 'dynamic', 'characteristic') : 3
# ('dynamic', 'characteristic', 'dry') : 3
# ('characteristic', 'dry', 'moist') : 3
# ('dry', 'moist', 'heatwaves') : 3
# ('moist', 'heatwaves', 'east') : 3
# ('heatwaves', 'east', 'asia') : 4
# ('east', 'asia', 'npj') : 3
# ('asia', 'npj', 'clim') : 3
# ('sci', 'chen', 'lu') : 2
# ('chen', 'lu', 'comparison') : 2
# ('lu', 'comparison', 'circulation') : 2
# ('comparison', 'circulation', 'anomaly') : 2
# ('circulation', 'anomaly', 'associate') : 2
# ('anomaly', 'associate', 'different') : 2
# ('different', 'region', 'eastern') : 2
# ('region', 'eastern', 'china') : 4
# ('eastern', 'china', 'clim') : 2
# ('china', 'clim', 'needham') : 2
# ('clim', 'needham', 'keim') : 2
# ('needham', 'keim', 'sathiaraj') : 2
# ('keim', 'sathiaraj', 'review') : 2
# ('sathiaraj', 'review', 'tropical') : 2
# ('review', 'tropical', 'storm') : 2
# ('tropical', 'storm', 'surge') : 2
# ('storm', 'surge', 'global') : 2
# ('surge', 'global', 'source') : 2
# ('global', 'source', 'observation') : 2
# ('source', 'observation', 'impact') : 2
# ('observation', 'impact', 'rev') : 2
# ('impact', 'rev', 'geophys') : 2
# ('rev', 'geophys', 'gori') : 2
# ('geophys', 'gori', 'lin') : 2
# ('gori', 'lin', 'xi') : 2
# ('lin', 'xi', 'emanuel') : 2
# ('xi', 'emanuel', 'tropical') : 2
# ('cyclone', 'climatology', 'greatly') : 2
# ('climatology', 'greatly', 'exacerbate') : 2
# ('greatly', 'exacerbate', 'u') : 2
# ('exacerbate', 'u', 'hazard') : 2
# ('u', 'hazard', 'nat') : 2
# ('hazard', 'nat', 'clim') : 5
# ('nat', 'clim', 'lin') : 2
# ('clim', 'lin', 'emanuel') : 2
# ('lin', 'emanuel', 'oppenheimer') : 2
# ('emanuel', 'oppenheimer', 'vanmarcke') : 2
# ('oppenheimer', 'vanmarcke', 'physically') : 2
# ('vanmarcke', 'physically', 'base') : 2
# ('physically', 'base', 'assessment') : 2
# ('base', 'assessment', 'hurricane') : 2
# ('assessment', 'hurricane', 'surge') : 2
# ('surge', 'threat', 'nat') : 2
# ('threat', 'nat', 'clim') : 2
# ('nat', 'clim', 'muis') : 2
# ('clim', 'muis', 'verlaan') : 2
# ('muis', 'verlaan', 'winsemius') : 2
# ('verlaan', 'winsemius', 'aerts') : 2
# ('winsemius', 'aerts', 'ward') : 2
# ('aerts', 'ward', 'global') : 2
# ('ward', 'global', 'reanalysis') : 2
# ('global', 'reanalysis', 'storm') : 2
# ('reanalysis', 'storm', 'surge') : 2
# ('sea', 'level', 'nat') : 2
# ('level', 'nat', 'commun') : 2
# ('nat', 'commun', 'wade') : 2
# ('commun', 'wade', 'melt') : 2
# ('wade', 'melt', 'ice') : 2
# ('sheet', 'could', 'actually') : 2
# ('could', 'actually', 'lower') : 2
# ('actually', 'lower', 'sea') : 2
# ('lower', 'sea', 'level') : 2
# ('level', 'place', 'science') : 2
# ('place', 'science', 'magazine') : 2
# ('science', 'magazine', 'rogers') : 2
# ('magazine', 'rogers', 'recent') : 2
# ('rogers', 'recent', 'increase') : 2
# ('recent', 'increase', 'exposure') : 3
# ('increase', 'exposure', 'event') : 3
# ('exposure', 'event', 'disproportionately') : 3
# ('event', 'disproportionately', 'affect') : 3
# ('disproportionately', 'affect', 'populated') : 3
# ('affect', 'populated', 'region') : 3
# ('populated', 'region', 'geophys') : 3
# ('region', 'geophys', 're') : 5
# ('re', 'lett', 'speizer') : 2
# ('lett', 'speizer', 'raymond') : 2
# ('speizer', 'raymond', 'ivanovich') : 2
# ('raymond', 'ivanovich', 'horton') : 2
# ('ivanovich', 'horton', 'concentrate') : 2
# ('horton', 'concentrate', 'intensify') : 2
# ('concentrate', 'intensify', 'humid') : 2
# ('intensify', 'humid', 'extreme') : 2
# ('humid', 'extreme', 'ipcc') : 2
# ('extreme', 'ipcc', 'region') : 2
# ('ipcc', 'region', 'geophys') : 2
# ('re', 'lett', 'wang') : 2
# ('lett', 'wang', 'increase') : 2
# ('wang', 'increase', 'compound') : 2
# ('compound', 'hazard', 'tropical') : 2
# ('cyclone', 'heatwaves', 'southeastern') : 2
# ('heatwaves', 'southeastern', 'coast') : 2
# ('coast', 'china', 'warm') : 2
# ('china', 'warm', 'clim') : 2
# ('warm', 'clim', 'zhao') : 2
# ('clim', 'zhao', 'lin') : 2
# ('zhao', 'lin', 'li') : 2
# ('lin', 'li', 'gao') : 2
# ('li', 'gao', 'induce') : 2
# ('gao', 'induce', 'typhoon') : 2
# ('induce', 'typhoon', 'lekima') : 2
# ('typhoon', 'lekima', 'contribute') : 2
# ('lekima', 'contribute', 'factor') : 2
# ('contribute', 'factor', 'geophys') : 2
# ('factor', 'geophys', 're') : 2
# ('re', 'atmos', 'matthew') : 2
# ('atmos', 'matthew', 'wilby') : 2
# ('emerge', 'tropical', 'deadly') : 3
# ('tropical', 'deadly', 'compound') : 3
# ('deadly', 'compound', 'hazard') : 3
# ('compound', 'hazard', 'nat') : 3
# ('nat', 'clim', 'davis') : 2
# ('clim', 'davis', 'gertler') : 2
# ('davis', 'gertler', 'jarvis') : 2
# ('gertler', 'jarvis', 'wolfram') : 2
# ('jarvis', 'wolfram', 'air') : 2
# ('wolfram', 'air', 'condition') : 2
# ('air', 'condition', 'global') : 2
# ('condition', 'global', 'inequality') : 2
# ('global', 'inequality', 'global') : 2
# ('inequality', 'global', 'environ') : 2
# ('global', 'environ', 'pavanello') : 2
# ('environ', 'pavanello', 'cool') : 2
# ('pavanello', 'cool', 'deﬁcit') : 2
# ('cool', 'deﬁcit', 'emerge') : 2
# ('deﬁcit', 'emerge', 'economy') : 2
# ('emerge', 'economy', 'nat') : 2
# ('economy', 'nat', 'commun') : 2
# ('nat', 'commun', 'panteli') : 2
# ('commun', 'panteli', 'mancarella') : 2
# ('panteli', 'mancarella', 'inﬂuence') : 2
# ('mancarella', 'inﬂuence', 'weather') : 2
# ('inﬂuence', 'weather', 'resilience') : 2
# ('weather', 'resilience', 'power') : 2
# ('power', 'system', 'impact') : 2
# ('system', 'impact', 'possible') : 2
# ('impact', 'possible', 'mitigation') : 2
# ('mitigation', 'strategy', 'electric') : 2
# ('strategy', 'electric', 'power') : 2
# ('electric', 'power', 'syst') : 2
# ('syst', 'res', 'biardeau') : 2
# ('res', 'biardeau', 'davis') : 2
# ('biardeau', 'davis', 'gertler') : 2
# ('davis', 'gertler', 'wolfram') : 2
# ('gertler', 'wolfram', 'exposure') : 2
# ('wolfram', 'exposure', 'global') : 2
# ('nat', 'sustain', 'matthew') : 2
# ('sustain', 'matthew', 'humid') : 2
# ('matthew', 'humid', 'progr') : 2
# ('humid', 'progr', 'phys') : 2
# ('progr', 'phys', 'geogr') : 2
# ('phys', 'geogr', 'earth') : 2
# ('geogr', 'earth', 'environ') : 2
# ('earth', 'environ', 'hooijer') : 2
# ('environ', 'hooijer', 'vernimmen') : 2
# ('hooijer', 'vernimmen', 'global') : 2
# ('vernimmen', 'global', 'lidar') : 2
# ('global', 'lidar', 'land') : 2
# ('lidar', 'land', 'elevation') : 2
# ('land', 'elevation', 'reveal') : 2
# ('elevation', 'reveal', 'great') : 2
# ('reveal', 'great', 'rise') : 2
# ('great', 'rise', 'vulnerability') : 2
# ('rise', 'vulnerability', 'tropic') : 2
# ('vulnerability', 'tropic', 'nat') : 2
# ('tropic', 'nat', 'commun') : 2
# ('nat', 'commun', 'cia') : 2
# ('commun', 'cia', 'country') : 2
# ('cia', 'country', 'high') : 2
# ('country', 'high', 'population') : 2
# ('high', 'population', 'growth') : 2
# ('growth', 'rate', 'compare') : 2
# ('previous', 'year', 'graph') : 2
# ('year', 'graph', 'statista') : 2
# ('graph', 'statista', 'jones') : 2
# ('statista', 'jones', 'b') : 2
# ('harrington', 'inequality', 'climatechange') : 2
# ('inequality', 'climatechange', 'global') : 2
# ('climatechange', 'global', 'warming') : 2
# ('res', 'lett', 'hersbach') : 2
# ('lett', 'hersbach', 'hourly') : 2
# ('hersbach', 'hourly', 'single') : 2
# ('level', 'present', 'dataset') : 4
# ('present', 'dataset', 'copernicus') : 4
# ('dataset', 'copernicus', 'service') : 6
# ('cd', 'access', 'hersbach') : 2
# ('access', 'hersbach', 'hourly') : 2
# ('hersbach', 'hourly', 'pressure') : 2
# ('cd', 'access', 'di') : 2
# ('access', 'di', 'virgilio') : 2
# ('di', 'virgilio', 'select') : 2
# ('virgilio', 'select', 'gcms') : 2
# ('select', 'gcms', 'cordex') : 2
# ('gcms', 'cordex', 'dynamical') : 2
# ('cordex', 'dynamical', 'downscaling') : 2
# ('dynamical', 'downscaling', 'performance') : 2
# ('downscaling', 'performance', 'independence') : 2
# ('performance', 'independence', 'signal') : 2
# ('independence', 'signal', 'earth') : 2
# ('signal', 'earth', 'fut') : 2
# ('earth', 'fut', 'copernicus') : 2
# ('fut', 'copernicus', 'service') : 2
# ('copernicus', 'service', 'projection') : 2
# ('service', 'projection', 'dataset') : 2
# ('projection', 'dataset', 'projection') : 2
# ('dataset', 'projection', 'copernicus') : 2
# ('projection', 'copernicus', 'service') : 2
# ('cd', 'access', 'sanne') : 2
# ('access', 'sanne', 'muis') : 2
# ('sanne', 'muis', 'global') : 2
# ('muis', 'global', 'sea') : 2
# ('sea', 'level', 'time') : 2
# ('series', 'derive', 'reanalysis') : 2
# ('derive', 'reanalysis', 'resolution') : 2
# ('reanalysis', 'resolution', 'projection') : 2
# ('resolution', 'projection', 'dataset') : 2
# ('projection', 'dataset', 'copernicus') : 2
# ('cd', 'access', 'wang') : 2
# ('access', 'wang', 'high') : 2
# ('wang', 'high', 'occurrence') : 2
# ('high', 'occurrence', 'hotter') : 2
# ('occurrence', 'hotter', 'shorter') : 2
# ('hotter', 'shorter', 'wave') : 2
# ('shorter', 'wave', 'follow') : 2
# ('wave', 'follow', 'heavy') : 2
# ('heavy', 'rainfall', 'geophys') : 2
# ('res', 'lett', 'chen') : 4
# ('lett', 'chen', 'wang') : 2
# ('chen', 'wang', 'accelerate') : 2
# ('wang', 'accelerate', 'transition') : 3
# ('accelerate', 'transition', 'dry') : 3
# ('transition', 'dry', 'wet') : 4
# ('dry', 'wet', 'period') : 3
# ('period', 'warm', 'geophys') : 3
# ('re', 'lett', 'wessel') : 2
# ('lett', 'wessel', 'smith') : 2
# ('wessel', 'smith', 'global') : 2
# ('smith', 'global', 'hierarchical') : 2
# ('global', 'hierarchical', 'shoreline') : 2
# ('hierarchical', 'shoreline', 'database') : 2
# ('shoreline', 'database', 'geophys') : 2
# ('geophys', 'res', 'solid') : 2
# ('res', 'solid', 'earth') : 2
# ('solid', 'earth', 'qiu') : 2
# ('earth', 'qiu', 'liu') : 2
# ('qiu', 'liu', 'wang') : 2
# ('liu', 'wang', 'x') : 2
# ('wang', 'x', 'quantitative') : 2
# ('x', 'quantitative', 'stress') : 2
# ('quantitative', 'stress', 'test') : 2
# ('stress', 'test', 'compound') : 2
# ('test', 'compound', 'ﬂoods') : 2
# ('compound', 'ﬂoods', 'china') : 2
# ('ﬂoods', 'china', 'pearl') : 2
# ('china', 'pearl', 'river') : 2
# ('pearl', 'river', 'delta') : 2
# ('river', 'delta', 'earth') : 2
# ('delta', 'earth', 'fut') : 2
# ('earth', 'fut', 'marsooli') : 2
# ('fut', 'marsooli', 'lin') : 2
# ('marsooli', 'lin', 'numerical') : 2
# ('lin', 'numerical', 'model') : 2
# ('numerical', 'model', 'historical') : 2
# ('model', 'historical', 'storm') : 2
# ('historical', 'storm', 'tide') : 2
# ('storm', 'tide', 'wave') : 2
# ('tide', 'wave', 'interaction') : 2
# ('wave', 'interaction', 'along') : 2
# ('interaction', 'along', 'east') : 2
# ('gulf', 'coast', 'geophys') : 2
# ('coast', 'geophys', 're') : 2
# ('geophys', 're', 'ocean') : 2
# ('re', 'ocean', 'vousdoukas') : 2
# ('ocean', 'vousdoukas', 'sandy') : 2
# ('vousdoukas', 'sandy', 'coastline') : 2
# ('sandy', 'coastline', 'threat') : 2
# ('coastline', 'threat', 'erosion') : 2
# ('threat', 'erosion', 'nat') : 2
# ('erosion', 'nat', 'clim') : 2
# ('nat', 'clim', 'article') : 2
# ('clim', 'article', 'communication') : 2
# ('earth', 'environment', 'ipcc') : 2
# ('environment', 'ipcc', 'physical') : 2
# ('work', 'group', 'ﬁfth') : 2
# ('group', 'ﬁfth', 'assessment') : 2
# ('ﬁfth', 'assessment', 'intergovernmental') : 2
# ('university', 'press', 'burke') : 2
# ('press', 'burke', 'davis') : 2
# ('burke', 'davis', 'diffenbaugh') : 2
# ('davis', 'diffenbaugh', 'large') : 2
# ('diffenbaugh', 'large', 'potential') : 2
# ('large', 'potential', 'reduction') : 2
# ('potential', 'reduction', 'economic') : 2
# ('reduction', 'economic', 'damage') : 2
# ('economic', 'damage', 'un') : 2
# ('damage', 'un', 'mitigation') : 2
# ('un', 'mitigation', 'target') : 2
# ('mitigation', 'target', 'nature') : 2
# ('target', 'nature', 'rousi') : 2
# ('nature', 'rousi', 'kornhuber') : 2
# ('rousi', 'kornhuber', 'luo') : 3
# ('kornhuber', 'luo', 'coumou') : 3
# ('luo', 'coumou', 'accelerate') : 3
# ('coumou', 'accelerate', 'western') : 3
# ('accelerate', 'western', 'european') : 3
# ('western', 'european', 'heatwave') : 4
# ('european', 'heatwave', 'trend') : 3
# ('heatwave', 'trend', 'link') : 3
# ('trend', 'link', 'persistent') : 3
# ('link', 'persistent', 'double') : 3
# ('persistent', 'double', 'jet') : 3
# ('double', 'jet', 'eurasia') : 3
# ('jet', 'eurasia', 'nat') : 3
# ('eurasia', 'nat', 'commun') : 3
# ('nat', 'commun', 'schoof') : 2
# ('commun', 'schoof', 'heern') : 2
# ('schoof', 'heern', 'z') : 2
# ('heern', 'z', 'therrell') : 2
# ('z', 'therrell', 'remo') : 2
# ('therrell', 'remo', 'assess') : 2
# ('remo', 'assess', 'trend') : 2
# ('assess', 'trend', 'lower') : 2
# ('trend', 'lower', 'tropospheric') : 2
# ('lower', 'tropospheric', 'content') : 2
# ('tropospheric', 'content', 'central') : 2
# ('content', 'central', 'state') : 2
# ('central', 'state', 'use') : 2
# ('state', 'use', 'equivalent') : 2
# ('use', 'equivalent', 'int') : 2
# ('equivalent', 'int', 'climatol') : 2
# ('int', 'climatol', 'bolton') : 2
# ('climatol', 'bolton', 'computation') : 2
# ('bolton', 'computation', 'equivalent') : 2
# ('computation', 'equivalent', 'potential') : 2
# ('equivalent', 'potential', 'monthly') : 2
# ('potential', 'monthly', 'weather') : 2
# ('monthly', 'weather', 'rev') : 2
# ('weather', 'rev', 'lawrence') : 2
# ('rev', 'lawrence', 'relationship') : 2
# ('lawrence', 'relationship', 'relative') : 2
# ('relationship', 'relative', 'humidity') : 2
# ('relative', 'humidity', 'dewpoint') : 2
# ('humidity', 'dewpoint', 'moist') : 2
# ('dewpoint', 'moist', 'air') : 2
# ('moist', 'air', 'simple') : 2
# ('air', 'simple', 'conversion') : 2
# ('simple', 'conversion', 'application') : 2
# ('conversion', 'application', 'bull') : 2
# ('application', 'bull', 'meteorol') : 2
# ('meteorol', 'soc', 'lewis') : 2
# ('soc', 'lewis', 'increase') : 2
# ('nat', 'commun', 'wahl') : 2
# ('commun', 'wahl', 'chamber') : 2
# ('wahl', 'chamber', 'evidence') : 2
# ('chamber', 'evidence', 'multidecadal') : 2
# ('evidence', 'multidecadal', 'variability') : 2
# ('multidecadal', 'variability', 'u') : 2
# ('variability', 'u', 'sea') : 2
# ('u', 'sea', 'level') : 2
# ('sea', 'level', 'record') : 2
# ('level', 'record', 'geophys') : 2
# ('record', 'geophys', 're') : 2
# ('geophys', 're', 'oceans') : 2
# ('re', 'oceans', 'kirezci') : 2
# ('oceans', 'kirezci', 'projection') : 2
# ('kirezci', 'projection', 'sea') : 2
# ('sea', 'level', 'result') : 2
# ('level', 'result', 'episodic') : 2
# ('result', 'episodic', 'coastal') : 2
# ('episodic', 'coastal', 'ﬂooding') : 2
# ('coastal', 'ﬂooding', 'century') : 2
# ('ﬂooding', 'century', 'sci') : 2
# ('century', 'sci', 'rashid') : 2
# ('sci', 'rashid', 'wahl') : 2
# ('rashid', 'wahl', 'chamber') : 2
# ('wahl', 'chamber', 'calafat') : 2
# ('chamber', 'calafat', 'sweet') : 2
# ('calafat', 'sweet', 'sea') : 2
# ('sweet', 'sea', 'level') : 2
# ('sea', 'level', 'indicator') : 2
# ('level', 'indicator', 'contiguous') : 2
# ('indicator', 'contiguous', 'state') : 2
# ('contiguous', 'state', 'coastline') : 2
# ('state', 'coastline', 'sci') : 2
# ('coastline', 'sci', 'menéndez') : 2
# ('sci', 'menéndez', 'méndez') : 2
# ('menéndez', 'méndez', 'luceño') : 2
# ('méndez', 'luceño', 'losada') : 2
# ('luceño', 'losada', 'analyze') : 2
# ('losada', 'analyze', 'monthly') : 2
# ('analyze', 'monthly', 'sea') : 2
# ('monthly', 'sea', 'level') : 2
# ('sea', 'level', 'gev') : 2
# ('level', 'gev', 'atmos') : 2
# ('gev', 'atmos', 'oceanic') : 2
# ('atmos', 'oceanic', 'technol') : 2
# ('oceanic', 'technol', 'bevacqua') : 2
# ('technol', 'bevacqua', 'high') : 2
# ('high', 'compound', 'ﬂooding') : 2
# ('compound', 'ﬂooding', 'precipitation') : 2
# ('ﬂooding', 'precipitation', 'storm') : 2
# ('sci', 'adv', 'nairn') : 2
# ('adv', 'nairn', 'fawcett') : 2
# ('environ', 'res', 'horton') : 2
# ('res', 'horton', 'contribution') : 2
# ('trend', 'nature', 'acknowledgement') : 2
# ('nature', 'acknowledgement', 'acknowledge') : 2
# ('acknowledgement', 'acknowledge', 'support') : 2
# ('acknowledge', 'support', 'environment') : 2
# ('support', 'environment', 'conservation') : 2
# ('environment', 'conservation', 'fund') : 2
# ('conservation', 'fund', 'grant') : 2
# ('fund', 'grant', 'hong') : 2
# ('grant', 'hong', 'kong') : 2
# ('polytechnic', 'university', 'grant') : 2
# ('university', 'grant', 'author') : 2
# ('contribution', 'design', 'carried') : 2
# ('design', 'carried', 'analysis') : 3
# ('carried', 'analysis', 'draft') : 2
# ('draft', 'manuscript', 'supervise') : 2
# ('manuscript', 'supervise', 'analysis') : 2
# ('supervise', 'analysis', 'contribute') : 2
# ('analysis', 'contribute', 'interpretation') : 3
# ('contribute', 'interpretation', 'discussion') : 2
# ('interpretation', 'discussion', 'result') : 2
# ('discussion', 'result', 'revise') : 2
# ('result', 'revise', 'edited') : 2
# ('revise', 'edited', 'manuscript') : 2
# ('edited', 'manuscript', 'compete') : 2
# ('material', 'address', 'shuo') : 2
# ('address', 'shuo', 'wang') : 2
# ('shuo', 'wang', 'peer') : 2
# ('wang', 'peer', 'review') : 2
# ('environment', 'thanks', 'md') : 2
# ('thanks', 'md', 'mamunur') : 2
# ('md', 'mamunur', 'rashid') : 2
# ('mamunur', 'rashid', 'manal') : 2
# ('rashid', 'manal', 'elawady') : 2
# ('manal', 'elawady', 'anonymous') : 2
# ('elawady', 'anonymous', 'reviewer') : 2
# ('handling', 'editor', 'jennifer') : 2
# ('editor', 'jennifer', 'veitch') : 2
# ('jennifer', 'veitch', 'aliénor') : 2
# ('veitch', 'aliénor', 'lavergne') : 2
# ('author', 'article', 'communication') : 2
# ('rapid', 'attribution', 'heatwave') : 2
# ('attribution', 'heatwave', 'north') : 2
# ('heatwave', 'north', 'china') : 6
# ('north', 'china', 'june') : 11
# ('china', 'june', 'future') : 2
# ('june', 'future', 'risk') : 2
# ('re', 'lett', 'view') : 3
# ('f', 'b', 'tett') : 2
# ('heatwave', 'effect', 'gross') : 2
# ('effect', 'gross', 'primary') : 2
# ('primary', 'production', 'northern') : 2
# ('production', 'northern', 'ecosystems') : 2
# ('northern', 'ecosystems', 'hang') : 2
# ('ecosystems', 'hang', 'xu') : 2
# ('hang', 'xu', 'jingfeng') : 2
# ('xu', 'jingfeng', 'xiao') : 2
# ('jingfeng', 'xiao', 'zhiqiang') : 2
# ('xiao', 'zhiqiang', 'zhang') : 2
# ('zhiqiang', 'zhang', 'concurrent') : 2
# ('zhang', 'concurrent', 'drought') : 2
# ('concurrent', 'drought', 'heatwave') : 3
# ('drought', 'heatwave', 'event') : 3
# ('heatwave', 'event', 'asian') : 2
# ('event', 'asian', 'monsoon') : 2
# ('asian', 'monsoon', 'insight') : 2
# ('monsoon', 'insight', 'statistically') : 2
# ('insight', 'statistically', 'downscaling') : 2
# ('statistically', 'downscaling', 'dataset') : 2
# ('downscaling', 'dataset', 'lianlian') : 2
# ('dataset', 'lianlian', 'xu') : 2
# ('lianlian', 'xu', 'wei') : 2
# ('xu', 'wei', 'yu') : 2
# ('wei', 'yu', 'song') : 2
# ('yu', 'song', 'content') : 2
# ('song', 'content', 'download') : 2
# ('re', 'lett', 'open') : 4
# ('lett', 'open', 'access') : 4
# ('science', 'beijing', 'people') : 3
# ('beijing', 'people', 'republic') : 5
# ('institute', 'knmi', 'bilt') : 2
# ('knmi', 'bilt', 'netherlands') : 2
# ('tsinghua', 'university', 'beijing') : 2
# ('university', 'beijing', 'people') : 2
# ('heatwave', 'event', 'related') : 2
# ('intense', 'strong', 'heatwave') : 2
# ('strong', 'heatwave', 'event') : 2
# ('heatwave', 'event', 'future') : 2
# ('carry', 'rapid', 'attribution') : 2
# ('show', 'return', 'period') : 3
# ('consistently', 'show', 'intensity') : 2
# ('intensity', 'heatwave', 'event') : 3
# ('significantly', 'increase', 'least') : 2
# ('increase', 'least', 'range') : 2
# ('future', 'projection', 'indicate') : 2
# ('projection', 'indicate', 'event') : 2
# ('indicate', 'event', 'north') : 2
# ('event', 'north', 'china') : 6
# ('occur', 'least', 'range') : 2
# ('intense', 'even', 'carbon') : 2
# ('even', 'carbon', 'neutrality') : 4
# ('carbon', 'neutrality', 'achieve') : 5
# ('neutrality', 'achieve', 'base') : 2
# ('achieve', 'base', 'low') : 2
# ('base', 'low', 'emission') : 2
# ('emission', 'scenario', 'occurrence') : 2
# ('scenario', 'occurrence', 'event') : 2
# ('occurrence', 'event', 'north') : 2
# ('north', 'china', 'end') : 3
# ('china', 'end', 'century') : 3
# ('century', 'range', 'time') : 2
# ('range', 'time', 'intensity') : 2
# ('time', 'intensity', 'range') : 2
# ('heatwaves', 'north', 'china') : 2
# ('lett', 'c', 'qian') : 8
# ('unprecedented', 'observational', 'record') : 3
# ('attribution', 'analysis', 'heatwave') : 3
# ('attribution', 'empirical', 'approach') : 2
# ('empirical', 'approach', 'base') : 3
# ('approach', 'base', 'observation') : 4
# ('base', 'observation', 'couple') : 3
# ('observation', 'couple', 'approach') : 3
# ('couple', 'approach', 'base') : 3
# ('make', 'attribution', 'assessment') : 2
# ('assessment', 'use', 'weather') : 2
# ('use', 'weather', 'attribution') : 2
# ('weather', 'attribution', 'wwa') : 4
# ('wwa', 'protocol', 'however') : 2
# ('use', 'different', 'strategy') : 2
# ('attribution', 'future', 'projection') : 3
# ('include', 'low', 'emission') : 2
# ('scenario', 'carbon', 'neutrality') : 2
# ('forecast', 'ecmwf', 'reanalysis') : 2
# ('geopotential', 'height', 'gph') : 2
# ('volumetric', 'soil', 'water') : 2
# ('include', 'historical', 'simulation') : 2
# ('maximum', 'day', 'average') : 2
# ('average', 'tmax', 'june') : 3
# ('value', 'time', 'series') : 3
# ('approach', 'base', 'simulation') : 2
# ('adopt', 'wwa', 'protocol') : 2
# ('value', 'gev', 'method') : 2
# ('smooth', 'global', 'mean') : 3
# ('large', 'ensemble', 'simulation') : 2
# ('gev', 'distribution', 'fit') : 5
# ('obtain', 'gev', 'distribution') : 2
# ('intensity', 'similar', 'event') : 3
# ('similar', 'event', 'return') : 3
# ('pr', 'far', 'intensity') : 2
# ('intensity', 'calculate', 'use') : 2
# ('approach', 'use', 'time') : 2
# ('time', 'slice', 'year') : 2
# ('simulation', 'represent', 'state') : 2
# ('mean', 'historical', 'simulation') : 2
# ('observed', 'climatological', 'mean') : 2
# ('include', 'subsequent', 'attribution') : 2
# ('calculate', 'pr', 'intensity') : 2
# ('future', 'time', 'slice') : 2
# ('high', 'average', 'tmax') : 2
# ('june', 'time', 'period') : 2
# ('detrended', 'gph', 'anomaly') : 2
# ('return', 'period', 'state') : 2
# ('period', 'state', 'year') : 2
# ('state', 'year', 'uncertainty') : 2
# ('year', 'uncertainty', 'margin') : 2
# ('show', 'pr', 'range') : 3
# ('pr', 'range', 'statistically') : 2
# ('c', 'table', 'correspond') : 2
# ('table', 'correspond', 'far') : 2
# ('correspond', 'far', 'range') : 2
# ('far', 'range', 'c') : 2
# ('range', 'c', 'table') : 2
# ('c', 'table', 'intensity') : 2
# ('table', 'intensity', 'range') : 2
# ('intensity', 'range', 'statistically') : 2
# ('range', 'statistically', 'significant') : 2
# ('statistically', 'significant', 'table') : 2
# ('attribution', 'analysis', 'empirical') : 2
# ('re', 'lett', 'c') : 3
# ('average', 'three', 'day') : 2
# ('rectangle', 'indicate', 'b') : 2
# ('base', 'period', 'c') : 2
# ('anomaly', 'shade', 'unit') : 3
# ('june', 'rectangle', 'indicate') : 2
# ('period', 'environ', 'res') : 2
# ('indicate', 'uncertainty', 'range') : 2
# ('heatwave', 'event', 'compare') : 2
# ('event', 'compare', 'counterfactual') : 2
# ('compare', 'counterfactual', 'without') : 2
# ('counterfactual', 'without', 'human') : 2
# ('result', 'pool', 'ensemble') : 2
# ('show', 'first', 'column') : 2
# ('heatwave', 'event', 'north') : 2
# ('heatwave', 'event', 'typical') : 2
# ('event', 'typical', 'future') : 2
# ('typical', 'future', 'condition') : 2
# ('future', 'condition', 'compare') : 2
# ('shift', 'toward', 'warm') : 2
# ('range', 'statistically', 'ant') : 3
# ('among', 'individual', 'model') : 3
# ('nine', 'el', 'show') : 2
# ('el', 'show', 'consistent') : 2
# ('show', 'consistent', 'statistically') : 2
# ('consistent', 'statistically', 'significant') : 2
# ('statistically', 'significant', 'pr') : 2
# ('range', 'range', 'range') : 2
# ('range', 'range', 'respectively') : 2
# ('day', 'heatwave', 'event') : 2
# ('occur', 'often', 'intense') : 2
# ('china', 'june', 'occur') : 2
# ('least', 'range', 'statistically') : 2
# ('emission', 'scenario', 'intermediate') : 2
# ('avoid', 'outdoor', 'activity') : 2
# ('sponsor', 'natural', 'science') : 2
# ('grant', 'jiangsu', 'collaborative') : 2
# ('jiangsu', 'collaborative', 'innovation') : 2
# ('collaborative', 'innovation', 'center') : 4
# ('reviewer', 'comment', 'suggestion') : 2
# ('heatwave', 'nature', 'stott') : 2
# ('weather', 'event', 'wire') : 2
# ('event', 'wire', 'clim') : 2
# ('update', 'review', 'attribution') : 2
# ('review', 'attribution', 'approach') : 2
# ('attribution', 'approach', 'meteorol') : 2
# ('approach', 'meteorol', 'res') : 2
# ('zhang', 'x', 'b') : 2
# ('meteorol', 'soc', 'zhou') : 3
# ('central', 'eastern', 'china') : 2
# ('re', 'lett', 'chen') : 3
# ('china', 'bull', 'meteorol') : 2
# ('conditional', 'attribution', 'atmospheric') : 2
# ('attribution', 'atmospheric', 'circulation') : 2
# ('atmospheric', 'circulation', 'contribute') : 3
# ('circulation', 'contribute', 'precipitation') : 2
# ('contribute', 'precipitation', 'summer') : 2
# ('precipitation', 'summer', 'southern') : 2
# ('summer', 'southern', 'china') : 2
# ('southern', 'china', 'environ') : 2
# ('china', 'environ', 'res') : 3
# ('van', 'oldenborgh', 'pathway') : 2
# ('oldenborgh', 'pathway', 'pitfall') : 2
# ('pathway', 'pitfall', 'attribution') : 2
# ('pitfall', 'attribution', 'clim') : 3
# ('clim', 'otto', 'f') : 2
# ('europe', 'bull', 'meteorol') : 4
# ('state', 'bull', 'meteorol') : 2
# ('philip', 'protocol', 'probabilistic') : 2
# ('protocol', 'probabilistic', 'attribution') : 3
# ('probabilistic', 'attribution', 'analysis') : 3
# ('attribution', 'analysis', 'adv') : 3
# ('analysis', 'adv', 'stat') : 3
# ('hersbach', 'h', 'global') : 2
# ('h', 'global', 'reanalysis') : 2
# ('eyring', 'v', 'bony') : 2
# ('v', 'bony', 'meehl') : 2
# ('meehl', 'senior', 'c') : 2
# ('senior', 'c', 'stevens') : 2
# ('c', 'stevens', 'b') : 2
# ('stevens', 'b', 'stouffer') : 2
# ('b', 'stouffer', 'r') : 2
# ('stouffer', 'r', 'taylor') : 2
# ('r', 'taylor', 'k') : 2
# ('taylor', 'k', 'overview') : 2
# ('k', 'overview', 'couple') : 2
# ('change', 'wave', 'height') : 2
# ('wave', 'height', 'northern') : 2
# ('height', 'northern', 'hemisphere') : 2
# ('northern', 'hemisphere', 'ocean') : 2
# ('hemisphere', 'ocean', 'related') : 2
# ('ocean', 'related', 'atmospheric') : 2
# ('related', 'atmospheric', 'circulation') : 2
# ('atmospheric', 'circulation', 'regime') : 2
# ('circulation', 'regime', 'clim') : 2
# ('linear', 'trend', 'extremes') : 2
# ('trend', 'extremes', 'china') : 2
# ('extremes', 'china', 'emphasis') : 2
# ('china', 'emphasis', 'serially') : 2
# ('emphasis', 'serially', 'dependent') : 2
# ('serially', 'dependent', 'characteristic') : 2
# ('dependent', 'characteristic', 'clim') : 2
# ('extremes', 'north', 'america') : 2
# ('anthropogenic', 'western', 'europe') : 2
# ('western', 'europe', 'bull') : 2
# ('major', 'impediment', 'type') : 2
# ('impediment', 'type', 'analysis') : 2
# ('type', 'analysis', 'restrict') : 2
# ('analysis', 'restrict', 'access') : 2
# ('restrict', 'access', 'daily') : 3
# ('access', 'daily', 'record') : 3
# ('temporally', 'aggregate', 'daily') : 3
# ('daily', 'temperature', 'mortality') : 2
# ('temperature', 'mortality', 'record') : 2
# ('contiguous', 'region', 'european') : 4
# ('region', 'european', 'country') : 4
# ('estimate', 'mortality', 'relationship') : 2
# ('mortality', 'relationship', 'use') : 2
# ('relationship', 'use', 'standard') : 2
# ('regression', 'model', 'apply') : 4
# ('model', 'apply', 'daily') : 4
# ('apply', 'daily', 'compare') : 3
# ('daily', 'compare', 'result') : 3
# ('result', 'obtain', 'different') : 3
# ('obtain', 'different', 'degree') : 3
# ('different', 'degree', 'temporal') : 3
# ('degree', 'temporal', 'aggregation') : 9
# ('summer', 'underestimation', 'weekly') : 2
# ('infer', 'mortality', 'burden') : 3
# ('present', 'work', 'represent') : 3
# ('work', 'represent', 'ﬁrst') : 3
# ('represent', 'ﬁrst', 'reference') : 3
# ('ﬁrst', 'reference', 'validate') : 2
# ('reference', 'validate', 'weekly') : 2
# ('validate', 'weekly', 'time') : 2
# ('weekly', 'time', 'series') : 2
# ('time', 'series', 'approximation') : 2
# ('effect', 'cold', 'human') : 2
# ('cold', 'human', 'mortality') : 2
# ('approach', 'adopt', 'complement') : 2
# ('network', 'facilitate', 'access') : 3
# ('facilitate', 'access', 'research') : 3
# ('access', 'research', 'translation') : 3
# ('effect', 'ambient', 'temperature') : 4
# ('effect', 'cold', 'distribute') : 2
# ('daily', 'record', 'many') : 2
# ('record', 'many', 'country') : 2
# ('country', 'region', 'city') : 2
# ('possible', 'solution', 'circumvent') : 2
# ('weekly', 'monthly', 'outcome') : 2
# ('monthly', 'outcome', 'readily') : 2
# ('outcome', 'readily', 'available') : 2
# ('readily', 'available', 'open') : 2
# ('available', 'open', 'access') : 3
# ('open', 'access', 'lower') : 2
# ('access', 'lower', 'level') : 2
# ('lower', 'level', 'temporal') : 2
# ('open', 'access', 'weekly') : 2
# ('access', 'weekly', 'mortality') : 2
# ('aggregate', 'daily', 'mortality') : 2
# ('daily', 'mortality', 'database') : 2
# ('mortality', 'database', 'contiguous') : 2
# ('database', 'contiguous', 'region') : 2
# ('european', 'country', 'analyse') : 2
# ('country', 'analyse', 'contrast') : 2
# ('analyse', 'contrast', 'estimate') : 2
# ('contrast', 'estimate', 'obtain') : 2
# ('estimate', 'obtain', 'daily') : 4
# ('obtain', 'daily', 'weekly') : 2
# ('knowledge', 'ﬁrst', 'analyse') : 2
# ('ﬁrst', 'analyse', 'temporal') : 2
# ('analyse', 'temporal', 'aggregation') : 2
# ('temporal', 'aggregation', 'epidemiological') : 2
# ('aggregation', 'epidemiological', 'study') : 2
# ('epidemiological', 'study', 'mortality') : 2
# ('generally', 'find', 'degree') : 2
# ('find', 'degree', 'aggregation') : 2
# ('degree', 'aggregation', 'monthly') : 2
# ('aggregation', 'monthly', 'temporally') : 2
# ('monthly', 'temporally', 'coarse') : 2
# ('temporally', 'coarse', 'use') : 2
# ('coarse', 'use', 'purpose') : 2
# ('use', 'purpose', 'estimate') : 2
# ('purpose', 'estimate', 'effect') : 2
# ('human', 'mortality', 'instead') : 2
# ('mortality', 'instead', 'aggregate') : 2
# ('instead', 'aggregate', 'weekly') : 2
# ('aggregate', 'weekly', 'mortality') : 2
# ('weekly', 'mortality', 'show') : 2
# ('mortality', 'show', 'represent') : 2
# ('show', 'represent', 'approximation') : 2
# ('represent', 'approximation', 'estimate') : 2
# ('approximation', 'estimate', 'obtain') : 2
# ('research', 'translation', 'use') : 2
# ('source', 'explore', 'date') : 2
# ('use', 'develop', 'indicator') : 2
# ('develop', 'indicator', 'track') : 2
# ('daily', 'weekly', 'weekly') : 4
# ('weekly', 'weekly', 'model') : 6
# ('weekly', 'time', 'period') : 2
# ('use', 'regression', 'model') : 2
# ('log', 'mort', 'intercept') : 4
# ('mort', 'intercept', 'ns') : 4
# ('intercept', 'ns', 'time') : 4
# ('ns', 'time', 'df') : 4
# ('time', 'df', 'year') : 4
# ('df', 'year', 'crossbasis') : 4
# ('year', 'crossbasis', 'temp') : 4
# ('three', 'internal', 'knot') : 2
# ('daily', 'weekly', 'model') : 5
# ('four', 'temporally', 'aggregated') : 2
# ('temporally', 'aggregated', 'model') : 3
# ('aggregated', 'model', 'daily') : 2
# ('rr', 'value', 'monotonically') : 2
# ('symmetric', 'association', 'small') : 2
# ('association', 'small', 'rr') : 2
# ('small', 'rr', 'value') : 3
# ('rr', 'value', 'central') : 3
# ('value', 'central', 'distribution') : 3
# ('regional', 'value', 'mmt') : 2
# ('correlation', 'r', 'mean') : 4
# ('r', 'mean', 'difference') : 3
# ('relative', 'daily', 'weekly') : 3
# ('daily', 'weekly', 'percentile') : 2
# ('weekly', 'percentile', 'lag') : 2
# ('percentile', 'lag', 'day') : 2
# ('lag', 'day', 'relative') : 2
# ('day', 'relative', 'daily') : 2
# ('daily', 'model', 'r') : 6
# ('model', 'r', 'r') : 6
# ('r', 'r', 'relative') : 2
# ('r', 'relative', 'percentile') : 2
# ('relative', 'percentile', 'daily') : 2
# ('percentile', 'daily', 'model') : 2
# ('r', 'b', 'c') : 3
# ('correspond', 'identity', 'best') : 2
# ('identity', 'best', 'linear') : 2
# ('best', 'linear', 'ﬁtting') : 2
# ('linear', 'ﬁtting', 'respectively') : 2
# ('ﬁtting', 'respectively', 'pearson') : 2
# ('respectively', 'pearson', 'correlation') : 2
# ('mean', 'difference', 'top') : 2
# ('difference', 'top', 'leave') : 2
# ('top', 'leave', 'corner') : 2
# ('daily', 'black', 'weekly') : 3
# ('black', 'weekly', 'blue') : 3
# ('weekly', 'blue', 'grey') : 6
# ('blue', 'grey', 'model') : 4
# ('weekly', 'model', 'systematically') : 2
# ('model', 'systematically', 'underestimate') : 2
# ('low', 'af', 'value') : 3
# ('af', 'value', 'weekly') : 2
# ('value', 'weekly', 'model') : 2
# ('year', 'year', 'table') : 2
# ('attributable', 'fraction', 'daily') : 12
# ('fraction', 'daily', 'model') : 3
# ('r', 'r', 'cold') : 3
# ('r', 'cold', 'attributable') : 3
# ('cold', 'attributable', 'fraction') : 3
# ('r', 'r', 'attributable') : 4
# ('r', 'attributable', 'fraction') : 4
# ('value', 'attributable', 'fraction') : 5
# ('attributable', 'fraction', 'aggregate') : 4
# ('fraction', 'aggregate', 'european') : 4
# ('aggregate', 'european', 'region') : 4
# ('region', 'show', 'temperature') : 3
# ('show', 'temperature', 'cold') : 3
# ('temperature', 'cold', 'b') : 4
# ('cold', 'b', 'c') : 4
# ('daily', 'weekly', 'blue') : 2
# ('solid', 'line', 'correspond') : 2
# ('month', 'attributable', 'fraction') : 3
# ('attributable', 'fraction', 'f') : 3
# ('fraction', 'f', 'n') : 3
# ('f', 'n', 'daily') : 3
# ('n', 'daily', 'weekly') : 3
# ('daily', 'weekly', 'cold') : 2
# ('daily', 'weekly', 'b') : 2
# ('weekly', 'b', 'c') : 2
# ('c', 'daily', 'black') : 2
# ('grey', 'model', 'shade') : 2
# ('model', 'shade', 'represent') : 2
# ('shade', 'represent', 'conﬁdence') : 2
# ('year', 'attributable', 'fraction') : 3
# ('fraction', 'daily', 'weekly') : 3
# ('correspond', 'linear', 'trend') : 2
# ('absolute', 'number', 'daily') : 2
# ('number', 'daily', 'weekly') : 2
# ('equal', 'ci', 'death') : 2
# ('much', 'large', 'difference') : 2
# ('find', 'relatively', 'constant') : 2
# ('throughout', 'year', 'therefore') : 2
# ('year', 'therefore', 'linear') : 2
# ('therefore', 'linear', 'trend') : 2
# ('compare', 'straight', 'line') : 2
# ('minus', 'daily', 'relative') : 2
# ('daily', 'relative', 'difference') : 5
# ('relative', 'difference', 'minus') : 2
# ('difference', 'minus', 'daily') : 3
# ('minus', 'daily', 'divide') : 2
# ('daily', 'divide', 'daily') : 2
# ('difference', 'attributable', 'fraction') : 2
# ('fraction', 'daily', 'absolute') : 3
# ('daily', 'absolute', 'difference') : 3
# ('absolute', 'difference', 'weekly') : 3
# ('difference', 'weekly', 'r') : 6
# ('weekly', 'r', 'r') : 6
# ('fraction', 'daily', 'relative') : 3
# ('relative', 'difference', 'weekly') : 3
# ('difference', 'mortality', 'estimate') : 2
# ('weekly', 'monthly', 'seasonal') : 2
# ('monthly', 'seasonal', 'variability') : 2
# ('misclassiﬁed', 'aggregate', 'period') : 3
# ('ballester', 'estimate', 'af') : 2
# ('estimate', 'af', 'year') : 2
# ('result', 'immediately', 'generalise') : 2
# ('europe', 'research', 'innovation') : 3
# ('research', 'council', 'european') : 2
# ('grant', 'agreement', 'horizon') : 2
# ('spanish', 'ministry', 'science') : 2
# ('ministry', 'science', 'innovation') : 2
# ('support', 'grant', 'fund') : 2
# ('global', 'regional', 'burden') : 2
# ('regional', 'burden', 'mortality') : 2
# ('burden', 'mortality', 'associate') : 2
# ('mortality', 'associate', 'ambient') : 2
# ('associate', 'ambient', 'temperature') : 2
# ('ambient', 'temperature', 'model') : 2
# ('temperature', 'model', 'lancet') : 2
# ('model', 'lancet', 'planet') : 2
# ('lancet', 'planet', 'è') : 2
# ('planet', 'è', 'achebak') : 2
# ('è', 'achebak', 'h') : 2
# ('armstrong', 'b', 'kenward') : 2
# ('achebak', 'h', 'devolder') : 3
# ('h', 'devolder', 'ballester') : 2
# ('mortality', 'cardiovascular', 'disease') : 2
# ('lancet', 'serum', 'f') : 2
# ('serum', 'f', 'armstrong') : 2
# ('f', 'armstrong', 'b') : 2
# ('herrmann', 'fr', 'rodó') : 2
# ('fr', 'rodó', 'x') : 2
# ('distribute', 'lag', 'model') : 2
# ('bmc', 'med', 're') : 2
# ('med', 're', 'methodol') : 2
# ('stage', 'time', 'series') : 2
# ('future', 'increase', 'risk') : 2
# ('beijing', 'china', 'b') : 2
# ('computational', 'hydrosystems', 'helmholtz') : 2
# ('hydrosystems', 'helmholtz', 'centre') : 2
# ('helmholtz', 'centre', 'environmental') : 2
# ('contribution', 'storyline', 'approach') : 2
# ('storyline', 'approach', 'approach') : 2
# ('attribution', 'spatially', 'compound') : 2
# ('spatially', 'compound', 'event') : 7
# ('compound', 'event', 'different') : 2
# ('present', 'comprehensive', 'framework') : 2
# ('comprehensive', 'framework', 'compound') : 2
# ('framework', 'compound', 'attribution') : 2
# ('thermodynamic', 'contribution', 'intensity') : 3
# ('introduction', 'compound', 'event') : 2
# ('compound', 'event', 'cause') : 3
# ('attribution', 'compound', 'event') : 2
# ('compound', 'event', 'occur') : 3
# ('zscheischler', 'lehner', 'attribute') : 2
# ('revised', 'form', 'accept') : 2
# ('spheric', 'circulation', 'resemble') : 3
# ('circulation', 'resemble', 'observation') : 2
# ('resemble', 'observation', 'dynamic') : 2
# ('observation', 'dynamic', 'anthropogenic') : 2
# ('dynamic', 'anthropogenic', 'forcings') : 2
# ('anthropogenic', 'forcings', 'conditional') : 3
# ('forcings', 'conditional', 'atmospheric') : 3
# ('overall', 'anthropogenic', 'contribution') : 4
# ('time', 'south', 'china') : 2
# ('zhou', 'lu', 'tang') : 2
# ('heavy', 'rainfall', 'middle') : 2
# ('rainfall', 'middle', 'low') : 2
# ('consider', 'spatially', 'compound') : 2
# ('standardized', 'precipitation', 'anomaly') : 2
# ('conditional', 'atmospheric', 'circulation') : 2
# ('first', 'estimate', 'contribution') : 2
# ('estimate', 'contribution', 'atmospheric') : 3
# ('atmospheric', 'circulation', 'resemble') : 3
# ('novel', 'construct', 'flow') : 2
# ('construct', 'flow', 'analogue') : 2
# ('construct', 'analogue', 'atmospheric') : 2
# ('atmospheric', 'circulation', 'almost') : 2
# ('circulation', 'almost', 'observe') : 2
# ('observe', 'atmospheric', 'circulation') : 3
# ('atmospheric', 'circulation', 'well') : 2
# ('flow', 'analogue', 'method') : 3
# ('analogue', 'method', 'yiou') : 2
# ('method', 'yiou', 'equel') : 2
# ('late', 'met', 'office') : 2
# ('met', 'office', 'attribution') : 2
# ('condition', 'atmospheric', 'circulation') : 6
# ('atmospheric', 'circulation', 'use') : 2
# ('storyline', 'approach', 'help') : 2
# ('approach', 'help', 'u') : 2
# ('influence', 'anthropogenic', 'forcings') : 2
# ('forcings', 'change', 'atmospheric') : 3
# ('return', 'period', 'base') : 2
# ('occurrence', 'similar', 'compound') : 2
# ('similar', 'compound', 'event') : 3
# ('anthropogenic', 'forcings', 'atmospheric') : 2
# ('observed', 'daily', 'maximum') : 2
# ('qian', 'weather', 'extremes') : 2
# ('large', 'number', 'member') : 3
# ('sample', 'size', 'require') : 2
# ('anomaly', 'percentage', 'r') : 2
# ('percentage', 'r', 'anomaly') : 2
# ('r', 'anomaly', 'middle') : 2
# ('anomaly', 'middle', 'low') : 3
# ('anomaly', 'south', 'china') : 2
# ('precipitation', 'percentage', 'anomaly') : 2
# ('interpretation', 'reference', 'colour') : 5
# ('reference', 'colour', 'legend') : 6
# ('colour', 'legend', 'reader') : 6
# ('version', 'article', 'qian') : 4
# ('article', 'qian', 'weather') : 4
# ('tmax', 'anomaly', 'r') : 2
# ('anomaly', 'r', 'anomaly') : 3
# ('significantly', 'different', 'base') : 2
# ('magnitude', 'spatially', 'compound') : 2
# ('r', 'anom', 'σr') : 2
# ('anom', 'σr', 'anom') : 2
# ('climatological', 'standard', 'deviation') : 3
# ('climatological', 'mean', 'climatological') : 2
# ('mean', 'climatological', 'standard') : 2
# ('contribution', 'intensity', 'compound') : 2
# ('via', 'condition', 'atmospheric') : 2
# ('atmospheric', 'circulation', 'condition') : 2
# ('atmospheric', 'circulation', 'intensity') : 2
# ('atmospheric', 'culation', 'pattern') : 2
# ('air', 'trend', 'north') : 2
# ('trend', 'north', 'america') : 2
# ('step', 'flow', 'analogue') : 2
# ('atmospheric', 'circulation', 'day') : 2
# ('tmax', 'r', 'anomaly') : 2
# ('prior', 'select', 'analogue') : 2
# ('select', 'analogue', 'minimize') : 2
# ('supplementary', 'fig', 'suitable') : 2
# ('qian', 'weather', 'extreme') : 6
# ('anomaly', 'compound', 'index') : 2
# ('atmospheric', 'circulation', 'dynamic') : 2
# ('reconstruct', 'compound', 'index') : 3
# ('one', 'argue', 'anthropogenic') : 2
# ('argue', 'anthropogenic', 'forcings') : 2
# ('anthropogenic', 'forcings', 'affect') : 2
# ('forcings', 'affect', 'atmospheric') : 2
# ('affect', 'atmospheric', 'circulation') : 2
# ('contribution', 'anthropogenic', 'forcings') : 7
# ('return', 'period', 'observe') : 3
# ('compound', 'index', 'observation') : 2
# ('base', 'conditional', 'storyline') : 2
# ('conditional', 'storyline', 'approach') : 2
# ('detrended', 'compound', 'index') : 2
# ('compound', 'index', 'base') : 2
# ('gev', 'distribution', 'base') : 2
# ('uncertainty', 'range', 'obtain') : 2
# ('line', 'represent', 'intensity') : 3
# ('represent', 'intensity', 'event') : 3
# ('intensity', 'event', 'return') : 2
# ('forcings', 'intensity', 'event') : 3
# ('bar', 'denote', 'uncertainty') : 2
# ('denote', 'uncertainty', 'range') : 3
# ('gev', 'distribution', 'compound') : 2
# ('distribution', 'compound', 'index') : 3
# ('mean', 'surface', 'anomaly') : 4
# ('condition', 'christidis', 'stott') : 2
# ('anthropogenic', 'forcings', 'intensity') : 3
# ('previous', 'attribution', 'study') : 3
# ('similar', 'event', 'equal') : 2
# ('attribution', 'projection', 'compound') : 2
# ('intensity', 'event', 'respectively') : 2
# ('panel', 'b', 'far') : 2
# ('uncertainty', 'range', 'see') : 2
# ('range', 'see', 'section') : 2
# ('see', 'section', 'c') : 2
# ('change', 'compound', 'index') : 2
# ...
# ('column', 'precipitation', 'right') : 2
# ('precipitation', 'nature', 'article') : 2
# ('extend', 'uncertainty', 'local') : 2
# ('fhd', 'change', 'mean') : 2
# ('event', 'fhd', 'mean') : 2
# ('warmer', 'condition', 'b') : 2
# ('relative', 'fhd', 'historical') : 2
# ('future', 'period', 'respectively') : 4
# ('washington', 'state', 'university') : 2
# ('simultaneous', 'heatwaves', 'affect') : 2
# ('heatwaves', 'affect', 'multiple') : 2
# ('affect', 'multiple', 'region') : 2
# ('multiple', 'region', 'refer') : 2
# ('region', 'refer', 'concurrent') : 2
# ('refer', 'concurrent', 'heatwaves') : 2
# ('trend', 'concurrent', 'heatwaves') : 5
# ('identify', 'circulation', 'pattern') : 2
# ('speciﬁc', 'concurrent', 'heatwave') : 2
# ('change', 'frequency', 'speciﬁc') : 2
# ('north', 'america', 'eastern') : 3
# ('asia', 'barents', 'kara') : 2
# ('barents', 'kara', 'seas') : 5
# ('circulation', 'pattern', 'change') : 5
# ('concurrent', 'heatwave', 'day') : 44
# ('increase', 'concurrent', 'heatwave') : 2
# ('concurrent', 'heatwave', 'frequency') : 7
# ('multiple', 'region', 'simultaneously') : 2
# ('concurrent', 'heatwave', 'characteristic') : 5
# ('simultaneous', 'heatwaves', 'multiple') : 2
# ('heatwaves', 'multiple', 'region') : 2
# ('r', 'l', 'february') : 8
# ('l', 'february', 'unauthenticated') : 8
# ('february', 'unauthenticated', 'downloaded') : 8
# ('northern', 'hemisphere', 'relate') : 2
# ('change', 'midlatitude', 'circulation') : 2
# ('recurrent', 'rossby', 'wave') : 2
# ('associate', 'concurrent', 'heatwaves') : 3
# ('change', 'circulation', 'pattern') : 12
# ('concurrent', 'wave', 'change') : 2
# ('experience', 'concurrent', 'heatwaves') : 2
# ('concurrent', 'heatwaves', 'associate') : 4
# ('different', 'circulation', 'pattern') : 2
# ('change', 'concurrent', 'heatwave') : 4
# ('conﬁgurations', 'concurrent', 'heatwaves') : 2
# ('concurrent', 'heatwaves', 'occur') : 4
# ('heatwaves', 'occur', 'anywhere') : 2
# ('n', 'l', 'f') : 8
# ('l', 'f', 'c') : 8
# ('f', 'c', 'l') : 8
# ('c', 'l', 'unauthenticated') : 8
# ('l', 'unauthenticated', 'downloaded') : 8
# ('hourly', 'maximum', 'minimum') : 3
# ('utc', 'day', 'x') : 2
# ('use', 'geopotential', 'height') : 2
# ('associate', 'concurrent', 'wave') : 2
# ('great', 'local', 'percentile') : 2
# ('cell', 'heatwave', 'condition') : 2
# ('heatwave', 'condition', 'day') : 2
# ('heatwave', 'intensity', 'deﬁned') : 2
# ('intensity', 'deﬁned', 'average') : 2
# ('concurrent', 'heatwave', 'metric') : 2
# ('deﬁne', 'concurrent', 'heatwave') : 2
# ('day', 'day', 'two') : 2
# ('large', 'heatwaves', 'occur') : 2
# ('concurrent', 'heatwave', 'intensity') : 5
# ('heatwaves', 'occur', 'concurrent') : 2
# ('occur', 'concurrent', 'heatwave') : 2
# ('seasonal', 'maximum', 'mean') : 2
# ('maximum', 'mean', 'concurrent') : 2
# ('mean', 'concurrent', 'heatwave') : 2
# ('intensity', 'concurrent', 'heatwave') : 2
# ('concurrent', 'heatwave', 'extent') : 5
# ('seasonal', 'mean', 'intensity') : 2
# ('concurrent', 'heatwave', 'event') : 4
# ('heatwave', 'extent', 'threshold') : 2
# ('heatwaves', 'europe', 'lyon') : 2
# ('trend', 'concurrent', 'heatwave') : 5
# ('examine', 'number', 'concurrent') : 2
# ('number', 'concurrent', 'heatwave') : 14
# ('heatwave', 'day', 'mjjas') : 5
# ('circulation', 'pattern', 'use') : 2
# ('region', 'northern', 'hemisphere') : 2
# ('typical', 'atmospheric', 'pattern') : 2
# ('current', 'heatwaves', 'associate') : 2
# ('som', 'toolbox', 'matlab') : 3
# ('toolbox', 'matlab', 'package') : 2
# ('helsinki', 'university', 'technology') : 2
# ('university', 'technology', 'laboratory') : 2
# ('technology', 'laboratory', 'computer') : 2
# ('laboratory', 'computer', 'information') : 3
# ('computer', 'information', 'science') : 3
# ('daily', 'geopotential', 'height') : 3
# ('occur', 'geopotential', 'height') : 2
# ('circulation', 'pattern', 'capture') : 2
# ('section', 'supplemental', 'material') : 3
# ('pattern', 'concurrent', 'heatwaves') : 5
# ('concurrent', 'heatwaves', 'ated') : 2
# ('day', 'associate', 'node') : 2
# ('midlatitude', 'circulation', 'pattern') : 6
# ('day', 'frequency', 'node') : 2
# ('current', 'heatwave', 'day') : 2
# ('heatwave', 'day', 'associate') : 4
# ('number', 'concurrent', 'wave') : 3
# ('concurrent', 'wave', 'day') : 8
# ('heatwaves', 'occur', 'day') : 2
# ('geopotential', 'height', 'pattern') : 2
# ('concurrent', 'heatwave', 'occurrence') : 2
# ('number', 'large', 'concurrent') : 2
# ('large', 'concurrent', 'heatwaves') : 3
# ('concurrent', 'heatwaves', 'inﬂuence') : 2
# ('trend', 'number', 'concurrent') : 7
# ('frequency', 'concurrent', 'heatwave') : 3
# ('time', 'series', 'number') : 2
# ('heatwave', 'day', 'node') : 2
# ('number', 'day', 'node') : 3
# ('day', 'node', 'occurs') : 2
# ('node', 'occurs', 'refer') : 2
# ('mean', 'fraction', 'node') : 3
# ('fraction', 'node', 'occurrence') : 4
# ('node', 'occurrence', 'concurrent') : 3
# ('occurrence', 'concurrent', 'heatwave') : 2
# ('mean', 'frequency', 'node') : 2
# ('frequency', 'node', 'f') : 2
# ('trend', 'frequency', 'node') : 3
# ('trend', 'product', 'deviation') : 2
# ('som', 'node', 'trend') : 2
# ('trend', 'number', 'node') : 2
# ('number', 'node', 'occurrence') : 2
# ('column', 'show', 'portion') : 3
# ('portion', 'trend', 'number') : 3
# ('thermodynamic', 'dynamic', 'interactive') : 3
# ('dynamic', 'interactive', 'term') : 6
# ('equal', 'total', 'contribution') : 2
# ('trend', 'node', 'occurrence') : 2
# ('term', 'portion', 'trend') : 2
# ('heatwave', 'day', 'solely') : 2
# ('day', 'solely', 'change') : 2
# ('circulation', 'pattern', 'assume') : 2
# ('interactive', 'term', 'contribution') : 6
# ('overall', 'trend', 'concurrent') : 2
# ('concurrent', 'heatwave', 'trend') : 4
# ('concurrent', 'heatwaves', 'northern') : 2
# ('day', 'season', 'day') : 3
# ('season', 'day', 'season') : 3
# ('heatwave', 'day', 'deﬁned') : 2
# ('day', 'deﬁned', 'number') : 3
# ('deﬁned', 'number', 'day') : 3
# ('heatwaves', 'heatwave', 'day') : 4
# ('day', 'mjjas', 'season') : 5
# ('mjjas', 'season', 'two') : 2
# ('heatwave', 'day', 'solid') : 2
# ('blue', 'marker', 'leave') : 2
# ('marker', 'leave', 'axis') : 4
# ('number', 'heatwaves', 'heatwave') : 2
# ('number', 'day', 'mjjas') : 2
# ('trend', 'signiﬁcant', 'conﬁdence') : 3
# ('pm', 'utc', 'heatwaves') : 2
# ('maximum', 'concurrent', 'heatwave') : 3
# ('intensity', 'median', 'intensity') : 2
# ('mean', 'concurrent', 'wave') : 2
# ('concurrent', 'wave', 'intensity') : 2
# ('large', 'extent', 'event') : 2
# ('number', 'large', 'extent') : 2
# ('signiﬁcance', 'determine', 'use') : 2
# ('test', 'fatichi', 'conﬁdence') : 3
# ('fatichi', 'conﬁdence', 'level') : 3
# ('conﬁdence', 'level', 'r') : 3
# ('level', 'r', 'r') : 2
# ('drive', 'concurrent', 'heatwaves') : 2
# ('pattern', 'associate', 'concurrent') : 2
# ('characteristic', 'circulation', 'pattern') : 2
# ('circulation', 'pattern', 'node') : 3
# ('concurrent', 'heatwave', 'hotspot') : 4
# ('geopotential', 'height', 'lie') : 2
# ('region', 'concurrent', 'heatwaves') : 2
# ('associate', 'geopotential', 'height') : 2
# ('northeast', 'paciﬁc', 'northwest') : 2
# ('paciﬁc', 'northwest', 'paciﬁc') : 2
# ('northwest', 'paciﬁc', 'eastern') : 2
# ('hotspot', 'associate', 'node') : 3
# ('percentage', 'subplot', 'show') : 2
# ('subplot', 'show', 'frequently') : 2
# ('show', 'frequently', 'node') : 2
# ('frequently', 'node', 'occurs') : 2
# ('node', 'occurs', 'note') : 2
# ('occurs', 'note', 'color') : 2
# ('note', 'color', 'bar') : 2
# ('barents', 'kara', 'sea') : 2
# ('pattern', 'represent', 'node') : 2
# ('conﬁdence', 'level', 'table') : 2
# ('node', 'node', 'show') : 3
# ('increase', 'day', 'season') : 2
# ('node', 'concurrent', 'heatwave') : 2
# ('underscore', 'importance', 'dynamic') : 2
# ('node', 'frequency', 'concurrent') : 2
# ('large', 'dynamic', 'contribution') : 2
# ('heatwaves', 'associate', 'node') : 3
# ('mean', 'warm', 'circulation') : 2
# ('pattern', 'concurrent', 'heatwave') : 2
# ('contribution', 'change', 'circulation') : 2
# ('line', 'marker', 'leave') : 2
# ('show', 'trend', 'signiﬁcant') : 3
# ('contribution', 'concurrent', 'heatwave') : 2
# ('four', 'node', 'node') : 2
# ('imply', 'dynamical', 'change') : 2
# ('heatwave', 'hotspot', 'associate') : 2
# ('dynamic', 'active', 'term') : 2
# ('active', 'term', 'contribution') : 2
# ('eastern', 'europe', 'barents') : 2
# ('europe', 'barents', 'kara') : 3
# ('kara', 'seas', 'eastern') : 2
# ('seas', 'eastern', 'paciﬁc') : 2
# ('eastern', 'paciﬁc', 'dynamic') : 2
# ('paciﬁc', 'dynamic', 'interactive') : 2
# ('number', 'concurrent', 'heatwaves') : 2
# ('speciﬁc', 'circulation', 'pattern') : 2
# ('method', 'use', 'identify') : 2
# ('use', 'identify', 'dynamic') : 2
# ('circulation', 'pattern', 'concurrent') : 2
# ('raw', 'detrended', 'geopotential') : 2
# ('detrended', 'geopotential', 'height') : 2
# ('zonal', 'mean', 'trend') : 2
# ('see', 'section', 'supplemental') : 2
# ('historical', 'circulation', 'change') : 2
# ('eddy', 'kinetic', 'energy') : 2
# ('certain', 'circulation', 'pattern') : 2
# ('without', 'anthropogenic', 'global') : 2
# ('examine', 'rare', 'event') : 2
# ('examine', 'circulation', 'pattern') : 2
# ('circulation', 'pattern', 'persist') : 2
# ('pattern', 'persist', 'day') : 2
# ('concurrent', 'heatwaves', 'ern') : 2
# ('future', 'circulation', 'change') : 2
# ('grant', 'support', 'science') : 2
# ('cassou', 'terray', 'phillips') : 2
# ('terray', 'phillips', 'tropical') : 2
# ('phillips', 'tropical', 'atlantic') : 2
# ('petoukhov', 'petri', 'rahmstorf') : 2
# ('petri', 'rahmstorf', 'coumou') : 2
# ('rahmstorf', 'coumou', 'kornhuber') : 2
# ('coumou', 'kornhuber', 'schellnhuber') : 2
# ('kornhuber', 'schellnhuber', 'role') : 2
# ('planetary', 'wave', 'dynamic') : 3
# ('wave', 'dynamic', 'recent') : 2
# ('dynamic', 'recent', 'boreal') : 2
# ('recent', 'boreal', 'event') : 2
# ('summer', 'weather', 'become') : 2
# ('weather', 'become', 'persistent') : 2
# ('occurrence', 'precipitation', 'extremes') : 2
# ('c', 'c', 'global') : 3
# ('heatwaves', 'warm', 'summer') : 2
# ('warm', 'summer', 'among') : 2
# ('summer', 'heatwaves', 'france') : 2
# ('heatwaves', 'france', 'scandinavia') : 2
# ('france', 'scandinavia', 'algorithm') : 2
# ('algorithm', 'concentrate', 'simulation') : 2
# ('statistically', 'significant', 'composite') : 3
# ('significant', 'composite', 'map') : 3
# ('composite', 'map', 'dynamical') : 3
# ('map', 'dynamical', 'quantity') : 3
# ('show', 'warm', 'summer') : 2
# ('warm', 'summer', 'associate') : 2
# ('summer', 'associate', 'wavenumber') : 2
# ('wavenumber', 'hemispheric', 'teleconnection') : 2
# ('hemispheric', 'teleconnection', 'pattern') : 2
# ('summer', 'related', 'succession') : 2
# ('optimize', 'computational', 'resource') : 2
# ('warm', 'summer', 'france') : 7
# ('summer', 'france', 'scandinavia') : 2
# ('warm', 'summer', 'scandinavia') : 5
# ('sample', 'warm', 'summer') : 2
# ('teleconnection', 'pattern', 'warm') : 2
# ('pattern', 'warm', 'summer') : 2
# ('summer', 'scandinavia', 'show') : 2
# ('lau', 'kim', 'petoukhov') : 2
# ('ragone', 'bouchet', 'ragone') : 6
# ('compute', 'return', 'time') : 3
# ('use', 'rare', 'algorithm') : 2
# ('average', 'france', 'scandinavia') : 3
# ('warm', 'summer', 'seasonal') : 2
# ('summer', 'seasonal', 'heatwaves') : 2
# ('ragone', 'bouchet', 'download') : 6
# ('bouchet', 'download', 'koc') : 6
# ('rare', 'algorithm', 'experiment') : 3
# ('resampling', 'time', 'τ') : 2
# ('trajectory', 'lead', 'event') : 2
# ('support', 'information', 'ragone') : 2
# ('x', 'distribution', 'function') : 2
# ('distribution', 'function', 'trajectory') : 2
# ('trajectory', 'obtain', 'simulation') : 2
# ('value', 'time', 'average') : 3
# ('summer', 'control', 'run') : 3
# ('perform', 'importance', 'sample') : 2
# ('ajja', 'control', 'run') : 2
# ('control', 'run', 'rare') : 6
# ('run', 'rare', 'algorithm') : 5
# ('extremely', 'warm', 'summer') : 3
# ('control', 'run', 'black') : 2
# ('run', 'black', 'rare') : 2
# ('black', 'rare', 'algorithm') : 2
# ('obtain', 'control', 'run') : 2
# ('return', 'time', 'curve') : 2
# ('return', 'time', 'large') : 3
# ('time', 'large', 'year') : 3
# ('composite', 'map', 'anomaly') : 2
# ('surface', 'hpa', 'geopotential') : 4
# ('rare', 'algorithm', 'give') : 3
# ('algorithm', 'give', 'much') : 2
# ('give', 'much', 'good') : 2
# ('algorithm', 'give', 'access') : 2
# ('give', 'access', 'composite') : 2
# ('access', 'composite', 'statistic') : 2
# ('show', 'composite', 'statistic') : 3
# ('composite', 'statistic', 'surface') : 3
# ('statistic', 'surface', 'hpa') : 3
# ('geopotential', 'height', 'warm') : 3
# ('height', 'warm', 'summer') : 3
# ('summer', 'france', 'control') : 2
# ('france', 'control', 'run') : 2
# ('year', 'control', 'run') : 2
# ('figure', 'show', 'composite') : 2
# ('show', 'composite', 'map') : 2
# ('rare', 'algorithm', 'allow') : 2
# ('unavailable', 'control', 'run') : 2
# ('application', 'rare', 'algorithm') : 2
# ('scandinavian', 'warm', 'summer') : 2
# ('anomaly', 'surface', 'color') : 2
# ('surface', 'color', 'hpa') : 2
# ('color', 'hpa', 'geopotential') : 2
# ('height', 'contour', 'warm') : 2
# ('contour', 'warm', 'summer') : 2
# ('time', 'series', 'day') : 2
# ('series', 'day', 'run') : 2
# ('day', 'run', 'mean') : 3
# ('run', 'mean', 'surface') : 2
# ('surface', 'anomaly', 'respect') : 2
# ('anomaly', 'respect', 'climatological') : 2
# ('respect', 'climatological', 'seasonal') : 2
# ('climatological', 'seasonal', 'average') : 4
# ('seasonal', 'average', 'scandinavia') : 2
# ('first', 'june', 'end') : 2
# ('june', 'end', 'august') : 2
# ('experiment', 'sample', 'low') : 2
# ('sample', 'low', 'mode') : 5
# ('black', 'show', 'climatological') : 2
# ('show', 'climatological', 'average') : 2
# ('solid', 'range', 'standard') : 2
# ('deviation', 'positive', 'anomaly') : 2
# ('typical', 'trajectory', 'control') : 2
# ('trajectory', 'control', 'run') : 2
# ('seasonal', 'average', 'value') : 2
# ('large', 'deviation', 'asymptotics') : 3
# ('reproduce', 'present', 'day') : 2
# ('stationary', 'rossby', 'wave') : 2
# ('chaos', 'interdisciplinary', 'journal') : 2
# ('interdisciplinary', 'journal', 'nonlinear') : 2
# ('journal', 'nonlinear', 'science') : 2
# ('journal', 'statistical', 'mechanic') : 2
# ('journal', 'statistical', 'physic') : 2
# ('ross', 'slater', 'nicolas') : 2
# ('slater', 'nicolas', 'freychet') : 2
# ('nicolas', 'freychet', 'gabriele') : 2
# ('freychet', 'gabriele', 'hegerl') : 2
# ('use', 'generalize', 'value') : 2
# ('extremely', 'hot', 'event') : 2
# ('daily', 'near', 'surface') : 2
# ('near', 'surface', 'air') : 4
# ('variability', 'scale', 'parameter') : 2
# ('parameter', 'show', 'clear') : 2
# ('decrease', 'high', 'latitude') : 2
# ('high', 'latitude', 'change') : 2
# ('atmospheric', 'science', 'letter') : 2
# ('expect', 'global', 'warm') : 2
# ('extremely', 'hot', 'daily') : 2
# ('warm', 'relative', 'period') : 2
# ('slater', 'download', 'koc') : 9
# ('daily', 'average', 'index') : 4
# ('average', 'index', 'global') : 2
# ('index', 'global', 'warm') : 2
# ('relative', 'period', 'hatch') : 2
# ('period', 'hatch', 'indicates') : 2
# ('hatch', 'indicates', 'area') : 2
# ('indicates', 'area', 'mean') : 2
# ('area', 'mean', 'less') : 2
# ('mean', 'less', 'sd') : 2
# ('less', 'sd', 'bootstrapped') : 2
# ('sd', 'bootstrapped', 'value') : 2
# ('bootstrapped', 'value', 'therefore') : 2
# ('value', 'therefore', 'less') : 2
# ('therefore', 'less', 'internal') : 2
# ('less', 'internal', 'variability') : 2
# ('reference', 'period', 'exceedance') : 2
# ('period', 'exceedance', 'decade') : 2
# ('edge', 'arctic', 'sea') : 2
# ('see', 'shape', 'parameter') : 2
# ('western', 'australia', 'central') : 2
# ('australia', 'central', 'europe') : 3
# ('show', 'gev', 'fit') : 2
# ('central', 'europe', 'exhibit') : 2
# ('future', 'rr', 'indicate') : 2
# ('change', 'shape', 'parameter') : 2
# ('decrease', 'shape', 'parameter') : 2
# ('respective', 'level', 'warm') : 2
# ('land', 'average', 'rrs') : 2
# ('warm', 'significantly', 'increase') : 2
# ('significantly', 'increase', 'occur') : 2
# ('two', 'model', 'show') : 2
# ('short', 'duration', 'event') : 2
# ('europe', 'environmental', 'research') : 2
# ('record', 'last', 'decade') : 2
# ('australia', 'virtually', 'impossible') : 2
# ('ﬁrst', 'decade', 'century') : 2
# ('event', 'virtually', 'impossible') : 2
# ('ratio', 'observe', 'local') : 2
# ('observe', 'local', 'monthly') : 2
# ('robinson', 'publish', 'partnership') : 2
# ('compare', 'expect', 'stationary') : 2
# ('number', 'rainfall', 'record') : 2
# ('global', 'gridded', 'dataset') : 2
# ('record', 'expect', 'stationary') : 2
# ('black', 'show', 'trend') : 2
# ('robinson', 'npj', 'atmospheric') : 2
# ('rainfall', 'estimate', 'gridded') : 2
# ('estimate', 'gridded', 'network') : 2
# ('gridded', 'network', 'regen') : 2
# ('impossible', 'without', 'accessed') : 2

# %% [markdown]
# ### BERT topic

# %%
def preprocess_texts(docs):
    preprocessed_docs = [' '.join(tokens) for tokens in (doc[0] for doc in docs.values())]
    return preprocessed_docs
preprocessed_texts = preprocess_texts(docs)

# %%
# Initializing the SentenceTransformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Encoding the preprocessed texts into embeddings
embeddings = model.encode(preprocessed_texts, show_progress_bar=True)

# %%
# Initializing BERTopic with custom parameters
topic_model = BERTopic(min_topic_size=2,
                       top_n_words=5,
                       n_gram_range=(1, 2),
                       calculate_probabilities=True)

# Fitting BERTopic on the preprocessed texts and embeddings
topics, probs = topic_model.fit_transform(preprocessed_texts,embeddings)

# %%
# Checking the topics identified
topic_info = topic_model.get_topic_info()
print(topic_info)
# Out:
#     Topic  Count                                               Name  \
# 0      -1     17                      -1_water_global_impact_hazard
# 1       0     15            0_flood_vulnerability_mumbai_population
# 2       1     11                             1_ehe_green_water_cool
# 3       2     11               2_change_project_water_precipitation
# 4       3     10                         3_drought_water_event_mean
# 5       4     10               4_australia_queensland_fire_heatwave
# 6       5      7                  5_forecast_mortality_cool_weather
# 7       6      7                     6_heatwave_heatwaves_trend_day
# 8       7      7                 7_european_europe_disaster_natural
# 9       8      6  8_anomaly_precipitation_attribution_anthropogenic
# 10      9      5               9_fishery_chwesl_chwesl event_marine
# 11     10      4                                10_utci_ta_tibet_hw
# 12     11      3              11_mortality_wave_mortality rate_rate
# 13     12      2                     12_drought_sector_europe_water
#
#                                        Representation  \
# 0               [water, global, impact, hazard, risk]
# 1    [flood, vulnerability, mumbai, population, area]
# 2                  [ehe, green, water, cool, element]
# 3       [change, project, water, precipitation, rise]
# 4        [drought, water, event, mean, precipitation]
# 5   [australia, queensland, fire, heatwave, austra...
# 6           [forecast, mortality, cool, weather, day]
# 7             [heatwave, heatwaves, trend, day, wave]
# 8           [european, europe, disaster, natural, eu]
# 9   [anomaly, precipitation, attribution, anthropo...
# 10       [fishery, chwesl, chwesl event, marine, sea]
# 11                       [utci, ta, tibet, hw, trend]
# 12      [mortality, wave, mortality rate, rate, ewes]
# 13        [drought, sector, europe, water, australia]
#
#                                   Representative_Docs
# 0   [occasional australian water industry occasion...
# 1   [map climatic biological disaster spatial temp...
# 2   [substantial occurrence human exposure heatwav...
# 3   [h v l p n r south asia hotspot precipitation ...
# 4   [article drought typical century could occur e...
# 5   [risk australia warm australian academy scienc...
# 6   [article energy demand cool increase past two ...
# 7   [article increase trend regional heatwaves hea...
# 8   [research wwf equilibrium argument protection ...
# 9   [weather clim author work distribute common at...
# 10  [fish fishery receive november revise february...
# 11  [scientific report real time extend range pred...
# 12  [central fund development knowledge network we...
# 13  [open access future drought flood european cit...

# %%
topic_model.get_topic(4)
# Out:
# [('australia', 0.02496560983317131),
#  ('queensland', 0.02480183432355833),
#  ('fire', 0.021898160818782115),
#  ('heatwave', 0.01740754710328006),
#  ('australian', 0.014810765345015646)]

# %%
# Getting the topic words
topic_words = topic_model.get_topics()

# Preprocessing the texts
preprocessed_texts = preprocess_texts(docs)

# Converting preprocessed texts to list of words for coherence model
texts = [doc.split() for doc in preprocessed_texts]

# Creating a dictionary and corpus for the coherence model
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

coherence_scores = []
for topic_id, topic in topic_words.items():
    # Preparing the data for coherence model
    topics = [[word for word, _ in topic]]

    # Computing Coherence Score using Gensim's CoherenceModel for each topic
    coherence_model = CoherenceModel(topics=topics, texts=texts, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()

    coherence_scores.append((topic_id, coherence_score))

# Printing coherence scores for each topic
for topic_id, coherence_score in coherence_scores:
    print(f'Topic {topic_id}: Coherence Score: {coherence_score}')
# Out:
# Topic -1: Coherence Score: 0.5429251061592422
# Topic 0: Coherence Score: 0.5854180370920362
# Topic 1: Coherence Score: 0.637400711843347
# Topic 2: Coherence Score: 0.6176852614555182
# Topic 3: Coherence Score: 0.5656932913561492
# Topic 4: Coherence Score: 0.7622246675960754
# Topic 5: Coherence Score: 0.5528102746404895
# Topic 6: Coherence Score: 0.633660605104796
# Topic 7: Coherence Score: 0.765090569521656
# Topic 8: Coherence Score: 0.661445338830486
# Topic 9: Coherence Score: 0.4692130955977548
# Topic 10: Coherence Score: 0.5155617820027103
# Topic 11: Coherence Score: 0.7529643578799841
# Topic 12: Coherence Score: 0.5709401964420581
