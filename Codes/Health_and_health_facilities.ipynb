# %%
pip install PyMuPDF

# %%
pip install BERTopic

# %%
import os
import fitz
import nltk
import re
import string
import gensim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pprint


# For tokenization
from nltk.tokenize import word_tokenize
nltk.download("punkt")
nltk.download('wordnet')

# For removing stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')

# For lemmatization
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')

# For TF-IDC
from gensim import corpora
from gensim.models import TfidfModel

# For N-grams
from collections import defaultdict
from nltk.util import ngrams as nltk_ngrams
from nltk.tokenize import word_tokenize

# For BERT topic
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# For coherence score
from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# ### Get text from PDFs

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as pdf:
        for page_num in range(len(pdf)):
            page = pdf.load_page(page_num)
            text += page.get_text()
    return text

# %% [markdown]
# ### Preprocess and vectorize text

# %% [markdown]
# *Preprocess pipeline*

# %%
# Loading WordNet POS tags for lemmatization
def wordnet_pos_tags(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def txt_preprocess_pipeline(text):

    # Removing multiple white spaces and line breaks
    clean_txt = re.sub(r'\n', ' ', text)
    clean_txt = re.sub(r'\s+', ' ', clean_txt)
    clean_txt = clean_txt.strip()

    # Tokenizing text
    tokens = nltk.word_tokenize(clean_txt)

    # Loading NLTK stopword list and adding original stopwords
    stop_words = set(stopwords.words('english')+['schneider','cdd','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health','heat','temperature','change','risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])

    # Adding custom stopwords directly to the set
    custom_stopwords = set(['schneider','cdd','paper','forum','figgs','enfield','literature','estimate','model','effect','impact','extreme','study','tantly','treme','tsuji','tural','yt','en','ings','factsheet','edney','budin','apps','app','enbel','alth','aunan','basu','user','search','photo','tures','mistry','letter','cdds','ly','national','plan','hhaps','use','initiate','various','public','health', 'heat', 'temperature', 'change', 'risk', 'increase','health','india','plan', 'brutally','management','part','highlight','world','united','nation','joint', 'cooperation','brief','issue','professor','tsdps','ons','qlw','lfb','qh','qc','humber','osdma','hse','hm','maha','ucs','lok','international','doya','gsdma','cdri','eswd','dluhc','esd','dfe','niosh','naic','desnz','odisha','defra','easac','bouhi','awhp','ndma','rachel','bureau','scientist','adequate','annual','address','amplify','billion','calculation,','activate','adaptation','additionally','acknowledge','afternoon','accordance','act','accord','data','high','ukhsa','osha','mrt','donthu','ensemble','kristina','webinar','qr','percent','interviewee','licker','eea','ccc','conv','january','iiphb','ferguson','ulbrich','trenberth','schär','rcms','nao','germi','veisz','spell','sres','srex','phenomenon','probability','ρ','qsw','moj','nhs','imd','october','academicians','academic','absorb','aapda','nrdc','report','online','across','action','expand','page','u','https','j','g','figure','thank','you','mbove','print','info','escalate','isbn','volume','dr','vol','phd','upon','al', 'e', 'fig', 'cl', 'hap', 'et', 'http', 'ew', 'climate','jun','simon', 'yang','go','copyright','ltd','license','creative','imply','dot', 'dashed','line', 'may', 'either','bi','de', 'la', 'paix', 'tel', 'box', 'fax','front', 'oli', 'scarff', 'getty', 'image', 'back', 'atlas','ness','net', 'san', 'felipe','also','informa', 'tion', 'per', 'cent','due','distri', 'bution','com','bin','thus','km', 'grid','would','christopher','u','aa','aap','aas','ab','abares','abatzoglou','abbs','abc','aberystwyth','doi'])
    stop_words.update(custom_stopwords)

    # Standardize the text and removing non-alphabetic or stop words
    words = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

    # Defining lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Conducting POS tagging
    pos_tags = nltk.pos_tag(words)

    # Lemmatizing word-tokens via assigned POS tags
    lemma_tokens = [lemmatizer.lemmatize(token, wordnet_pos_tags(pos_tag)) for token, pos_tag in pos_tags]

    return lemma_tokens

# %% [markdown]
# *Iteration function*

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def iterate_pdf_files(pdf_folder):
    # Creating a dictionary to display all documents and tokens together
    docs = {}

    # Counting to track the number of processed texts
    text_count = 0

    # Iterating over each file in the folder
    for filename in os.listdir(pdf_folder):

        # Checking whether the files are PDFs
        if filename.endswith('.pdf'):

            # Creating a path to the PDF files
            pdf_path = os.path.join(pdf_folder, filename)

            # Extracting the content of files
            text = extract_text_from_pdf(pdf_path)

            # Applying the preprocessing pipeline to the extracted tex
            preprocessed_text = txt_preprocess_pipeline(text)

            # Generating a unique name for the document based on the length of the docs dictionary for ease in readibility
            doc_name = f'doc{len(docs) + 1}'

            # Assigning the preprocessed text content of the current document in the docs dictionary with the document name as the key
            docs[doc_name] = [preprocessed_text]

            # Increasing the text count when finished assigning
            text_count += 1

    return docs

pdf_folder = '/content/drive/MyDrive/Documents/health'

# Calling the iterate_pdf_files function to get the dictionary of documents
docs = iterate_pdf_files(pdf_folder)

# Printing each document's tokens as a list
for doc_name, tokens in docs.items():
    print(f"{doc_name}: {tokens}")

# %% [markdown]
# *Token dictionary*

# %%
# Iterating over the values in the docs dictionary created in the previous step. Each value in the sublist represents the tokens in a certain document
all_preprocessed_text = [token for sublist in docs.values() for token in sublist]

# Creating a gensim dictionary to assign an integer ID to each token
dictionary = corpora.Dictionary(all_preprocessed_text)
print(dictionary)

# %% [markdown]
# *BoW representation*

# %%
# Creating a Bag-of-Words (BoW) representation of the preprocessed text data using the dictionary created in the previous step
bow_corpus = [dictionary.doc2bow(text) for text in all_preprocessed_text]
pprint.pprint(bow_corpus)

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(bow_corpus))

# %% [markdown]
# ### TF-IDF

# %%
# Creating a TF-IDF model from the Bag-of-Words corpus
tfidf_model = TfidfModel(bow_corpus)

# Applying the TF-IDF model to the Bag-of-Words corpus to get the TF-IDF representation
tfidf_corpus = tfidf_model[bow_corpus]

# Printing the TF-IDF representation for the first few documents
for doc in tfidf_corpus[:5]:
    print(doc)

# %%
# Looking up the word corresponding to word_id = 0
word_id = 5
word = dictionary[word_id]
print("Word corresponding to word_id =", word_id, ":", word)

# %%
# Defining the TF-IDF threshold
threshold = 0.05

# Iterating through the TF-IDF representation of the documents
for doc in tfidf_corpus[:5]:  # Iterating over the first few documents

    # Filtering words with TF-IDF scores above the threshold
    words_above_threshold = [(dictionary[word_id], tfidf_score) for word_id, tfidf_score in doc if tfidf_score > threshold]

    # Printing the words with TF-IDF scores above the threshold
    print("Words with TF-IDF score > 0.05:", words_above_threshold)
# Out:
# Words with TF-IDF score > 0.05: [('adaptation', 0.05556396544997512), ('adult', 0.17779096184977977), ('age', 0.10464880427795568), ('atlantic', 0.16835190249785884), ('bedi', 0.052109390168967845), ('bhutta', 0.05800542138330654), ('cdd', 0.2236550840917583), ('census', 0.08192503600830066), ('central', 0.0763688950199926), ('contemporary', 0.13249143240504066), ('coterminous', 0.07734056184440873), ('county', 0.09052705784666408), ('cumulative', 0.06554002880664053), ('decomposition', 0.052109390168967845), ('driver', 0.05803039531532237), ('east', 0.07782484465119477), ('england', 0.09113489963508593), ('eyring', 0.052109390168967845), ('florida', 0.1882239644555403), ('gamble', 0.06643198745489658), ('geographic', 0.05063049979726996), ('gerontological', 0.06808475331837915), ('gerontologist', 0.21268654507212398), ('gerontology', 0.09077967109117221), ('historically', 0.10638892661449063), ('huard', 0.06808475331837915), ('ihrl', 0.2269491777279305), ('koc', 0.14010019411298408), ('law', 0.09255808526029562), ('lesser', 0.07734056184440873), ('meade', 0.10425629508149016), ('midcentury', 0.08830910086404303), ('midwest', 0.16607996863724142), ('modest', 0.0896195285638065), ('mountain', 0.11715266309568291), ('northeast', 0.086117718513682), ('old', 0.11988596802488666), ('older', 0.08254443700074164), ('pacific', 0.0974578402824613), ('pd', 0.05131132182251422), ('pdd', 0.2723390132735166), ('pop', 0.059575025760851524), ('region', 0.05562185843117043), ('romitti', 0.06808475331837915), ('scenario', 0.0691266555535274), ('skarha', 0.09077967109117221), ('south', 0.06682168709583847), ('striessnig', 0.07734056184440873), ('sue', 0.07987681574705655), ('supplementary', 0.08973233168655562), ('texas', 0.06479065968220693), ('west', 0.10881108214419209), ('wing', 0.09667570230551091), ('wy', 0.052109390168967845)]
# Words with TF-IDF score > 0.05: [('comfort', 0.0659437292376771), ('effectiveness', 0.06436771111586978), ('forecast', 0.08748728346382731), ('message', 0.07900662161669095), ('service', 0.13966985262410575), ('strain', 0.06417619085394656), ('transfer', 0.08605630549239078), ('warn', 0.1353632977175435), ('warning', 0.13177993188981685), ('advice', 0.11297238615191414), ('always', 0.05066667824335597), ('belmont', 0.08683919991231749), ('beneficiary', 0.07033568061568211), ('chamnha', 0.05992311925279415), ('chaudhary', 0.07033568061568211), ('chuansi', 0.07033568061568211), ('climapp', 0.28134272246272846), ('collective', 0.06862827321181285), ('dedicated', 0.09902111577981237), ('derstanding', 0.05383216131904671), ('discipline', 0.08683919991231749), ('employer', 0.09207409157839137), ('enterprises', 0.07033568061568211), ('europe', 0.056034564247708654), ('everyone', 0.06862827321181285), ('folkerts', 0.05383216131904671), ('formation', 0.052207749433701385), ('giver', 0.05992311925279415), ('hackair', 0.42201408369409266), ('helplines', 0.05992311925279415), ('ijerph', 0.07033568061568211), ('individualize', 0.07033568061568211), ('infographics', 0.05992311925279415), ('intl', 0.07033568061568211), ('isabelle', 0.05383216131904671), ('isprs', 0.05992311925279415), ('julian', 0.07033568061568211), ('kenya', 0.17872950242282973), ('kilifi', 0.17976935775838243), ('kosmidis', 0.07033568061568211), ('languages', 0.09902111577981237), ('ljøsne', 0.07033568061568211), ('lund', 0.05383216131904671), ('lusambili', 0.07033568061568211), ('mobile', 0.1195078762150923), ('n', 0.051114297744715376), ('natukunda', 0.07033568061568211), ('ned', 0.05992311925279415), ('nefit', 0.07033568061568211), ('neonates', 0.05992311925279415), ('norwegian', 0.0714918009691319), ('oped', 0.05383216131904671), ('operational', 0.07380121777714908), ('operationalise', 0.05992311925279415), ('personalise', 0.21100704184704633), ('personalised', 0.14067136123136423), ('personnel', 0.08332416888791572), ('phone', 0.06138272771892758), ('platform', 0.16263669918589072), ('postpartum', 0.05383216131904671), ('predicting', 0.07033568061568211), ('pregnant', 0.07380121777714908), ('proaches', 0.05383216131904671), ('ristics', 0.07033568061568211), ('sector', 0.0674450694006525), ('sylvie', 0.05992311925279415), ('thessaly', 0.05383216131904671), ('translate', 0.08556825447192876), ('understandable', 0.14067136123136423), ('user', 0.08605630549239078), ('woman', 0.07889842566202225)]
# Words with TF-IDF score > 0.05: [('birth', 0.10151896794257115), ('setting', 0.052199627870982056), ('africa', 0.06616704744583765), ('belmont', 0.13390005705842745), ('chamnha', 0.06159821136974789), ('kenya', 0.1469805685088795), ('kilifi', 0.06159821136974789), ('maternal', 0.1610014978287042), ('postpartum', 0.16601096001522245), ('pregnant', 0.3287451203735829), ('woman', 0.20855302428196293), ('antenatal', 0.050894577050816216), ('anthropological', 0.07230184568867956), ('atures', 0.10178915410163243), ('breastfeed', 0.5061129198207569), ('burkina', 0.17853340941123658), ('cial', 0.050894577050816216), ('demiological', 0.05533698667174082), ('faso', 0.17853340941123658), ('feeding', 0.11067397334348164), ('filippi', 0.07230184568867956), ('hausted', 0.07230184568867956), ('hiv', 0.050894577050816216), ('infant', 0.24569720372504358), ('midwife', 0.050894577050816216), ('mother', 0.1961621527586803), ('nakstad', 0.05533698667174082), ('neonatal', 0.0948975528923031), ('newborn', 0.20357830820326486), ('newborns', 0.18479463410924366), ('paediatrics', 0.06159821136974789), ('placenta', 0.050894577050816216), ('postnatal', 0.06159821136974789), ('pregnancy', 0.1562490468497292), ('preterm', 0.09464793264177107), ('scorgie', 0.07230184568867956), ('stillbirth', 0.06538738425289344), ('supplementation', 0.06159821136974789), ('trim', 0.050894577050816216), ('unsplash', 0.14234632933845465), ('willing', 0.050894577050816216)]
# Words with TF-IDF score > 0.05: [('air', 0.0686126892861949), ('humidity', 0.16607846327843365), ('intersection', 0.10373429494770124), ('pollutant', 0.05711929712000558), ('pulmonary', 0.058635357055859996), ('pollution', 0.20537584300606282), ('compound', 0.22175013073663818), ('crescent', 0.06280438896614654), ('dardir', 0.05040948030412922), ('díaz', 0.05763016385983403), ('embase', 0.05040948030412922), ('grigorieva', 0.05040948030412922), ('interactive', 0.08659885274453478), ('kidney', 0.06780184116288421), ('lepeule', 0.13585664312433088), ('lilac', 0.05916890093314734), ('lokotola', 0.11833780186629468), ('lukyanets', 0.05916890093314734), ('machin', 0.17750670279944203), ('manisalidis', 0.07889186791086313), ('mcgregor', 0.05123887309640392), ('mena', 0.05177354143959233), ('pande', 0.17750670279944203), ('paper', 0.5292152112166015), ('prather', 0.05553341290014815), ('reliefweb', 0.05916890093314734), ('respiratory', 0.05730726871166824), ('retrieve', 0.0516373553737646), ('rodrigues', 0.07305225415818437), ('schnell', 0.0603807302774804), ('scoping', 0.11682547300577058), ('scopus', 0.2868084688180319), ('screen', 0.06434991577886634), ('sohrab', 0.09861483488857889), ('tobaldini', 0.09861483488857889), ('variable', 0.0529473034921955), ('wichmann', 0.0905710954162206), ('wright', 0.05773256849635653)]
# Words with TF-IDF score > 0.05: [('cold', 0.05409560926456019), ('diurnal', 0.0955604909952354), ('finding', 0.06873121717107644), ('intensify', 0.07659571206115261), ('ity', 0.05837931549200605), ('letter', 0.08647925115742158), ('planetary', 0.1368813970571542), ('refine', 0.05564913662705545), ('reveal', 0.050103753181493946), ('belmont', 0.2027866035683428), ('enbelmanagement', 0.06759553452278093), ('eu', 0.0723406981810143), ('europe', 0.05815632150610086), ('exhaustion', 0.07515562977224091), ('horizon', 0.07659571206115261), ('pollution', 0.1151727668219268), ('websites', 0.06086767212692296), ('duced', 0.06759553452278093), ('jpi', 0.07185938848995482), ('showcase', 0.05811314505573954), ('gasparrini', 0.09771280385784524), ('hu', 0.07441983602426691), ('interactive', 0.053420169875032834), ('japan', 0.06660623203635646), ('lv', 0.05811314505573954), ('overcenco', 0.07185938848995482), ('rai', 0.09902673576215523), ('schneider', 0.11831665429246822), ('scortichini', 0.12173534425384593), ('serum', 0.09726151117739627), ('stafoggia', 0.05138528265988156), ('tang', 0.06399049736051708), ('wildfire', 0.06313998726943665), ('zafeiratou', 0.06086767212692296), ('zhao', 0.07035006159396437), ('ailment', 0.06759553452278093), ('avoidable', 0.07185938848995482), ('büker', 0.1094984277156211), ('choi', 0.05811314505573954), ('cially', 0.05564913662705545), ('colleague', 0.29708020728646567), ('connell', 0.06759553452278093), ('consortium', 0.06399049736051708), ('creased', 0.07707792398982234), ('deaths', 0.05837143030522066), ('dedicate', 0.053420169875032834), ('elevates', 0.09328817585272173), ('emberson', 0.1094984277156211), ('fernandez', 0.053420169875032834), ('gate', 0.05564913662705545), ('heatcost', 0.2189968554312422), ('heatstroke', 0.0723406981810143), ('hypothermia', 0.06759553452278093), ('islam', 0.18657635170544346), ('issn', 0.06399049736051708), ('istockphoto', 0.2155781654698645), ('iungman', 0.06759553452278093), ('lethal', 0.053420169875032834), ('lo', 0.11622629011147909), ('lyzed', 0.2189968554312422), ('masselot', 0.16694740988116635), ('oort', 0.1094984277156211), ('pact', 0.05811314505573954), ('paramedic', 0.06759553452278093), ('pean', 0.06399049736051708), ('polluted', 0.09328817585272173), ('resilence', 0.1094984277156211), ('roye', 0.07185938848995482), ('rush', 0.08380578638568031), ('saturday', 0.07185938848995482), ('scene', 0.07185938848995482), ('scovronick', 0.05138528265988156), ('shahidul', 0.2189968554312422), ('stem', 0.05138528265988156), ('timespan', 0.09328817585272173), ('tokyo', 0.05811314505573954), ('underscore', 0.09902673576215523), ('upscale', 0.1094984277156211), ('vanoli', 0.08380578638568031), ('ventable', 0.1094984277156211), ('wipe', 0.1094984277156211)]

# %% [markdown]
# ### N-grams

# %%
# Taking a list of tokens as input and generating n-grams
def generate_ngrams(tokens, n=3):
    return list(nltk_ngrams(tokens, n))

# Creating n-gram model from a corpus
def create_ngram_model(corpus, n=3):
    ngram_model = defaultdict(int)
    for text in corpus:
        tokens = word_tokenize(text)
        ngrams = generate_ngrams(tokens, n)
        for ngram in ngrams:
            ngram_model[ngram] += 1
    return ngram_model

max_texts_to_process = None
docs = iterate_pdf_files(pdf_folder)

# Concatenating preprocessed tokens for each document into a single list of tokens
corpus_tokens = [tokens for sublist in docs.values() for tokens in sublist]

# Concatenating tokens into a single string for each document
corpus_strings = [' '.join(tokens) for tokens in corpus_tokens]

# Creating an n-gram model
ngram_model = create_ngram_model(corpus_strings, n=3)

# Printing all n-grams
print("All N-grams:")
for ngram, frequency in ngram_model.items():
    print(ngram, ":", frequency)

# %%
# Filtering n-grams with frequency greater than 1
filtered_ngram_model = {ngram: frequency for ngram, frequency in ngram_model.items() if frequency > 1}

# Printing filtered n-grams
print("Filtered N-grams:")
for ngram, frequency in filtered_ngram_model.items():
    print(ngram, ":", frequency)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('work', 'scientific', 'uncertainty') : 2
# ('scientific', 'uncertainty', 'advance') : 2
# ('uncertainty', 'advance', 'u') : 2
# ('advance', 'u', 'park') : 2
# ('u', 'park', 'park') : 2
# ('park', 'park', 'stewardship') : 2
# ('park', 'stewardship', 'available') : 2
# ('stewardship', 'available', 'lawrence') : 2
# ('available', 'lawrence', 'dj') : 2
# ('lawrence', 'dj', 'runyon') : 2
# ('dj', 'runyon', 'gross') : 2
# ('runyon', 'gross', 'je') : 2
# ('gross', 'je', 'schuurman') : 2
# ('je', 'schuurman', 'gw') : 2
# ('schuurman', 'gw', 'miller') : 2
# ('gw', 'miller', 'bw') : 2
# ('miller', 'bw', 'divergent') : 2
# ('bw', 'divergent', 'plausible') : 2
# ('divergent', 'plausible', 'relevant') : 2
# ('plausible', 'relevant', 'mate') : 2
# ('relevant', 'mate', 'future') : 2
# ('mate', 'future', 'resource') : 2
# ('future', 'resource', 'plan') : 2
# ('resource', 'plan', 'clim') : 2
# ('plan', 'clim', 'moss') : 2
# ('clim', 'moss', 'rh') : 2
# ('moss', 'rh', 'edmonds') : 2
# ('rh', 'edmonds', 'ja') : 2
# ('edmonds', 'ja', 'hibbard') : 2
# ('ja', 'hibbard', 'ka') : 2
# ('hibbard', 'ka', 'man') : 2
# ('ka', 'man', 'mr') : 2
# ('man', 'mr', 'rise') : 2
# ('mr', 'rise', 'sk') : 2
# ('rise', 'sk', 'van') : 2
# ('sk', 'van', 'vuuren') : 2
# ('vuuren', 'dp', 'next') : 2
# ('dp', 'next', 'generation') : 2
# ('next', 'generation', 'scenario') : 3
# ('generation', 'scenario', 'research') : 3
# ('scenario', 'research', 'assessment') : 3
# ('research', 'assessment', 'nature') : 3
# ('assessment', 'nature', 'pmid') : 2
# ('nature', 'pmid', 'van') : 2
# ('pmid', 'van', 'buuren') : 2
# ('van', 'buuren', 'mouse') : 2
# ('buuren', 'mouse', 'multivariate') : 2
# ('mouse', 'multivariate', 'imputation') : 2
# ('multivariate', 'imputation', 'chain') : 2
# ('imputation', 'chain', 'equation') : 2
# ('chain', 'equation', 'stat') : 2
# ('equation', 'stat', 'softw') : 2
# ('stat', 'softw', 'hosmer') : 2
# ('softw', 'hosmer', 'dw') : 2
# ('hosmer', 'dw', 'lemeshow') : 2
# ('dw', 'lemeshow', 'apply') : 2
# ('lemeshow', 'apply', 'logistic') : 2
# ('apply', 'logistic', 'akaike') : 2
# ('logistic', 'akaike', 'new') : 2
# ('akaike', 'new', 'look') : 2
# ('new', 'look', 'statistical') : 2
# ('look', 'statistical', 'identification') : 2
# ('statistical', 'identification', 'ieee') : 2
# ('identification', 'ieee', 'trans') : 2
# ('ieee', 'trans', 'automat') : 2
# ('trans', 'automat', 'contr') : 2
# ('automat', 'contr', 'buse') : 2
# ('contr', 'buse', 'likelihood') : 2
# ('buse', 'likelihood', 'ratio') : 2
# ('likelihood', 'ratio', 'wald') : 2
# ('ratio', 'wald', 'lagrange') : 2
# ('wald', 'lagrange', 'multiplier') : 2
# ('lagrange', 'multiplier', 'test') : 2
# ('multiplier', 'test', 'expository') : 2
# ('test', 'expository', 'note') : 2
# ('expository', 'note', 'stat') : 2
# ('note', 'stat', 'r') : 2
# ('stat', 'r', 'core') : 2
# ('team', 'r', 'r') : 2
# ('r', 'r', 'project') : 2
# ('r', 'project', 'statistical') : 2
# ('project', 'statistical', 'compute') : 2
# ('statistical', 'compute', 'venables') : 2
# ('compute', 'venables', 'wn') : 2
# ('venables', 'wn', 'modern') : 2
# ('wn', 'modern', 'apply') : 2
# ('modern', 'apply', 'statistic') : 2
# ('apply', 'statistic', 'plos') : 2
# ('statistic', 'plos', 'one') : 2
# ('one', 'august', 'wickham') : 2
# ('august', 'wickham', 'h') : 2
# ('wickham', 'h', 'navarro') : 2
# ('h', 'navarro', 'lin') : 2
# ('navarro', 'lin', 'elegant') : 2
# ('lin', 'elegant', 'graphic') : 2
# ('elegant', 'graphic', 'analysis') : 2
# ('graphic', 'analysis', 'fisichelli') : 2
# ('analysis', 'fisichelli', 'na') : 2
# ('fisichelli', 'na', 'schuurman') : 2
# ('na', 'schuurman', 'gw') : 2
# ('schuurman', 'gw', 'monahan') : 2
# ('gw', 'monahan', 'wb') : 2
# ('monahan', 'wb', 'ziesler') : 2
# ('wb', 'ziesler', 'p') : 2
# ('ziesler', 'p', 'protect') : 2
# ('p', 'protect', 'area') : 2
# ('protect', 'area', 'tourism') : 2
# ('area', 'tourism', 'change') : 2
# ('tourism', 'change', 'mate') : 2
# ('change', 'mate', 'visitation') : 2
# ('mate', 'visitation', 'u') : 2
# ('visitation', 'u', 'park') : 2
# ('u', 'park', 'warm') : 2
# ('park', 'warm', 'overheat') : 2
# ('warm', 'overheat', 'plo') : 2
# ('overheat', 'plo', 'one') : 2
# ('one', 'pmid', 'liss') : 2
# ('pmid', 'liss', 'naumova') : 2
# ('heatwaves', 'hospitalization', 'hyperthermia') : 2
# ('hospitalization', 'hyperthermia', 'define') : 2
# ('hyperthermia', 'define', 'region') : 2
# ('ass', 'suppl', 'pmid') : 2
# ('suppl', 'pmid', 'ebi') : 2
# ('pmid', 'ebi', 'kl') : 3
# ('risk', 'lancet', 'pmid') : 3
# ('lancet', 'pmid', 'leyk') : 2
# ('pmid', 'leyk', 'hoitz') : 2
# ('leyk', 'hoitz', 'becker') : 2
# ('hoitz', 'becker', 'c') : 2
# ('becker', 'c', 'glitz') : 2
# ('c', 'glitz', 'kj') : 2
# ('glitz', 'kj', 'nestler') : 2
# ('kj', 'nestler', 'k') : 2
# ('nestler', 'k', 'piekarski') : 2
# ('k', 'piekarski', 'risk') : 2
# ('piekarski', 'risk', 'intervention') : 2
# ('stress', 'dtsch', 'arztebl') : 2
# ('dtsch', 'arztebl', 'int') : 2
# ('arztebl', 'int', 'pmid') : 2
# ('int', 'pmid', 'arbuthnott') : 2
# ('pmid', 'arbuthnott', 'k') : 2
# ('environ', 'suppl', 'suppl') : 2
# ('suppl', 'suppl', 'pmid') : 2
# ('suppl', 'pmid', 'howe') : 2
# ('pmid', 'howe', 'pd') : 2
# ('acad', 'sci', 'pmid') : 2
# ('sci', 'pmid', 'schwalm') : 2
# ('pmid', 'schwalm', 'cr') : 2
# ('cumulative', 'emission', 'pnas') : 2
# ('emission', 'pnas', 'available') : 2
# ('pnas', 'available', 'pmid') : 2
# ('available', 'pmid', 'chapman') : 2
# ('pmid', 'chapman', 'hess') : 2
# ('chapman', 'hess', 'hw') : 2
# ('hess', 'hw', 'lucas') : 2
# ('hw', 'lucas', 'rai') : 2
# ('lucas', 'rai', 'glaser') : 2
# ('rai', 'glaser', 'saran') : 2
# ('glaser', 'saran', 'r') : 2
# ('saran', 'r', 'occupational') : 2
# ('r', 'occupational', 'exposure') : 2
# ('occupational', 'exposure', 'chronic') : 2
# ('exposure', 'chronic', 'kidney') : 2
# ('kidney', 'disease', 'nontraditional') : 2
# ('disease', 'nontraditional', 'origin') : 2
# ('nontraditional', 'origin', 'state') : 2
# ('origin', 'state', 'siol') : 2
# ('state', 'siol', 'regul') : 2
# ('siol', 'regul', 'integr') : 2
# ('comp', 'physiol', 'pmid') : 2
# ('physiol', 'pmid', 'watt') : 2
# ('come', 'lancet', 'available') : 2
# ('lancet', 'available', 'pmid') : 2
# ('available', 'pmid', 'robledo') : 2
# ('pmid', 'robledo', 'batle') : 2
# ('robledo', 'batle', 'transformational') : 2
# ('batle', 'transformational', 'tourism') : 2
# ('transformational', 'tourism', 'hero') : 2
# ('tourism', 'hero', 'journey') : 2
# ('hero', 'journey', 'current') : 2
# ('journey', 'current', 'issue') : 2
# ('current', 'issue', 'tourism') : 2
# ('issue', 'tourism', 'morse') : 2
# ('tourism', 'morse', 'wc') : 2
# ('morse', 'wc', 'stern') : 2
# ('wc', 'stern', 'blahna') : 2
# ('stern', 'blahna', 'stein') : 2
# ('blahna', 'stein', 'recreation') : 2
# ('stein', 'recreation', 'transformative') : 2
# ('recreation', 'transformative', 'experience') : 2
# ('transformative', 'experience', 'synthesize') : 2
# ('experience', 'synthesize', 'erature') : 2
# ('synthesize', 'erature', 'outdoor') : 2
# ('erature', 'outdoor', 'recreation') : 2
# ('outdoor', 'recreation', 'recreation') : 2
# ('recreation', 'recreation', 'ecosystem') : 2
# ('recreation', 'ecosystem', 'service') : 2
# ('ecosystem', 'service', 'system') : 2
# ('service', 'system', 'framework') : 2
# ('system', 'framework', 'journal') : 2
# ('framework', 'journal', 'outdoor') : 2
# ('journal', 'outdoor', 'recreation') : 2
# ('outdoor', 'recreation', 'tourism') : 2
# ('recreation', 'tourism', 'liu') : 2
# ('tourism', 'liu', 'xu') : 2
# ('liu', 'xu', 'yj') : 2
# ('xu', 'yj', 'zhang') : 2
# ('yj', 'zhang', 'yh') : 2
# ('zhang', 'yh', 'yan') : 2
# ('yh', 'yan', 'song') : 2
# ('yan', 'song', 'xl') : 2
# ('song', 'xl', 'xie') : 2
# ('xl', 'xie', 'hy') : 2
# ('xie', 'hy', 'association') : 2
# ('hy', 'association', 'perception') : 2
# ('association', 'perception', 'neous') : 2
# ('perception', 'neous', 'behavior') : 2
# ('neous', 'behavior', 'wave') : 2
# ('behavior', 'wave', 'heatstroke') : 2
# ('wave', 'heatstroke', 'guangdong') : 2
# ('heatstroke', 'guangdong', 'province') : 2
# ('guangdong', 'province', 'china') : 2
# ('province', 'china', 'bmc') : 2
# ('china', 'bmc', 'pmid') : 2
# ('bmc', 'pmid', 'schmeltz') : 2
# ('pmid', 'schmeltz', 'mt') : 2
# ('research', 'available', 'pmid') : 2
# ('available', 'pmid', 'abed') : 2
# ('pmid', 'abed', 'ahad') : 2
# ('ahad', 'sullivan', 'f') : 2
# ('sullivan', 'f', 'dems') : 2
# ('f', 'dems', 'ˇar') : 2
# ('dems', 'ˇar', 'melhem') : 2
# ('ˇar', 'melhem', 'kulu') : 2
# ('kulu', 'weather', 'sure') : 2
# ('weather', 'sure', 'mortality') : 2
# ('sure', 'mortality', 'hospital') : 2
# ('one', 'pmid', 'c') : 2
# ('pmid', 'c', 'kim') : 2
# ('c', 'kim', 'h') : 2
# ('kim', 'h', 'hashizume') : 3
# ('h', 'hashizume', 'lee') : 2
# ('hashizume', 'lee', 'w') : 2
# ('lee', 'w', 'honda') : 2
# ('w', 'honda', 'kim') : 2
# ('honda', 'kim', 'se') : 2
# ('kim', 'se', 'effect') : 2
# ('se', 'effect', 'warm') : 2
# ('effect', 'warm', 'tality') : 2
# ('warm', 'tality', 'burden') : 2
# ('tality', 'burden', 'future') : 2
# ('burden', 'future', 'scenario') : 3
# ('future', 'scenario', 'model') : 3
# ('lancet', 'planet', 'pmid') : 4
# ('planet', 'pmid', 'plos') : 2
# ('pmid', 'plos', 'one') : 2
# ('count', 'year', 'season') : 2
# ('ﬁndings', 'urgent', 'need') : 3
# ('need', 'strong', 'mitigation') : 2
# ('ﬁve', 'large', 'ensemble') : 2
# ('large', 'ensemble', 'smile') : 2
# ('exceedance', 'frequency', 'curve') : 7
# ('daily', 'mortality', 'location') : 2
# ('day', 'mean', 'mmt') : 2
# ('year', 'year', 'return') : 3
# ('within', 'give', 'period') : 2
# ('expect', 'every', 'year') : 3
# ('rapid', 'reduction', 'return') : 2
# ('reduction', 'return', 'period') : 3
# ('return', 'period', 'mortality') : 3
# ('shift', 'along', 'axis') : 2
# ('different', 'warm', 'rate') : 2
# ('internal', 'variability', 'inner') : 2
# ('variability', 'inner', 'whisker') : 2
# ('association', 'outer', 'whisker') : 2
# ('overall', 'result', 'show') : 2
# ('change', 'return', 'period') : 5
# ('display', 'new', 'return') : 2
# ('new', 'return', 'period') : 2
# ('u', 'atlantic', 'gulf') : 2
# ('atlantic', 'gulf', 'coast') : 2
# ('latin', 'american', 'paciﬁc') : 2
# ('american', 'paciﬁc', 'coast') : 2
# ('mortality', 'são', 'paulo') : 2
# ('minimum', 'tality', 'temperature') : 2
# ('unbiased', 'prediction', 'blups') : 2
# ('warm', 'level', 'warm') : 3
# ('fraction', 'year', 'season') : 2
# ('return', 'period', 'season') : 2
# ('distribute', 'lag', 'nonlinear') : 2
# ('lag', 'nonlinear', 'model') : 2
# ('internal', 'knot', 'equally') : 3
# ('daily', 'mean', 'value') : 3
# ('south', 'africa', 'south') : 2
# ('africa', 'south', 'africa') : 2
# ('east', 'asia', 'iran') : 2
# ('kuwait', 'east', 'asia') : 2
# ('v', 'x', 'exceedance') : 2
# ('x', 'exceedance', 'frequency') : 2
# ('accounting', 'cost', 'beneﬁts') : 2
# ('extreme', 'nat', 'clim') : 2
# ('meet', 'paris', 'agreement') : 2
# ('paris', 'agreement', 'goal') : 3
# ('hoffman', 'shandas', 'pendleton') : 2
# ('shandas', 'pendleton', 'effect') : 2
# ('urban', 'di', 'napoli') : 2
# ('association', 'distribute', 'lag') : 2
# ('mortality', 'risk', 'use') : 2
# ('wave', 'mortality', 'multicountry') : 2
# ('globally', 'consistent', 'assessment') : 2
# ('nat', 'hazard', 'earth') : 2
# ('hazard', 'earth', 'syst') : 2
# ('conduct', 'formal', 'analysis') : 2
# ('information', 'nature', 'communication') : 2
# ('review', 'work', 'peer') : 2
# ('available', 'reprint', 'permission') : 3
# ('neutral', 'regard', 'isdictional') : 2
# ('regard', 'isdictional', 'claim') : 2
# ('isdictional', 'claim', 'publish') : 2
# ('map', 'institutional', 'afﬁliations') : 4
# ('institutional', 'afﬁliations', 'open') : 4
# ('afﬁliations', 'open', 'access') : 4
# ('eth', 'zurich', 'zurich') : 2
# ('zurich', 'zurich', 'switzerland') : 2
# ('zhunan', 'taiwan', 'institute') : 2
# ('institute', 'environmental', 'study') : 3
# ('environmental', 'study', 'tsukuba') : 3
# ('study', 'tsukuba', 'japan') : 3
# ('planetary', 'london', 'school') : 3
# ('choi', 'ey', 'epidemiol') : 8
# ('ey', 'epidemiol', 'community') : 8
# ('epidemiol', 'community', 'original') : 8
# ('community', 'original', 'research') : 8
# ('exposure', 'trajectory', 'cognitive') : 2
# ('cognitive', 'decline', 'among') : 3
# ('decline', 'among', 'old') : 3
# ('eun', 'young', 'choi') : 3
# ('young', 'choi', 'haena') : 2
# ('choi', 'haena', 'lee') : 2
# ('haena', 'lee', 'virginia') : 2
# ('lee', 'virginia', 'w') : 2
# ('virginia', 'w', 'chang') : 2
# ('supplemental', 'material', 'publish') : 3
# ('new', 'york', 'university') : 5
# ('york', 'university', 'new') : 3
# ('whether', 'exposure', 'associate') : 2
# ('neighbourhood', 'socioeconomic', 'status') : 2
# ('growth', 'curve', 'model') : 4
# ('trajectory', 'cognitive', 'function') : 4
# ('cognitive', 'function', 'among') : 2
# ('u', 'adult', 'age') : 2
# ('exposure', 'associate', 'faster') : 5
# ('associate', 'faster', 'cognitive') : 5
# ('faster', 'cognitive', 'decline') : 6
# ('cognitive', 'decline', 'black') : 3
# ('decline', 'black', 'resident') : 2
# ('black', 'resident', 'poor') : 2
# ('resident', 'poor', 'neighbourhood') : 3
# ('white', 'hispanic', 'resident') : 2
# ('stroke', 'follow', 'exposure') : 2
# ('representative', 'sample', 'u') : 2
# ('sample', 'u', 'old') : 2
# ('u', 'old', 'adult') : 2
# ('exposure', 'affect', 'cognitive') : 2
# ('affect', 'cognitive', 'decline') : 2
# ('cognitive', 'decline', 'unequally') : 2
# ('decline', 'unequally', 'population') : 2
# ('exposure', 'cognitive', 'decline') : 2
# ('factor', 'cognitive', 'ageing') : 2
# ('cognitive', 'ageing', 'especially') : 2
# ('ageing', 'especially', 'among') : 2
# ('especially', 'among', 'socially') : 2
# ('among', 'socially', 'vulnerable') : 2
# ('socially', 'vulnerable', 'group') : 2
# ('universitesi', 'protect', 'epidemiol') : 7
# ('protect', 'epidemiol', 'community') : 7
# ('epidemiol', 'community', 'first') : 8
# ('community', 'first', 'publish') : 8
# ('first', 'publish', 'august') : 8
# ('publish', 'august', 'download') : 8
# ('august', 'download', 'choi') : 7
# ('download', 'choi', 'ey') : 7
# ('black', 'old', 'adult') : 4
# ('grow', 'early', 'century') : 2
# ('exacerbate', 'cognitive', 'decline') : 2
# ('cumulative', 'exposure', 'associate') : 3
# ('ethnicity', 'neighbourhood', 's') : 3
# ('hispanic', 'white', 'hispanic') : 3
# ('hispanic', 'black', 'hispanic') : 3
# ('number', 'day', 'usa') : 2
# ('day', 'usa', 'note') : 2
# ('exposure', 'create', 'measure') : 2
# ('participant', 'period', 'year') : 2
# ('period', 'year', 'precede') : 2
# ('year', 'precede', 'last') : 2
# ('last', 'cognitive', 'assessment') : 2
# ('exposure', 'analysis', 'use') : 2
# ('level', 'fall', 'within') : 2
# ('fall', 'within', 'high') : 2
# ('within', 'high', 'quintile') : 2
# ('high', 'quintile', 'corresponds') : 2
# ('quintile', 'corresponds', 'day') : 2
# ('measure', 'cognitive', 'function') : 2
# ('census', 'level', 'indicator') : 2
# ('level', 'indicator', 'cronbach') : 2
# ('average', 'neighbourhood', 'include') : 2
# ('sex', 'living', 'arrangement') : 2
# ('control', 'region', 'account') : 2
# ('hot', 'day', 'south') : 2
# ('level', 'cognitive', 'function') : 5
# ('cognitive', 'function', 'rate') : 3
# ('cognitive', 'function', 'time') : 2
# ('preliminary', 'analysis', 'show') : 2
# ('association', 'exposure', 'cognitive') : 2
# ('test', 'whether', 'association') : 2
# ('association', 'cognitive', 'trajectory') : 3
# ('red', 'dot', 'represent') : 3
# ('exposure', 'period', 'mean') : 2
# ('resident', 'disadvantage', 'neighbourhood') : 2
# ('cognitive', 'function', 'trajectory') : 3
# ('coefficient', 'interaction', 'term') : 2
# ('associate', 'point', 'faster') : 2
# ('point', 'faster', 'decrease') : 2
# ('faster', 'decrease', 'point') : 2
# ('decrease', 'point', 'scale') : 2
# ('point', 'scale', 'cognitive') : 2
# ('scale', 'cognitive', 'function') : 2
# ('additional', 'year', 'age') : 2
# ('neighbourhood', 'exposure', 'associate') : 2
# ('year', 'age', 'associate') : 2
# ('predict', 'trajectory', 'cognitive') : 2
# ('summary', 'statistic', 'sample') : 2
# ('neighbourhood', 'affluent', 'neighbourhood') : 2
# ('household', 'wealth', 'region') : 3
# ('census', 'tract', 'score') : 2
# ('tract', 'score', 'sd') : 2
# ('s', 'socioeconomic', 'status') : 2
# ('socioeconomic', 'status', 'koc') : 3
# ('status', 'koc', 'universitesi') : 3
# ('associate', 'rate', 'decline') : 2
# ('average', 'cognitive', 'score') : 2
# ('cognitive', 'score', 'age') : 2
# ('score', 'age', 'decline') : 4
# ('age', 'decline', 'age') : 4
# ('decline', 'age', 'decrease') : 4
# ('average', 'score', 'age') : 2
# ('accelerate', 'cognitive', 'decline') : 2
# ('nomically', 'disadvantage', 'neighbourhood') : 2
# ('intercept', 'rate', 'intercept') : 2
# ('rate', 'intercept', 'rate') : 2
# ('b', 'p', 'value') : 6
# ('p', 'value', 'b') : 5
# ('value', 'b', 'p') : 5
# ('interactive', 'effect', 'exposure') : 7
# ('arrangement', 'educational', 'attainment') : 2
# ('educational', 'attainment', 'household') : 2
# ('attainment', 'household', 'wealth') : 2
# ('wealth', 'region', 'residence') : 2
# ('region', 'residence', 'urbanicity') : 2
# ('residence', 'urbanicity', 'year') : 2
# ('ses', 'socioeconomic', 'status') : 2
# ('publicly', 'available', 'restrict') : 2
# ('retirement', 'hr', 'sponsor') : 2
# ('hr', 'sponsor', 'institute') : 2
# ('sponsor', 'institute', 'age') : 2
# ('institute', 'age', 'nia') : 3
# ('age', 'nia', 'conduct') : 2
# ('nia', 'conduct', 'university') : 2
# ('conduct', 'university', 'michigan') : 2
# ('university', 'michigan', 'website') : 2
# ('result', 'author', 'contribute') : 2
# ('available', 'accessed', 'dec') : 5
# ('response', 'passive', 'stress') : 2
# ('rev', 'lee', 'h') : 2
# ('gerontol', 'b', 'psychol') : 2
# ('b', 'psychol', 'sci') : 2
# ('psychol', 'sci', 'soc') : 2
# ('sci', 'soc', 'sci') : 2
# ('case', 'chicago', 'wave') : 2
# ('humidity', 'absolute', 'humidity') : 2
# ('elsevier', 'right', 'reserve') : 3
# ('school', 'environment', 'enterprise') : 2
# ('environment', 'enterprise', 'development') : 2
# ('enterprise', 'development', 'university') : 2
# ('development', 'university', 'waterloo') : 2
# ('university', 'waterloo', 'waterloo') : 2
# ('waterloo', 'waterloo', 'canada') : 2
# ('great', 'toronto', 'area') : 2
# ('combine', 'effect', 'event') : 2
# ('effect', 'event', 'poor') : 2
# ('event', 'poor', 'air') : 4
# ('air', 'quality', 'condition') : 2
# ('environmental', 'variable', 'air') : 2
# ('multiple', 'record', 'different') : 2
# ('record', 'different', 'level') : 2
# ('different', 'level', 'investigation') : 3
# ('total', 'elderly', 'elderly') : 3
# ('ture', 'relative', 'humidity') : 2
# ('relative', 'humidity', 'ozone') : 2
# ('ozone', 'fine', 'particulate') : 2
# ('hot', 'warm', 'season') : 4
# ('warm', 'season', 'municipality') : 2
# ('season', 'municipality', 'mississauga') : 2
# ('municipality', 'mississauga', 'brampton') : 4
# ('mississauga', 'brampton', 'peel') : 2
# ('brampton', 'peel', 'region') : 2
# ('variable', 'increase', 'daily') : 2
# ('elderly', 'sector', 'show') : 2
# ('sector', 'show', 'high') : 2
# ('high', 'vulnerability', 'environmental') : 2
# ('vulnerability', 'environmental', 'change') : 2
# ('environmental', 'change', 'furthermore') : 2
# ('change', 'furthermore', 'association') : 2
# ('condition', 'poor', 'air') : 3
# ('cardiorespiratory', 'patient', 'especially') : 3
# ('patient', 'especially', 'elderly') : 3
# ('poor', 'environmental', 'condition') : 3
# ('study', 'report', 'exposure') : 3
# ('receive', 'receive', 'revised') : 2
# ('day', 'day', 'event') : 2
# ('event', 'elderly', 'mortality') : 2
# ('importance', 'consider', 'effect') : 2
# ('consider', 'effect', 'variation') : 2
# ('elderly', 'people', 'year') : 2
# ('ambient', 'even', 'wave') : 2
# ('even', 'wave', 'condition') : 2
# ('wave', 'condition', 'meet') : 2
# ('causality', 'mortality', 'warm') : 2
# ('mortality', 'warm', 'condition') : 2
# ('warm', 'condition', 'day') : 2
# ('air', 'quality', 'record') : 2
# ('ambient', 'condition', 'population') : 2
# ('air', 'pollutant', 'concentration') : 12
# ('previous', 'study', 'primarily') : 2
# ('variable', 'air', 'quality') : 4
# ('quality', 'ambient', 'condition') : 3
# ('relationship', 'environmental', 'variable') : 2
# ('del', 'pozo', 'cruz') : 3
# ('hierarchical', 'clustering', 'analysis') : 3
# ('flexibility', 'robust', 'cluster') : 2
# ('robust', 'cluster', 'scheme') : 2
# ('time', 'series', 'datasets') : 3
# ('cluster', 'analysis', 'cluster') : 2
# ('analysis', 'provide', 'classification') : 2
# ('provide', 'classification', 'cluster') : 2
# ('ibm', 'spss', 'statistic') : 3
# ('dardir', 'environmental', 'research') : 16
# ('possible', 'statistically', 'significant') : 3
# ('significant', 'cluster', 'observation') : 2
# ('k', 'number', 'cluster') : 2
# ('number', 'cluster', 'achieve') : 2
# ('cloud', 'observation', 'cluster') : 2
# ('especially', 'specific', 'record') : 2
# ('assess', 'large', 'community') : 2
# ('large', 'community', 'response') : 2
# ('community', 'response', 'use') : 2
# ('response', 'use', 'propose') : 2
# ('use', 'propose', 'method') : 3
# ('result', 'cluster', 'analysis') : 2
# ('air', 'quality', 'parameter') : 3
# ('independent', 'variable', 'response') : 2
# ('mortality', 'count', 'emergency') : 2
# ('count', 'emergency', 'department') : 3
# ('test', 'propose', 'method') : 2
# ('air', 'quality', 'variable') : 14
# ('quality', 'variable', 'concentration') : 2
# ('meteorological', 'parameter', 'ambient') : 2
# ('rh', 'solar', 'radiation') : 2
# ('lations', 'among', 'variable') : 2
# ('focus', 'daily', 'record') : 3
# ('daily', 'record', 'daily') : 5
# ('value', 'environmental', 'variable') : 2
# ('environmental', 'variable', 'lag') : 3
# ('specific', 'record', 'assess') : 2
# ('period', 'daily', 'maximum') : 2
# ('daily', 'maximum', 'mean') : 3
# ('maximum', 'mean', 'value') : 7
# ('count', 'mortality', 'emergency') : 2
# ('emergency', 'visit', 'include') : 2
# ('visit', 'include', 'dataset') : 2
# ('age', 'cardiorespiratory', 'cause') : 2
# ('cluster', 'analysis', 'conduct') : 3
# ('record', 'ambient', 'condition') : 2
# ('ambient', 'condition', 'air') : 4
# ('condition', 'air', 'quality') : 4
# ('count', 'mortality', 'mor') : 2
# ('mortality', 'mor', 'emergency') : 2
# ('mor', 'emergency', 'visit') : 2
# ('emergency', 'visit', 'emr') : 2
# ('mor', 'emr', 'daily') : 4
# ('total', 'mor', 'emr') : 15
# ('mor', 'emr', 'represent') : 5
# ('event', 'elderly', 'mor') : 2
# ('elderly', 'mor', 'emr') : 5
# ('emr', 'represent', 'case') : 3
# ('base', 'mor', 'emr') : 2
# ('classification', 'disease', 'related') : 2
# ('disease', 'related', 'code') : 2
# ('related', 'code', 'tenth') : 2
# ('code', 'tenth', 'revision') : 2
# ('emr', 'level', 'elderly') : 2
# ('daily', 'count', 'mor') : 4
# ('count', 'mor', 'emr') : 3
# ('mor', 'emr', 'elderly') : 2
# ('include', 'age', 'date') : 2
# ('statistic', 'canada', 'guideline') : 2
# ('canada', 'guideline', 'restriction') : 2
# ('period', 'september', 'hot') : 2
# ('september', 'hot', 'warm') : 2
# ('mississauga', 'brampton', 'ontario') : 2
# ('total', 'emergency', 'visit') : 6
# ('brampton', 'air', 'monitor') : 2
# ('air', 'monitor', 'station') : 3
# ('station', 'n', 'w') : 2
# ('include', 'maximum', 'minimum') : 2
# ('value', 'relative', 'humidity') : 3
# ('power', 'access', 'viewer') : 2
# ('mean', 'value', 'daily') : 2
# ('mean', 'total', 'mor') : 2
# ('mor', 'emr', 'associate') : 2
# ('mor', 'record', 'high') : 2
# ('associate', 'moderate', 'value') : 2
# ('value', 'ozone', 'level') : 2
# ('correlation', 'analysis', 'conduct') : 2
# ('degree', 'value', 'say') : 2
# ('daily', 'total', 'mortality') : 2
# ('value', 'ambient', 'air') : 2
# ('maximum', 'daily', 'value') : 2
# ('location', 'weather', 'station') : 2
# ('low', 'degree', 'negative') : 3
# ('degree', 'negative', 'correlation') : 3
# ('negative', 'correlation', 'relative') : 3
# ('correlation', 'relative', 'humidity') : 3
# ('relationship', 'air', 'quality') : 2
# ('correlation', 'notice', 'total') : 2
# ('low', 'degree', 'positive') : 3
# ('degree', 'positive', 'correlation') : 3
# ('lag', 'environmental', 'variable') : 4
# ('variable', 'daily', 'mean') : 2
# ('daily', 'average', 'value') : 2
# ('average', 'value', 'cumulative') : 2
# ('value', 'cumulative', 'average') : 2
# ('pearson', 'correlation', 'environmental') : 2
# ('consider', 'lag', 'period') : 2
# ('high', 'positive', 'correlation') : 2
# ('positive', 'correlation', 'notice') : 3
# ('elderly', 'emr', 'regard') : 2
# ('relationship', 'maximum', 'mean') : 2
# ('mean', 'value', 'level') : 3
# ('value', 'level', 'record') : 3
# ('level', 'record', 'total') : 2
# ('record', 'total', 'mor') : 3
# ('total', 'mor', 'b') : 3
# ('mor', 'b', 'total') : 3
# ('b', 'total', 'emr') : 3
# ('total', 'emr', 'mississauga') : 2
# ('emr', 'mississauga', 'relationship') : 2
# ('mississauga', 'relationship', 'maximum') : 2
# ('correlation', 'analysis', 'total') : 2
# ('analysis', 'total', 'mor') : 2
# ('day', 'event', 'however') : 2
# ('maximum', 'value', 'meteorological') : 3
# ('humidity', 'air', 'quality') : 2
# ('achieve', 'possible', 'statistically') : 2
# ('relationship', 'among', 'cluster') : 2
# ('total', 'mortality', 'emergency') : 2
# ('daily', 'total', 'mor') : 2
# ('ambient', 'temperature', 'associate') : 2
# ('mor', 'emr', 'correlate') : 3
# ('emr', 'correlate', 'value') : 2
# ('correlate', 'value', 'daily') : 2
# ('value', 'daily', 'ambient') : 2
# ('daily', 'ambient', 'temperature') : 5
# ('ambient', 'temperature', 'air') : 5
# ('high', 'centroid', 'total') : 3
# ('centroid', 'total', 'mor') : 2
# ('maximum', 'mississauga', 'brampton') : 3
# ('mississauga', 'brampton', 'respectively') : 13
# ('centrations', 'ppb', 'ppb') : 2
# ('ppb', 'ppb', 'mississauga') : 3
# ('ppb', 'mississauga', 'brampton') : 3
# ('emr', 'associate', 'centroid') : 2
# ('associate', 'centroid', 'maximum') : 2
# ('centroid', 'maximum', 'mississauga') : 2
# ('max', 'temp', 'min') : 23
# ('temp', 'min', 'temp') : 25
# ('temp', 'mean', 'temp') : 7
# ('corr', 'corr', 'corr') : 2
# ('daily', 'mor', 'emr') : 2
# ('high', 'centroid', 'elderly') : 2
# ('mississauga', 'associate', 'centroid') : 2
# ('associate', 'centroid', 'ppb') : 7
# ('centroid', 'ppb', 'maximum') : 10
# ('ppb', 'maximum', 'concentration') : 4
# ('maximum', 'concentration', 'respectively') : 3
# ('environmental', 'variable', 'total') : 3
# ('variable', 'total', 'mor') : 3
# ('emergency', 'visit', 'cardiorespiratory') : 2
# ('cluster', 'environmental', 'parameter') : 2
# ('mortality', 'divide', 'two') : 2
# ('divide', 'two', 'group') : 2
# ('two', 'group', 'group') : 2
# ('group', 'group', 'daily') : 2
# ('group', 'daily', 'low') : 2
# ('daily', 'low', 'record') : 5
# ('record', 'daily', 'mortality') : 2
# ('daily', 'mortality', 'case') : 2
# ('another', 'group', 'daily') : 2
# ('group', 'daily', 'record') : 2
# ('record', 'daily', 'mor') : 2
# ('dataset', 'observation', 'daily') : 2
# ('record', 'mississauga', 'brampton') : 3
# ('daily', 'record', 'mississauga') : 2
# ('table', 'high', 'probability') : 2
# ('high', 'probability', 'occurrence') : 5
# ('probability', 'occurrence', 'daily') : 6
# ('occurrence', 'daily', 'low') : 3
# ('daily', 'low', 'mor') : 2
# ('low', 'mor', 'correlate') : 2
# ('correlate', 'high', 'centroid') : 6
# ('high', 'centroid', 'ambient') : 5
# ('centroid', 'ambient', 'condition') : 3
# ('mississauga', 'centroid', 'high') : 3
# ('centroid', 'high', 'cluster') : 2
# ('high', 'cluster', 'associate') : 2
# ('cluster', 'associate', 'centroid') : 2
# ('concentration', 'respectively', 'brampton') : 5
# ('respectively', 'brampton', 'centroid') : 2
# ('brampton', 'centroid', 'high') : 3
# ('high', 'occurrence', 'mississauga') : 2
# ('high', 'centroid', 'maximum') : 2
# ('centroid', 'maximum', 'high') : 2
# ('maximum', 'high', 'centroid') : 2
# ('high', 'centroid', 'minimum') : 2
# ('centroid', 'minimum', 'high') : 2
# ('minimum', 'high', 'centroid') : 2
# ('high', 'centroid', 'concentration') : 2
# ('centroid', 'concentration', 'ppb') : 2
# ('concentration', 'ppb', 'centroid') : 2
# ('ppb', 'centroid', 'concentration') : 2
# ('high', 'centroid', 'environmental') : 3
# ('centroid', 'environmental', 'parameter') : 3
# ('environmental', 'parameter', 'associate') : 2
# ('centroid', 'ronmental', 'parameter') : 2
# ('occurrence', 'daily', 'mor') : 2
# ('high', 'cluster', 'environmental') : 2
# ('emergency', 'visit', 'mississauga') : 6
# ('mississauga', 'brampton', 'daily') : 2
# ('brampton', 'daily', 'record') : 2
# ('daily', 'record', 'occupy') : 2
# ('record', 'occupy', 'dataset') : 3
# ('occupy', 'dataset', 'mississauga') : 3
# ('dataset', 'mississauga', 'brampton') : 4
# ('maximum', 'concentration', 'ppb') : 3
# ('centroid', 'high', 'occurrence') : 2
# ('high', 'occurrence', 'daily') : 4
# ('daily', 'table', 'cluster') : 3
# ('table', 'cluster', 'analysis') : 4
# ('emergency', 'visit', 'municipality') : 4
# ('visit', 'municipality', 'cluster') : 4
# ('cluster', 'total', 'mortality') : 2
# ('mortality', 'mississauga', 'cluster') : 4
# ('mississauga', 'cluster', 'size') : 8
# ('cluster', 'size', 'max') : 8
# ('size', 'max', 'temp') : 8
# ('min', 'temp', 'ppb') : 20
# ('temp', 'ppb', 'cluster') : 16
# ('ppb', 'cluster', 'total') : 3
# ('mortality', 'brampton', 'cluster') : 4
# ('brampton', 'cluster', 'size') : 8
# ('cluster', 'total', 'emergency') : 2
# ('visit', 'mississauga', 'cluster') : 4
# ('emergency', 'visit', 'brampton') : 4
# ('visit', 'brampton', 'cluster') : 4
# ('temp', 'ppb', 'dardir') : 4
# ('ppb', 'dardir', 'environmental') : 4
# ('parameter', 'maximum', 'minimum') : 2
# ('maximum', 'minimum', 'concentration') : 8
# ('cluster', 'high', 'environmental') : 3
# ('high', 'environmental', 'parameter') : 2
# ('centroid', 'high', 'daily') : 4
# ('high', 'daily', 'low') : 2
# ('daily', 'low', 'associate') : 2
# ('low', 'associate', 'two') : 2
# ('associate', 'two', 'cluster') : 2
# ('two', 'cluster', 'refer') : 2
# ('minimum', 'concentration', 'respectively') : 7
# ('respectively', 'brampton', 'high') : 3
# ('refer', 'cluster', 'high') : 2
# ('ppb', 'maximum', 'minimum') : 8
# ('concentration', 'respectively', 'high') : 2
# ('respectively', 'high', 'probability') : 2
# ('environmental', 'parameter', 'municipality') : 2
# ('occurrence', 'daily', 'mississauga') : 2
# ('daily', 'mississauga', 'associate') : 2
# ('brampton', 'high', 'occurrence') : 2
# ('occurrence', 'daily', 'associate') : 2
# ('daily', 'associate', 'centroid') : 4
# ('observe', 'ascend', 'trend') : 2
# ('ascend', 'trend', 'daily') : 5
# ('trend', 'daily', 'ambient') : 2
# ('investigated', 'dataset', 'daily') : 2
# ('municipality', 'cluster', 'elderly') : 2
# ('cluster', 'elderly', 'mortality') : 4
# ('elderly', 'mortality', 'mississauga') : 2
# ('ppb', 'cluster', 'elderly') : 6
# ('elderly', 'mortality', 'brampton') : 2
# ('cluster', 'elderly', 'emergency') : 4
# ('elderly', 'emergency', 'visit') : 7
# ('could', 'every', 'maximum') : 3
# ('concentration', 'b', 'show') : 2
# ('b', 'show', 'ascend') : 2
# ('show', 'ascend', 'trend') : 2
# ('worth', 'mention', 'report') : 2
# ('related', 'whole', 'dataset') : 2
# ('mississauga', 'correlate', 'high') : 2
# ('centroid', 'ambient', 'parameter') : 2
# ('ambient', 'parameter', 'centroid') : 2
# ('parameter', 'centroid', 'high') : 2
# ('high', 'daily', 'associate') : 3
# ('daily', 'ambient', 'air') : 2
# ('report', 'every', 'maximum') : 2
# ('cluster', 'analysis', 'occurrence') : 2
# ('cluster', 'size', 'prob') : 10
# ('size', 'prob', 'max') : 10
# ('prob', 'max', 'temp') : 12
# ('ppb', 'cluster', 'size') : 4
# ('ppb', 'cluster', 'emergency') : 2
# ('cluster', 'emergency', 'visit') : 2
# ('environmental', 'research', 'concentration') : 2
# ('total', 'mor', 'mississauga') : 2
# ('cluster', 'lag', 'period') : 2
# ('day', 'use', 'daily') : 2
# ('use', 'daily', 'average') : 2
# ('cluster', 'total', 'mor') : 2
# ('total', 'mor', 'respect') : 2
# ('mor', 'respect', 'moderate') : 2
# ('cluster', 'environmental', 'variable') : 3
# ('variable', 'lag', 'period') : 2
# ('total', 'mor', 'record') : 2
# ('cluster', 'size', 'value') : 2
# ('size', 'value', 'prob') : 2
# ('value', 'prob', 'max') : 2
# ('quantify', 'predictive', 'ability') : 2
# ('regression', 'analysis', 'conduct') : 2
# ('mississauga', 'predict', 'base') : 2
# ('predict', 'base', 'depended') : 2
# ('base', 'depended', 'maximum') : 2
# ('occurrence', 'daily', 'relate') : 2
# ('daily', 'relate', 'ambient') : 2
# ('relate', 'ambient', 'condition') : 2
# ('ambient', 'condition', 'b') : 2
# ('condition', 'b', 'air') : 2
# ('b', 'air', 'pollutant') : 2
# ('concentration', 'occurrence', 'daily') : 2
# ('concentration', 'predict', 'depend') : 2
# ('predict', 'depend', 'maximum') : 2
# ('equation', 'represent', 'prediction') : 2
# ('base', 'concentration', 'respectively') : 2
# ('maximum', 'maximum', 'concentration') : 2
# ('correlation', 'ambient', 'temperature') : 2
# ('record', 'environmental', 'variable') : 2
# ('mean', 'temp', 'mean') : 6
# ('table', 'predictive', 'multiple') : 2
# ('predictive', 'multiple', 'regression') : 2
# ('multiple', 'regression', 'municipality') : 2
# ('regression', 'municipality', 'dependent') : 2
# ('municipality', 'dependent', 'variable') : 2
# ('dependent', 'variable', 'adjusted') : 2
# ('variable', 'adjusted', 'std') : 2
# ('adjusted', 'std', 'error') : 2
# ('std', 'error', 'f') : 4
# ('error', 'f', 'mi') : 4
# ('f', 'mi', 'brm') : 4
# ('mi', 'brm', 'mi') : 4
# ('brm', 'mi', 'brm') : 4
# ('mi', 'brm', 'coef') : 4
# ('brm', 'coef', 'coef') : 4
# ('coef', 'coef', 'constant') : 4
# ('coef', 'constant', 'constant') : 2
# ('constant', 'constant', 'max') : 2
# ('constant', 'max', 'temp') : 2
# ('max', 'temp', 'max') : 4
# ('temp', 'max', 'temp') : 4
# ('min', 'temp', 'min') : 2
# ('temp', 'dependent', 'variable') : 2
# ('dependent', 'variable', 'adjust') : 2
# ('variable', 'adjust', 'std') : 2
# ('adjust', 'std', 'error') : 2
# ('coef', 'constant', 'intercept') : 2
# ('constant', 'intercept', 'max') : 2
# ('intercept', 'max', 'temp') : 2
# ('temp', 'dardir', 'environmental') : 2
# ('solar', 'radiation', 'total') : 2
# ('solar', 'radiation', 'response') : 2
# ('ambient', 'condition', 'record') : 2
# ('concentration', 'result', 'show') : 2
# ('result', 'show', 'low') : 2
# ('event', 'air', 'quality') : 3
# ('ass', 'combine', 'environmental') : 2
# ('associate', 'moderate', 'condition') : 2
# ('within', 'level', 'cluster') : 2
# ('mor', 'emr', 'level') : 3
# ('associate', 'low', 'value') : 2
# ('low', 'value', 'environmental') : 2
# ('concentration', 'ppb', 'concentration') : 2
# ('ambient', 'condition', 'maximum') : 2
# ('record', 'mortality', 'emergency') : 3
# ('daily', 'elderly', 'base') : 2
# ('elderly', 'base', 'mortality') : 2
# ('associate', 'high', 'centroid') : 2
# ('occurrence', 'daily', 'elderly') : 4
# ('daily', 'elderly', 'emergency') : 2
# ('elderly', 'population', 'vulnerable') : 2
# ('elderly', 'people', 'primarily') : 2
# ('people', 'primarily', 'subject') : 2
# ('primarily', 'subject', 'great') : 2
# ('subject', 'great', 'risk') : 2
# ('report', 'ascend', 'trend') : 2
# ('daily', 'elderly', 'mortality') : 2
# ('analysis', 'original', 'draft') : 2
# ('review', 'edit', 'declaration') : 2
# ('financial', 'support', 'provide') : 2
# ('support', 'provide', 'mitacs') : 2
# ('provide', 'mitacs', 'canada') : 2
# ('respiratory', 'tuberculosis', 'without') : 2
# ('tuberculosis', 'without', 'mention') : 2
# ('without', 'mention', 'bacteriological') : 3
# ('mention', 'bacteriological', 'histological') : 3
# ('bacteriological', 'histological', 'confirmation') : 3
# ('histological', 'confirmation', 'respiratory') : 2
# ('confirmation', 'respiratory', 'tuberculosis') : 2
# ('upper', 'respiratory', 'tract') : 4
# ('respiratory', 'tract', 'unspecified') : 2
# ('respiratory', 'system', 'unspecified') : 3
# ('neoplasm', 'uncertain', 'unknown') : 2
# ('uncertain', 'unknown', 'behavior') : 2
# ('unknown', 'behavior', 'respiratory') : 2
# ('behavior', 'respiratory', 'organ') : 2
# ('acute', 'upper', 'respiratory') : 2
# ('upper', 'respiratory', 'infection') : 2
# ('influenza', 'respiratory', 'manifestation') : 2
# ('respiratory', 'syncytial', 'virus') : 3
# ('disease', 'upper', 'respiratory') : 2
# ('chemical', 'gas', 'fume') : 5
# ('gas', 'fume', 'vapor') : 5
# ('respiratory', 'condition', 'chemical') : 4
# ('condition', 'chemical', 'gas') : 4
# ('fume', 'vapor', 'respiratory') : 2
# ('vapor', 'respiratory', 'condition') : 2
# ('newborn', 'respiratory', 'distress') : 2
# ('respiratory', 'distress', 'newborn') : 2
# ('unspecified', 'chronic', 'respiratory') : 2
# ('respiratory', 'disease', 'originate') : 2
# ('disease', 'originate', 'perinatal') : 2
# ('originate', 'perinatal', 'period') : 4
# ('perinatal', 'period', 'unspecified') : 2
# ('respiratory', 'condition', 'newborn') : 2
# ('cardiovascular', 'disorder', 'originate') : 2
# ('disorder', 'originate', 'perinatal') : 2
# ('congenital', 'malformation', 'respiratory') : 2
# ('malformation', 'respiratory', 'system') : 2
# ('abnormal', 'finding', 'specimens') : 10
# ('finding', 'specimens', 'respiratory') : 10
# ('specimens', 'respiratory', 'organ') : 10
# ('respiratory', 'organ', 'thorax') : 10
# ('organ', 'thorax', 'abnormal') : 9
# ('thorax', 'abnormal', 'level') : 4
# ('finding', 'abnormal', 'finding') : 4
# ('cause', 'obstruction', 'respiratory') : 2
# ('obstruction', 'respiratory', 'tract') : 2
# ('unspecified', 'agent', 'primarily') : 2
# ('system', 'cause', 'adverse') : 2
# ('cause', 'adverse', 'effect') : 3
# ('adverse', 'effect', 'therapeutic') : 3
# ('cardiovascular', 'device', 'associate') : 5
# ('device', 'associate', 'adverse') : 5
# ('associate', 'adverse', 'incident') : 5
# ('device', 'cardiovascular', 'device') : 3
# ('congestive', 'heart', 'failure') : 3
# ('particulate', 'matter', 'wave') : 2
# ('thermal', 'index', 'mortality') : 2
# ('total', 'environ', 'wang') : 2
# ('project', 'spatiotemporal', 'trend') : 2
# ('spatiotemporal', 'trend', 'future') : 2
# ('global', 'urban', 'settlement') : 3
# ('scenario', 'result', 'show') : 2
# ('urban', 'heatwave', 'exposure') : 6
# ('exposure', 'increase', 'respectively') : 2
# ('country', 'increase', 'trend') : 2
# ('trend', 'regional', 'average') : 3
# ('exposure', 'elderly', 'individual') : 2
# ('future', 'heatwave', 'exposure') : 2
# ('npj', 'urban', 'sustainability') : 11
# ('expect', 'continue', 'rise') : 3
# ('study', 'show', 'global') : 2
# ('inequitable', 'heatwave', 'exposure') : 2
# ('temperature', 'different', 'region') : 2
# ('heatwave', 'exposure', 'risk') : 7
# ('heatwave', 'exposure', 'urban') : 2
# ('urban', 'settlement', 'base') : 2
# ('chinese', 'academy', 'science') : 5
# ('academy', 'science', 'beijing') : 3
# ('science', 'beijing', 'china') : 3
# ('publish', 'partnership', 'rmit') : 11
# ('partnership', 'rmit', 'university') : 11
# ('heatwaves', 'global', 'city') : 2
# ('result', 'reveal', 'exposure') : 2
# ('reveal', 'exposure', 'risk') : 2
# ('exposure', 'growth', 'trend') : 2
# ('urban', 'elderly', 'population') : 6
# ('elderly', 'population', 'exposure') : 4
# ('heatwave', 'characteristic', 'population') : 2
# ('heatwave', 'duration', 'hwd') : 2
# ('duration', 'hwd', 'heatwave') : 2
# ('hwd', 'heatwave', 'average') : 2
# ('heatwave', 'average', 'intensity') : 2
# ('average', 'intensity', 'hwi') : 2
# ('slope', 'estimator', 'use') : 2
# ('signiﬁcant', 'trend', 'p') : 2
# ('global', 'average', 'trend') : 2
# ('day', 'decade', 'hwi') : 2
# ('decade', 'hwi', 'decade') : 2
# ('increase', 'trend', 'hwd') : 2
# ('america', 'africa', 'southeast') : 2
# ('see', 'supplementary', 'result') : 2
# ('supplementary', 'result', 'reveal') : 2
# ('area', 'heatwave', 'exposure') : 2
# ('spatial', 'distribution', 'exposure') : 2
# ('exposure', 'risk', 'city') : 2
# ('increase', 'trend', 'exposure') : 2
# ('expect', 'experience', 'approximately') : 2
# ('urban', 'area', 'find') : 2
# ('urban', 'elderly', 'exposure') : 2
# ('elderly', 'exposure', 'risk') : 2
# ('chen', 'npj', 'urban') : 5
# ('urban', 'sustainability', 'publish') : 5
# ('sustainability', 'publish', 'partnership') : 5
# ('however', 'growth', 'rate') : 2
# ('use', 'stepwise', 'regression') : 2
# ('disproportionate', 'burden', 'elderly') : 2
# ('statistically', 'signiﬁcant', 'difference') : 2
# ('heatwave', 'exposure', 'trend') : 2
# ('population', 'exposure', 'risk') : 2
# ('different', 'city', 'size') : 2
# ('b', 'exposure', 'trend') : 2
# ('chen', 'publish', 'partnership') : 5
# ('rmit', 'university', 'npj') : 5
# ('university', 'npj', 'urban') : 5
# ('different', 'income', 'country') : 2
# ('compound', 'exposure', 'factor') : 2
# ('urban', 'population', 'size') : 4
# ('std', 'std', 'std') : 3
# ('exposure', 'trend', 'b') : 2
# ('exposure', 'trend', 'elderly') : 2
# ('increase', 'exposure', 'risk') : 2
# ('south', 'america', 'oceania') : 2
# ('exposure', 'risk', 'total') : 2
# ('risk', 'total', 'population') : 2
# ('exposure', 'urban', 'elderly') : 2
# ('elderly', 'population', 'c') : 2
# ('growth', 'trend', 'exposure') : 3
# ('population', 'projection', 'ssp') : 2
# ('projection', 'ssp', 'scenario') : 2
# ('trend', 'exposure', 'risk') : 2
# ('socioeconomic', 'pathway', 'scenario') : 2
# ('p', 'p', 'p') : 6
# ('p', 'p', 'hic') : 2
# ('p', 'hic', 'umic') : 2
# ('hic', 'umic', 'lmic') : 12
# ('umic', 'lmic', 'lic') : 12
# ('lmic', 'lic', 'b') : 2
# ('million', 'million', 'exposure') : 2
# ('trend', 'exposure', 'trend') : 2
# ('different', 'exposure', 'trend') : 2
# ('exposure', 'trend', 'different') : 2
# ('different', 'income', 'group') : 3
# ('age', 'rate', 'develop') : 2
# ('rate', 'develop', 'country') : 2
# ('develop', 'country', 'city') : 2
# ('exposure', 'growth', 'rate') : 3
# ('south', 'korea', 'china') : 3
# ('lead', 'large', 'increase') : 2
# ('lmic', 'lic', 'hic') : 4
# ('lic', 'hic', 'umic') : 4
# ('b', 'hic', 'umic') : 2
# ('lmic', 'lic', 'income') : 2
# ('lic', 'income', 'class') : 2
# ('c', 'hic', 'umic') : 2
# ('growth', 'rate', 'gross') : 2
# ('rate', 'gross', 'exposure') : 2
# ('income', 'group', 'city') : 2
# ('group', 'city', 'size') : 2
# ('exposure', 'vertical', 'axis') : 2
# ('vertical', 'axis', 'urban') : 2
# ('axis', 'urban', 'elderly') : 2
# ('population', 'heatwave', 'exposure') : 2
# ('heatwave', 'exposure', 'within') : 2
# ('contribution', 'factor', 'period') : 2
# ('gridded', 'population', 'projection') : 2
# ('summer', 'season', 'june') : 2
# ('season', 'june', 'august') : 2
# ('percentile', 'warm', 'season') : 2
# ('heatwave', 'event', 'year') : 2
# ('year', 'within', 'country') : 2
# ('interaction', 'simpopulation', 'þ') : 2
# ('simpopulation', 'þ', 'simclimate') : 2
# ('þ', 'þ', 'simcontrol') : 3
# ('þ', 'simcontrol', 'population') : 2
# ('simcontrol', 'population', 'age') : 2
# ('population', 'age', 'interaction') : 2
# ('þ', 'simageing', 'ð') : 2
# ('simageing', 'ð', 'þ') : 2
# ('chakraborty', 'hsu', 'manya') : 2
# ('hsu', 'manya', 'sheriff') : 2
# ('manya', 'sheriff', 'disproportionately') : 2
# ('sheriff', 'disproportionately', 'higher') : 2
# ('urban', 'neighborhood', 'perspective') : 2
# ('neighborhood', 'perspective', 'environ') : 2
# ('perspective', 'environ', 're') : 2
# ('empirical', 'evidence', 'decline') : 2
# ('evidence', 'decline', 'global') : 2
# ('decline', 'global', 'vulnerability') : 2
# ('global', 'vulnerability', 'hazard') : 2
# ('vulnerability', 'hazard', 'glob') : 2
# ('hazard', 'glob', 'environ') : 2
# ('npj', 'urban', 'sustain') : 2
# ('global', 'projection', 'local') : 2
# ('western', 'north', 'america') : 2
# ('acknowledgement', 'work', 'support') : 2
# ('circulation', 'circulation', 'available') : 2
# ('yuewei', 'liu', 'md') : 2
# ('epidemiology', 'school', 'sun') : 2
# ('guangzhou', 'guangdong', 'china') : 2
# ('hong', 'sun', 'md') : 2
# ('institute', 'environment', 'jiangsu') : 2
# ('environment', 'jiangsu', 'provincial') : 2
# ('nanjing', 'jiangsu', 'china') : 2
# ('department', 'atmospheric', 'oceanic') : 2
# ('atmospheric', 'oceanic', 'science') : 2
# ('oceanic', 'science', 'earth') : 2
# ('science', 'earth', 'system') : 2
# ('interdisciplinary', 'center', 'university') : 2
# ('center', 'university', 'maryland') : 2
# ('material', 'available', 'continue') : 2
# ('available', 'continue', 'medical') : 2
# ('medical', 'education', 'cme') : 2
# ('education', 'cme', 'credit') : 2
# ('cme', 'credit', 'available') : 2
# ('credit', 'available', 'article') : 2
# ('available', 'article', 'take') : 2
# ('article', 'take', 'quiz') : 2
# ('take', 'quiz', 'source') : 2
# ('quiz', 'source', 'funding') : 2
# ('event', 'fine', 'particulate') : 6
# ('particulate', 'matter', 'myocardial') : 3
# ('matter', 'myocardial', 'infarction') : 3
# ('event', 'etes', 'include') : 2
# ('etes', 'include', 'wave') : 2
# ('include', 'wave', 'cold') : 2
# ('myocardial', 'infarction', 'mi') : 2
# ('effect', 'mi', 'mortality') : 2
# ('temperature', 'cardiovascular', 'mortality') : 14
# ('mortality', 'remain', 'unknown') : 2
# ('trigger', 'mi', 'death') : 6
# ('mi', 'death', 'jiangsu') : 3
# ('death', 'jiangsu', 'province') : 3
# ('jiangsu', 'province', 'china') : 13
# ('investigate', 'association', 'exposure') : 2
# ('association', 'exposure', 'etes') : 5
# ('exposure', 'etes', 'mi') : 11
# ('etes', 'mi', 'mortality') : 34
# ('evaluate', 'interactive', 'effect') : 3
# ('subject', 'geocoded', 'residential') : 2
# ('logistic', 'regression', 'model') : 3
# ('regression', 'model', 'apply') : 2
# ('relative', 'excess', 'odds') : 7
# ('excess', 'odds', 'interaction') : 7
# ('odds', 'interaction', 'proportion') : 2
# ('interaction', 'proportion', 'attributable') : 2
# ('proportion', 'attributable', 'interaction') : 4
# ('attributable', 'interaction', 'synergy') : 2
# ('interaction', 'synergy', 'index') : 4
# ('different', 'ete', 'definition') : 2
# ('exposure', 'significantly', 'associate') : 4
# ('significantly', 'associate', 'increase') : 7
# ('associate', 'increase', 'odds') : 6
# ('increase', 'odds', 'mi') : 6
# ('odds', 'mi', 'mortality') : 7
# ('synergistic', 'interaction', 'wave') : 2
# ('interaction', 'wave', 'mi') : 2
# ('wave', 'mi', 'mortality') : 7
# ('great', 'intensity', 'longer') : 4
# ('intensity', 'longer', 'duration') : 4
# ('death', 'attributable', 'exposure') : 2
# ('level', 'exceed', 'interim') : 2
# ('exceed', 'interim', 'target') : 2
# ('interim', 'target', 'value') : 2
# ('target', 'value', 'organization') : 2
# ('value', 'organization', 'air') : 2
# ('woman', 'old', 'adult') : 5
# ('old', 'adult', 'vulnerable') : 2
# ('etes', 'interactive', 'effect') : 4
# ('interactive', 'effect', 'etes') : 4
# ('effect', 'etes', 'mi') : 7
# ('mi', 'mortality', 'vary') : 2
# ('mortality', 'vary', 'sex') : 2
# ('vary', 'sex', 'age') : 2
# ('exposure', 'etes', 'significantly') : 2
# ('mi', 'mortality', 'especially') : 2
# ('old', 'adult', 'wave') : 3
# ('synergistically', 'trigger', 'mi') : 3
# ('mi', 'death', 'cold') : 2
# ('bring', 'cobenefits', 'prevent') : 2
# ('cobenefits', 'prevent', 'premature') : 2
# ('prevent', 'premature', 'death') : 3
# ('premature', 'death', 'mi') : 2
# ('key', 'word', 'cold') : 2
# ('article', 'circulation', 'july') : 6
# ('circulation', 'july', 'xu') : 6
# ('july', 'xu', 'etes') : 6
# ('xu', 'etes', 'mi') : 11
# ('association', 'etes', 'mi') : 3
# ('mi', 'mortality', 'remain') : 2
# ('wave', 'cold', 'mi') : 2
# ('cold', 'mi', 'mortality') : 2
# ('mi', 'mortality', 'result') : 2
# ('possible', 'reason', 'inconsistent') : 2
# ('exposure', 'ambient', 'temperature') : 2
# ('cold', 'significantly', 'associate') : 3
# ('note', 'study', 'use') : 2
# ('interact', 'tically', 'trigger') : 2
# ('tically', 'trigger', 'mi') : 2
# ('million', 'mi', 'death') : 3
# ('assess', 'association', 'exposure') : 2
# ('exposure', 'etes', 'ambient') : 3
# ('etes', 'ambient', 'mi') : 2
# ('ambient', 'mi', 'mortality') : 3
# ('availability', 'air', 'pollution') : 2
# ('mortality', 'jiangsu', 'provincial') : 2
# ('jiangsu', 'provincial', 'mortality') : 2
# ('provincial', 'mortality', 'surveillance') : 2
# ('exposure', 'event', 'fine') : 3
# ('mortality', 'especially', 'among') : 2
# ('among', 'woman', 'old') : 2
# ('independent', 'interactive', 'effect') : 2
# ('mi', 'myocardial', 'infarction') : 2
# ('odds', 'ratio', 'fine') : 4
# ('ratio', 'fine', 'particulate') : 4
# ('particulate', 'matter', 'reoi') : 3
# ('matter', 'reoi', 'relative') : 3
# ('reoi', 'relative', 'excess') : 4
# ('odds', 'interaction', 'synergy') : 2
# ('research', 'article', 'july') : 5
# ('article', 'july', 'circulation') : 5
# ('july', 'circulation', 'xu') : 5
# ('circulation', 'xu', 'etes') : 5
# ('domestic', 'product', 'caput') : 3
# ('waiver', 'inform', 'consent') : 2
# ('make', 'basis', 'physiobiochemistry') : 2
# ('basis', 'physiobiochemistry', 'pathology') : 2
# ('physiobiochemistry', 'pathology', 'autopsy') : 2
# ('pathology', 'autopsy', 'surgery') : 2
# ('mi', 'mortality', 'quantify') : 3
# ('mortality', 'quantify', 'interactive') : 3
# ('quantify', 'interactive', 'effect') : 3
# ('use', 'design', 'widely') : 2
# ('design', 'widely', 'use') : 2
# ('effect', 'environmental', 'exposure') : 2
# ('exposure', 'date', 'death') : 2
# ('within', 'time', 'stratum') : 2
# ('time', 'stratum', 'ie') : 2
# ('define', 'case', 'day') : 2
# ('year', 'month', 'day') : 3
# ('month', 'day', 'week') : 3
# ('week', 'case', 'day') : 2
# ('eg', 'age', 'sex') : 3
# ('time', 'trend', 'seasonality') : 2
# ('case', 'day', 'match') : 2
# ('day', 'match', 'control') : 2
# ('match', 'control', 'day') : 2
# ('control', 'day', 'case') : 2
# ('case', 'day', 'control') : 6
# ('day', 'control', 'day') : 7
# ('land', 'assimilation', 'system') : 2
# ('relative', 'humidity', 'calculate') : 2
# ('humidity', 'calculate', 'daily') : 2
# ('definition', 'wave', 'cold') : 2
# ('daily', 'apparent', 'perature') : 3
# ('identify', 'daily', 'apparent') : 2
# ('daily', 'apparent', 'equal') : 8
# ('apparent', 'equal', 'high') : 7
# ('threshold', 'ie', 'least') : 2
# ('consecutive', 'day', 'whereas') : 5
# ('least', 'secutive', 'day') : 2
# ('example', 'represent', 'wave') : 6
# ('represent', 'wave', 'define') : 7
# ('wave', 'define', 'daily') : 7
# ('define', 'daily', 'apparent') : 12
# ('equal', 'high', 'percentile') : 8
# ('high', 'percentile', 'least') : 7
# ('percentile', 'least', 'consecutive') : 13
# ('day', 'whereas', 'represent') : 5
# ('whereas', 'represent', 'cold') : 5
# ('represent', 'cold', 'define') : 5
# ('cold', 'define', 'daily') : 6
# ('daily', 'apparent', 'low') : 4
# ('apparent', 'low', 'equal') : 4
# ('low', 'equal', 'percentile') : 4
# ('equal', 'percentile', 'least') : 6
# ...
# ('neuroinflammation', 'signal', 'synaptic') : 2
# ('signal', 'synaptic', 'depression') : 2
# ('synaptic', 'depression', 'signal') : 2
# ('predict', 'pathway', 'circuit') : 2
# ('pathway', 'circuit', 'unveil') : 2
# ('circuit', 'unveil', 'neurological') : 2
# ('unveil', 'neurological', 'disease') : 2
# ('neurological', 'disease', 'network') : 4
# ('disease', 'network', 'within') : 3
# ('network', 'within', 'brain') : 3
# ('within', 'brain', 'inflammatory') : 2
# ('brain', 'inflammatory', 'control') : 2
# ('inflammatory', 'control', 'network') : 3
# ('control', 'network', 'within') : 3
# ('network', 'within', 'liver') : 3
# ('liver', 'tissue', 'follow') : 2
# ('tissue', 'follow', 'exposure') : 2
# ('follow', 'exposure', 'stress') : 2
# ('enhancement', 'measurement', 'activation') : 2
# ('measurement', 'activation', 'gene') : 3
# ('activation', 'gene', 'product') : 2
# ('volcano', 'plot', 'obtain') : 2
# ('plot', 'obtain', 'compare') : 2
# ('obtain', 'compare', 'brain') : 5
# ('compare', 'brain', 'tissue') : 4
# ('brain', 'tissue', 'control') : 4
# ('tissue', 'control', 'stress') : 11
# ('stress', 'group', 'analyze') : 2
# ('group', 'analyze', 'differential') : 2
# ('analyze', 'differential', 'gene') : 2
# ('expression', 'change', 'transcriptomic') : 2
# ('change', 'transcriptomic', 'profile') : 2
# ('transcriptomic', 'profile', 'p') : 2
# ('profile', 'p', 'pfdr') : 2
# ('p', 'pfdr', 'change') : 2
# ('pfdr', 'change', 'plot') : 2
# ('change', 'plot', 'respectively') : 2
# ('plot', 'respectively', 'along') : 2
# ('respectively', 'along', 'ordinate') : 2
# ('along', 'ordinate', 'abscissa') : 2
# ('ordinate', 'abscissa', 'significance') : 2
# ('abscissa', 'significance', 'cut') : 2
# ('significance', 'cut', 'set') : 2
# ('cut', 'set', 'pfdr') : 2
# ('set', 'pfdr', 'fold') : 2
# ('pfdr', 'fold', 'blue') : 2
# ('fold', 'blue', 'dot') : 2
# ('blue', 'dot', 'represent') : 2
# ('dot', 'represent', 'downregulated') : 2
# ('represent', 'downregulated', 'red') : 2
# ('downregulated', 'red', 'dot') : 2
# ('dot', 'represent', 'upregulated') : 2
# ('represent', 'upregulated', 'gene') : 2
# ('upregulated', 'gene', 'gene') : 2
# ('gene', 'gene', 'represent') : 2
# ('gene', 'represent', 'gray') : 2
# ('represent', 'gray', 'dot') : 2
# ('gray', 'dot', 'lay') : 2
# ('dot', 'lay', 'zone') : 2
# ('lay', 'zone', 'significance') : 2
# ('zone', 'significance', 'total') : 2
# ('significance', 'total', 'number') : 2
# ('total', 'number', 'upregulated') : 2
# ('number', 'upregulated', 'downregulated') : 2
# ('upregulated', 'downregulated', 'gene') : 2
# ('downregulated', 'gene', 'indicate') : 2
# ('gene', 'indicate', 'similar') : 2
# ('indicate', 'similar', 'color') : 2
# ('similar', 'color', 'arrowhead') : 2
# ('color', 'arrowhead', 'b') : 2
# ('arrowhead', 'b', 'heatmap') : 2
# ('b', 'heatmap', 'generate') : 2
# ('tissue', 'volcano', 'plot') : 2
# ('volcano', 'plot', 'delineate') : 2
# ('plot', 'delineate', 'fold') : 2
# ('delineate', 'fold', 'gradient') : 2
# ('fold', 'gradient', 'extremity') : 5
# ('gradient', 'extremity', 'red') : 5
# ('extremity', 'red', 'blue') : 5
# ('red', 'blue', 'signify') : 2
# ('blue', 'signify', 'downregulations') : 2
# ('signify', 'downregulations', 'respectively') : 2
# ('downregulations', 'respectively', 'blue') : 5
# ('respectively', 'blue', 'red') : 5
# ('blue', 'red', 'color') : 8
# ('red', 'color', 'code') : 5
# ('color', 'code', 'set') : 5
# ('code', 'set', 'represent') : 2
# ('set', 'represent', 'intensity') : 2
# ('represent', 'intensity', 'gene') : 2
# ('intensity', 'gene', 'expression') : 2
# ('gene', 'expression', 'fall') : 2
# ('expression', 'fall', 'within') : 2
# ('fall', 'within', 'give') : 5
# ('within', 'give', 'gradient') : 5
# ('give', 'gradient', 'reflect') : 2
# ('gradient', 'reflect', 'fold') : 2
# ('reflect', 'fold', 'individual') : 2
# ('fold', 'individual', 'gene') : 2
# ('individual', 'gene', 'name') : 2
# ('gene', 'name', 'parallel') : 2
# ('name', 'parallel', 'scientific') : 2
# ('parallel', 'scientific', 'report') : 2
# ('measurement', 'inhibition', 'gene') : 2
# ('inhibition', 'gene', 'product') : 2
# ('decrease', 'measurement', 'inhibition') : 2
# ('obtain', 'compare', 'liver') : 3
# ('compare', 'liver', 'tissue') : 4
# ('liver', 'tissue', 'control') : 7
# ('alter', 'functional', 'interactome') : 2
# ('functional', 'interactome', 'emerge') : 2
# ('interactome', 'emerge', 'brain') : 2
# ('liver', 'tissue', 'exposure') : 2
# ('tissue', 'exposure', 'stress') : 2
# ('gene', 'cluster', 'predict') : 2
# ('biological', 'pathway', 'predict') : 3
# ('pathway', 'predict', 'base') : 3
# ('predict', 'base', 'differentially') : 5
# ('base', 'differentially', 'express') : 5
# ('express', 'gene', 'list') : 4
# ('gene', 'list', 'obtain') : 3
# ('list', 'obtain', 'compare') : 3
# ('stress', 'group', 'significance') : 3
# ('group', 'significance', 'level') : 3
# ('significance', 'level', 'set') : 17
# ('level', 'set', 'pfdr') : 3
# ('set', 'pfdr', 'threshold') : 3
# ('value', 'fold', 'gradient') : 3
# ('fold', 'gradient', 'blue') : 3
# ('gradient', 'blue', 'red') : 3
# ('color', 'represent', 'downregulations') : 3
# ('represent', 'downregulations', 'pathway') : 3
# ('downregulations', 'pathway', 'respectively') : 3
# ('commonly', 'differentially', 'express') : 2
# ('compare', 'brain', 'liver') : 3
# ('connection', 'stress', 'pathology') : 2
# ('stress', 'pathology', 'project') : 2
# ('pathology', 'project', 'share') : 2
# ('pathway', 'circuit', 'interactome') : 2
# ('pathway', 'circuit', 'predict') : 3
# ('circuit', 'predict', 'base') : 3
# ('predict', 'base', 'project') : 3
# ('base', 'project', 'pathway') : 3
# ('project', 'pathway', 'obtain') : 3
# ('pathway', 'obtain', 'compare') : 3
# ('stress', 'group', 'shape') : 3
# ('group', 'shape', 'represent') : 3
# ('shape', 'represent', 'different') : 3
# ('represent', 'different', 'biological') : 3
# ('different', 'biological', 'kind') : 3
# ('biological', 'kind', 'molecules') : 3
# ('kind', 'molecules', 'pathway') : 3
# ('molecules', 'pathway', 'component') : 3
# ('pathway', 'component', 'connector') : 3
# ('component', 'connector', 'style') : 3
# ('connector', 'style', 'represent') : 3
# ('status', 'detailed', 'legends') : 3
# ('detailed', 'legends', 'prediction') : 3
# ('legends', 'prediction', 'network') : 3
# ('prediction', 'network', 'path') : 3
# ('network', 'path', 'designer') : 3
# ('path', 'designer', 'shape') : 3
# ('designer', 'shape', 'include') : 3
# ('shape', 'include', 'b') : 2
# ('style', 'represent', 'inhibition') : 2
# ('represent', 'inhibition', 'status') : 2
# ('inhibition', 'status', 'detailed') : 2
# ('expression', 'fold', 'change') : 3
# ('fold', 'change', 'top') : 2
# ('change', 'top', 'gene') : 2
# ('top', 'gene', 'observe') : 2
# ('gene', 'observe', 'brain') : 2
# ('observe', 'brain', 'liver') : 2
# ('brain', 'liver', 'unveil') : 2
# ('liver', 'unveil', 'potential') : 2
# ('unveil', 'potential', 'validatory') : 2
# ('potential', 'validatory', 'mediator') : 2
# ('validatory', 'mediator', 'axis') : 2
# ('axis', 'exposure', 'stress') : 3
# ('interactome', 'predict', 'base') : 3
# ('express', 'gene', 'obtain') : 3
# ('gene', 'obtain', 'transcriptomic') : 3
# ('obtain', 'transcriptomic', 'profile') : 3
# ('transcriptomic', 'profile', 'compare') : 3
# ('profile', 'compare', 'brain') : 2
# ('stress', 'group', 'interaction') : 3
# ('group', 'interaction', 'intensity') : 3
# ('interaction', 'intensity', 'signify') : 3
# ('intensity', 'signify', 'possible') : 3
# ('signify', 'possible', 'upregulations') : 3
# ('possible', 'upregulations', 'downregulations') : 3
# ('upregulations', 'downregulations', 'respective') : 3
# ('downregulations', 'respective', 'gene') : 3
# ('respective', 'gene', 'cluster') : 3
# ('gene', 'cluster', 'fold') : 3
# ('cluster', 'fold', 'gradient') : 3
# ('red', 'blue', 'indicated') : 3
# ('blue', 'indicated', 'downregulations') : 3
# ('indicated', 'downregulations', 'respectively') : 3
# ('code', 'set', 'mark') : 3
# ('set', 'mark', 'gene') : 3
# ('mark', 'gene', 'cluster') : 3
# ('gene', 'cluster', 'fall') : 3
# ('give', 'gradient', 'gene') : 3
# ('gradient', 'gene', 'name') : 3
# ('gene', 'name', 'provide') : 3
# ('name', 'provide', 'represent') : 3
# ('provide', 'represent', 'shape') : 3
# ('represent', 'shape', 'connector') : 3
# ('shape', 'connector', 'indicate') : 3
# ('connector', 'indicate', 'possible') : 3
# ('indicate', 'possible', 'biological') : 3
# ('possible', 'biological', 'strength') : 3
# ('biological', 'strength', 'interconnection') : 3
# ('strength', 'interconnection', 'interact') : 3
# ('interconnection', 'interact', 'gene') : 3
# ('interact', 'gene', 'product') : 3
# ('b', 'interactome', 'predict') : 2
# ('gene', 'product', 'scientific') : 2
# ('product', 'scientific', 'report') : 2
# ('find', 'upregulated', 'brain') : 2
# ('via', 'systemic', 'route') : 2
# ('scientific', 'report', 'stress') : 2
# ('stress', 'augment', 'secretion') : 2
# ('augment', 'secretion', 'hepatic') : 2
# ('secretion', 'hepatic', 'abundance') : 2
# ('hepatic', 'abundance', 'hippocampus') : 2
# ('abundance', 'hippocampus', 'along') : 2
# ('hippocampus', 'along', 'frontal') : 2
# ('along', 'frontal', 'cortex') : 2
# ('traverse', 'leaky', 'bbb') : 2
# ('stress', 'group', 'b') : 2
# ('group', 'b', 'p') : 2
# ('release', 'liver', 'involvement') : 2
# ('liver', 'involvement', 'intestinal') : 2
# ('intestinal', 'inflammation', 'gut') : 2
# ('stress', 'group', 'compare') : 7
# ('group', 'compare', 'control') : 7
# ('compare', 'control', 'p') : 3
# ('dysbiosis', 'intestinal', 'inflammation') : 2
# ('marker', 'gut', 'dysbiosis') : 2
# ('whole', 'metagenome', 'sequence') : 2
# ('sample', 'control', 'stress') : 2
# ('control', 'stress', 'mouse') : 12
# ('stress', 'mouse', 'group') : 11
# ('firmicutes', 'bacteroidetes', 'ratio') : 4
# ('relative', 'mrna', 'expression') : 2
# ('mrna', 'expression', 'change') : 2
# ('expression', 'change', 'rrna') : 2
# ('change', 'rrna', 'normalize') : 2
# ('rrna', 'normalize', 'top') : 2
# ('normalize', 'top', 'gene') : 2
# ('sample', 'convert', 'fold') : 2
# ('convert', 'fold', 'change') : 2
# ('fold', 'change', 'base') : 2
# ('change', 'base', 'transcriptomic') : 2
# ('base', 'transcriptomic', 'plotted') : 2
# ('transcriptomic', 'plotted', 'bar') : 2
# ('plotted', 'bar', 'graph') : 2
# ('bar', 'graph', 'represent') : 2
# ('graph', 'represent', 'gene') : 2
# ('represent', 'gene', 'control') : 2
# ('gene', 'control', 'represent') : 2
# ('control', 'represent', 'baseline') : 2
# ('represent', 'baseline', 'negative') : 2
# ('baseline', 'negative', 'fold') : 2
# ('negative', 'fold', 'change') : 2
# ('fold', 'change', 'indicate') : 4
# ('change', 'indicate', 'blue') : 2
# ('indicate', 'blue', 'color') : 2
# ('blue', 'color', 'gradient') : 2
# ('color', 'gradient', 'whereas') : 2
# ('gradient', 'whereas', 'positive') : 2
# ('whereas', 'positive', 'fold') : 2
# ('positive', 'fold', 'change') : 2
# ('change', 'indicate', 'red') : 2
# ('gradient', 'p', 'value') : 2
# ('p', 'value', 'derive') : 14
# ('value', 'derive', 'unpaired') : 14
# ('derive', 'unpaired', 'significance') : 14
# ('unpaired', 'significance', 'level') : 14
# ('level', 'set', 'p') : 14
# ('set', 'p', 'scientific') : 3
# ('p', 'scientific', 'report') : 3
# ('respective', 'mouse', 'group') : 2
# ('role', 'neuroinflammation', 'ischemic') : 2
# ('neuroinflammation', 'ischemic', 'stroke') : 2
# ('hippocampus', 'frontal', 'cortex') : 3
# ('frontal', 'cortex', 'region') : 2
# ('possibly', 'reach', 'brain') : 2
# ('reach', 'brain', 'tissue') : 2
# ('transcriptomic', 'alteration', 'together') : 2
# ('alteration', 'together', 'acute') : 2
# ('together', 'acute', 'phase') : 2
# ('phase', 'response', 'ensue') : 2
# ('response', 'ensue', 'neural') : 2
# ('ensue', 'neural', 'hepatic') : 2
# ('systemic', 'inflammation', 'debilitate') : 2
# ('inflammation', 'debilitate', 'synaptic') : 2
# ('debilitate', 'synaptic', 'plasticity') : 2
# ('neurotrophic', 'factor', 'bdnf') : 2
# ('within', 'stress', 'group') : 2
# ('stress', 'group', 'p') : 2
# ('kupffer', 'cell', 'activation') : 2
# ('intellectual', 'disability', 'progressive') : 2
# ('disability', 'progressive', 'motor') : 2
# ('progressive', 'motor', 'impairment') : 2
# ('indicate', 'potential', 'role') : 2
# ('brain', 'tissue', 'stress') : 3
# ('stress', 'group', 'report') : 2
# ('lysates', 'stress', 'group') : 3
# ('stress', 'group', 'know') : 2
# ('observation', 'transcriptomic', 'profile') : 2
# ('transcriptomic', 'profile', 'downstream') : 2
# ('profile', 'downstream', 'bioinformatic') : 2
# ('downstream', 'bioinformatic', 'analysis') : 2
# ('tissue', 'compare', 'control') : 2
# ('liver', 'lysates', 'stress') : 2
# ('liver', 'metabolism', 'homeostasis') : 2
# ('liver', 'tissue', 'stress') : 2
# ('liver', 'inflammation', 'fibrosis') : 2
# ('hepatosteatosis', 'insulin', 'resistance') : 2
# ('kupfer', 'cell', 'activation') : 2
# ('immunoreactivity', 'show', 'immunohistochemistry') : 3
# ('show', 'immunohistochemistry', 'liver') : 2
# ('immunohistochemistry', 'liver', 'section') : 2
# ('liver', 'section', 'control') : 2
# ('section', 'control', 'stress') : 5
# ('mouse', 'group', 'image') : 5
# ('group', 'image', 'take') : 5
# ('image', 'take', 'magnification') : 5
# ('take', 'magnification', 'display') : 5
# ('magnification', 'display', 'scale') : 5
# ('display', 'scale', 'μm') : 5
# ('scale', 'μm', 'b') : 2
# ('μm', 'b', 'immunoreactivity') : 2
# ('b', 'immunoreactivity', 'group') : 2
# ('immunoreactivity', 'group', 'measure') : 8
# ('group', 'measure', 'arbitrary') : 8
# ('measure', 'arbitrary', 'light') : 8
# ('arbitrary', 'light', 'unit') : 8
# ('light', 'unit', 'six') : 8
# ('unit', 'six', 'separate') : 8
# ('six', 'separate', 'microscopic') : 8
# ('separate', 'microscopic', 'field') : 8
# ('microscopic', 'field', 'plot') : 9
# ('field', 'plot', 'along') : 9
# ('plot', 'along', 'ordinate') : 9
# ('along', 'ordinate', 'p') : 9
# ('ordinate', 'p', 'value') : 9
# ('set', 'p', 'c') : 2
# ('scale', 'μm', 'immunoreactivity') : 2
# ('μm', 'immunoreactivity', 'group') : 2
# ('phylum', 'firmicutes', 'bacteroidetes') : 2
# ('set', 'p', 'f') : 2
# ('set', 'p', 'immunoreactivity') : 2
# ('show', 'immunohistochemistry', 'brain') : 2
# ('gut', 'liver', 'brain') : 2
# ('gut', 'dysbiosis', 'hepatic') : 2
# ('usa', 'primary', 'antibody') : 4
# ('primary', 'antibody', 'cluster') : 2
# ('antibody', 'cluster', 'differentiation') : 2
# ('secondary', 'antibody', 'conjugate') : 2
# ('purchase', 'proteintech', 'group') : 2
# ('proteintech', 'group', 'inc') : 2
# ('group', 'inc', 'rosemont') : 2
# ('inc', 'rosemont', 'il') : 2
# ('rosemont', 'il', 'usa') : 2
# ('immunoreactivities', 'show', 'immunohistochemistry') : 2
# ('serum', 'level', 'graph') : 2
# ('level', 'graph', 'violin') : 2
# ('graph', 'violin', 'plot') : 2
# ('violin', 'plot', 'control') : 2
# ('plot', 'control', 'stress') : 2
# ('stress', 'mouse', 'serum') : 2
# ('mouse', 'serum', 'sample') : 2
# ('serum', 'sample', 'n') : 2
# ('sample', 'n', 'p') : 2
# ('n', 'p', 'value') : 2
# ('louis', 'mo', 'usa') : 4
# ('prolong', 'gold', 'antifade') : 2
# ('gold', 'antifade', 'mount') : 2
# ('antifade', 'mount', 'medium') : 2
# ('mount', 'medium', 'dapi') : 2
# ('thermofisher', 'scientific', 'grand') : 2
# ('scientific', 'grand', 'island') : 2
# ('grand', 'island', 'ny') : 2
# ('island', 'ny', 'usa') : 2
# ('liver', 'tissue', 'section') : 2
# ('augustine', 'fl', 'usa') : 2
# ('ml', 'microfuge', 'tube') : 2
# ('tube', 'centrifuge', 'min') : 2
# ('discard', 'rna', 'wash') : 2
# ('rna', 'wash', 'buffer') : 2
# ('wash', 'buffer', 'add') : 2
# ('buffer', 'add', 'column') : 2
# ('quality', 'control', 'use') : 2
# ('trim', 'read', 'align') : 2
# ('expression', 'level', 'quantify') : 2
# ('log', 'fold', 'cutoff') : 2
# ('fold', 'cutoff', 'less') : 2
# ('cutoff', 'less', 'great') : 2
# ('p', 'value', 'less') : 2
# ('tissue', 'section', 'deparaffinized') : 2
# ('manufacturer', 'recommend', 'dilution') : 2
# ('use', 'olympus', 'microscope') : 2
# ('olympus', 'microscope', 'olympus') : 2
# ('microscope', 'olympus', 'center') : 2
# ('olympus', 'center', 'valley') : 4
# ('center', 'valley', 'pa') : 4
# ('valley', 'pa', 'usa') : 4
# ('pa', 'usa', 'morphometry') : 2
# ('usa', 'morphometry', 'analysis') : 2
# ('morphometry', 'analysis', 'perform') : 2
# ('perform', 'use', 'cellsens') : 2
# ('use', 'cellsens', 'software') : 2
# ('cellsens', 'software', 'olympus') : 2
# ('software', 'olympus', 'center') : 2
# ('respiratory', 'effect', 'airborne') : 2
# ('effect', 'airborne', 'hazard') : 2
# ('airborne', 'hazard', 'exposures') : 2
# ('hazard', 'exposures', 'southwest') : 2
# ('exposures', 'southwest', 'asia') : 2
# ('southwest', 'asia', 'theater') : 2
# ('asia', 'theater', 'military') : 2
# ('theater', 'military', 'operation') : 2
# ('broiler', 'poult', 'sci') : 2
# ('acute', 'phase', 'protein') : 2

# %% [markdown]
# ### BERT topic

# %%
def preprocess_texts(docs):
    preprocessed_docs = [' '.join(tokens) for tokens in (doc[0] for doc in docs.values())]
    return preprocessed_docs
preprocessed_texts = preprocess_texts(docs)

# %%
# Initializing the SentenceTransformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Encoding the preprocessed texts into embeddings
embeddings = model.encode(preprocessed_texts, show_progress_bar=True)

# %%
# Initializing BERTopic with custom parameters
topic_model = BERTopic(min_topic_size=5,
                       top_n_words=5,
                       n_gram_range=(1, 2),
                       calculate_probabilities=True)

# Fitting BERTopic on the preprocessed texts and embeddings
topics, probs = topic_model.fit_transform(preprocessed_texts,embeddings)

# %%
# Checking the topics identified
topic_info = topic_model.get_topic_info()
print(topic_info)
# Out:
#    Topic  Count                              Name  \
# 0     -1      4       -1_wave_child_physical_skin
# 1      0     95          0_mortality_city_air_day
# 2      1      9  1_exposure_birth_child_pregnancy
#
#                                   Representation  \
# 0        [wave, child, physical, skin, compound]
# 1        [mortality, city, air, day, population]
# 2  [exposure, birth, child, pregnancy, maternal]
#
#                                  Representative_Docs
# 0  [temporally compound wave event global warm em...
# 1  [lancet commission publish june publish june s...
# 2  [content list available sciencedirect environm...

# %%
topic_model.get_topic(1)
# Out:
# [('exposure', 0.0368769238398767),
#  ('birth', 0.03321001029683097),
#  ('child', 0.028792958666768943),
#  ('pregnancy', 0.028249590214513173),
#  ('maternal', 0.023636854359651842)]

# %%
# Getting the topic words
topic_words = topic_model.get_topics()

# Preprocessing the texts
preprocessed_texts = preprocess_texts(docs)

# Converting preprocessed texts to list of words for coherence model
texts = [doc.split() for doc in preprocessed_texts]

# Creating a dictionary and corpus for the coherence model
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

coherence_scores = []
for topic_id, topic in topic_words.items():
    # Preparing the data for coherence model
    topics = [[word for word, _ in topic]]

    # Computing Coherence Score using Gensim's CoherenceModel for each topic
    coherence_model = CoherenceModel(topics=topics, texts=texts, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()

    coherence_scores.append((topic_id, coherence_score))

# Printing coherence scores for each topic
for topic_id, coherence_score in coherence_scores:
    print(f'Topic {topic_id}: Coherence Score: {coherence_score}')
# Out:
# Topic -1: Coherence Score: 0.5112636207074596
# Topic 0: Coherence Score: 0.4949331804664162
# Topic 1: Coherence Score: 0.7607485565729086
